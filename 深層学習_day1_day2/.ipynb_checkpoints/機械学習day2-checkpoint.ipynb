# %% [markdown]
# # 機械学習day2
# ## Section1 勾配消失問題

# %% [markdown]
# - 中間層の数について
# AlexNetでは、7層。最近のNNは100以上の層を持つ。
# 画像データは入力が非常に多くなり、分析のために層を多くする。
# 中間層を増やしていくと問題が発生する。
# - 勾配消失問題
# 誤差逆伝播がうまくいかなくなってしまう問題。
# 中間層の数が増えると、掛け合わされる微分のセットが非常に多くなり、1未満の数を大量に掛け合わせることになって計算上0に近づいていってしまう。

# %% [markdown]
# - 連鎖率の例題
# $$
# \begin{eqnarray*}
# \frac{dz}{dx} &=& \frac{\partial z}{\partial t}\frac{\partial t}{\partial x}\\
# &=& 2t \times 1\\
# &=& 2(x+y)
# \end{eqnarray*}
# $$

# %% [markdown]
# 逆伝播のコード例

# %%
import numpy as np
import matplotlib.pyplot as plt

def d_mean_squared_error(d,y):
    if type(d) == np.ndarray:
        batch_size = d.shape[0]
        dx = (y-d)/batch_size
    else:
        dx = y-d
    return dx

def sigmoid(x):
    return 1/(1 + np.exp(-x))

def d_sigmoid(x):
    return (1.0 - sigmoid(x))*sigmoid(x)

def backward(x,d,z1,y,network: dict):
    grad = {}
    
    W1, b1 = network["W1"], network["b1"]
    W2, b2 = network["W2"], network["b2"]
    
    delta2 = d_mean_squared_error(d,y)
    grad["b2"] = np.sum(delta2, axis=0)
    grad["W2"] = np.dot(z1.T, delta2)
    
    delta1 = np.dot(delta2, W2.T) * d_sigmoid(z1)
    delta1 = delta1[np.newaxis, :]
    grad["b1"] = np.sum(delta1, axis=0)
    x = x[np.newaxis, :]
    grad["W1"] = np.dot(x.T, delta1)
    
    return grad

# %% [markdown]
# シグモイド関数の微分のグラフ

# %%
x = np.linspace(-8,8,300)
y = d_sigmoid(x)

plt.plot(x,y)

# %% [markdown]
# 特に、シグモイドの微分の最大値が0.25（1未満）であることが重要。なんどもかけると、0に収束していってしまう。

# %%
# 0の時最大値をとる
print(d_sigmoid(0))
# Out:
# 0.25

# %% [markdown]
# - 勾配消失への対策
#  1. 活性化関数の選択
#  勾配消失を起こしにくい活性化関数として、ReLU関数が選択されることがある。
#  ニューロンのうち必要のない部分は微分値がゼロになり、スパース化にも寄与する。
#  2. パラメータの初期値の工夫
#  普通は乱数を用いるが、どういった乱数を使うかどうかに選択肢がある。
#  例えば、Xavierという方法を使うと、良いパラメータ設定ができる。
#  3. バッチ正規化
# - Xavier
# 　標準正規分布に従う乱数に対して、前の層のノード数の平方根で除算した値を初期値に用いる。

# %% [markdown]
# - 初期値の設定の効果
# シグモイド関数を活性化関数にしている場合は、正規分布（σ=1）で初期化すると、ノードのほとんどは0 or 1を出力するようになる。⇒微分はほぼ0。⇒学習が進まない。
# 一方で、小さな値を掛けて、パラメータを初期化すると、ほとんどのノードが0.5を出力するようになり、NNが機能しない。
# 適度な小ささにパラメータを調整することができれば、学習がうまくいく⇒ここで使うのが、Xavier。
# ReLUのような場合には、He初期化をすると、うまく初期化できる。

# %% [markdown]
# - バッチ正規化
# 通常NNの学習は、訓練用のデータを小さなバッチ（ミニバッチ）に分けて、学習を行う。
# この際、ミニバッチの、偏りを抑制することで、ミニバッチごとの学習効率を上げ、過学習も抑制できる。
# 計算は以下のように行われる。
# $$
#     \mu_t =\frac{1}{N_t}\sum_{i=1}^{N_t}x_{ni}\\
#     \sigma_t^2=\frac{1}{N_t}\sum_{i=1}^{N_t}(x_{ni}-\mu_t)^2\\
#     \hat{x}_{ni} = \frac{x_{ni}-\mu_t}{\sqrt{\sigma_t^2+\theta}}\\
#     y_{ni}=\gamma x_{ni} + \beta
# $$
# つまり、統計的な正規化処理＋各パラメータの変倍、移動を行う。

# %% [markdown]
# 以下で、コードによる実装を見る。

# %%
import numpy as np
from collections import OrderedDict
# 正規化周りが面倒なので、配布のmnistを使う。
# from sklearn.datasets import load_digits
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from abc import ABC, abstractmethod

# %%
class ActivationFunctionBase(ABC):
    @abstractmethod
    def forward(self, x):
        pass
    
    @abstractmethod
    def backward(self, dout):
        pass

class Sigmoid(ActivationFunctionBase):
    def __init__(self):
        self.out = None
        
    def __sigmoid(self, x):
        return 1/(1 + np.exp(-x))
        
    def forward(self, x):
        self.out = self.__sigmoid(x)
        return self.out
        
    def backward(self, dout):
        return dout * (1.0 - self.out) * self.out

class Relu(ActivationFunctionBase):
    def __init__(self):
        self.mask = None
        
    def forward(self, x):
        self.mask = (x <= 0)
        out = x.copy()
        out[self.mask] = 0
        return out
        
    def backward(self, dout):
        dout[self.mask] = 0
        return dout

class Affine:
    def __init__(self, W, b):
        self.W = W
        self.b = b
        
        self.x = None
        self.original_x_shape = None
        self.dW = None
        self.db = None
        
    def forward(self, x):
        self.original_x_shape = x.shape
        x = x.reshape(x.shape[0], -1)
        self.x = x
        out = np.dot(self.x, self.W) + self.b
        
        return out
    
    def backward(self, dout):
        dx = np.dot(dout, self.W.T)
        self.dW = np.dot(self.x.T, dout)
        self.db = np.sum(dout, axis = 0)
        dx = dx.reshape(*self.original_x_shape)
        
        return dx

class SoftMaxWithLoss():
    def __init__(self):
        self.loss = None
        self.y = None
        self.d = None
        
    def __softmax(self, x):
        if x.ndim == 2:
            x = x.T
            x = x - np.max(x, axis = 0)
            y = np.exp(x) / np.sum(np.exp(x), axis = 0)
            return y.T
        
    def __cross_entropy_error(self, d, y):
        if y.ndim == 1:
            d = d.reshape(1, d.size)
            y = y.reshape(1, y.size)
            
        if d.size == y.size:
            d = d.argmax(axis = 1)
            
        batch_size = y.shape[0]
        return -np.sum(np.log(y[np.arange(batch_size), d] + 1e-7)) / batch_size
        
    def forward(self, x, d):
        self.d = d
        self.y = self.__softmax(x)
        self.loss = self.__cross_entropy_error(self.d, self.y)
        
        return self.loss
    
    def backward(self, dout=1):
        batch_size = self.d.shape[0]
        if self.d.size == self.y.size:
            dx = (self.y - self.d) / batch_size
        else:
            dx = self.y.copy()
            dx[np.arange(batch_size), self.d] -= 1
            dx = dx / batch_size
            
        return dx

# %%
class MultiLayerNet:
    '''
    input_size        : 入力層のノード数(例えば、mnistなら、8x8=64)
    hidden_size_list  :隠れ層のノード数のリスト
    output_size       :出力層のノード数
    activation        :活性化関数 ("relu"または"sigmoid")
    weight_init_std   :重みの初期化方法（数値を、あるいは"Xavier","He"）
    '''
    def __init__(self, input_size, hidden_size_list, output_size, activation="relu", weight_init_std="relu"):
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size_list = hidden_size_list
        self.hidden_layer_num = len(hidden_size_list)
        self.activation = activation
        self.weight_init_std = weight_init_std
        self.params = {}
        
        # 重みの初期化
        # ここで、self.params["W" + str(idx)]が定義されている。 
        self.__init_weight()
        
        # レイヤの生成,sigmoidまたはreluの選択
        activation_layer = {"sigmoid": Sigmoid,"relu": Relu}
        self.layers = OrderedDict()
        for idx in range(1, self.hidden_layer_num + 1):
            self.layers["Affine" + str(idx)] = Affine(self.params["W" + str(idx)], self.params["b" + str(idx)])
            self.layers["Activation_function" + str(idx)] = activation_layer[self.activation]()
        
        idx = self.hidden_layer_num + 1
        self.layers["Affine" + str(idx)] = Affine(self.params["W" + str(idx)], self.params["b" + str(idx)])
        
        self.last_layer = SoftMaxWithLoss()
        
    def __init_weight(self):
        all_size_list = [self.input_size] + self.hidden_size_list + [self.output_size]
        for idx in range(1, len(all_size_list)):
            scale = self.weight_init_std
            if str(self.weight_init_std).lower() in ("relu", "he"):
                scale = np.sqrt(2.0 / all_size_list[idx - 1])
            elif str(self.weight_init_std).lower() in ("sigmoid", "xavier"):
                scale = np.sqrt(1.0 / all_size_list[idx - 1])
                
            self.params["W" + str(idx)] = scale * np.random.randn(all_size_list[idx - 1], all_size_list[idx])
            self.params["b" + str(idx)] = np.zeros(all_size_list[idx])
    
    def predict(self, x):
        # 順伝播の計算
        for layer in self.layers.values():
            x = layer.forward(x)
        
        return x
    
    def loss(self, x, d):
        y = self.predict(x)
        
        weight_decay = 0
        for idx in range(1, self.hidden_layer_num + 2):
            W = self.params["W" + str(idx)]
        
        return self.last_layer.forward(y,d) + weight_decay
    
    def accuracy(self, x, d):
        y = self.predict(x)
        y = np.argmax(y, axis = 1)
        if d.ndim != 1 : d = np.argmax(d, axis = 1)
        
        accuracy = np.sum(y == d) / float(x.shape[0])
        return accuracy
    
    def gradient(self, x, d):
        # forward
        self.loss(x,d)
        
        # backward
        dout = 1
        dout = self.last_layer.backward(dout)
        
        layerBuf = list(self.layers.values())
        layerBuf.reverse()
        
        for layer in layerBuf:
            dout = layer.backward(dout)
            
        grad = {}
        for idx in range(1, self.hidden_layer_num + 2):
            grad["W" + str(idx)] = self.layers["Affine" + str(idx)].dW
            grad["b" + str(idx)] = self.layers["Affine" + str(idx)].db

        return grad

# %%
class VanishingGradientTest:
    def __init__(self, activation, weight_init_std, x_train, d_train, x_test, d_test, hidden_size_list=[40,20], iters_num = 2000, batch_size = 100, learning_rate = 0.01):
        self.activation = activation
        self.weight_init_std = weight_init_std
        self.hidden_size_list = [40, 20]
        self.x_train = x_train
        self.d_train = d_train
        self.x_test = x_test
        self.d_test = d_test
        self.input_size = x_train.shape[1]
        self.output_size = d_train.shape[1]
        self.network = MultiLayerNet(input_size = self.input_size, 
                                     hidden_size_list = self.hidden_size_list,
                                     output_size = self.output_size,
                                     activation = self.activation, 
                                     weight_init_std = self.weight_init_std)
        self.iters_num = iters_num
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.train_size = self.x_train.shape[0] 
        self.plot_interval = 10
        
    def train(self):
        self.train_loss_list = []
        self.accuracies_train = []
        self.accuracies_test = []
        
        for i in range(self.iters_num):
            batch_mask = np.random.choice(self.train_size, self.batch_size)
            x_batch = self.x_train[batch_mask]
            d_batch = self.d_train[batch_mask]
            
            grad = self.network.gradient(x_batch, d_batch)
            
            for key in ("W1", "W2", "W3", "b1", "b2", "b3"):
                self.network.params[key] -= self.learning_rate * grad[key]
            
            loss = self.network.loss(x_batch, d_batch)
            self.train_loss_list.append(loss)
            
            if (i + 1) % self.plot_interval == 0:
                accr_test = self.network.accuracy(self.x_test, self.d_test)
                self.accuracies_test.append(accr_test)
                accr_train = self.network.accuracy(self.x_train, self.d_train)
                self.accuracies_train.append(accr_train)
                
                print("Generation: " + str(i+1) + ". 正答率（トレーニング） = " + str(accr_train))
                print("                : " + str(i+1) + ". 正答率（テスト） = " + str(accr_test))
    
    def plot_results(self):
        lists = range(0, self.iters_num, self.plot_interval)
        plt.plot(lists, self.accuracies_train, label = "training set")
        plt.plot(lists, self.accuracies_test, label = "test set")
        plt.legend(loc = "lower right")
        plt.title("accuracy")
        plt.xlabel("count")
        plt.ylabel("accuracy")
        plt.ylim(0, 1.0)

# %%
(x_train, d_train) , (x_test, d_test) = load_mnist(normalize=True, one_hot_label = True)

# %%
Tester1 = VanishingGradientTest(activation = "relu", weight_init_std = 0.01 , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test)
Tester1.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.09888333333333334
#                 : 10. 正答率（テスト） = 0.1003
# Generation: 20. 正答率（トレーニング） = 0.09736666666666667
#                 : 20. 正答率（テスト） = 0.0982
# Generation: 30. 正答率（トレーニング） = 0.09736666666666667
#                 : 30. 正答率（テスト） = 0.0982
# Generation: 40. 正答率（トレーニング） = 0.09278333333333333
#                 : 40. 正答率（テスト） = 0.0906
# Generation: 50. 正答率（トレーニング） = 0.10441666666666667
#                 : 50. 正答率（テスト） = 0.1028
# Generation: 60. 正答率（トレーニング） = 0.10441666666666667
#                 : 60. 正答率（テスト） = 0.1028
# Generation: 70. 正答率（トレーニング） = 0.10441666666666667
#                 : 70. 正答率（テスト） = 0.1028
# Generation: 80. 正答率（トレーニング） = 0.10168333333333333
#                 : 80. 正答率（テスト） = 0.0993
# Generation: 90. 正答率（トレーニング） = 0.11308333333333333
#                 : 90. 正答率（テスト） = 0.1143
# Generation: 100. 正答率（トレーニング） = 0.11236666666666667
#                 : 100. 正答率（テスト） = 0.1135
# Generation: 110. 正答率（トレーニング） = 0.11236666666666667
#                 : 110. 正答率（テスト） = 0.1135
# Generation: 120. 正答率（トレーニング） = 0.11236666666666667
#                 : 120. 正答率（テスト） = 0.1135
# Generation: 130. 正答率（トレーニング） = 0.11236666666666667
#                 : 130. 正答率（テスト） = 0.1135
# Generation: 140. 正答率（トレーニング） = 0.11236666666666667
#                 : 140. 正答率（テスト） = 0.1135
# Generation: 150. 正答率（トレーニング） = 0.11236666666666667
#                 : 150. 正答率（テスト） = 0.1135
# Generation: 160. 正答率（トレーニング） = 0.11236666666666667
#                 : 160. 正答率（テスト） = 0.1135
# Generation: 170. 正答率（トレーニング） = 0.11236666666666667
#                 : 170. 正答率（テスト） = 0.1135
# Generation: 180. 正答率（トレーニング） = 0.11236666666666667
#                 : 180. 正答率（テスト） = 0.1135
# Generation: 190. 正答率（トレーニング） = 0.11236666666666667
#                 : 190. 正答率（テスト） = 0.1135
# Generation: 200. 正答率（トレーニング） = 0.11236666666666667
#                 : 200. 正答率（テスト） = 0.1135
# Generation: 210. 正答率（トレーニング） = 0.11236666666666667
#                 : 210. 正答率（テスト） = 0.1135
# Generation: 220. 正答率（トレーニング） = 0.11236666666666667
#                 : 220. 正答率（テスト） = 0.1135
# Generation: 230. 正答率（トレーニング） = 0.11236666666666667
#                 : 230. 正答率（テスト） = 0.1135
# Generation: 240. 正答率（トレーニング） = 0.11236666666666667
#                 : 240. 正答率（テスト） = 0.1135
# Generation: 250. 正答率（トレーニング） = 0.11236666666666667
#                 : 250. 正答率（テスト） = 0.1135
# Generation: 260. 正答率（トレーニング） = 0.11236666666666667
#                 : 260. 正答率（テスト） = 0.1135
# Generation: 270. 正答率（トレーニング） = 0.11236666666666667
#                 : 270. 正答率（テスト） = 0.1135
# Generation: 280. 正答率（トレーニング） = 0.11236666666666667
#                 : 280. 正答率（テスト） = 0.1135
# Generation: 290. 正答率（トレーニング） = 0.11236666666666667
#                 : 290. 正答率（テスト） = 0.1135
# Generation: 300. 正答率（トレーニング） = 0.11236666666666667
#                 : 300. 正答率（テスト） = 0.1135
# Generation: 310. 正答率（トレーニング） = 0.11236666666666667
#                 : 310. 正答率（テスト） = 0.1135
# Generation: 320. 正答率（トレーニング） = 0.11236666666666667
#                 : 320. 正答率（テスト） = 0.1135
# Generation: 330. 正答率（トレーニング） = 0.11236666666666667
#                 : 330. 正答率（テスト） = 0.1135
# Generation: 340. 正答率（トレーニング） = 0.11236666666666667
#                 : 340. 正答率（テスト） = 0.1135
# Generation: 350. 正答率（トレーニング） = 0.11236666666666667
#                 : 350. 正答率（テスト） = 0.1135
# Generation: 360. 正答率（トレーニング） = 0.11236666666666667
#                 : 360. 正答率（テスト） = 0.1135
# Generation: 370. 正答率（トレーニング） = 0.11236666666666667
#                 : 370. 正答率（テスト） = 0.1135
# Generation: 380. 正答率（トレーニング） = 0.11236666666666667
#                 : 380. 正答率（テスト） = 0.1135
# Generation: 390. 正答率（トレーニング） = 0.11236666666666667
#                 : 390. 正答率（テスト） = 0.1135
# Generation: 400. 正答率（トレーニング） = 0.11236666666666667
#                 : 400. 正答率（テスト） = 0.1135
# Generation: 410. 正答率（トレーニング） = 0.11236666666666667
#                 : 410. 正答率（テスト） = 0.1135
# Generation: 420. 正答率（トレーニング） = 0.11236666666666667
#                 : 420. 正答率（テスト） = 0.1135
# Generation: 430. 正答率（トレーニング） = 0.11236666666666667
#                 : 430. 正答率（テスト） = 0.1135
# Generation: 440. 正答率（トレーニング） = 0.11236666666666667
#                 : 440. 正答率（テスト） = 0.1135
# Generation: 450. 正答率（トレーニング） = 0.11236666666666667
#                 : 450. 正答率（テスト） = 0.1135
# Generation: 460. 正答率（トレーニング） = 0.11236666666666667
#                 : 460. 正答率（テスト） = 0.1135
# Generation: 470. 正答率（トレーニング） = 0.11236666666666667
#                 : 470. 正答率（テスト） = 0.1135
# Generation: 480. 正答率（トレーニング） = 0.11236666666666667
#                 : 480. 正答率（テスト） = 0.1135
# Generation: 490. 正答率（トレーニング） = 0.11236666666666667
#                 : 490. 正答率（テスト） = 0.1135
# Generation: 500. 正答率（トレーニング） = 0.11236666666666667
#                 : 500. 正答率（テスト） = 0.1135
# Generation: 510. 正答率（トレーニング） = 0.11236666666666667
#                 : 510. 正答率（テスト） = 0.1135
# Generation: 520. 正答率（トレーニング） = 0.11236666666666667
#                 : 520. 正答率（テスト） = 0.1135
# Generation: 530. 正答率（トレーニング） = 0.11236666666666667
#                 : 530. 正答率（テスト） = 0.1135
# Generation: 540. 正答率（トレーニング） = 0.11236666666666667
#                 : 540. 正答率（テスト） = 0.1135
# Generation: 550. 正答率（トレーニング） = 0.11236666666666667
#                 : 550. 正答率（テスト） = 0.1135
# Generation: 560. 正答率（トレーニング） = 0.11236666666666667
#                 : 560. 正答率（テスト） = 0.1135
# Generation: 570. 正答率（トレーニング） = 0.11236666666666667
#                 : 570. 正答率（テスト） = 0.1135
# Generation: 580. 正答率（トレーニング） = 0.11236666666666667
#                 : 580. 正答率（テスト） = 0.1135
# Generation: 590. 正答率（トレーニング） = 0.11236666666666667
#                 : 590. 正答率（テスト） = 0.1135
# Generation: 600. 正答率（トレーニング） = 0.11236666666666667
#                 : 600. 正答率（テスト） = 0.1135
# Generation: 610. 正答率（トレーニング） = 0.11236666666666667
#                 : 610. 正答率（テスト） = 0.1135
# Generation: 620. 正答率（トレーニング） = 0.11236666666666667
#                 : 620. 正答率（テスト） = 0.1135
# Generation: 630. 正答率（トレーニング） = 0.11236666666666667
#                 : 630. 正答率（テスト） = 0.1135
# Generation: 640. 正答率（トレーニング） = 0.11236666666666667
#                 : 640. 正答率（テスト） = 0.1135
# Generation: 650. 正答率（トレーニング） = 0.11236666666666667
#                 : 650. 正答率（テスト） = 0.1135
# Generation: 660. 正答率（トレーニング） = 0.11236666666666667
#                 : 660. 正答率（テスト） = 0.1135
# Generation: 670. 正答率（トレーニング） = 0.11236666666666667
#                 : 670. 正答率（テスト） = 0.1135
# Generation: 680. 正答率（トレーニング） = 0.11236666666666667
#                 : 680. 正答率（テスト） = 0.1135
# Generation: 690. 正答率（トレーニング） = 0.11236666666666667
#                 : 690. 正答率（テスト） = 0.1135
# Generation: 700. 正答率（トレーニング） = 0.11236666666666667
#                 : 700. 正答率（テスト） = 0.1135
# Generation: 710. 正答率（トレーニング） = 0.11236666666666667
#                 : 710. 正答率（テスト） = 0.1135
# Generation: 720. 正答率（トレーニング） = 0.11236666666666667
#                 : 720. 正答率（テスト） = 0.1135
# Generation: 730. 正答率（トレーニング） = 0.11236666666666667
#                 : 730. 正答率（テスト） = 0.1135
# Generation: 740. 正答率（トレーニング） = 0.11236666666666667
#                 : 740. 正答率（テスト） = 0.1135
# Generation: 750. 正答率（トレーニング） = 0.11236666666666667
#                 : 750. 正答率（テスト） = 0.1135
# Generation: 760. 正答率（トレーニング） = 0.11236666666666667
#                 : 760. 正答率（テスト） = 0.1135
# Generation: 770. 正答率（トレーニング） = 0.11236666666666667
#                 : 770. 正答率（テスト） = 0.1135
# Generation: 780. 正答率（トレーニング） = 0.11236666666666667
#                 : 780. 正答率（テスト） = 0.1135
# Generation: 790. 正答率（トレーニング） = 0.11236666666666667
#                 : 790. 正答率（テスト） = 0.1135
# Generation: 800. 正答率（トレーニング） = 0.11236666666666667
#                 : 800. 正答率（テスト） = 0.1135
# Generation: 810. 正答率（トレーニング） = 0.11236666666666667
#                 : 810. 正答率（テスト） = 0.1135
# Generation: 820. 正答率（トレーニング） = 0.11236666666666667
#                 : 820. 正答率（テスト） = 0.1135
# Generation: 830. 正答率（トレーニング） = 0.11236666666666667
#                 : 830. 正答率（テスト） = 0.1135
# Generation: 840. 正答率（トレーニング） = 0.11236666666666667
#                 : 840. 正答率（テスト） = 0.1135
# Generation: 850. 正答率（トレーニング） = 0.11236666666666667
#                 : 850. 正答率（テスト） = 0.1135
# Generation: 860. 正答率（トレーニング） = 0.11236666666666667
#                 : 860. 正答率（テスト） = 0.1135
# Generation: 870. 正答率（トレーニング） = 0.11236666666666667
#                 : 870. 正答率（テスト） = 0.1135
# Generation: 880. 正答率（トレーニング） = 0.11236666666666667
#                 : 880. 正答率（テスト） = 0.1135
# Generation: 890. 正答率（トレーニング） = 0.11236666666666667
#                 : 890. 正答率（テスト） = 0.1135
# Generation: 900. 正答率（トレーニング） = 0.11236666666666667
#                 : 900. 正答率（テスト） = 0.1135
# Generation: 910. 正答率（トレーニング） = 0.11236666666666667
#                 : 910. 正答率（テスト） = 0.1135
# Generation: 920. 正答率（トレーニング） = 0.11236666666666667
#                 : 920. 正答率（テスト） = 0.1135
# Generation: 930. 正答率（トレーニング） = 0.11236666666666667
#                 : 930. 正答率（テスト） = 0.1135
# Generation: 940. 正答率（トレーニング） = 0.11236666666666667
#                 : 940. 正答率（テスト） = 0.1135
# Generation: 950. 正答率（トレーニング） = 0.11236666666666667
#                 : 950. 正答率（テスト） = 0.1135
# Generation: 960. 正答率（トレーニング） = 0.11236666666666667
#                 : 960. 正答率（テスト） = 0.1135
# Generation: 970. 正答率（トレーニング） = 0.11236666666666667
#                 : 970. 正答率（テスト） = 0.1135
# Generation: 980. 正答率（トレーニング） = 0.11236666666666667
#                 : 980. 正答率（テスト） = 0.1135
# Generation: 990. 正答率（トレーニング） = 0.11236666666666667
#                 : 990. 正答率（テスト） = 0.1135
# Generation: 1000. 正答率（トレーニング） = 0.11236666666666667
#                 : 1000. 正答率（テスト） = 0.1135
# Generation: 1010. 正答率（トレーニング） = 0.11236666666666667
#                 : 1010. 正答率（テスト） = 0.1135
# Generation: 1020. 正答率（トレーニング） = 0.11236666666666667
#                 : 1020. 正答率（テスト） = 0.1135
# Generation: 1030. 正答率（トレーニング） = 0.11236666666666667
#                 : 1030. 正答率（テスト） = 0.1135
# Generation: 1040. 正答率（トレーニング） = 0.11236666666666667
#                 : 1040. 正答率（テスト） = 0.1135
# Generation: 1050. 正答率（トレーニング） = 0.11236666666666667
#                 : 1050. 正答率（テスト） = 0.1135
# Generation: 1060. 正答率（トレーニング） = 0.11236666666666667
#                 : 1060. 正答率（テスト） = 0.1135
# Generation: 1070. 正答率（トレーニング） = 0.11236666666666667
#                 : 1070. 正答率（テスト） = 0.1135
# Generation: 1080. 正答率（トレーニング） = 0.11236666666666667
#                 : 1080. 正答率（テスト） = 0.1135
# Generation: 1090. 正答率（トレーニング） = 0.11236666666666667
#                 : 1090. 正答率（テスト） = 0.1135
# Generation: 1100. 正答率（トレーニング） = 0.11236666666666667
#                 : 1100. 正答率（テスト） = 0.1135
# Generation: 1110. 正答率（トレーニング） = 0.11236666666666667
#                 : 1110. 正答率（テスト） = 0.1135
# Generation: 1120. 正答率（トレーニング） = 0.11236666666666667
#                 : 1120. 正答率（テスト） = 0.1135
# Generation: 1130. 正答率（トレーニング） = 0.11236666666666667
#                 : 1130. 正答率（テスト） = 0.1135
# Generation: 1140. 正答率（トレーニング） = 0.11236666666666667
#                 : 1140. 正答率（テスト） = 0.1135
# Generation: 1150. 正答率（トレーニング） = 0.11236666666666667
#                 : 1150. 正答率（テスト） = 0.1135
# Generation: 1160. 正答率（トレーニング） = 0.11236666666666667
#                 : 1160. 正答率（テスト） = 0.1135
# Generation: 1170. 正答率（トレーニング） = 0.11236666666666667
#                 : 1170. 正答率（テスト） = 0.1135
# Generation: 1180. 正答率（トレーニング） = 0.11236666666666667
#                 : 1180. 正答率（テスト） = 0.1135
# Generation: 1190. 正答率（トレーニング） = 0.11236666666666667
#                 : 1190. 正答率（テスト） = 0.1135
# Generation: 1200. 正答率（トレーニング） = 0.11236666666666667
#                 : 1200. 正答率（テスト） = 0.1135
# Generation: 1210. 正答率（トレーニング） = 0.11236666666666667
#                 : 1210. 正答率（テスト） = 0.1135
# Generation: 1220. 正答率（トレーニング） = 0.11236666666666667
#                 : 1220. 正答率（テスト） = 0.1135
# Generation: 1230. 正答率（トレーニング） = 0.11236666666666667
#                 : 1230. 正答率（テスト） = 0.1135
# Generation: 1240. 正答率（トレーニング） = 0.11236666666666667
#                 : 1240. 正答率（テスト） = 0.1135
# Generation: 1250. 正答率（トレーニング） = 0.11236666666666667
#                 : 1250. 正答率（テスト） = 0.1135
# Generation: 1260. 正答率（トレーニング） = 0.11236666666666667
#                 : 1260. 正答率（テスト） = 0.1135
# Generation: 1270. 正答率（トレーニング） = 0.11236666666666667
#                 : 1270. 正答率（テスト） = 0.1135
# Generation: 1280. 正答率（トレーニング） = 0.11236666666666667
#                 : 1280. 正答率（テスト） = 0.1135
# Generation: 1290. 正答率（トレーニング） = 0.11236666666666667
#                 : 1290. 正答率（テスト） = 0.1135
# Generation: 1300. 正答率（トレーニング） = 0.11236666666666667
#                 : 1300. 正答率（テスト） = 0.1135
# Generation: 1310. 正答率（トレーニング） = 0.11236666666666667
#                 : 1310. 正答率（テスト） = 0.1135
# Generation: 1320. 正答率（トレーニング） = 0.11236666666666667
#                 : 1320. 正答率（テスト） = 0.1135
# Generation: 1330. 正答率（トレーニング） = 0.11236666666666667
#                 : 1330. 正答率（テスト） = 0.1135
# Generation: 1340. 正答率（トレーニング） = 0.11236666666666667
#                 : 1340. 正答率（テスト） = 0.1135
# Generation: 1350. 正答率（トレーニング） = 0.11236666666666667
#                 : 1350. 正答率（テスト） = 0.1135
# Generation: 1360. 正答率（トレーニング） = 0.11236666666666667
#                 : 1360. 正答率（テスト） = 0.1135
# Generation: 1370. 正答率（トレーニング） = 0.11236666666666667
#                 : 1370. 正答率（テスト） = 0.1135
# Generation: 1380. 正答率（トレーニング） = 0.11236666666666667
#                 : 1380. 正答率（テスト） = 0.1135
# Generation: 1390. 正答率（トレーニング） = 0.11236666666666667
#                 : 1390. 正答率（テスト） = 0.1135
# Generation: 1400. 正答率（トレーニング） = 0.11236666666666667
#                 : 1400. 正答率（テスト） = 0.1135
# Generation: 1410. 正答率（トレーニング） = 0.11236666666666667
#                 : 1410. 正答率（テスト） = 0.1135
# Generation: 1420. 正答率（トレーニング） = 0.11236666666666667
#                 : 1420. 正答率（テスト） = 0.1135
# Generation: 1430. 正答率（トレーニング） = 0.11236666666666667
#                 : 1430. 正答率（テスト） = 0.1135
# Generation: 1440. 正答率（トレーニング） = 0.11236666666666667
#                 : 1440. 正答率（テスト） = 0.1135
# Generation: 1450. 正答率（トレーニング） = 0.11236666666666667
#                 : 1450. 正答率（テスト） = 0.1135
# Generation: 1460. 正答率（トレーニング） = 0.11236666666666667
#                 : 1460. 正答率（テスト） = 0.1135
# Generation: 1470. 正答率（トレーニング） = 0.11236666666666667
#                 : 1470. 正答率（テスト） = 0.1135
# Generation: 1480. 正答率（トレーニング） = 0.11236666666666667
#                 : 1480. 正答率（テスト） = 0.1135
# Generation: 1490. 正答率（トレーニング） = 0.11236666666666667
#                 : 1490. 正答率（テスト） = 0.1135
# Generation: 1500. 正答率（トレーニング） = 0.11236666666666667
#                 : 1500. 正答率（テスト） = 0.1135
# Generation: 1510. 正答率（トレーニング） = 0.11236666666666667
#                 : 1510. 正答率（テスト） = 0.1135
# Generation: 1520. 正答率（トレーニング） = 0.11236666666666667
#                 : 1520. 正答率（テスト） = 0.1135
# Generation: 1530. 正答率（トレーニング） = 0.11236666666666667
#                 : 1530. 正答率（テスト） = 0.1135
# Generation: 1540. 正答率（トレーニング） = 0.11236666666666667
#                 : 1540. 正答率（テスト） = 0.1135
# Generation: 1550. 正答率（トレーニング） = 0.11236666666666667
#                 : 1550. 正答率（テスト） = 0.1135
# Generation: 1560. 正答率（トレーニング） = 0.11236666666666667
#                 : 1560. 正答率（テスト） = 0.1135
# Generation: 1570. 正答率（トレーニング） = 0.11236666666666667
#                 : 1570. 正答率（テスト） = 0.1135
# Generation: 1580. 正答率（トレーニング） = 0.11236666666666667
#                 : 1580. 正答率（テスト） = 0.1135
# Generation: 1590. 正答率（トレーニング） = 0.11236666666666667
#                 : 1590. 正答率（テスト） = 0.1135
# Generation: 1600. 正答率（トレーニング） = 0.11236666666666667
#                 : 1600. 正答率（テスト） = 0.1135
# Generation: 1610. 正答率（トレーニング） = 0.11236666666666667
#                 : 1610. 正答率（テスト） = 0.1135
# Generation: 1620. 正答率（トレーニング） = 0.11236666666666667
#                 : 1620. 正答率（テスト） = 0.1135
# Generation: 1630. 正答率（トレーニング） = 0.11236666666666667
#                 : 1630. 正答率（テスト） = 0.1135
# Generation: 1640. 正答率（トレーニング） = 0.11236666666666667
#                 : 1640. 正答率（テスト） = 0.1135
# Generation: 1650. 正答率（トレーニング） = 0.11236666666666667
#                 : 1650. 正答率（テスト） = 0.1135
# Generation: 1660. 正答率（トレーニング） = 0.11236666666666667
#                 : 1660. 正答率（テスト） = 0.1135
# Generation: 1670. 正答率（トレーニング） = 0.11236666666666667
#                 : 1670. 正答率（テスト） = 0.1135
# Generation: 1680. 正答率（トレーニング） = 0.11236666666666667
#                 : 1680. 正答率（テスト） = 0.1135
# Generation: 1690. 正答率（トレーニング） = 0.11236666666666667
#                 : 1690. 正答率（テスト） = 0.1135
# Generation: 1700. 正答率（トレーニング） = 0.11236666666666667
#                 : 1700. 正答率（テスト） = 0.1135
# Generation: 1710. 正答率（トレーニング） = 0.11236666666666667
#                 : 1710. 正答率（テスト） = 0.1135
# Generation: 1720. 正答率（トレーニング） = 0.11236666666666667
#                 : 1720. 正答率（テスト） = 0.1135
# Generation: 1730. 正答率（トレーニング） = 0.11236666666666667
#                 : 1730. 正答率（テスト） = 0.1135
# Generation: 1740. 正答率（トレーニング） = 0.11236666666666667
#                 : 1740. 正答率（テスト） = 0.1135
# Generation: 1750. 正答率（トレーニング） = 0.11236666666666667
#                 : 1750. 正答率（テスト） = 0.1135
# Generation: 1760. 正答率（トレーニング） = 0.11236666666666667
#                 : 1760. 正答率（テスト） = 0.1135
# Generation: 1770. 正答率（トレーニング） = 0.11236666666666667
#                 : 1770. 正答率（テスト） = 0.1135
# Generation: 1780. 正答率（トレーニング） = 0.11236666666666667
#                 : 1780. 正答率（テスト） = 0.1135
# Generation: 1790. 正答率（トレーニング） = 0.11236666666666667
#                 : 1790. 正答率（テスト） = 0.1135
# Generation: 1800. 正答率（トレーニング） = 0.11236666666666667
#                 : 1800. 正答率（テスト） = 0.1135
# Generation: 1810. 正答率（トレーニング） = 0.11236666666666667
#                 : 1810. 正答率（テスト） = 0.1135
# Generation: 1820. 正答率（トレーニング） = 0.11236666666666667
#                 : 1820. 正答率（テスト） = 0.1135
# Generation: 1830. 正答率（トレーニング） = 0.11236666666666667
#                 : 1830. 正答率（テスト） = 0.1135
# Generation: 1840. 正答率（トレーニング） = 0.11236666666666667
#                 : 1840. 正答率（テスト） = 0.1135
# Generation: 1850. 正答率（トレーニング） = 0.11236666666666667
#                 : 1850. 正答率（テスト） = 0.1135
# Generation: 1860. 正答率（トレーニング） = 0.11236666666666667
#                 : 1860. 正答率（テスト） = 0.1135
# Generation: 1870. 正答率（トレーニング） = 0.11236666666666667
#                 : 1870. 正答率（テスト） = 0.1135
# Generation: 1880. 正答率（トレーニング） = 0.11236666666666667
#                 : 1880. 正答率（テスト） = 0.1135
# Generation: 1890. 正答率（トレーニング） = 0.11236666666666667
#                 : 1890. 正答率（テスト） = 0.1135
# Generation: 1900. 正答率（トレーニング） = 0.11236666666666667
#                 : 1900. 正答率（テスト） = 0.1135
# Generation: 1910. 正答率（トレーニング） = 0.11236666666666667
#                 : 1910. 正答率（テスト） = 0.1135
# Generation: 1920. 正答率（トレーニング） = 0.11236666666666667
#                 : 1920. 正答率（テスト） = 0.1135
# Generation: 1930. 正答率（トレーニング） = 0.11236666666666667
#                 : 1930. 正答率（テスト） = 0.1135
# Generation: 1940. 正答率（トレーニング） = 0.11236666666666667
#                 : 1940. 正答率（テスト） = 0.1135
# Generation: 1950. 正答率（トレーニング） = 0.11236666666666667
#                 : 1950. 正答率（テスト） = 0.1135
# Generation: 1960. 正答率（トレーニング） = 0.11236666666666667
#                 : 1960. 正答率（テスト） = 0.1135
# Generation: 1970. 正答率（トレーニング） = 0.11236666666666667
#                 : 1970. 正答率（テスト） = 0.1135
# Generation: 1980. 正答率（トレーニング） = 0.11236666666666667
#                 : 1980. 正答率（テスト） = 0.1135
# Generation: 1990. 正答率（トレーニング） = 0.11236666666666667
#                 : 1990. 正答率（テスト） = 0.1135
# Generation: 2000. 正答率（トレーニング） = 0.11236666666666667
#                 : 2000. 正答率（テスト） = 0.1135

# %%
Tester1.plot_results()
plt.show()

# %%
Tester2 = VanishingGradientTest(activation = "sigmoid", weight_init_std = 0.01 , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test)
Tester2.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.11236666666666667
#                 : 10. 正答率（テスト） = 0.1135
# Generation: 20. 正答率（トレーニング） = 0.11236666666666667
#                 : 20. 正答率（テスト） = 0.1135
# Generation: 30. 正答率（トレーニング） = 0.11236666666666667
#                 : 30. 正答率（テスト） = 0.1135
# Generation: 40. 正答率（トレーニング） = 0.11236666666666667
#                 : 40. 正答率（テスト） = 0.1135
# Generation: 50. 正答率（トレーニング） = 0.11236666666666667
#                 : 50. 正答率（テスト） = 0.1135
# Generation: 60. 正答率（トレーニング） = 0.11236666666666667
#                 : 60. 正答率（テスト） = 0.1135
# Generation: 70. 正答率（トレーニング） = 0.11236666666666667
#                 : 70. 正答率（テスト） = 0.1135
# Generation: 80. 正答率（トレーニング） = 0.11236666666666667
#                 : 80. 正答率（テスト） = 0.1135
# Generation: 90. 正答率（トレーニング） = 0.11236666666666667
#                 : 90. 正答率（テスト） = 0.1135
# Generation: 100. 正答率（トレーニング） = 0.11236666666666667
#                 : 100. 正答率（テスト） = 0.1135
# Generation: 110. 正答率（トレーニング） = 0.11236666666666667
#                 : 110. 正答率（テスト） = 0.1135
# Generation: 120. 正答率（トレーニング） = 0.11236666666666667
#                 : 120. 正答率（テスト） = 0.1135
# Generation: 130. 正答率（トレーニング） = 0.11236666666666667
#                 : 130. 正答率（テスト） = 0.1135
# Generation: 140. 正答率（トレーニング） = 0.11236666666666667
#                 : 140. 正答率（テスト） = 0.1135
# Generation: 150. 正答率（トレーニング） = 0.11236666666666667
#                 : 150. 正答率（テスト） = 0.1135
# Generation: 160. 正答率（トレーニング） = 0.11236666666666667
#                 : 160. 正答率（テスト） = 0.1135
# Generation: 170. 正答率（トレーニング） = 0.11236666666666667
#                 : 170. 正答率（テスト） = 0.1135
# Generation: 180. 正答率（トレーニング） = 0.11236666666666667
#                 : 180. 正答率（テスト） = 0.1135
# Generation: 190. 正答率（トレーニング） = 0.11236666666666667
#                 : 190. 正答率（テスト） = 0.1135
# Generation: 200. 正答率（トレーニング） = 0.11236666666666667
#                 : 200. 正答率（テスト） = 0.1135
# Generation: 210. 正答率（トレーニング） = 0.11236666666666667
#                 : 210. 正答率（テスト） = 0.1135
# Generation: 220. 正答率（トレーニング） = 0.11236666666666667
#                 : 220. 正答率（テスト） = 0.1135
# Generation: 230. 正答率（トレーニング） = 0.11236666666666667
#                 : 230. 正答率（テスト） = 0.1135
# Generation: 240. 正答率（トレーニング） = 0.11236666666666667
#                 : 240. 正答率（テスト） = 0.1135
# Generation: 250. 正答率（トレーニング） = 0.11236666666666667
#                 : 250. 正答率（テスト） = 0.1135
# Generation: 260. 正答率（トレーニング） = 0.11236666666666667
#                 : 260. 正答率（テスト） = 0.1135
# Generation: 270. 正答率（トレーニング） = 0.11236666666666667
#                 : 270. 正答率（テスト） = 0.1135
# Generation: 280. 正答率（トレーニング） = 0.11236666666666667
#                 : 280. 正答率（テスト） = 0.1135
# Generation: 290. 正答率（トレーニング） = 0.11236666666666667
#                 : 290. 正答率（テスト） = 0.1135
# Generation: 300. 正答率（トレーニング） = 0.11236666666666667
#                 : 300. 正答率（テスト） = 0.1135
# Generation: 310. 正答率（トレーニング） = 0.11236666666666667
#                 : 310. 正答率（テスト） = 0.1135
# Generation: 320. 正答率（トレーニング） = 0.11236666666666667
#                 : 320. 正答率（テスト） = 0.1135
# Generation: 330. 正答率（トレーニング） = 0.11236666666666667
#                 : 330. 正答率（テスト） = 0.1135
# Generation: 340. 正答率（トレーニング） = 0.11236666666666667
#                 : 340. 正答率（テスト） = 0.1135
# Generation: 350. 正答率（トレーニング） = 0.11236666666666667
#                 : 350. 正答率（テスト） = 0.1135
# Generation: 360. 正答率（トレーニング） = 0.11236666666666667
#                 : 360. 正答率（テスト） = 0.1135
# Generation: 370. 正答率（トレーニング） = 0.11236666666666667
#                 : 370. 正答率（テスト） = 0.1135
# Generation: 380. 正答率（トレーニング） = 0.11236666666666667
#                 : 380. 正答率（テスト） = 0.1135
# Generation: 390. 正答率（トレーニング） = 0.11236666666666667
#                 : 390. 正答率（テスト） = 0.1135
# Generation: 400. 正答率（トレーニング） = 0.11236666666666667
#                 : 400. 正答率（テスト） = 0.1135
# Generation: 410. 正答率（トレーニング） = 0.11236666666666667
#                 : 410. 正答率（テスト） = 0.1135
# Generation: 420. 正答率（トレーニング） = 0.11236666666666667
#                 : 420. 正答率（テスト） = 0.1135
# Generation: 430. 正答率（トレーニング） = 0.11236666666666667
#                 : 430. 正答率（テスト） = 0.1135
# Generation: 440. 正答率（トレーニング） = 0.11236666666666667
#                 : 440. 正答率（テスト） = 0.1135
# Generation: 450. 正答率（トレーニング） = 0.11236666666666667
#                 : 450. 正答率（テスト） = 0.1135
# Generation: 460. 正答率（トレーニング） = 0.11236666666666667
#                 : 460. 正答率（テスト） = 0.1135
# Generation: 470. 正答率（トレーニング） = 0.11236666666666667
#                 : 470. 正答率（テスト） = 0.1135
# Generation: 480. 正答率（トレーニング） = 0.11236666666666667
#                 : 480. 正答率（テスト） = 0.1135
# Generation: 490. 正答率（トレーニング） = 0.11236666666666667
#                 : 490. 正答率（テスト） = 0.1135
# Generation: 500. 正答率（トレーニング） = 0.11236666666666667
#                 : 500. 正答率（テスト） = 0.1135
# Generation: 510. 正答率（トレーニング） = 0.11236666666666667
#                 : 510. 正答率（テスト） = 0.1135
# Generation: 520. 正答率（トレーニング） = 0.11236666666666667
#                 : 520. 正答率（テスト） = 0.1135
# Generation: 530. 正答率（トレーニング） = 0.11236666666666667
#                 : 530. 正答率（テスト） = 0.1135
# Generation: 540. 正答率（トレーニング） = 0.11236666666666667
#                 : 540. 正答率（テスト） = 0.1135
# Generation: 550. 正答率（トレーニング） = 0.11236666666666667
#                 : 550. 正答率（テスト） = 0.1135
# Generation: 560. 正答率（トレーニング） = 0.11236666666666667
#                 : 560. 正答率（テスト） = 0.1135
# Generation: 570. 正答率（トレーニング） = 0.11236666666666667
#                 : 570. 正答率（テスト） = 0.1135
# Generation: 580. 正答率（トレーニング） = 0.11236666666666667
#                 : 580. 正答率（テスト） = 0.1135
# Generation: 590. 正答率（トレーニング） = 0.11236666666666667
#                 : 590. 正答率（テスト） = 0.1135
# Generation: 600. 正答率（トレーニング） = 0.11236666666666667
#                 : 600. 正答率（テスト） = 0.1135
# Generation: 610. 正答率（トレーニング） = 0.11236666666666667
#                 : 610. 正答率（テスト） = 0.1135
# Generation: 620. 正答率（トレーニング） = 0.11236666666666667
#                 : 620. 正答率（テスト） = 0.1135
# Generation: 630. 正答率（トレーニング） = 0.11236666666666667
#                 : 630. 正答率（テスト） = 0.1135
# Generation: 640. 正答率（トレーニング） = 0.11236666666666667
#                 : 640. 正答率（テスト） = 0.1135
# Generation: 650. 正答率（トレーニング） = 0.11236666666666667
#                 : 650. 正答率（テスト） = 0.1135
# Generation: 660. 正答率（トレーニング） = 0.11236666666666667
#                 : 660. 正答率（テスト） = 0.1135
# Generation: 670. 正答率（トレーニング） = 0.11236666666666667
#                 : 670. 正答率（テスト） = 0.1135
# Generation: 680. 正答率（トレーニング） = 0.11236666666666667
#                 : 680. 正答率（テスト） = 0.1135
# Generation: 690. 正答率（トレーニング） = 0.11236666666666667
#                 : 690. 正答率（テスト） = 0.1135
# Generation: 700. 正答率（トレーニング） = 0.11236666666666667
#                 : 700. 正答率（テスト） = 0.1135
# Generation: 710. 正答率（トレーニング） = 0.11236666666666667
#                 : 710. 正答率（テスト） = 0.1135
# Generation: 720. 正答率（トレーニング） = 0.11236666666666667
#                 : 720. 正答率（テスト） = 0.1135
# Generation: 730. 正答率（トレーニング） = 0.11236666666666667
#                 : 730. 正答率（テスト） = 0.1135
# Generation: 740. 正答率（トレーニング） = 0.11236666666666667
#                 : 740. 正答率（テスト） = 0.1135
# Generation: 750. 正答率（トレーニング） = 0.11236666666666667
#                 : 750. 正答率（テスト） = 0.1135
# Generation: 760. 正答率（トレーニング） = 0.11236666666666667
#                 : 760. 正答率（テスト） = 0.1135
# Generation: 770. 正答率（トレーニング） = 0.11236666666666667
#                 : 770. 正答率（テスト） = 0.1135
# Generation: 780. 正答率（トレーニング） = 0.11236666666666667
#                 : 780. 正答率（テスト） = 0.1135
# Generation: 790. 正答率（トレーニング） = 0.11236666666666667
#                 : 790. 正答率（テスト） = 0.1135
# Generation: 800. 正答率（トレーニング） = 0.11236666666666667
#                 : 800. 正答率（テスト） = 0.1135
# Generation: 810. 正答率（トレーニング） = 0.11236666666666667
#                 : 810. 正答率（テスト） = 0.1135
# Generation: 820. 正答率（トレーニング） = 0.11236666666666667
#                 : 820. 正答率（テスト） = 0.1135
# Generation: 830. 正答率（トレーニング） = 0.11236666666666667
#                 : 830. 正答率（テスト） = 0.1135
# Generation: 840. 正答率（トレーニング） = 0.11236666666666667
#                 : 840. 正答率（テスト） = 0.1135
# Generation: 850. 正答率（トレーニング） = 0.11236666666666667
#                 : 850. 正答率（テスト） = 0.1135
# Generation: 860. 正答率（トレーニング） = 0.11236666666666667
#                 : 860. 正答率（テスト） = 0.1135
# Generation: 870. 正答率（トレーニング） = 0.11236666666666667
#                 : 870. 正答率（テスト） = 0.1135
# Generation: 880. 正答率（トレーニング） = 0.11236666666666667
#                 : 880. 正答率（テスト） = 0.1135
# Generation: 890. 正答率（トレーニング） = 0.11236666666666667
#                 : 890. 正答率（テスト） = 0.1135
# Generation: 900. 正答率（トレーニング） = 0.11236666666666667
#                 : 900. 正答率（テスト） = 0.1135
# Generation: 910. 正答率（トレーニング） = 0.11236666666666667
#                 : 910. 正答率（テスト） = 0.1135
# Generation: 920. 正答率（トレーニング） = 0.11236666666666667
#                 : 920. 正答率（テスト） = 0.1135
# Generation: 930. 正答率（トレーニング） = 0.11236666666666667
#                 : 930. 正答率（テスト） = 0.1135
# Generation: 940. 正答率（トレーニング） = 0.11236666666666667
#                 : 940. 正答率（テスト） = 0.1135
# Generation: 950. 正答率（トレーニング） = 0.11236666666666667
#                 : 950. 正答率（テスト） = 0.1135
# Generation: 960. 正答率（トレーニング） = 0.11236666666666667
#                 : 960. 正答率（テスト） = 0.1135
# Generation: 970. 正答率（トレーニング） = 0.11236666666666667
#                 : 970. 正答率（テスト） = 0.1135
# Generation: 980. 正答率（トレーニング） = 0.11236666666666667
#                 : 980. 正答率（テスト） = 0.1135
# Generation: 990. 正答率（トレーニング） = 0.11236666666666667
#                 : 990. 正答率（テスト） = 0.1135
# Generation: 1000. 正答率（トレーニング） = 0.11236666666666667
#                 : 1000. 正答率（テスト） = 0.1135
# Generation: 1010. 正答率（トレーニング） = 0.11236666666666667
#                 : 1010. 正答率（テスト） = 0.1135
# Generation: 1020. 正答率（トレーニング） = 0.11236666666666667
#                 : 1020. 正答率（テスト） = 0.1135
# Generation: 1030. 正答率（トレーニング） = 0.11236666666666667
#                 : 1030. 正答率（テスト） = 0.1135
# Generation: 1040. 正答率（トレーニング） = 0.11236666666666667
#                 : 1040. 正答率（テスト） = 0.1135
# Generation: 1050. 正答率（トレーニング） = 0.11236666666666667
#                 : 1050. 正答率（テスト） = 0.1135
# Generation: 1060. 正答率（トレーニング） = 0.11236666666666667
#                 : 1060. 正答率（テスト） = 0.1135
# Generation: 1070. 正答率（トレーニング） = 0.11236666666666667
#                 : 1070. 正答率（テスト） = 0.1135
# Generation: 1080. 正答率（トレーニング） = 0.11236666666666667
#                 : 1080. 正答率（テスト） = 0.1135
# Generation: 1090. 正答率（トレーニング） = 0.11236666666666667
#                 : 1090. 正答率（テスト） = 0.1135
# Generation: 1100. 正答率（トレーニング） = 0.11236666666666667
#                 : 1100. 正答率（テスト） = 0.1135
# Generation: 1110. 正答率（トレーニング） = 0.11236666666666667
#                 : 1110. 正答率（テスト） = 0.1135
# Generation: 1120. 正答率（トレーニング） = 0.11236666666666667
#                 : 1120. 正答率（テスト） = 0.1135
# Generation: 1130. 正答率（トレーニング） = 0.11236666666666667
#                 : 1130. 正答率（テスト） = 0.1135
# Generation: 1140. 正答率（トレーニング） = 0.11236666666666667
#                 : 1140. 正答率（テスト） = 0.1135
# Generation: 1150. 正答率（トレーニング） = 0.11236666666666667
#                 : 1150. 正答率（テスト） = 0.1135
# Generation: 1160. 正答率（トレーニング） = 0.11236666666666667
#                 : 1160. 正答率（テスト） = 0.1135
# Generation: 1170. 正答率（トレーニング） = 0.11236666666666667
#                 : 1170. 正答率（テスト） = 0.1135
# Generation: 1180. 正答率（トレーニング） = 0.11236666666666667
#                 : 1180. 正答率（テスト） = 0.1135
# Generation: 1190. 正答率（トレーニング） = 0.11236666666666667
#                 : 1190. 正答率（テスト） = 0.1135
# Generation: 1200. 正答率（トレーニング） = 0.11236666666666667
#                 : 1200. 正答率（テスト） = 0.1135
# Generation: 1210. 正答率（トレーニング） = 0.11236666666666667
#                 : 1210. 正答率（テスト） = 0.1135
# Generation: 1220. 正答率（トレーニング） = 0.11236666666666667
#                 : 1220. 正答率（テスト） = 0.1135
# Generation: 1230. 正答率（トレーニング） = 0.11236666666666667
#                 : 1230. 正答率（テスト） = 0.1135
# Generation: 1240. 正答率（トレーニング） = 0.11236666666666667
#                 : 1240. 正答率（テスト） = 0.1135
# Generation: 1250. 正答率（トレーニング） = 0.11236666666666667
#                 : 1250. 正答率（テスト） = 0.1135
# Generation: 1260. 正答率（トレーニング） = 0.11236666666666667
#                 : 1260. 正答率（テスト） = 0.1135
# Generation: 1270. 正答率（トレーニング） = 0.11236666666666667
#                 : 1270. 正答率（テスト） = 0.1135
# Generation: 1280. 正答率（トレーニング） = 0.11236666666666667
#                 : 1280. 正答率（テスト） = 0.1135
# Generation: 1290. 正答率（トレーニング） = 0.11236666666666667
#                 : 1290. 正答率（テスト） = 0.1135
# Generation: 1300. 正答率（トレーニング） = 0.11236666666666667
#                 : 1300. 正答率（テスト） = 0.1135
# Generation: 1310. 正答率（トレーニング） = 0.11236666666666667
#                 : 1310. 正答率（テスト） = 0.1135
# Generation: 1320. 正答率（トレーニング） = 0.11236666666666667
#                 : 1320. 正答率（テスト） = 0.1135
# Generation: 1330. 正答率（トレーニング） = 0.11236666666666667
#                 : 1330. 正答率（テスト） = 0.1135
# Generation: 1340. 正答率（トレーニング） = 0.11236666666666667
#                 : 1340. 正答率（テスト） = 0.1135
# Generation: 1350. 正答率（トレーニング） = 0.11236666666666667
#                 : 1350. 正答率（テスト） = 0.1135
# Generation: 1360. 正答率（トレーニング） = 0.11236666666666667
#                 : 1360. 正答率（テスト） = 0.1135
# Generation: 1370. 正答率（トレーニング） = 0.11236666666666667
#                 : 1370. 正答率（テスト） = 0.1135
# Generation: 1380. 正答率（トレーニング） = 0.11236666666666667
#                 : 1380. 正答率（テスト） = 0.1135
# Generation: 1390. 正答率（トレーニング） = 0.11236666666666667
#                 : 1390. 正答率（テスト） = 0.1135
# Generation: 1400. 正答率（トレーニング） = 0.11236666666666667
#                 : 1400. 正答率（テスト） = 0.1135
# Generation: 1410. 正答率（トレーニング） = 0.11236666666666667
#                 : 1410. 正答率（テスト） = 0.1135
# Generation: 1420. 正答率（トレーニング） = 0.11236666666666667
#                 : 1420. 正答率（テスト） = 0.1135
# Generation: 1430. 正答率（トレーニング） = 0.11236666666666667
#                 : 1430. 正答率（テスト） = 0.1135
# Generation: 1440. 正答率（トレーニング） = 0.11236666666666667
#                 : 1440. 正答率（テスト） = 0.1135
# Generation: 1450. 正答率（トレーニング） = 0.11236666666666667
#                 : 1450. 正答率（テスト） = 0.1135
# Generation: 1460. 正答率（トレーニング） = 0.11236666666666667
#                 : 1460. 正答率（テスト） = 0.1135
# Generation: 1470. 正答率（トレーニング） = 0.11236666666666667
#                 : 1470. 正答率（テスト） = 0.1135
# Generation: 1480. 正答率（トレーニング） = 0.11236666666666667
#                 : 1480. 正答率（テスト） = 0.1135
# Generation: 1490. 正答率（トレーニング） = 0.11236666666666667
#                 : 1490. 正答率（テスト） = 0.1135
# Generation: 1500. 正答率（トレーニング） = 0.11236666666666667
#                 : 1500. 正答率（テスト） = 0.1135
# Generation: 1510. 正答率（トレーニング） = 0.11236666666666667
#                 : 1510. 正答率（テスト） = 0.1135
# Generation: 1520. 正答率（トレーニング） = 0.11236666666666667
#                 : 1520. 正答率（テスト） = 0.1135
# Generation: 1530. 正答率（トレーニング） = 0.11236666666666667
#                 : 1530. 正答率（テスト） = 0.1135
# Generation: 1540. 正答率（トレーニング） = 0.11236666666666667
#                 : 1540. 正答率（テスト） = 0.1135
# Generation: 1550. 正答率（トレーニング） = 0.11236666666666667
#                 : 1550. 正答率（テスト） = 0.1135
# Generation: 1560. 正答率（トレーニング） = 0.11236666666666667
#                 : 1560. 正答率（テスト） = 0.1135
# Generation: 1570. 正答率（トレーニング） = 0.11236666666666667
#                 : 1570. 正答率（テスト） = 0.1135
# Generation: 1580. 正答率（トレーニング） = 0.11236666666666667
#                 : 1580. 正答率（テスト） = 0.1135
# Generation: 1590. 正答率（トレーニング） = 0.11236666666666667
#                 : 1590. 正答率（テスト） = 0.1135
# Generation: 1600. 正答率（トレーニング） = 0.11236666666666667
#                 : 1600. 正答率（テスト） = 0.1135
# Generation: 1610. 正答率（トレーニング） = 0.11236666666666667
#                 : 1610. 正答率（テスト） = 0.1135
# Generation: 1620. 正答率（トレーニング） = 0.11236666666666667
#                 : 1620. 正答率（テスト） = 0.1135
# Generation: 1630. 正答率（トレーニング） = 0.11236666666666667
#                 : 1630. 正答率（テスト） = 0.1135
# Generation: 1640. 正答率（トレーニング） = 0.11236666666666667
#                 : 1640. 正答率（テスト） = 0.1135
# Generation: 1650. 正答率（トレーニング） = 0.11236666666666667
#                 : 1650. 正答率（テスト） = 0.1135
# Generation: 1660. 正答率（トレーニング） = 0.11236666666666667
#                 : 1660. 正答率（テスト） = 0.1135
# Generation: 1670. 正答率（トレーニング） = 0.11236666666666667
#                 : 1670. 正答率（テスト） = 0.1135
# Generation: 1680. 正答率（トレーニング） = 0.11236666666666667
#                 : 1680. 正答率（テスト） = 0.1135
# Generation: 1690. 正答率（トレーニング） = 0.11236666666666667
#                 : 1690. 正答率（テスト） = 0.1135
# Generation: 1700. 正答率（トレーニング） = 0.11236666666666667
#                 : 1700. 正答率（テスト） = 0.1135
# Generation: 1710. 正答率（トレーニング） = 0.11236666666666667
#                 : 1710. 正答率（テスト） = 0.1135
# Generation: 1720. 正答率（トレーニング） = 0.11236666666666667
#                 : 1720. 正答率（テスト） = 0.1135
# Generation: 1730. 正答率（トレーニング） = 0.11236666666666667
#                 : 1730. 正答率（テスト） = 0.1135
# Generation: 1740. 正答率（トレーニング） = 0.11236666666666667
#                 : 1740. 正答率（テスト） = 0.1135
# Generation: 1750. 正答率（トレーニング） = 0.11236666666666667
#                 : 1750. 正答率（テスト） = 0.1135
# Generation: 1760. 正答率（トレーニング） = 0.11236666666666667
#                 : 1760. 正答率（テスト） = 0.1135
# Generation: 1770. 正答率（トレーニング） = 0.11236666666666667
#                 : 1770. 正答率（テスト） = 0.1135
# Generation: 1780. 正答率（トレーニング） = 0.11236666666666667
#                 : 1780. 正答率（テスト） = 0.1135
# Generation: 1790. 正答率（トレーニング） = 0.11236666666666667
#                 : 1790. 正答率（テスト） = 0.1135
# Generation: 1800. 正答率（トレーニング） = 0.11236666666666667
#                 : 1800. 正答率（テスト） = 0.1135
# Generation: 1810. 正答率（トレーニング） = 0.11236666666666667
#                 : 1810. 正答率（テスト） = 0.1135
# Generation: 1820. 正答率（トレーニング） = 0.11236666666666667
#                 : 1820. 正答率（テスト） = 0.1135
# Generation: 1830. 正答率（トレーニング） = 0.11236666666666667
#                 : 1830. 正答率（テスト） = 0.1135
# Generation: 1840. 正答率（トレーニング） = 0.11236666666666667
#                 : 1840. 正答率（テスト） = 0.1135
# Generation: 1850. 正答率（トレーニング） = 0.11236666666666667
#                 : 1850. 正答率（テスト） = 0.1135
# Generation: 1860. 正答率（トレーニング） = 0.11236666666666667
#                 : 1860. 正答率（テスト） = 0.1135
# Generation: 1870. 正答率（トレーニング） = 0.11236666666666667
#                 : 1870. 正答率（テスト） = 0.1135
# Generation: 1880. 正答率（トレーニング） = 0.11236666666666667
#                 : 1880. 正答率（テスト） = 0.1135
# Generation: 1890. 正答率（トレーニング） = 0.11236666666666667
#                 : 1890. 正答率（テスト） = 0.1135
# Generation: 1900. 正答率（トレーニング） = 0.11236666666666667
#                 : 1900. 正答率（テスト） = 0.1135
# Generation: 1910. 正答率（トレーニング） = 0.11236666666666667
#                 : 1910. 正答率（テスト） = 0.1135
# Generation: 1920. 正答率（トレーニング） = 0.11236666666666667
#                 : 1920. 正答率（テスト） = 0.1135
# Generation: 1930. 正答率（トレーニング） = 0.11236666666666667
#                 : 1930. 正答率（テスト） = 0.1135
# Generation: 1940. 正答率（トレーニング） = 0.11236666666666667
#                 : 1940. 正答率（テスト） = 0.1135
# Generation: 1950. 正答率（トレーニング） = 0.11236666666666667
#                 : 1950. 正答率（テスト） = 0.1135
# Generation: 1960. 正答率（トレーニング） = 0.11236666666666667
#                 : 1960. 正答率（テスト） = 0.1135
# Generation: 1970. 正答率（トレーニング） = 0.11236666666666667
#                 : 1970. 正答率（テスト） = 0.1135
# Generation: 1980. 正答率（トレーニング） = 0.11236666666666667
#                 : 1980. 正答率（テスト） = 0.1135
# Generation: 1990. 正答率（トレーニング） = 0.11236666666666667
#                 : 1990. 正答率（テスト） = 0.1135
# Generation: 2000. 正答率（トレーニング） = 0.11236666666666667
#                 : 2000. 正答率（テスト） = 0.1135

# %%
Tester2.plot_results()
plt.show()

# %%
Tester3 = VanishingGradientTest(activation = "sigmoid", weight_init_std = "Xavier" , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test)
Tester3.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.08626666666666667
#                 : 10. 正答率（テスト） = 0.0868
# Generation: 20. 正答率（トレーニング） = 0.07623333333333333
#                 : 20. 正答率（テスト） = 0.0763
# Generation: 30. 正答率（トレーニング） = 0.07613333333333333
#                 : 30. 正答率（テスト） = 0.0739
# Generation: 40. 正答率（トレーニング） = 0.08
#                 : 40. 正答率（テスト） = 0.0809
# Generation: 50. 正答率（トレーニング） = 0.07911666666666667
#                 : 50. 正答率（テスト） = 0.0782
# Generation: 60. 正答率（トレーニング） = 0.07941666666666666
#                 : 60. 正答率（テスト） = 0.0788
# Generation: 70. 正答率（トレーニング） = 0.07901666666666667
#                 : 70. 正答率（テスト） = 0.0783
# Generation: 80. 正答率（トレーニング） = 0.07016666666666667
#                 : 80. 正答率（テスト） = 0.0689
# Generation: 90. 正答率（トレーニング） = 0.06986666666666666
#                 : 90. 正答率（テスト） = 0.0694
# Generation: 100. 正答率（トレーニング） = 0.06673333333333334
#                 : 100. 正答率（テスト） = 0.0644
# Generation: 110. 正答率（トレーニング） = 0.09208333333333334
#                 : 110. 正答率（テスト） = 0.0925
# Generation: 120. 正答率（トレーニング） = 0.12158333333333333
#                 : 120. 正答率（テスト） = 0.1237
# Generation: 130. 正答率（トレーニング） = 0.13863333333333333
#                 : 130. 正答率（テスト） = 0.1412
# Generation: 140. 正答率（トレーニング） = 0.16328333333333334
#                 : 140. 正答率（テスト） = 0.1651
# Generation: 150. 正答率（トレーニング） = 0.16806666666666667
#                 : 150. 正答率（テスト） = 0.1713
# Generation: 160. 正答率（トレーニング） = 0.19475
#                 : 160. 正答率（テスト） = 0.1988
# Generation: 170. 正答率（トレーニング） = 0.20555
#                 : 170. 正答率（テスト） = 0.2106
# Generation: 180. 正答率（トレーニング） = 0.20075
#                 : 180. 正答率（テスト） = 0.2059
# Generation: 190. 正答率（トレーニング） = 0.19608333333333333
#                 : 190. 正答率（テスト） = 0.2007
# Generation: 200. 正答率（トレーニング） = 0.22753333333333334
#                 : 200. 正答率（テスト） = 0.2333
# Generation: 210. 正答率（トレーニング） = 0.17406666666666668
#                 : 210. 正答率（テスト） = 0.1751
# Generation: 220. 正答率（トレーニング） = 0.15928333333333333
#                 : 220. 正答率（テスト） = 0.1606
# Generation: 230. 正答率（トレーニング） = 0.13721666666666665
#                 : 230. 正答率（テスト） = 0.137
# Generation: 240. 正答率（トレーニング） = 0.14151666666666668
#                 : 240. 正答率（テスト） = 0.1403
# Generation: 250. 正答率（トレーニング） = 0.1269
#                 : 250. 正答率（テスト） = 0.1255
# Generation: 260. 正答率（トレーニング） = 0.12463333333333333
#                 : 260. 正答率（テスト） = 0.1233
# Generation: 270. 正答率（トレーニング） = 0.13353333333333334
#                 : 270. 正答率（テスト） = 0.1331
# Generation: 280. 正答率（トレーニング） = 0.14606666666666668
#                 : 280. 正答率（テスト） = 0.1458
# Generation: 290. 正答率（トレーニング） = 0.14698333333333333
#                 : 290. 正答率（テスト） = 0.1488
# Generation: 300. 正答率（トレーニング） = 0.13808333333333334
#                 : 300. 正答率（テスト） = 0.1401
# Generation: 310. 正答率（トレーニング） = 0.1404
#                 : 310. 正答率（テスト） = 0.1437
# Generation: 320. 正答率（トレーニング） = 0.14631666666666668
#                 : 320. 正答率（テスト） = 0.1481
# Generation: 330. 正答率（トレーニング） = 0.139
#                 : 330. 正答率（テスト） = 0.143
# Generation: 340. 正答率（トレーニング） = 0.14796666666666666
#                 : 340. 正答率（テスト） = 0.153
# Generation: 350. 正答率（トレーニング） = 0.15141666666666667
#                 : 350. 正答率（テスト） = 0.1577
# Generation: 360. 正答率（トレーニング） = 0.1502
#                 : 360. 正答率（テスト） = 0.1564
# Generation: 370. 正答率（トレーニング） = 0.13353333333333334
#                 : 370. 正答率（テスト） = 0.1395
# Generation: 380. 正答率（トレーニング） = 0.14751666666666666
#                 : 380. 正答率（テスト） = 0.1556
# Generation: 390. 正答率（トレーニング） = 0.13671666666666665
#                 : 390. 正答率（テスト） = 0.1429
# Generation: 400. 正答率（トレーニング） = 0.12595
#                 : 400. 正答率（テスト） = 0.1317
# Generation: 410. 正答率（トレーニング） = 0.12423333333333333
#                 : 410. 正答率（テスト） = 0.1287
# Generation: 420. 正答率（トレーニング） = 0.1242
#                 : 420. 正答率（テスト） = 0.1288
# Generation: 430. 正答率（トレーニング） = 0.1382
#                 : 430. 正答率（テスト） = 0.1445
# Generation: 440. 正答率（トレーニング） = 0.13925
#                 : 440. 正答率（テスト） = 0.1463
# Generation: 450. 正答率（トレーニング） = 0.16363333333333333
#                 : 450. 正答率（テスト） = 0.171
# Generation: 460. 正答率（トレーニング） = 0.17105
#                 : 460. 正答率（テスト） = 0.1777
# Generation: 470. 正答率（トレーニング） = 0.17218333333333333
#                 : 470. 正答率（テスト） = 0.1784
# Generation: 480. 正答率（トレーニング） = 0.16628333333333334
#                 : 480. 正答率（テスト） = 0.1733
# Generation: 490. 正答率（トレーニング） = 0.16713333333333333
#                 : 490. 正答率（テスト） = 0.1747
# Generation: 500. 正答率（トレーニング） = 0.16485
#                 : 500. 正答率（テスト） = 0.1733
# Generation: 510. 正答率（トレーニング） = 0.16863333333333333
#                 : 510. 正答率（テスト） = 0.1758
# Generation: 520. 正答率（トレーニング） = 0.17248333333333332
#                 : 520. 正答率（テスト） = 0.1804
# Generation: 530. 正答率（トレーニング） = 0.1594
#                 : 530. 正答率（テスト） = 0.1676
# Generation: 540. 正答率（トレーニング） = 0.17145
#                 : 540. 正答率（テスト） = 0.1793
# Generation: 550. 正答率（トレーニング） = 0.1745
#                 : 550. 正答率（テスト） = 0.1823
# Generation: 560. 正答率（トレーニング） = 0.15845
#                 : 560. 正答率（テスト） = 0.1656
# Generation: 570. 正答率（トレーニング） = 0.15611666666666665
#                 : 570. 正答率（テスト） = 0.1656
# Generation: 580. 正答率（トレーニング） = 0.1621
#                 : 580. 正答率（テスト） = 0.1719
# Generation: 590. 正答率（トレーニング） = 0.15865
#                 : 590. 正答率（テスト） = 0.1683
# Generation: 600. 正答率（トレーニング） = 0.17123333333333332
#                 : 600. 正答率（テスト） = 0.1789
# Generation: 610. 正答率（トレーニング） = 0.16545
#                 : 610. 正答率（テスト） = 0.1736
# Generation: 620. 正答率（トレーニング） = 0.15501666666666666
#                 : 620. 正答率（テスト） = 0.1649
# Generation: 630. 正答率（トレーニング） = 0.157
#                 : 630. 正答率（テスト） = 0.167
# Generation: 640. 正答率（トレーニング） = 0.16351666666666667
#                 : 640. 正答率（テスト） = 0.1725
# Generation: 650. 正答率（トレーニング） = 0.16925
#                 : 650. 正答率（テスト） = 0.1782
# Generation: 660. 正答率（トレーニング） = 0.16188333333333332
#                 : 660. 正答率（テスト） = 0.1708
# Generation: 670. 正答率（トレーニング） = 0.16781666666666667
#                 : 670. 正答率（テスト） = 0.1764
# Generation: 680. 正答率（トレーニング） = 0.17783333333333334
#                 : 680. 正答率（テスト） = 0.1848
# Generation: 690. 正答率（トレーニング） = 0.17875
#                 : 690. 正答率（テスト） = 0.1871
# Generation: 700. 正答率（トレーニング） = 0.18071666666666666
#                 : 700. 正答率（テスト） = 0.1888
# Generation: 710. 正答率（トレーニング） = 0.17728333333333332
#                 : 710. 正答率（テスト） = 0.1849
# Generation: 720. 正答率（トレーニング） = 0.1768
#                 : 720. 正答率（テスト） = 0.1863
# Generation: 730. 正答率（トレーニング） = 0.16261666666666666
#                 : 730. 正答率（テスト） = 0.1718
# Generation: 740. 正答率（トレーニング） = 0.1568
#                 : 740. 正答率（テスト） = 0.1672
# Generation: 750. 正答率（トレーニング） = 0.16141666666666668
#                 : 750. 正答率（テスト） = 0.1696
# Generation: 760. 正答率（トレーニング） = 0.17063333333333333
#                 : 760. 正答率（テスト） = 0.1796
# Generation: 770. 正答率（トレーニング） = 0.17315
#                 : 770. 正答率（テスト） = 0.1829
# Generation: 780. 正答率（トレーニング） = 0.1724
#                 : 780. 正答率（テスト） = 0.182
# Generation: 790. 正答率（トレーニング） = 0.19015
#                 : 790. 正答率（テスト） = 0.1992
# Generation: 800. 正答率（トレーニング） = 0.1818
#                 : 800. 正答率（テスト） = 0.1916
# Generation: 810. 正答率（トレーニング） = 0.18391666666666667
#                 : 810. 正答率（テスト） = 0.1938
# Generation: 820. 正答率（トレーニング） = 0.17923333333333333
#                 : 820. 正答率（テスト） = 0.1899
# Generation: 830. 正答率（トレーニング） = 0.18376666666666666
#                 : 830. 正答率（テスト） = 0.1945
# Generation: 840. 正答率（トレーニング） = 0.19095
#                 : 840. 正答率（テスト） = 0.2019
# Generation: 850. 正答率（トレーニング） = 0.18968333333333334
#                 : 850. 正答率（テスト） = 0.201
# Generation: 860. 正答率（トレーニング） = 0.20588333333333333
#                 : 860. 正答率（テスト） = 0.218
# Generation: 870. 正答率（トレーニング） = 0.19036666666666666
#                 : 870. 正答率（テスト） = 0.2003
# Generation: 880. 正答率（トレーニング） = 0.19458333333333333
#                 : 880. 正答率（テスト） = 0.2033
# Generation: 890. 正答率（トレーニング） = 0.2154
#                 : 890. 正答率（テスト） = 0.2221
# Generation: 900. 正答率（トレーニング） = 0.22291666666666668
#                 : 900. 正答率（テスト） = 0.2333
# Generation: 910. 正答率（トレーニング） = 0.22478333333333333
#                 : 910. 正答率（テスト） = 0.2332
# Generation: 920. 正答率（トレーニング） = 0.23753333333333335
#                 : 920. 正答率（テスト） = 0.2446
# Generation: 930. 正答率（トレーニング） = 0.2588
#                 : 930. 正答率（テスト） = 0.2605
# Generation: 940. 正答率（トレーニング） = 0.25025
#                 : 940. 正答率（テスト） = 0.253
# Generation: 950. 正答率（トレーニング） = 0.2590166666666667
#                 : 950. 正答率（テスト） = 0.2652
# Generation: 960. 正答率（トレーニング） = 0.276
#                 : 960. 正答率（テスト） = 0.2806
# Generation: 970. 正答率（トレーニング） = 0.2854833333333333
#                 : 970. 正答率（テスト） = 0.286
# Generation: 980. 正答率（トレーニング） = 0.25385
#                 : 980. 正答率（テスト） = 0.2559
# Generation: 990. 正答率（トレーニング） = 0.2367
#                 : 990. 正答率（テスト） = 0.2392
# Generation: 1000. 正答率（トレーニング） = 0.2331
#                 : 1000. 正答率（テスト） = 0.2368
# Generation: 1010. 正答率（トレーニング） = 0.23985
#                 : 1010. 正答率（テスト） = 0.2459
# Generation: 1020. 正答率（トレーニング） = 0.22878333333333334
#                 : 1020. 正答率（テスト） = 0.2349
# Generation: 1030. 正答率（トレーニング） = 0.22321666666666667
#                 : 1030. 正答率（テスト） = 0.2297
# Generation: 1040. 正答率（トレーニング） = 0.21453333333333333
#                 : 1040. 正答率（テスト） = 0.2211
# Generation: 1050. 正答率（トレーニング） = 0.21501666666666666
#                 : 1050. 正答率（テスト） = 0.222
# Generation: 1060. 正答率（トレーニング） = 0.23633333333333334
#                 : 1060. 正答率（テスト） = 0.2421
# Generation: 1070. 正答率（トレーニング） = 0.21926666666666667
#                 : 1070. 正答率（テスト） = 0.2267
# Generation: 1080. 正答率（トレーニング） = 0.21876666666666666
#                 : 1080. 正答率（テスト） = 0.2252
# Generation: 1090. 正答率（トレーニング） = 0.20733333333333334
#                 : 1090. 正答率（テスト） = 0.2159
# Generation: 1100. 正答率（トレーニング） = 0.19566666666666666
#                 : 1100. 正答率（テスト） = 0.2041
# Generation: 1110. 正答率（トレーニング） = 0.21165
#                 : 1110. 正答率（テスト） = 0.2209
# Generation: 1120. 正答率（トレーニング） = 0.22438333333333332
#                 : 1120. 正答率（テスト） = 0.2297
# Generation: 1130. 正答率（トレーニング） = 0.25405
#                 : 1130. 正答率（テスト） = 0.2576
# Generation: 1140. 正答率（トレーニング） = 0.26416666666666666
#                 : 1140. 正答率（テスト） = 0.2664
# Generation: 1150. 正答率（トレーニング） = 0.24513333333333334
#                 : 1150. 正答率（テスト） = 0.2468
# Generation: 1160. 正答率（トレーニング） = 0.25803333333333334
#                 : 1160. 正答率（テスト） = 0.2614
# Generation: 1170. 正答率（トレーニング） = 0.25375
#                 : 1170. 正答率（テスト） = 0.2551
# Generation: 1180. 正答率（トレーニング） = 0.24505
#                 : 1180. 正答率（テスト） = 0.2449
# Generation: 1190. 正答率（トレーニング） = 0.26821666666666666
#                 : 1190. 正答率（テスト） = 0.271
# Generation: 1200. 正答率（トレーニング） = 0.24188333333333334
#                 : 1200. 正答率（テスト） = 0.2453
# Generation: 1210. 正答率（トレーニング） = 0.2213
#                 : 1210. 正答率（テスト） = 0.2275
# Generation: 1220. 正答率（トレーニング） = 0.22436666666666666
#                 : 1220. 正答率（テスト） = 0.227
# Generation: 1230. 正答率（トレーニング） = 0.21851666666666666
#                 : 1230. 正答率（テスト） = 0.2188
# Generation: 1240. 正答率（トレーニング） = 0.21685
#                 : 1240. 正答率（テスト） = 0.2163
# Generation: 1250. 正答率（トレーニング） = 0.21575
#                 : 1250. 正答率（テスト） = 0.2132
# Generation: 1260. 正答率（トレーニング） = 0.22781666666666667
#                 : 1260. 正答率（テスト） = 0.2249
# Generation: 1270. 正答率（トレーニング） = 0.23731666666666668
#                 : 1270. 正答率（テスト） = 0.2339
# Generation: 1280. 正答率（トレーニング） = 0.24486666666666668
#                 : 1280. 正答率（テスト） = 0.2426
# Generation: 1290. 正答率（トレーニング） = 0.23948333333333333
#                 : 1290. 正答率（テスト） = 0.2391
# Generation: 1300. 正答率（トレーニング） = 0.23161666666666667
#                 : 1300. 正答率（テスト） = 0.232
# Generation: 1310. 正答率（トレーニング） = 0.2257
#                 : 1310. 正答率（テスト） = 0.227
# Generation: 1320. 正答率（トレーニング） = 0.22706666666666667
#                 : 1320. 正答率（テスト） = 0.23
# Generation: 1330. 正答率（トレーニング） = 0.23961666666666667
#                 : 1330. 正答率（テスト） = 0.2397
# Generation: 1340. 正答率（トレーニング） = 0.25255
#                 : 1340. 正答率（テスト） = 0.2538
# Generation: 1350. 正答率（トレーニング） = 0.25645
#                 : 1350. 正答率（テスト） = 0.2596
# Generation: 1360. 正答率（トレーニング） = 0.25303333333333333
#                 : 1360. 正答率（テスト） = 0.2562
# Generation: 1370. 正答率（トレーニング） = 0.26471666666666666
#                 : 1370. 正答率（テスト） = 0.2652
# Generation: 1380. 正答率（トレーニング） = 0.2673333333333333
#                 : 1380. 正答率（テスト） = 0.2678
# Generation: 1390. 正答率（トレーニング） = 0.2545
#                 : 1390. 正答率（テスト） = 0.2564
# Generation: 1400. 正答率（トレーニング） = 0.24331666666666665
#                 : 1400. 正答率（テスト） = 0.247
# Generation: 1410. 正答率（トレーニング） = 0.23486666666666667
#                 : 1410. 正答率（テスト） = 0.238
# Generation: 1420. 正答率（トレーニング） = 0.2415
#                 : 1420. 正答率（テスト） = 0.2447
# Generation: 1430. 正答率（トレーニング） = 0.24383333333333335
#                 : 1430. 正答率（テスト） = 0.2462
# Generation: 1440. 正答率（トレーニング） = 0.2398
#                 : 1440. 正答率（テスト） = 0.2432
# Generation: 1450. 正答率（トレーニング） = 0.23355
#                 : 1450. 正答率（テスト） = 0.2374
# Generation: 1460. 正答率（トレーニング） = 0.22276666666666667
#                 : 1460. 正答率（テスト） = 0.2263
# Generation: 1470. 正答率（トレーニング） = 0.23961666666666667
#                 : 1470. 正答率（テスト） = 0.2419
# Generation: 1480. 正答率（トレーニング） = 0.22963333333333333
#                 : 1480. 正答率（テスト） = 0.2297
# Generation: 1490. 正答率（トレーニング） = 0.24201666666666666
#                 : 1490. 正答率（テスト） = 0.2414
# Generation: 1500. 正答率（トレーニング） = 0.24826666666666666
#                 : 1500. 正答率（テスト） = 0.2479
# Generation: 1510. 正答率（トレーニング） = 0.2506
#                 : 1510. 正答率（テスト） = 0.2487
# Generation: 1520. 正答率（トレーニング） = 0.269
#                 : 1520. 正答率（テスト） = 0.2658
# Generation: 1530. 正答率（トレーニング） = 0.28818333333333335
#                 : 1530. 正答率（テスト） = 0.2868
# Generation: 1540. 正答率（トレーニング） = 0.30241666666666667
#                 : 1540. 正答率（テスト） = 0.2996
# Generation: 1550. 正答率（トレーニング） = 0.31471666666666664
#                 : 1550. 正答率（テスト） = 0.3101
# Generation: 1560. 正答率（トレーニング） = 0.33225
#                 : 1560. 正答率（テスト） = 0.3289
# Generation: 1570. 正答率（トレーニング） = 0.31315
#                 : 1570. 正答率（テスト） = 0.3116
# Generation: 1580. 正答率（トレーニング） = 0.29986666666666667
#                 : 1580. 正答率（テスト） = 0.2958
# Generation: 1590. 正答率（トレーニング） = 0.28691666666666665
#                 : 1590. 正答率（テスト） = 0.2849
# Generation: 1600. 正答率（トレーニング） = 0.29356666666666664
#                 : 1600. 正答率（テスト） = 0.2907
# Generation: 1610. 正答率（トレーニング） = 0.31235
#                 : 1610. 正答率（テスト） = 0.3103
# Generation: 1620. 正答率（トレーニング） = 0.31643333333333334
#                 : 1620. 正答率（テスト） = 0.3133
# Generation: 1630. 正答率（トレーニング） = 0.3342333333333333
#                 : 1630. 正答率（テスト） = 0.3315
# Generation: 1640. 正答率（トレーニング） = 0.33945
#                 : 1640. 正答率（テスト） = 0.3401
# Generation: 1650. 正答率（トレーニング） = 0.3581666666666667
#                 : 1650. 正答率（テスト） = 0.3577
# Generation: 1660. 正答率（トレーニング） = 0.37766666666666665
#                 : 1660. 正答率（テスト） = 0.3768
# Generation: 1670. 正答率（トレーニング） = 0.3989333333333333
#                 : 1670. 正答率（テスト） = 0.3982
# Generation: 1680. 正答率（トレーニング） = 0.4105
#                 : 1680. 正答率（テスト） = 0.4098
# Generation: 1690. 正答率（トレーニング） = 0.4030166666666667
#                 : 1690. 正答率（テスト） = 0.4015
# Generation: 1700. 正答率（トレーニング） = 0.3998833333333333
#                 : 1700. 正答率（テスト） = 0.3995
# Generation: 1710. 正答率（トレーニング） = 0.4260833333333333
#                 : 1710. 正答率（テスト） = 0.4227
# Generation: 1720. 正答率（トレーニング） = 0.4041666666666667
#                 : 1720. 正答率（テスト） = 0.4009
# Generation: 1730. 正答率（トレーニング） = 0.4149833333333333
#                 : 1730. 正答率（テスト） = 0.4138
# Generation: 1740. 正答率（トレーニング） = 0.4265833333333333
#                 : 1740. 正答率（テスト） = 0.4244
# Generation: 1750. 正答率（トレーニング） = 0.4266666666666667
#                 : 1750. 正答率（テスト） = 0.4219
# Generation: 1760. 正答率（トレーニング） = 0.39698333333333335
#                 : 1760. 正答率（テスト） = 0.3945
# Generation: 1770. 正答率（トレーニング） = 0.4042
#                 : 1770. 正答率（テスト） = 0.4029
# Generation: 1780. 正答率（トレーニング） = 0.41346666666666665
#                 : 1780. 正答率（テスト） = 0.4107
# Generation: 1790. 正答率（トレーニング） = 0.41323333333333334
#                 : 1790. 正答率（テスト） = 0.4103
# Generation: 1800. 正答率（トレーニング） = 0.38766666666666666
#                 : 1800. 正答率（テスト） = 0.386
# Generation: 1810. 正答率（トレーニング） = 0.3723166666666667
#                 : 1810. 正答率（テスト） = 0.3739
# Generation: 1820. 正答率（トレーニング） = 0.36948333333333333
#                 : 1820. 正答率（テスト） = 0.3722
# Generation: 1830. 正答率（トレーニング） = 0.3811833333333333
#                 : 1830. 正答率（テスト） = 0.3817
# Generation: 1840. 正答率（トレーニング） = 0.38233333333333336
#                 : 1840. 正答率（テスト） = 0.3809
# Generation: 1850. 正答率（トレーニング） = 0.35995
#                 : 1850. 正答率（テスト） = 0.3588
# Generation: 1860. 正答率（トレーニング） = 0.3374333333333333
#                 : 1860. 正答率（テスト） = 0.3373
# Generation: 1870. 正答率（トレーニング） = 0.32805
#                 : 1870. 正答率（テスト） = 0.3286
# Generation: 1880. 正答率（トレーニング） = 0.3381166666666667
#                 : 1880. 正答率（テスト） = 0.3402
# Generation: 1890. 正答率（トレーニング） = 0.34513333333333335
#                 : 1890. 正答率（テスト） = 0.3457
# Generation: 1900. 正答率（トレーニング） = 0.31798333333333334
#                 : 1900. 正答率（テスト） = 0.3177
# Generation: 1910. 正答率（トレーニング） = 0.3225166666666667
#                 : 1910. 正答率（テスト） = 0.3203
# Generation: 1920. 正答率（トレーニング） = 0.34978333333333333
#                 : 1920. 正答率（テスト） = 0.3487
# Generation: 1930. 正答率（トレーニング） = 0.32198333333333334
#                 : 1930. 正答率（テスト） = 0.32
# Generation: 1940. 正答率（トレーニング） = 0.32835
#                 : 1940. 正答率（テスト） = 0.3262
# Generation: 1950. 正答率（トレーニング） = 0.32358333333333333
#                 : 1950. 正答率（テスト） = 0.3228
# Generation: 1960. 正答率（トレーニング） = 0.33518333333333333
#                 : 1960. 正答率（テスト） = 0.3327
# Generation: 1970. 正答率（トレーニング） = 0.33098333333333335
#                 : 1970. 正答率（テスト） = 0.3277
# Generation: 1980. 正答率（トレーニング） = 0.32755
#                 : 1980. 正答率（テスト） = 0.3251
# Generation: 1990. 正答率（トレーニング） = 0.3594833333333333
#                 : 1990. 正答率（テスト） = 0.3549
# Generation: 2000. 正答率（トレーニング） = 0.3616333333333333
#                 : 2000. 正答率（テスト） = 0.3583

# %%
Tester3.plot_results()
plt.show()

# %%
Tester4 = VanishingGradientTest(activation = "relu", weight_init_std = "He" , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test)
Tester4.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.12945
#                 : 10. 正答率（テスト） = 0.1291
# Generation: 20. 正答率（トレーニング） = 0.12946666666666667
#                 : 20. 正答率（テスト） = 0.1294
# Generation: 30. 正答率（トレーニング） = 0.13725
#                 : 30. 正答率（テスト） = 0.1332
# Generation: 40. 正答率（トレーニング） = 0.1503
#                 : 40. 正答率（テスト） = 0.1458
# Generation: 50. 正答率（トレーニング） = 0.15963333333333332
#                 : 50. 正答率（テスト） = 0.1545
# Generation: 60. 正答率（トレーニング） = 0.17745
#                 : 60. 正答率（テスト） = 0.1732
# Generation: 70. 正答率（トレーニング） = 0.19816666666666666
#                 : 70. 正答率（テスト） = 0.1949
# Generation: 80. 正答率（トレーニング） = 0.22661666666666666
#                 : 80. 正答率（テスト） = 0.2202
# Generation: 90. 正答率（トレーニング） = 0.2531333333333333
#                 : 90. 正答率（テスト） = 0.2487
# Generation: 100. 正答率（トレーニング） = 0.29105
#                 : 100. 正答率（テスト） = 0.2881
# Generation: 110. 正答率（トレーニング） = 0.3188666666666667
#                 : 110. 正答率（テスト） = 0.3165
# Generation: 120. 正答率（トレーニング） = 0.3415
#                 : 120. 正答率（テスト） = 0.34
# Generation: 130. 正答率（トレーニング） = 0.3634
#                 : 130. 正答率（テスト） = 0.3619
# Generation: 140. 正答率（トレーニング） = 0.3993333333333333
#                 : 140. 正答率（テスト） = 0.3962
# Generation: 150. 正答率（トレーニング） = 0.42391666666666666
#                 : 150. 正答率（テスト） = 0.4198
# Generation: 160. 正答率（トレーニング） = 0.4437833333333333
#                 : 160. 正答率（テスト） = 0.4389
# Generation: 170. 正答率（トレーニング） = 0.44971666666666665
#                 : 170. 正答率（テスト） = 0.4433
# Generation: 180. 正答率（トレーニング） = 0.4716666666666667
#                 : 180. 正答率（テスト） = 0.4636
# Generation: 190. 正答率（トレーニング） = 0.48611666666666664
#                 : 190. 正答率（テスト） = 0.48
# Generation: 200. 正答率（トレーニング） = 0.49483333333333335
#                 : 200. 正答率（テスト） = 0.4877
# Generation: 210. 正答率（トレーニング） = 0.5068833333333334
#                 : 210. 正答率（テスト） = 0.5
# Generation: 220. 正答率（トレーニング） = 0.5314666666666666
#                 : 220. 正答率（テスト） = 0.5278
# Generation: 230. 正答率（トレーニング） = 0.5372666666666667
#                 : 230. 正答率（テスト） = 0.5335
# Generation: 240. 正答率（トレーニング） = 0.5525
#                 : 240. 正答率（テスト） = 0.5481
# Generation: 250. 正答率（トレーニング） = 0.5696
#                 : 250. 正答率（テスト） = 0.5659
# Generation: 260. 正答率（トレーニング） = 0.5836333333333333
#                 : 260. 正答率（テスト） = 0.5831
# Generation: 270. 正答率（トレーニング） = 0.5942
#                 : 270. 正答率（テスト） = 0.5911
# Generation: 280. 正答率（トレーニング） = 0.6127
#                 : 280. 正答率（テスト） = 0.61
# Generation: 290. 正答率（トレーニング） = 0.6214833333333334
#                 : 290. 正答率（テスト） = 0.621
# Generation: 300. 正答率（トレーニング） = 0.6390833333333333
#                 : 300. 正答率（テスト） = 0.6428
# Generation: 310. 正答率（トレーニング） = 0.64835
#                 : 310. 正答率（テスト） = 0.6516
# Generation: 320. 正答率（トレーニング） = 0.6608166666666667
#                 : 320. 正答率（テスト） = 0.6658
# Generation: 330. 正答率（トレーニング） = 0.6721
#                 : 330. 正答率（テスト） = 0.6776
# Generation: 340. 正答率（トレーニング） = 0.6933833333333334
#                 : 340. 正答率（テスト） = 0.6966
# Generation: 350. 正答率（トレーニング） = 0.70855
#                 : 350. 正答率（テスト） = 0.7126
# Generation: 360. 正答率（トレーニング） = 0.7170333333333333
#                 : 360. 正答率（テスト） = 0.7204
# Generation: 370. 正答率（トレーニング） = 0.7328166666666667
#                 : 370. 正答率（テスト） = 0.7391
# Generation: 380. 正答率（トレーニング） = 0.7451
#                 : 380. 正答率（テスト） = 0.7493
# Generation: 390. 正答率（トレーニング） = 0.7443166666666666
#                 : 390. 正答率（テスト） = 0.7494
# Generation: 400. 正答率（トレーニング） = 0.75435
#                 : 400. 正答率（テスト） = 0.7576
# Generation: 410. 正答率（トレーニング） = 0.7584166666666666
#                 : 410. 正答率（テスト） = 0.7613
# Generation: 420. 正答率（トレーニング） = 0.7652
#                 : 420. 正答率（テスト） = 0.7672
# Generation: 430. 正答率（トレーニング） = 0.76825
#                 : 430. 正答率（テスト） = 0.7734
# Generation: 440. 正答率（トレーニング） = 0.7713666666666666
#                 : 440. 正答率（テスト） = 0.7768
# Generation: 450. 正答率（トレーニング） = 0.7744666666666666
#                 : 450. 正答率（テスト） = 0.7789
# Generation: 460. 正答率（トレーニング） = 0.7813833333333333
#                 : 460. 正答率（テスト） = 0.7854
# Generation: 470. 正答率（トレーニング） = 0.7846833333333333
#                 : 470. 正答率（テスト） = 0.7885
# Generation: 480. 正答率（トレーニング） = 0.7900166666666667
#                 : 480. 正答率（テスト） = 0.7925
# Generation: 490. 正答率（トレーニング） = 0.79445
#                 : 490. 正答率（テスト） = 0.7975
# Generation: 500. 正答率（トレーニング） = 0.7963
#                 : 500. 正答率（テスト） = 0.8
# Generation: 510. 正答率（トレーニング） = 0.79935
#                 : 510. 正答率（テスト） = 0.8003
# Generation: 520. 正答率（トレーニング） = 0.8029
#                 : 520. 正答率（テスト） = 0.8049
# Generation: 530. 正答率（トレーニング） = 0.8062833333333334
#                 : 530. 正答率（テスト） = 0.8095
# Generation: 540. 正答率（トレーニング） = 0.8081833333333334
#                 : 540. 正答率（テスト） = 0.8123
# Generation: 550. 正答率（トレーニング） = 0.80825
#                 : 550. 正答率（テスト） = 0.8118
# Generation: 560. 正答率（トレーニング） = 0.8127666666666666
#                 : 560. 正答率（テスト） = 0.8155
# Generation: 570. 正答率（トレーニング） = 0.81255
#                 : 570. 正答率（テスト） = 0.8171
# Generation: 580. 正答率（トレーニング） = 0.8153333333333334
#                 : 580. 正答率（テスト） = 0.8202
# Generation: 590. 正答率（トレーニング） = 0.8181166666666667
#                 : 590. 正答率（テスト） = 0.8205
# Generation: 600. 正答率（トレーニング） = 0.82215
#                 : 600. 正答率（テスト） = 0.8249
# Generation: 610. 正答率（トレーニング） = 0.8242833333333334
#                 : 610. 正答率（テスト） = 0.827
# Generation: 620. 正答率（トレーニング） = 0.8239666666666666
#                 : 620. 正答率（テスト） = 0.8268
# Generation: 630. 正答率（トレーニング） = 0.82515
#                 : 630. 正答率（テスト） = 0.8291
# Generation: 640. 正答率（トレーニング） = 0.8248
#                 : 640. 正答率（テスト） = 0.8297
# Generation: 650. 正答率（トレーニング） = 0.8298333333333333
#                 : 650. 正答率（テスト） = 0.8335
# Generation: 660. 正答率（トレーニング） = 0.8324
#                 : 660. 正答率（テスト） = 0.8348
# Generation: 670. 正答率（トレーニング） = 0.8344166666666667
#                 : 670. 正答率（テスト） = 0.838
# Generation: 680. 正答率（トレーニング） = 0.8338166666666667
#                 : 680. 正答率（テスト） = 0.8379
# Generation: 690. 正答率（トレーニング） = 0.8379333333333333
#                 : 690. 正答率（テスト） = 0.8385
# Generation: 700. 正答率（トレーニング） = 0.8390833333333333
#                 : 700. 正答率（テスト） = 0.8422
# Generation: 710. 正答率（トレーニング） = 0.8399833333333333
#                 : 710. 正答率（テスト） = 0.8423
# Generation: 720. 正答率（トレーニング） = 0.8411833333333333
#                 : 720. 正答率（テスト） = 0.8432
# Generation: 730. 正答率（トレーニング） = 0.8428666666666667
#                 : 730. 正答率（テスト） = 0.8442
# Generation: 740. 正答率（トレーニング） = 0.8434
#                 : 740. 正答率（テスト） = 0.8467
# Generation: 750. 正答率（トレーニング） = 0.8442
#                 : 750. 正答率（テスト） = 0.8464
# Generation: 760. 正答率（トレーニング） = 0.8452166666666666
#                 : 760. 正答率（テスト） = 0.8479
# Generation: 770. 正答率（トレーニング） = 0.8471833333333333
#                 : 770. 正答率（テスト） = 0.8482
# Generation: 780. 正答率（トレーニング） = 0.8478166666666667
#                 : 780. 正答率（テスト） = 0.8511
# Generation: 790. 正答率（トレーニング） = 0.8485833333333334
#                 : 790. 正答率（テスト） = 0.8521
# Generation: 800. 正答率（トレーニング） = 0.8498833333333333
#                 : 800. 正答率（テスト） = 0.853
# Generation: 810. 正答率（トレーニング） = 0.8514
#                 : 810. 正答率（テスト） = 0.8548
# Generation: 820. 正答率（トレーニング） = 0.8481166666666666
#                 : 820. 正答率（テスト） = 0.8508
# Generation: 830. 正答率（トレーニング） = 0.8536666666666667
#                 : 830. 正答率（テスト） = 0.858
# Generation: 840. 正答率（トレーニング） = 0.8535833333333334
#                 : 840. 正答率（テスト） = 0.8568
# Generation: 850. 正答率（トレーニング） = 0.85455
#                 : 850. 正答率（テスト） = 0.8566
# Generation: 860. 正答率（トレーニング） = 0.8556833333333334
#                 : 860. 正答率（テスト） = 0.8584
# Generation: 870. 正答率（トレーニング） = 0.8564166666666667
#                 : 870. 正答率（テスト） = 0.8605
# Generation: 880. 正答率（トレーニング） = 0.8574
#                 : 880. 正答率（テスト） = 0.8608
# Generation: 890. 正答率（トレーニング） = 0.8584333333333334
#                 : 890. 正答率（テスト） = 0.8616
# Generation: 900. 正答率（トレーニング） = 0.8597333333333333
#                 : 900. 正答率（テスト） = 0.8625
# Generation: 910. 正答率（トレーニング） = 0.8580833333333333
#                 : 910. 正答率（テスト） = 0.8612
# Generation: 920. 正答率（トレーニング） = 0.8600166666666667
#                 : 920. 正答率（テスト） = 0.8631
# Generation: 930. 正答率（トレーニング） = 0.8621833333333333
#                 : 930. 正答率（テスト） = 0.8649
# Generation: 940. 正答率（トレーニング） = 0.8629666666666667
#                 : 940. 正答率（テスト） = 0.8661
# Generation: 950. 正答率（トレーニング） = 0.86305
#                 : 950. 正答率（テスト） = 0.8664
# Generation: 960. 正答率（トレーニング） = 0.86485
#                 : 960. 正答率（テスト） = 0.8676
# Generation: 970. 正答率（トレーニング） = 0.8644
#                 : 970. 正答率（テスト） = 0.8684
# Generation: 980. 正答率（トレーニング） = 0.8664166666666666
#                 : 980. 正答率（テスト） = 0.869
# Generation: 990. 正答率（トレーニング） = 0.8667
#                 : 990. 正答率（テスト） = 0.8702
# Generation: 1000. 正答率（トレーニング） = 0.8678
#                 : 1000. 正答率（テスト） = 0.8705
# Generation: 1010. 正答率（トレーニング） = 0.86805
#                 : 1010. 正答率（テスト） = 0.8711
# Generation: 1020. 正答率（トレーニング） = 0.8686
#                 : 1020. 正答率（テスト） = 0.872
# Generation: 1030. 正答率（トレーニング） = 0.8703666666666666
#                 : 1030. 正答率（テスト） = 0.8739
# Generation: 1040. 正答率（トレーニング） = 0.8711666666666666
#                 : 1040. 正答率（テスト） = 0.8723
# Generation: 1050. 正答率（トレーニング） = 0.87045
#                 : 1050. 正答率（テスト） = 0.8743
# Generation: 1060. 正答率（トレーニング） = 0.8716666666666667
#                 : 1060. 正答率（テスト） = 0.8733
# Generation: 1070. 正答率（トレーニング） = 0.87185
#                 : 1070. 正答率（テスト） = 0.876
# Generation: 1080. 正答率（トレーニング） = 0.8732666666666666
#                 : 1080. 正答率（テスト） = 0.8762
# Generation: 1090. 正答率（トレーニング） = 0.8743
#                 : 1090. 正答率（テスト） = 0.8777
# Generation: 1100. 正答率（トレーニング） = 0.8744666666666666
#                 : 1100. 正答率（テスト） = 0.8781
# Generation: 1110. 正答率（トレーニング） = 0.8735
#                 : 1110. 正答率（テスト） = 0.8787
# Generation: 1120. 正答率（トレーニング） = 0.8750666666666667
#                 : 1120. 正答率（テスト） = 0.8794
# Generation: 1130. 正答率（トレーニング） = 0.8752333333333333
#                 : 1130. 正答率（テスト） = 0.8799
# Generation: 1140. 正答率（トレーニング） = 0.8760166666666667
#                 : 1140. 正答率（テスト） = 0.8808
# Generation: 1150. 正答率（トレーニング） = 0.8762
#                 : 1150. 正答率（テスト） = 0.8797
# Generation: 1160. 正答率（トレーニング） = 0.87565
#                 : 1160. 正答率（テスト） = 0.8803
# Generation: 1170. 正答率（トレーニング） = 0.8772666666666666
#                 : 1170. 正答率（テスト） = 0.8819
# Generation: 1180. 正答率（トレーニング） = 0.8783
#                 : 1180. 正答率（テスト） = 0.8833
# Generation: 1190. 正答率（トレーニング） = 0.8785166666666666
#                 : 1190. 正答率（テスト） = 0.8832
# Generation: 1200. 正答率（トレーニング） = 0.8777333333333334
#                 : 1200. 正答率（テスト） = 0.8828
# Generation: 1210. 正答率（トレーニング） = 0.8792166666666666
#                 : 1210. 正答率（テスト） = 0.8835
# Generation: 1220. 正答率（トレーニング） = 0.8790833333333333
#                 : 1220. 正答率（テスト） = 0.8842
# Generation: 1230. 正答率（トレーニング） = 0.8797666666666667
#                 : 1230. 正答率（テスト） = 0.8839
# Generation: 1240. 正答率（トレーニング） = 0.87975
#                 : 1240. 正答率（テスト） = 0.8853
# Generation: 1250. 正答率（トレーニング） = 0.8805666666666667
#                 : 1250. 正答率（テスト） = 0.8864
# Generation: 1260. 正答率（トレーニング） = 0.8805333333333333
#                 : 1260. 正答率（テスト） = 0.8873
# Generation: 1270. 正答率（トレーニング） = 0.8822666666666666
#                 : 1270. 正答率（テスト） = 0.8864
# Generation: 1280. 正答率（トレーニング） = 0.8820833333333333
#                 : 1280. 正答率（テスト） = 0.8863
# Generation: 1290. 正答率（トレーニング） = 0.8817
#                 : 1290. 正答率（テスト） = 0.8875
# Generation: 1300. 正答率（トレーニング） = 0.88225
#                 : 1300. 正答率（テスト） = 0.8872
# Generation: 1310. 正答率（トレーニング） = 0.8830666666666667
#                 : 1310. 正答率（テスト） = 0.8879
# Generation: 1320. 正答率（トレーニング） = 0.8843166666666666
#                 : 1320. 正答率（テスト） = 0.889
# Generation: 1330. 正答率（トレーニング） = 0.8839
#                 : 1330. 正答率（テスト） = 0.8878
# Generation: 1340. 正答率（トレーニング） = 0.8844166666666666
#                 : 1340. 正答率（テスト） = 0.8893
# Generation: 1350. 正答率（トレーニング） = 0.8843166666666666
#                 : 1350. 正答率（テスト） = 0.8896
# Generation: 1360. 正答率（トレーニング） = 0.8851
#                 : 1360. 正答率（テスト） = 0.8899
# Generation: 1370. 正答率（トレーニング） = 0.88555
#                 : 1370. 正答率（テスト） = 0.8899
# Generation: 1380. 正答率（トレーニング） = 0.8852333333333333
#                 : 1380. 正答率（テスト） = 0.8908
# Generation: 1390. 正答率（トレーニング） = 0.8857
#                 : 1390. 正答率（テスト） = 0.8907
# Generation: 1400. 正答率（トレーニング） = 0.8858166666666667
#                 : 1400. 正答率（テスト） = 0.891
# Generation: 1410. 正答率（トレーニング） = 0.8867
#                 : 1410. 正答率（テスト） = 0.8914
# Generation: 1420. 正答率（トレーニング） = 0.8862666666666666
#                 : 1420. 正答率（テスト） = 0.8911
# Generation: 1430. 正答率（トレーニング） = 0.88725
#                 : 1430. 正答率（テスト） = 0.8929
# Generation: 1440. 正答率（トレーニング） = 0.8883166666666666
#                 : 1440. 正答率（テスト） = 0.892
# Generation: 1450. 正答率（トレーニング） = 0.8880666666666667
#                 : 1450. 正答率（テスト） = 0.8929
# Generation: 1460. 正答率（トレーニング） = 0.88745
#                 : 1460. 正答率（テスト） = 0.8924
# Generation: 1470. 正答率（トレーニング） = 0.88825
#                 : 1470. 正答率（テスト） = 0.8916
# Generation: 1480. 正答率（トレーニング） = 0.8887833333333334
#                 : 1480. 正答率（テスト） = 0.8919
# Generation: 1490. 正答率（トレーニング） = 0.8869666666666667
#                 : 1490. 正答率（テスト） = 0.8919
# Generation: 1500. 正答率（トレーニング） = 0.88955
#                 : 1500. 正答率（テスト） = 0.8949
# Generation: 1510. 正答率（トレーニング） = 0.8901833333333333
#                 : 1510. 正答率（テスト） = 0.8955
# Generation: 1520. 正答率（トレーニング） = 0.89065
#                 : 1520. 正答率（テスト） = 0.8958
# Generation: 1530. 正答率（トレーニング） = 0.89055
#                 : 1530. 正答率（テスト） = 0.895
# Generation: 1540. 正答率（トレーニング） = 0.8903166666666666
#                 : 1540. 正答率（テスト） = 0.8939
# Generation: 1550. 正答率（トレーニング） = 0.8893833333333333
#                 : 1550. 正答率（テスト） = 0.8946
# Generation: 1560. 正答率（トレーニング） = 0.8906333333333334
#                 : 1560. 正答率（テスト） = 0.8953
# Generation: 1570. 正答率（トレーニング） = 0.8916833333333334
#                 : 1570. 正答率（テスト） = 0.8963
# Generation: 1580. 正答率（トレーニング） = 0.8917833333333334
#                 : 1580. 正答率（テスト） = 0.8959
# Generation: 1590. 正答率（トレーニング） = 0.89225
#                 : 1590. 正答率（テスト） = 0.8961
# Generation: 1600. 正答率（トレーニング） = 0.8928666666666667
#                 : 1600. 正答率（テスト） = 0.8968
# Generation: 1610. 正答率（トレーニング） = 0.8917833333333334
#                 : 1610. 正答率（テスト） = 0.896
# Generation: 1620. 正答率（トレーニング） = 0.893
#                 : 1620. 正答率（テスト） = 0.8979
# Generation: 1630. 正答率（トレーニング） = 0.8929166666666667
#                 : 1630. 正答率（テスト） = 0.8984
# Generation: 1640. 正答率（トレーニング） = 0.8929833333333334
#                 : 1640. 正答率（テスト） = 0.8983
# Generation: 1650. 正答率（トレーニング） = 0.8925
#                 : 1650. 正答率（テスト） = 0.8976
# Generation: 1660. 正答率（トレーニング） = 0.89345
#                 : 1660. 正答率（テスト） = 0.8987
# Generation: 1670. 正答率（トレーニング） = 0.8929333333333334
#                 : 1670. 正答率（テスト） = 0.8993
# Generation: 1680. 正答率（トレーニング） = 0.8941333333333333
#                 : 1680. 正答率（テスト） = 0.8989
# Generation: 1690. 正答率（トレーニング） = 0.895
#                 : 1690. 正答率（テスト） = 0.9001
# Generation: 1700. 正答率（トレーニング） = 0.8945666666666666
#                 : 1700. 正答率（テスト） = 0.8995
# Generation: 1710. 正答率（トレーニング） = 0.8947
#                 : 1710. 正答率（テスト） = 0.899
# Generation: 1720. 正答率（トレーニング） = 0.8956
#                 : 1720. 正答率（テスト） = 0.8992
# Generation: 1730. 正答率（トレーニング） = 0.89605
#                 : 1730. 正答率（テスト） = 0.9005
# Generation: 1740. 正答率（トレーニング） = 0.8952
#                 : 1740. 正答率（テスト） = 0.8994
# Generation: 1750. 正答率（トレーニング） = 0.8964333333333333
#                 : 1750. 正答率（テスト） = 0.9003
# Generation: 1760. 正答率（トレーニング） = 0.8962833333333333
#                 : 1760. 正答率（テスト） = 0.9003
# Generation: 1770. 正答率（トレーニング） = 0.8970666666666667
#                 : 1770. 正答率（テスト） = 0.9008
# Generation: 1780. 正答率（トレーニング） = 0.8977666666666667
#                 : 1780. 正答率（テスト） = 0.9005
# Generation: 1790. 正答率（トレーニング） = 0.89755
#                 : 1790. 正答率（テスト） = 0.9007
# Generation: 1800. 正答率（トレーニング） = 0.8980166666666667
#                 : 1800. 正答率（テスト） = 0.9009
# Generation: 1810. 正答率（トレーニング） = 0.8975166666666666
#                 : 1810. 正答率（テスト） = 0.9006
# Generation: 1820. 正答率（トレーニング） = 0.89735
#                 : 1820. 正答率（テスト） = 0.9001
# Generation: 1830. 正答率（トレーニング） = 0.8981
#                 : 1830. 正答率（テスト） = 0.9025
# Generation: 1840. 正答率（トレーニング） = 0.8984833333333333
#                 : 1840. 正答率（テスト） = 0.9004
# Generation: 1850. 正答率（トレーニング） = 0.8987666666666667
#                 : 1850. 正答率（テスト） = 0.9029
# Generation: 1860. 正答率（トレーニング） = 0.8969333333333334
#                 : 1860. 正答率（テスト） = 0.9024
# Generation: 1870. 正答率（トレーニング） = 0.8988833333333334
#                 : 1870. 正答率（テスト） = 0.9024
# Generation: 1880. 正答率（トレーニング） = 0.8985666666666666
#                 : 1880. 正答率（テスト） = 0.9029
# Generation: 1890. 正答率（トレーニング） = 0.89855
#                 : 1890. 正答率（テスト） = 0.9037
# Generation: 1900. 正答率（トレーニング） = 0.8994
#                 : 1900. 正答率（テスト） = 0.9026
# Generation: 1910. 正答率（トレーニング） = 0.8991833333333333
#                 : 1910. 正答率（テスト） = 0.9027
# Generation: 1920. 正答率（トレーニング） = 0.9003666666666666
#                 : 1920. 正答率（テスト） = 0.9031
# Generation: 1930. 正答率（トレーニング） = 0.90065
#                 : 1930. 正答率（テスト） = 0.9038
# Generation: 1940. 正答率（トレーニング） = 0.8994166666666666
#                 : 1940. 正答率（テスト） = 0.9038
# Generation: 1950. 正答率（トレーニング） = 0.9000833333333333
#                 : 1950. 正答率（テスト） = 0.9035
# Generation: 1960. 正答率（トレーニング） = 0.9009333333333334
#                 : 1960. 正答率（テスト） = 0.903
# Generation: 1970. 正答率（トレーニング） = 0.9005
#                 : 1970. 正答率（テスト） = 0.9041
# Generation: 1980. 正答率（トレーニング） = 0.9019
#                 : 1980. 正答率（テスト） = 0.905
# Generation: 1990. 正答率（トレーニング） = 0.9014833333333333
#                 : 1990. 正答率（テスト） = 0.9042
# Generation: 2000. 正答率（トレーニング） = 0.9026666666666666
#                 : 2000. 正答率（テスト） = 0.9048

# %%
Tester4.plot_results()
plt.show()

# %% [markdown]
# 試しに、sigmoid & He 、relu & Xavier　を試すと、下のようになる。

# %%
Tester11 = VanishingGradientTest(activation = "sigmoid", weight_init_std = "He" , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test)
Tester11.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.0993
#                 : 10. 正答率（テスト） = 0.1032
# Generation: 20. 正答率（トレーニング） = 0.0993
#                 : 20. 正答率（テスト） = 0.1032
# Generation: 30. 正答率（トレーニング） = 0.0993
#                 : 30. 正答率（テスト） = 0.1032
# Generation: 40. 正答率（トレーニング） = 0.0993
#                 : 40. 正答率（テスト） = 0.1032
# Generation: 50. 正答率（トレーニング） = 0.0993
#                 : 50. 正答率（テスト） = 0.1032
# Generation: 60. 正答率（トレーニング） = 0.0993
#                 : 60. 正答率（テスト） = 0.1032
# Generation: 70. 正答率（トレーニング） = 0.0993
#                 : 70. 正答率（テスト） = 0.1032
# Generation: 80. 正答率（トレーニング） = 0.0993
#                 : 80. 正答率（テスト） = 0.1032
# Generation: 90. 正答率（トレーニング） = 0.0993
#                 : 90. 正答率（テスト） = 0.1032
# Generation: 100. 正答率（トレーニング） = 0.0993
#                 : 100. 正答率（テスト） = 0.1032
# Generation: 110. 正答率（トレーニング） = 0.0993
#                 : 110. 正答率（テスト） = 0.1032
# Generation: 120. 正答率（トレーニング） = 0.0993
#                 : 120. 正答率（テスト） = 0.1032
# Generation: 130. 正答率（トレーニング） = 0.09926666666666667
#                 : 130. 正答率（テスト） = 0.1032
# Generation: 140. 正答率（トレーニング） = 0.09926666666666667
#                 : 140. 正答率（テスト） = 0.1032
# Generation: 150. 正答率（トレーニング） = 0.0994
#                 : 150. 正答率（テスト） = 0.1033
# Generation: 160. 正答率（トレーニング） = 0.0984
#                 : 160. 正答率（テスト） = 0.1017
# Generation: 170. 正答率（トレーニング） = 0.0989
#                 : 170. 正答率（テスト） = 0.1022
# Generation: 180. 正答率（トレーニング） = 0.09856666666666666
#                 : 180. 正答率（テスト） = 0.1028
# Generation: 190. 正答率（トレーニング） = 0.0967
#                 : 190. 正答率（テスト） = 0.0994
# Generation: 200. 正答率（トレーニング） = 0.09573333333333334
#                 : 200. 正答率（テスト） = 0.1008
# Generation: 210. 正答率（トレーニング） = 0.0981
#                 : 210. 正答率（テスト） = 0.1028
# Generation: 220. 正答率（トレーニング） = 0.09978333333333333
#                 : 220. 正答率（テスト） = 0.1039
# Generation: 230. 正答率（トレーニング） = 0.10606666666666667
#                 : 230. 正答率（テスト） = 0.1108
# Generation: 240. 正答率（トレーニング） = 0.107
#                 : 240. 正答率（テスト） = 0.1095
# Generation: 250. 正答率（トレーニング） = 0.12011666666666666
#                 : 250. 正答率（テスト） = 0.1234
# Generation: 260. 正答率（トレーニング） = 0.13756666666666667
#                 : 260. 正答率（テスト） = 0.1408
# Generation: 270. 正答率（トレーニング） = 0.15946666666666667
#                 : 270. 正答率（テスト） = 0.1623
# Generation: 280. 正答率（トレーニング） = 0.22056666666666666
#                 : 280. 正答率（テスト） = 0.2227
# Generation: 290. 正答率（トレーニング） = 0.24668333333333334
#                 : 290. 正答率（テスト） = 0.2476
# Generation: 300. 正答率（トレーニング） = 0.2523666666666667
#                 : 300. 正答率（テスト） = 0.2519
# Generation: 310. 正答率（トレーニング） = 0.25926666666666665
#                 : 310. 正答率（テスト） = 0.2584
# Generation: 320. 正答率（トレーニング） = 0.2668
#                 : 320. 正答率（テスト） = 0.2656
# Generation: 330. 正答率（トレーニング） = 0.27086666666666664
#                 : 330. 正答率（テスト） = 0.2699
# Generation: 340. 正答率（トレーニング） = 0.28185
#                 : 340. 正答率（テスト） = 0.2813
# Generation: 350. 正答率（トレーニング） = 0.283
#                 : 350. 正答率（テスト） = 0.2804
# Generation: 360. 正答率（トレーニング） = 0.27625
#                 : 360. 正答率（テスト） = 0.2732
# Generation: 370. 正答率（トレーニング） = 0.2828333333333333
#                 : 370. 正答率（テスト） = 0.28
# Generation: 380. 正答率（トレーニング） = 0.2897166666666667
#                 : 380. 正答率（テスト） = 0.287
# Generation: 390. 正答率（トレーニング） = 0.2982666666666667
#                 : 390. 正答率（テスト） = 0.2947
# Generation: 400. 正答率（トレーニング） = 0.30288333333333334
#                 : 400. 正答率（テスト） = 0.305
# Generation: 410. 正答率（トレーニング） = 0.31603333333333333
#                 : 410. 正答率（テスト） = 0.3186
# Generation: 420. 正答率（トレーニング） = 0.31871666666666665
#                 : 420. 正答率（テスト） = 0.3187
# Generation: 430. 正答率（トレーニング） = 0.31335
#                 : 430. 正答率（テスト） = 0.3154
# Generation: 440. 正答率（トレーニング） = 0.3202833333333333
#                 : 440. 正答率（テスト） = 0.3213
# Generation: 450. 正答率（トレーニング） = 0.3364333333333333
#                 : 450. 正答率（テスト） = 0.3406
# Generation: 460. 正答率（トレーニング） = 0.336
#                 : 460. 正答率（テスト） = 0.3386
# Generation: 470. 正答率（トレーニング） = 0.3600833333333333
#                 : 470. 正答率（テスト） = 0.3598
# Generation: 480. 正答率（トレーニング） = 0.36406666666666665
#                 : 480. 正答率（テスト） = 0.3662
# Generation: 490. 正答率（トレーニング） = 0.36206666666666665
#                 : 490. 正答率（テスト） = 0.3665
# Generation: 500. 正答率（トレーニング） = 0.3574833333333333
#                 : 500. 正答率（テスト） = 0.3589
# Generation: 510. 正答率（トレーニング） = 0.3574333333333333
#                 : 510. 正答率（テスト） = 0.3594
# Generation: 520. 正答率（トレーニング） = 0.3682666666666667
#                 : 520. 正答率（テスト） = 0.3711
# Generation: 530. 正答率（トレーニング） = 0.3758666666666667
#                 : 530. 正答率（テスト） = 0.3763
# Generation: 540. 正答率（トレーニング） = 0.3657166666666667
#                 : 540. 正答率（テスト） = 0.3669
# Generation: 550. 正答率（トレーニング） = 0.38085
#                 : 550. 正答率（テスト） = 0.3837
# Generation: 560. 正答率（トレーニング） = 0.3753
#                 : 560. 正答率（テスト） = 0.3777
# Generation: 570. 正答率（トレーニング） = 0.39581666666666665
#                 : 570. 正答率（テスト） = 0.4007
# Generation: 580. 正答率（トレーニング） = 0.3765833333333333
#                 : 580. 正答率（テスト） = 0.3823
# Generation: 590. 正答率（トレーニング） = 0.35325
#                 : 590. 正答率（テスト） = 0.359
# Generation: 600. 正答率（トレーニング） = 0.3708
#                 : 600. 正答率（テスト） = 0.3777
# Generation: 610. 正答率（トレーニング） = 0.3711
#                 : 610. 正答率（テスト） = 0.3774
# Generation: 620. 正答率（トレーニング） = 0.37651666666666667
#                 : 620. 正答率（テスト） = 0.385
# Generation: 630. 正答率（トレーニング） = 0.37185
#                 : 630. 正答率（テスト） = 0.3813
# Generation: 640. 正答率（トレーニング） = 0.37146666666666667
#                 : 640. 正答率（テスト） = 0.3805
# Generation: 650. 正答率（トレーニング） = 0.36546666666666666
#                 : 650. 正答率（テスト） = 0.374
# Generation: 660. 正答率（トレーニング） = 0.3708166666666667
#                 : 660. 正答率（テスト） = 0.3822
# Generation: 670. 正答率（トレーニング） = 0.3612
#                 : 670. 正答率（テスト） = 0.3706
# Generation: 680. 正答率（トレーニング） = 0.34773333333333334
#                 : 680. 正答率（テスト） = 0.3558
# Generation: 690. 正答率（トレーニング） = 0.33658333333333335
#                 : 690. 正答率（テスト） = 0.3453
# Generation: 700. 正答率（トレーニング） = 0.34271666666666667
#                 : 700. 正答率（テスト） = 0.3512
# Generation: 710. 正答率（トレーニング） = 0.3425166666666667
#                 : 710. 正答率（テスト） = 0.352
# Generation: 720. 正答率（トレーニング） = 0.3619
#                 : 720. 正答率（テスト） = 0.3692
# Generation: 730. 正答率（トレーニング） = 0.35965
#                 : 730. 正答率（テスト） = 0.3682
# Generation: 740. 正答率（トレーニング） = 0.36106666666666665
#                 : 740. 正答率（テスト） = 0.3686
# Generation: 750. 正答率（トレーニング） = 0.36178333333333335
#                 : 750. 正答率（テスト） = 0.369
# Generation: 760. 正答率（トレーニング） = 0.3621666666666667
#                 : 760. 正答率（テスト） = 0.3676
# Generation: 770. 正答率（トレーニング） = 0.36006666666666665
#                 : 770. 正答率（テスト） = 0.3661
# Generation: 780. 正答率（トレーニング） = 0.38201666666666667
#                 : 780. 正答率（テスト） = 0.3889
# Generation: 790. 正答率（トレーニング） = 0.39448333333333335
#                 : 790. 正答率（テスト） = 0.4025
# Generation: 800. 正答率（トレーニング） = 0.38895
#                 : 800. 正答率（テスト） = 0.3962
# Generation: 810. 正答率（トレーニング） = 0.38745
#                 : 810. 正答率（テスト） = 0.3959
# Generation: 820. 正答率（トレーニング） = 0.4033333333333333
#                 : 820. 正答率（テスト） = 0.4086
# Generation: 830. 正答率（トレーニング） = 0.4260833333333333
#                 : 830. 正答率（テスト） = 0.4316
# Generation: 840. 正答率（トレーニング） = 0.41931666666666667
#                 : 840. 正答率（テスト） = 0.4293
# Generation: 850. 正答率（トレーニング） = 0.43023333333333336
#                 : 850. 正答率（テスト） = 0.4368
# Generation: 860. 正答率（トレーニング） = 0.42685
#                 : 860. 正答率（テスト） = 0.4321
# Generation: 870. 正答率（トレーニング） = 0.44021666666666665
#                 : 870. 正答率（テスト） = 0.4481
# Generation: 880. 正答率（トレーニング） = 0.41975
#                 : 880. 正答率（テスト） = 0.4251
# Generation: 890. 正答率（トレーニング） = 0.4186166666666667
#                 : 890. 正答率（テスト） = 0.429
# Generation: 900. 正答率（トレーニング） = 0.4305333333333333
#                 : 900. 正答率（テスト） = 0.4405
# Generation: 910. 正答率（トレーニング） = 0.42966666666666664
#                 : 910. 正答率（テスト） = 0.4383
# Generation: 920. 正答率（トレーニング） = 0.43528333333333336
#                 : 920. 正答率（テスト） = 0.4455
# Generation: 930. 正答率（トレーニング） = 0.45316666666666666
#                 : 930. 正答率（テスト） = 0.4609
# Generation: 940. 正答率（トレーニング） = 0.43788333333333335
#                 : 940. 正答率（テスト） = 0.4455
# Generation: 950. 正答率（トレーニング） = 0.43385
#                 : 950. 正答率（テスト） = 0.4415
# Generation: 960. 正答率（トレーニング） = 0.4347666666666667
#                 : 960. 正答率（テスト） = 0.4452
# Generation: 970. 正答率（トレーニング） = 0.4578
#                 : 970. 正答率（テスト） = 0.4652
# Generation: 980. 正答率（トレーニング） = 0.44876666666666665
#                 : 980. 正答率（テスト） = 0.4559
# Generation: 990. 正答率（トレーニング） = 0.4496
#                 : 990. 正答率（テスト） = 0.455
# Generation: 1000. 正答率（トレーニング） = 0.46703333333333336
#                 : 1000. 正答率（テスト） = 0.4751
# Generation: 1010. 正答率（トレーニング） = 0.45793333333333336
#                 : 1010. 正答率（テスト） = 0.4687
# Generation: 1020. 正答率（トレーニング） = 0.4400833333333333
#                 : 1020. 正答率（テスト） = 0.4482
# Generation: 1030. 正答率（トレーニング） = 0.45365
#                 : 1030. 正答率（テスト） = 0.4628
# Generation: 1040. 正答率（トレーニング） = 0.4452333333333333
#                 : 1040. 正答率（テスト） = 0.4519
# Generation: 1050. 正答率（トレーニング） = 0.45098333333333335
#                 : 1050. 正答率（テスト） = 0.459
# Generation: 1060. 正答率（トレーニング） = 0.44266666666666665
#                 : 1060. 正答率（テスト） = 0.4496
# Generation: 1070. 正答率（トレーニング） = 0.45381666666666665
#                 : 1070. 正答率（テスト） = 0.4608
# Generation: 1080. 正答率（トレーニング） = 0.4271
#                 : 1080. 正答率（テスト） = 0.4336
# Generation: 1090. 正答率（トレーニング） = 0.4157666666666667
#                 : 1090. 正答率（テスト） = 0.4199
# Generation: 1100. 正答率（トレーニング） = 0.41738333333333333
#                 : 1100. 正答率（テスト） = 0.4216
# Generation: 1110. 正答率（トレーニング） = 0.42665
#                 : 1110. 正答率（テスト） = 0.4312
# Generation: 1120. 正答率（トレーニング） = 0.41935
#                 : 1120. 正答率（テスト） = 0.4238
# Generation: 1130. 正答率（トレーニング） = 0.4294
#                 : 1130. 正答率（テスト） = 0.4349
# Generation: 1140. 正答率（トレーニング） = 0.42843333333333333
#                 : 1140. 正答率（テスト） = 0.4346
# Generation: 1150. 正答率（トレーニング） = 0.4264833333333333
#                 : 1150. 正答率（テスト） = 0.4318
# Generation: 1160. 正答率（トレーニング） = 0.4237
#                 : 1160. 正答率（テスト） = 0.4282
# Generation: 1170. 正答率（トレーニング） = 0.4132
#                 : 1170. 正答率（テスト） = 0.4195
# Generation: 1180. 正答率（トレーニング） = 0.42005
#                 : 1180. 正答率（テスト） = 0.4265
# Generation: 1190. 正答率（トレーニング） = 0.41481666666666667
#                 : 1190. 正答率（テスト） = 0.4209
# Generation: 1200. 正答率（トレーニング） = 0.4011166666666667
#                 : 1200. 正答率（テスト） = 0.4077
# Generation: 1210. 正答率（トレーニング） = 0.41141666666666665
#                 : 1210. 正答率（テスト） = 0.4168
# Generation: 1220. 正答率（トレーニング） = 0.41265
#                 : 1220. 正答率（テスト） = 0.4178
# Generation: 1230. 正答率（トレーニング） = 0.43266666666666664
#                 : 1230. 正答率（テスト） = 0.4353
# Generation: 1240. 正答率（トレーニング） = 0.45313333333333333
#                 : 1240. 正答率（テスト） = 0.4557
# Generation: 1250. 正答率（トレーニング） = 0.45918333333333333
#                 : 1250. 正答率（テスト） = 0.4625
# Generation: 1260. 正答率（トレーニング） = 0.46563333333333334
#                 : 1260. 正答率（テスト） = 0.4708
# Generation: 1270. 正答率（トレーニング） = 0.46326666666666666
#                 : 1270. 正答率（テスト） = 0.4691
# Generation: 1280. 正答率（トレーニング） = 0.4683333333333333
#                 : 1280. 正答率（テスト） = 0.4739
# Generation: 1290. 正答率（トレーニング） = 0.4727
#                 : 1290. 正答率（テスト） = 0.4826
# Generation: 1300. 正答率（トレーニング） = 0.47695
#                 : 1300. 正答率（テスト） = 0.4852
# Generation: 1310. 正答率（トレーニング） = 0.46295
#                 : 1310. 正答率（テスト） = 0.4713
# Generation: 1320. 正答率（トレーニング） = 0.4725666666666667
#                 : 1320. 正答率（テスト） = 0.4805
# Generation: 1330. 正答率（トレーニング） = 0.4563333333333333
#                 : 1330. 正答率（テスト） = 0.4647
# Generation: 1340. 正答率（トレーニング） = 0.45463333333333333
#                 : 1340. 正答率（テスト） = 0.4611
# Generation: 1350. 正答率（トレーニング） = 0.4634666666666667
#                 : 1350. 正答率（テスト） = 0.4702
# Generation: 1360. 正答率（トレーニング） = 0.46403333333333335
#                 : 1360. 正答率（テスト） = 0.4733
# Generation: 1370. 正答率（トレーニング） = 0.46166666666666667
#                 : 1370. 正答率（テスト） = 0.4683
# Generation: 1380. 正答率（トレーニング） = 0.46475
#                 : 1380. 正答率（テスト） = 0.4738
# Generation: 1390. 正答率（トレーニング） = 0.4714
#                 : 1390. 正答率（テスト） = 0.4796
# Generation: 1400. 正答率（トレーニング） = 0.47823333333333334
#                 : 1400. 正答率（テスト） = 0.4873
# Generation: 1410. 正答率（トレーニング） = 0.4759
#                 : 1410. 正答率（テスト） = 0.4856
# Generation: 1420. 正答率（トレーニング） = 0.46718333333333334
#                 : 1420. 正答率（テスト） = 0.4747
# Generation: 1430. 正答率（トレーニング） = 0.46596666666666664
#                 : 1430. 正答率（テスト） = 0.4758
# Generation: 1440. 正答率（トレーニング） = 0.46476666666666666
#                 : 1440. 正答率（テスト） = 0.4746
# Generation: 1450. 正答率（トレーニング） = 0.47286666666666666
#                 : 1450. 正答率（テスト） = 0.4827
# Generation: 1460. 正答率（トレーニング） = 0.46953333333333336
#                 : 1460. 正答率（テスト） = 0.4789
# Generation: 1470. 正答率（トレーニング） = 0.47436666666666666
#                 : 1470. 正答率（テスト） = 0.4832
# Generation: 1480. 正答率（トレーニング） = 0.4797666666666667
#                 : 1480. 正答率（テスト） = 0.4879
# Generation: 1490. 正答率（トレーニング） = 0.47815
#                 : 1490. 正答率（テスト） = 0.4868
# Generation: 1500. 正答率（トレーニング） = 0.4731
#                 : 1500. 正答率（テスト） = 0.4818
# Generation: 1510. 正答率（トレーニング） = 0.47756666666666664
#                 : 1510. 正答率（テスト） = 0.4873
# Generation: 1520. 正答率（トレーニング） = 0.4788
#                 : 1520. 正答率（テスト） = 0.4878
# Generation: 1530. 正答率（トレーニング） = 0.47658333333333336
#                 : 1530. 正答率（テスト） = 0.4854
# Generation: 1540. 正答率（トレーニング） = 0.48341666666666666
#                 : 1540. 正答率（テスト） = 0.4906
# Generation: 1550. 正答率（トレーニング） = 0.47686666666666666
#                 : 1550. 正答率（テスト） = 0.4833
# Generation: 1560. 正答率（トレーニング） = 0.4794333333333333
#                 : 1560. 正答率（テスト） = 0.4839
# Generation: 1570. 正答率（トレーニング） = 0.47731666666666667
#                 : 1570. 正答率（テスト） = 0.4816
# Generation: 1580. 正答率（トレーニング） = 0.4824
#                 : 1580. 正答率（テスト） = 0.4855
# Generation: 1590. 正答率（トレーニング） = 0.47636666666666666
#                 : 1590. 正答率（テスト） = 0.4824
# Generation: 1600. 正答率（トレーニング） = 0.47176666666666667
#                 : 1600. 正答率（テスト） = 0.4776
# Generation: 1610. 正答率（トレーニング） = 0.46905
#                 : 1610. 正答率（テスト） = 0.4751
# Generation: 1620. 正答率（トレーニング） = 0.4796666666666667
#                 : 1620. 正答率（テスト） = 0.4846
# Generation: 1630. 正答率（トレーニング） = 0.4711666666666667
#                 : 1630. 正答率（テスト） = 0.4769
# Generation: 1640. 正答率（トレーニング） = 0.48246666666666665
#                 : 1640. 正答率（テスト） = 0.491
# Generation: 1650. 正答率（トレーニング） = 0.4855
#                 : 1650. 正答率（テスト） = 0.4928
# Generation: 1660. 正答率（トレーニング） = 0.4856
#                 : 1660. 正答率（テスト） = 0.4909
# Generation: 1670. 正答率（トレーニング） = 0.47755
#                 : 1670. 正答率（テスト） = 0.4812
# Generation: 1680. 正答率（トレーニング） = 0.4868
#                 : 1680. 正答率（テスト） = 0.4917
# Generation: 1690. 正答率（トレーニング） = 0.4761166666666667
#                 : 1690. 正答率（テスト） = 0.4809
# Generation: 1700. 正答率（トレーニング） = 0.4721
#                 : 1700. 正答率（テスト） = 0.4771
# Generation: 1710. 正答率（トレーニング） = 0.46925
#                 : 1710. 正答率（テスト） = 0.4746
# Generation: 1720. 正答率（トレーニング） = 0.4619
#                 : 1720. 正答率（テスト） = 0.4652
# Generation: 1730. 正答率（トレーニング） = 0.46648333333333336
#                 : 1730. 正答率（テスト） = 0.4699
# Generation: 1740. 正答率（トレーニング） = 0.4746
#                 : 1740. 正答率（テスト） = 0.478
# Generation: 1750. 正答率（トレーニング） = 0.4772166666666667
#                 : 1750. 正答率（テスト） = 0.481
# Generation: 1760. 正答率（トレーニング） = 0.47751666666666664
#                 : 1760. 正答率（テスト） = 0.4828
# Generation: 1770. 正答率（トレーニング） = 0.48141666666666666
#                 : 1770. 正答率（テスト） = 0.485
# Generation: 1780. 正答率（トレーニング） = 0.5009166666666667
#                 : 1780. 正答率（テスト） = 0.5056
# Generation: 1790. 正答率（トレーニング） = 0.5020166666666667
#                 : 1790. 正答率（テスト） = 0.5063
# Generation: 1800. 正答率（トレーニング） = 0.49933333333333335
#                 : 1800. 正答率（テスト） = 0.5029
# Generation: 1810. 正答率（トレーニング） = 0.48845
#                 : 1810. 正答率（テスト） = 0.4931
# Generation: 1820. 正答率（トレーニング） = 0.5011833333333333
#                 : 1820. 正答率（テスト） = 0.5056
# Generation: 1830. 正答率（トレーニング） = 0.5025666666666667
#                 : 1830. 正答率（テスト） = 0.506
# Generation: 1840. 正答率（トレーニング） = 0.5038333333333334
#                 : 1840. 正答率（テスト） = 0.5087
# Generation: 1850. 正答率（トレーニング） = 0.5097166666666667
#                 : 1850. 正答率（テスト） = 0.5155
# Generation: 1860. 正答率（トレーニング） = 0.5216
#                 : 1860. 正答率（テスト） = 0.5279
# Generation: 1870. 正答率（トレーニング） = 0.5100166666666667
#                 : 1870. 正答率（テスト） = 0.5158
# Generation: 1880. 正答率（トレーニング） = 0.5162
#                 : 1880. 正答率（テスト） = 0.5234
# Generation: 1890. 正答率（トレーニング） = 0.5211333333333333
#                 : 1890. 正答率（テスト） = 0.529
# Generation: 1900. 正答率（トレーニング） = 0.5254166666666666
#                 : 1900. 正答率（テスト） = 0.5314
# Generation: 1910. 正答率（トレーニング） = 0.5157166666666667
#                 : 1910. 正答率（テスト） = 0.519
# Generation: 1920. 正答率（トレーニング） = 0.5139166666666667
#                 : 1920. 正答率（テスト） = 0.5151
# Generation: 1930. 正答率（トレーニング） = 0.5125666666666666
#                 : 1930. 正答率（テスト） = 0.5151
# Generation: 1940. 正答率（トレーニング） = 0.5171
#                 : 1940. 正答率（テスト） = 0.5225
# Generation: 1950. 正答率（トレーニング） = 0.5087833333333334
#                 : 1950. 正答率（テスト） = 0.5138
# Generation: 1960. 正答率（トレーニング） = 0.5089666666666667
#                 : 1960. 正答率（テスト） = 0.5158
# Generation: 1970. 正答率（トレーニング） = 0.5072
#                 : 1970. 正答率（テスト） = 0.5129
# Generation: 1980. 正答率（トレーニング） = 0.5057333333333334
#                 : 1980. 正答率（テスト） = 0.5124
# Generation: 1990. 正答率（トレーニング） = 0.5031666666666667
#                 : 1990. 正答率（テスト） = 0.5107
# Generation: 2000. 正答率（トレーニング） = 0.5086666666666667
#                 : 2000. 正答率（テスト） = 0.5154

# %%
Tester11.plot_results()
plt.show()

# %%
Tester12 = VanishingGradientTest(activation = "relu", weight_init_std = "Xavier" , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test)
Tester12.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.17008333333333334
#                 : 10. 正答率（テスト） = 0.1714
# Generation: 20. 正答率（トレーニング） = 0.19216666666666668
#                 : 20. 正答率（テスト） = 0.1949
# Generation: 30. 正答率（トレーニング） = 0.20893333333333333
#                 : 30. 正答率（テスト） = 0.2114
# Generation: 40. 正答率（トレーニング） = 0.22411666666666666
#                 : 40. 正答率（テスト） = 0.2292
# Generation: 50. 正答率（トレーニング） = 0.24045
#                 : 50. 正答率（テスト） = 0.2449
# Generation: 60. 正答率（トレーニング） = 0.2754333333333333
#                 : 60. 正答率（テスト） = 0.2834
# Generation: 70. 正答率（トレーニング） = 0.30365
#                 : 70. 正答率（テスト） = 0.3092
# Generation: 80. 正答率（トレーニング） = 0.3171833333333333
#                 : 80. 正答率（テスト） = 0.3212
# Generation: 90. 正答率（トレーニング） = 0.33343333333333336
#                 : 90. 正答率（テスト） = 0.3388
# Generation: 100. 正答率（トレーニング） = 0.3443
#                 : 100. 正答率（テスト） = 0.3469
# Generation: 110. 正答率（トレーニング） = 0.34673333333333334
#                 : 110. 正答率（テスト） = 0.3508
# Generation: 120. 正答率（トレーニング） = 0.35641666666666666
#                 : 120. 正答率（テスト） = 0.3592
# Generation: 130. 正答率（トレーニング） = 0.3753666666666667
#                 : 130. 正答率（テスト） = 0.3759
# Generation: 140. 正答率（トレーニング） = 0.38765
#                 : 140. 正答率（テスト） = 0.3896
# Generation: 150. 正答率（トレーニング） = 0.4013
#                 : 150. 正答率（テスト） = 0.4037
# Generation: 160. 正答率（トレーニング） = 0.4094
#                 : 160. 正答率（テスト） = 0.4119
# Generation: 170. 正答率（トレーニング） = 0.42023333333333335
#                 : 170. 正答率（テスト） = 0.4214
# Generation: 180. 正答率（トレーニング） = 0.4356
#                 : 180. 正答率（テスト） = 0.4347
# Generation: 190. 正答率（トレーニング） = 0.44083333333333335
#                 : 190. 正答率（テスト） = 0.4387
# Generation: 200. 正答率（トレーニング） = 0.4540166666666667
#                 : 200. 正答率（テスト） = 0.4541
# Generation: 210. 正答率（トレーニング） = 0.46355
#                 : 210. 正答率（テスト） = 0.4631
# Generation: 220. 正答率（トレーニング） = 0.4801666666666667
#                 : 220. 正答率（テスト） = 0.48
# Generation: 230. 正答率（トレーニング） = 0.48328333333333334
#                 : 230. 正答率（テスト） = 0.4819
# Generation: 240. 正答率（トレーニング） = 0.49866666666666665
#                 : 240. 正答率（テスト） = 0.5002
# Generation: 250. 正答率（トレーニング） = 0.5103333333333333
#                 : 250. 正答率（テスト） = 0.514
# Generation: 260. 正答率（トレーニング） = 0.5207333333333334
#                 : 260. 正答率（テスト） = 0.5229
# Generation: 270. 正答率（トレーニング） = 0.5305833333333333
#                 : 270. 正答率（テスト） = 0.529
# Generation: 280. 正答率（トレーニング） = 0.5374833333333333
#                 : 280. 正答率（テスト） = 0.5401
# Generation: 290. 正答率（トレーニング） = 0.5421333333333334
#                 : 290. 正答率（テスト） = 0.5422
# Generation: 300. 正答率（トレーニング） = 0.5576
#                 : 300. 正答率（テスト） = 0.5589
# Generation: 310. 正答率（トレーニング） = 0.5648666666666666
#                 : 310. 正答率（テスト） = 0.5632
# Generation: 320. 正答率（トレーニング） = 0.5825166666666667
#                 : 320. 正答率（テスト） = 0.5806
# Generation: 330. 正答率（トレーニング） = 0.5954333333333334
#                 : 330. 正答率（テスト） = 0.5931
# Generation: 340. 正答率（トレーニング） = 0.6034666666666667
#                 : 340. 正答率（テスト） = 0.6031
# Generation: 350. 正答率（トレーニング） = 0.6213666666666666
#                 : 350. 正答率（テスト） = 0.6203
# Generation: 360. 正答率（トレーニング） = 0.6404166666666666
#                 : 360. 正答率（テスト） = 0.6385
# Generation: 370. 正答率（トレーニング） = 0.6537666666666667
#                 : 370. 正答率（テスト） = 0.6498
# Generation: 380. 正答率（トレーニング） = 0.6620166666666667
#                 : 380. 正答率（テスト） = 0.6591
# Generation: 390. 正答率（トレーニング） = 0.66495
#                 : 390. 正答率（テスト） = 0.6623
# Generation: 400. 正答率（トレーニング） = 0.6761666666666667
#                 : 400. 正答率（テスト） = 0.6719
# Generation: 410. 正答率（トレーニング） = 0.68085
#                 : 410. 正答率（テスト） = 0.6785
# Generation: 420. 正答率（トレーニング） = 0.6953666666666667
#                 : 420. 正答率（テスト） = 0.6933
# Generation: 430. 正答率（トレーニング） = 0.6996833333333333
#                 : 430. 正答率（テスト） = 0.7005
# Generation: 440. 正答率（トレーニング） = 0.7017666666666666
#                 : 440. 正答率（テスト） = 0.7028
# Generation: 450. 正答率（トレーニング） = 0.7140833333333333
#                 : 450. 正答率（テスト） = 0.7144
# Generation: 460. 正答率（トレーニング） = 0.7230166666666666
#                 : 460. 正答率（テスト） = 0.7233
# Generation: 470. 正答率（トレーニング） = 0.7150833333333333
#                 : 470. 正答率（テスト） = 0.7147
# Generation: 480. 正答率（トレーニング） = 0.7287333333333333
#                 : 480. 正答率（テスト） = 0.7268
# Generation: 490. 正答率（トレーニング） = 0.7331166666666666
#                 : 490. 正答率（テスト） = 0.7339
# Generation: 500. 正答率（トレーニング） = 0.7452166666666666
#                 : 500. 正答率（テスト） = 0.746
# Generation: 510. 正答率（トレーニング） = 0.7516
#                 : 510. 正答率（テスト） = 0.7526
# Generation: 520. 正答率（トレーニング） = 0.75435
#                 : 520. 正答率（テスト） = 0.7587
# Generation: 530. 正答率（トレーニング） = 0.7594333333333333
#                 : 530. 正答率（テスト） = 0.7611
# Generation: 540. 正答率（トレーニング） = 0.76365
#                 : 540. 正答率（テスト） = 0.7633
# Generation: 550. 正答率（トレーニング） = 0.7715833333333333
#                 : 550. 正答率（テスト） = 0.7729
# Generation: 560. 正答率（トレーニング） = 0.7712
#                 : 560. 正答率（テスト） = 0.7715
# Generation: 570. 正答率（トレーニング） = 0.7733666666666666
#                 : 570. 正答率（テスト） = 0.7749
# Generation: 580. 正答率（トレーニング） = 0.7770333333333334
#                 : 580. 正答率（テスト） = 0.7803
# Generation: 590. 正答率（トレーニング） = 0.7848833333333334
#                 : 590. 正答率（テスト） = 0.7861
# Generation: 600. 正答率（トレーニング） = 0.7865833333333333
#                 : 600. 正答率（テスト） = 0.7885
# Generation: 610. 正答率（トレーニング） = 0.7886166666666666
#                 : 610. 正答率（テスト） = 0.7904
# Generation: 620. 正答率（トレーニング） = 0.7904166666666667
#                 : 620. 正答率（テスト） = 0.7947
# Generation: 630. 正答率（トレーニング） = 0.7926333333333333
#                 : 630. 正答率（テスト） = 0.7944
# Generation: 640. 正答率（トレーニング） = 0.7946333333333333
#                 : 640. 正答率（テスト） = 0.7999
# Generation: 650. 正答率（トレーニング） = 0.7949833333333334
#                 : 650. 正答率（テスト） = 0.8005
# Generation: 660. 正答率（トレーニング） = 0.8007666666666666
#                 : 660. 正答率（テスト） = 0.8038
# Generation: 670. 正答率（トレーニング） = 0.8012666666666667
#                 : 670. 正答率（テスト） = 0.8052
# Generation: 680. 正答率（トレーニング） = 0.8062
#                 : 680. 正答率（テスト） = 0.8084
# Generation: 690. 正答率（トレーニング） = 0.8091
#                 : 690. 正答率（テスト） = 0.8114
# Generation: 700. 正答率（トレーニング） = 0.8105
#                 : 700. 正答率（テスト） = 0.8151
# Generation: 710. 正答率（トレーニング） = 0.8121333333333334
#                 : 710. 正答率（テスト） = 0.8161
# Generation: 720. 正答率（トレーニング） = 0.81205
#                 : 720. 正答率（テスト） = 0.8157
# Generation: 730. 正答率（トレーニング） = 0.81495
#                 : 730. 正答率（テスト） = 0.8205
# Generation: 740. 正答率（トレーニング） = 0.8145833333333333
#                 : 740. 正答率（テスト） = 0.8204
# Generation: 750. 正答率（トレーニング） = 0.8175
#                 : 750. 正答率（テスト） = 0.8223
# Generation: 760. 正答率（トレーニング） = 0.8195166666666667
#                 : 760. 正答率（テスト） = 0.8251
# Generation: 770. 正答率（トレーニング） = 0.8224166666666667
#                 : 770. 正答率（テスト） = 0.8269
# Generation: 780. 正答率（トレーニング） = 0.8229666666666666
#                 : 780. 正答率（テスト） = 0.8264
# Generation: 790. 正答率（トレーニング） = 0.8249333333333333
#                 : 790. 正答率（テスト） = 0.8298
# Generation: 800. 正答率（トレーニング） = 0.8268666666666666
#                 : 800. 正答率（テスト） = 0.8335
# Generation: 810. 正答率（トレーニング） = 0.82915
#                 : 810. 正答率（テスト） = 0.835
# Generation: 820. 正答率（トレーニング） = 0.8300333333333333
#                 : 820. 正答率（テスト） = 0.8365
# Generation: 830. 正答率（トレーニング） = 0.83285
#                 : 830. 正答率（テスト） = 0.8368
# Generation: 840. 正答率（トレーニング） = 0.8358166666666667
#                 : 840. 正答率（テスト） = 0.84
# Generation: 850. 正答率（トレーニング） = 0.8362166666666667
#                 : 850. 正答率（テスト） = 0.8408
# Generation: 860. 正答率（トレーニング） = 0.8349333333333333
#                 : 860. 正答率（テスト） = 0.8415
# Generation: 870. 正答率（トレーニング） = 0.83925
#                 : 870. 正答率（テスト） = 0.8434
# Generation: 880. 正答率（トレーニング） = 0.8427166666666667
#                 : 880. 正答率（テスト） = 0.8466
# Generation: 890. 正答率（トレーニング） = 0.8427666666666667
#                 : 890. 正答率（テスト） = 0.8474
# Generation: 900. 正答率（トレーニング） = 0.84185
#                 : 900. 正答率（テスト） = 0.8469
# Generation: 910. 正答率（トレーニング） = 0.8408666666666667
#                 : 910. 正答率（テスト） = 0.8489
# Generation: 920. 正答率（トレーニング） = 0.8450833333333333
#                 : 920. 正答率（テスト） = 0.8501
# Generation: 930. 正答率（トレーニング） = 0.8454666666666667
#                 : 930. 正答率（テスト） = 0.8508
# Generation: 940. 正答率（トレーニング） = 0.84485
#                 : 940. 正答率（テスト） = 0.852
# Generation: 950. 正答率（トレーニング） = 0.8464166666666667
#                 : 950. 正答率（テスト） = 0.8535
# Generation: 960. 正答率（トレーニング） = 0.8483
#                 : 960. 正答率（テスト） = 0.8526
# Generation: 970. 正答率（トレーニング） = 0.8500333333333333
#                 : 970. 正答率（テスト） = 0.8548
# Generation: 980. 正答率（トレーニング） = 0.8520166666666666
#                 : 980. 正答率（テスト） = 0.8556
# Generation: 990. 正答率（トレーニング） = 0.8529333333333333
#                 : 990. 正答率（テスト） = 0.856
# Generation: 1000. 正答率（トレーニング） = 0.8533333333333334
#                 : 1000. 正答率（テスト） = 0.8567
# Generation: 1010. 正答率（トレーニング） = 0.8540333333333333
#                 : 1010. 正答率（テスト） = 0.8585
# Generation: 1020. 正答率（トレーニング） = 0.8563333333333333
#                 : 1020. 正答率（テスト） = 0.8602
# Generation: 1030. 正答率（トレーニング） = 0.8564
#                 : 1030. 正答率（テスト） = 0.8614
# Generation: 1040. 正答率（トレーニング） = 0.8587833333333333
#                 : 1040. 正答率（テスト） = 0.8623
# Generation: 1050. 正答率（トレーニング） = 0.8595166666666667
#                 : 1050. 正答率（テスト） = 0.8633
# Generation: 1060. 正答率（トレーニング） = 0.8591166666666666
#                 : 1060. 正答率（テスト） = 0.8628
# Generation: 1070. 正答率（トレーニング） = 0.8598666666666667
#                 : 1070. 正答率（テスト） = 0.8632
# Generation: 1080. 正答率（トレーニング） = 0.8602166666666666
#                 : 1080. 正答率（テスト） = 0.8642
# Generation: 1090. 正答率（トレーニング） = 0.8605
#                 : 1090. 正答率（テスト） = 0.8652
# Generation: 1100. 正答率（トレーニング） = 0.86145
#                 : 1100. 正答率（テスト） = 0.8659
# Generation: 1110. 正答率（トレーニング） = 0.8623666666666666
#                 : 1110. 正答率（テスト） = 0.8665
# Generation: 1120. 正答率（トレーニング） = 0.8634333333333334
#                 : 1120. 正答率（テスト） = 0.8669
# Generation: 1130. 正答率（トレーニング） = 0.8622
#                 : 1130. 正答率（テスト） = 0.8677
# Generation: 1140. 正答率（トレーニング） = 0.8649666666666667
#                 : 1140. 正答率（テスト） = 0.8705
# Generation: 1150. 正答率（トレーニング） = 0.8657166666666667
#                 : 1150. 正答率（テスト） = 0.8707
# Generation: 1160. 正答率（トレーニング） = 0.8654333333333334
#                 : 1160. 正答率（テスト） = 0.8687
# Generation: 1170. 正答率（トレーニング） = 0.8649166666666667
#                 : 1170. 正答率（テスト） = 0.8704
# Generation: 1180. 正答率（トレーニング） = 0.8660333333333333
#                 : 1180. 正答率（テスト） = 0.8696
# Generation: 1190. 正答率（トレーニング） = 0.8650833333333333
#                 : 1190. 正答率（テスト） = 0.87
# Generation: 1200. 正答率（トレーニング） = 0.8682833333333333
#                 : 1200. 正答率（テスト） = 0.8717
# Generation: 1210. 正答率（トレーニング） = 0.8686
#                 : 1210. 正答率（テスト） = 0.8739
# Generation: 1220. 正答率（トレーニング） = 0.8685833333333334
#                 : 1220. 正答率（テスト） = 0.8718
# Generation: 1230. 正答率（トレーニング） = 0.8700833333333333
#                 : 1230. 正答率（テスト） = 0.8728
# Generation: 1240. 正答率（トレーニング） = 0.8707333333333334
#                 : 1240. 正答率（テスト） = 0.8735
# Generation: 1250. 正答率（トレーニング） = 0.8711833333333333
#                 : 1250. 正答率（テスト） = 0.8738
# Generation: 1260. 正答率（トレーニング） = 0.87035
#                 : 1260. 正答率（テスト） = 0.874
# Generation: 1270. 正答率（トレーニング） = 0.8718166666666667
#                 : 1270. 正答率（テスト） = 0.8761
# Generation: 1280. 正答率（トレーニング） = 0.8725
#                 : 1280. 正答率（テスト） = 0.8765
# Generation: 1290. 正答率（トレーニング） = 0.8707333333333334
#                 : 1290. 正答率（テスト） = 0.8764
# Generation: 1300. 正答率（トレーニング） = 0.8725833333333334
#                 : 1300. 正答率（テスト） = 0.8761
# Generation: 1310. 正答率（トレーニング） = 0.8732166666666666
#                 : 1310. 正答率（テスト） = 0.8784
# Generation: 1320. 正答率（トレーニング） = 0.8737666666666667
#                 : 1320. 正答率（テスト） = 0.8785
# Generation: 1330. 正答率（トレーニング） = 0.8746333333333334
#                 : 1330. 正答率（テスト） = 0.8778
# Generation: 1340. 正答率（トレーニング） = 0.8747
#                 : 1340. 正答率（テスト） = 0.8805
# Generation: 1350. 正答率（トレーニング） = 0.8748
#                 : 1350. 正答率（テスト） = 0.8793
# Generation: 1360. 正答率（トレーニング） = 0.8733166666666666
#                 : 1360. 正答率（テスト） = 0.8773
# Generation: 1370. 正答率（トレーニング） = 0.8745333333333334
#                 : 1370. 正答率（テスト） = 0.8786
# Generation: 1380. 正答率（トレーニング） = 0.8769166666666667
#                 : 1380. 正答率（テスト） = 0.8808
# Generation: 1390. 正答率（トレーニング） = 0.8765833333333334
#                 : 1390. 正答率（テスト） = 0.8815
# Generation: 1400. 正答率（トレーニング） = 0.8770666666666667
#                 : 1400. 正答率（テスト） = 0.8817
# Generation: 1410. 正答率（トレーニング） = 0.8779333333333333
#                 : 1410. 正答率（テスト） = 0.882
# Generation: 1420. 正答率（トレーニング） = 0.8777333333333334
#                 : 1420. 正答率（テスト） = 0.8816
# Generation: 1430. 正答率（トレーニング） = 0.8781333333333333
#                 : 1430. 正答率（テスト） = 0.8825
# Generation: 1440. 正答率（トレーニング） = 0.8783
#                 : 1440. 正答率（テスト） = 0.8813
# Generation: 1450. 正答率（トレーニング） = 0.8796166666666667
#                 : 1450. 正答率（テスト） = 0.8834
# Generation: 1460. 正答率（トレーニング） = 0.87825
#                 : 1460. 正答率（テスト） = 0.8827
# Generation: 1470. 正答率（トレーニング） = 0.87715
#                 : 1470. 正答率（テスト） = 0.8823
# Generation: 1480. 正答率（トレーニング） = 0.8791666666666667
#                 : 1480. 正答率（テスト） = 0.8839
# Generation: 1490. 正答率（トレーニング） = 0.8810333333333333
#                 : 1490. 正答率（テスト） = 0.8827
# Generation: 1500. 正答率（トレーニング） = 0.8807166666666667
#                 : 1500. 正答率（テスト） = 0.8844
# Generation: 1510. 正答率（トレーニング） = 0.8812
#                 : 1510. 正答率（テスト） = 0.8842
# Generation: 1520. 正答率（トレーニング） = 0.87965
#                 : 1520. 正答率（テスト） = 0.8846
# Generation: 1530. 正答率（トレーニング） = 0.8807333333333334
#                 : 1530. 正答率（テスト） = 0.8852
# Generation: 1540. 正答率（トレーニング） = 0.8812833333333333
#                 : 1540. 正答率（テスト） = 0.8863
# Generation: 1550. 正答率（トレーニング） = 0.88235
#                 : 1550. 正答率（テスト） = 0.8868
# Generation: 1560. 正答率（トレーニング） = 0.8826333333333334
#                 : 1560. 正答率（テスト） = 0.8861
# Generation: 1570. 正答率（トレーニング） = 0.8831666666666667
#                 : 1570. 正答率（テスト） = 0.8859
# Generation: 1580. 正答率（トレーニング） = 0.8838666666666667
#                 : 1580. 正答率（テスト） = 0.8882
# Generation: 1590. 正答率（トレーニング） = 0.8827333333333334
#                 : 1590. 正答率（テスト） = 0.8871
# Generation: 1600. 正答率（トレーニング） = 0.8823166666666666
#                 : 1600. 正答率（テスト） = 0.8868
# Generation: 1610. 正答率（トレーニング） = 0.8845833333333334
#                 : 1610. 正答率（テスト） = 0.8889
# Generation: 1620. 正答率（トレーニング） = 0.88425
#                 : 1620. 正答率（テスト） = 0.8884
# Generation: 1630. 正答率（トレーニング） = 0.8834666666666666
#                 : 1630. 正答率（テスト） = 0.8883
# Generation: 1640. 正答率（トレーニング） = 0.88425
#                 : 1640. 正答率（テスト） = 0.8896
# Generation: 1650. 正答率（トレーニング） = 0.8845833333333334
#                 : 1650. 正答率（テスト） = 0.8881
# Generation: 1660. 正答率（トレーニング） = 0.8833833333333333
#                 : 1660. 正答率（テスト） = 0.8897
# Generation: 1670. 正答率（トレーニング） = 0.8826666666666667
#                 : 1670. 正答率（テスト） = 0.8899
# Generation: 1680. 正答率（トレーニング） = 0.8858333333333334
#                 : 1680. 正答率（テスト） = 0.8895
# Generation: 1690. 正答率（トレーニング） = 0.8859666666666667
#                 : 1690. 正答率（テスト） = 0.8897
# Generation: 1700. 正答率（トレーニング） = 0.88415
#                 : 1700. 正答率（テスト） = 0.8889
# Generation: 1710. 正答率（トレーニング） = 0.8857333333333334
#                 : 1710. 正答率（テスト） = 0.8913
# Generation: 1720. 正答率（トレーニング） = 0.8851333333333333
#                 : 1720. 正答率（テスト） = 0.8916
# Generation: 1730. 正答率（トレーニング） = 0.8863333333333333
#                 : 1730. 正答率（テスト） = 0.8915
# Generation: 1740. 正答率（トレーニング） = 0.8865833333333333
#                 : 1740. 正答率（テスト） = 0.892
# Generation: 1750. 正答率（トレーニング） = 0.8874833333333333
#                 : 1750. 正答率（テスト） = 0.8917
# Generation: 1760. 正答率（トレーニング） = 0.8878333333333334
#                 : 1760. 正答率（テスト） = 0.8906
# Generation: 1770. 正答率（トレーニング） = 0.8872333333333333
#                 : 1770. 正答率（テスト） = 0.8907
# Generation: 1780. 正答率（トレーニング） = 0.8877
#                 : 1780. 正答率（テスト） = 0.8915
# Generation: 1790. 正答率（トレーニング） = 0.88645
#                 : 1790. 正答率（テスト） = 0.8927
# Generation: 1800. 正答率（トレーニング） = 0.8874333333333333
#                 : 1800. 正答率（テスト） = 0.8933
# Generation: 1810. 正答率（トレーニング） = 0.88775
#                 : 1810. 正答率（テスト） = 0.8909
# Generation: 1820. 正答率（トレーニング） = 0.8887666666666667
#                 : 1820. 正答率（テスト） = 0.8937
# Generation: 1830. 正答率（トレーニング） = 0.8885666666666666
#                 : 1830. 正答率（テスト） = 0.8926
# Generation: 1840. 正答率（トレーニング） = 0.8891
#                 : 1840. 正答率（テスト） = 0.8926
# Generation: 1850. 正答率（トレーニング） = 0.8890666666666667
#                 : 1850. 正答率（テスト） = 0.8935
# Generation: 1860. 正答率（トレーニング） = 0.8887666666666667
#                 : 1860. 正答率（テスト） = 0.893
# Generation: 1870. 正答率（トレーニング） = 0.8896833333333334
#                 : 1870. 正答率（テスト） = 0.8933
# Generation: 1880. 正答率（トレーニング） = 0.8899166666666667
#                 : 1880. 正答率（テスト） = 0.8926
# Generation: 1890. 正答率（トレーニング） = 0.8900833333333333
#                 : 1890. 正答率（テスト） = 0.8943
# Generation: 1900. 正答率（トレーニング） = 0.8903
#                 : 1900. 正答率（テスト） = 0.8956
# Generation: 1910. 正答率（トレーニング） = 0.8887833333333334
#                 : 1910. 正答率（テスト） = 0.8932
# Generation: 1920. 正答率（トレーニング） = 0.8898666666666667
#                 : 1920. 正答率（テスト） = 0.8939
# Generation: 1930. 正答率（トレーニング） = 0.8908833333333334
#                 : 1930. 正答率（テスト） = 0.8944
# Generation: 1940. 正答率（トレーニング） = 0.8902333333333333
#                 : 1940. 正答率（テスト） = 0.8957
# Generation: 1950. 正答率（トレーニング） = 0.8911166666666667
#                 : 1950. 正答率（テスト） = 0.8958
# Generation: 1960. 正答率（トレーニング） = 0.8913833333333333
#                 : 1960. 正答率（テスト） = 0.8963
# Generation: 1970. 正答率（トレーニング） = 0.89155
#                 : 1970. 正答率（テスト） = 0.8951
# Generation: 1980. 正答率（トレーニング） = 0.8914333333333333
#                 : 1980. 正答率（テスト） = 0.8954
# Generation: 1990. 正答率（トレーニング） = 0.8913833333333333
#                 : 1990. 正答率（テスト） = 0.8968
# Generation: 2000. 正答率（トレーニング） = 0.8921
#                 : 2000. 正答率（テスト） = 0.8977

# %%
Tester12.plot_results()
plt.show()

# %% [markdown]
# ## Section2 学習率最適化手法

# %% [markdown]
# - 学習率における工夫
# 学習率（パラメータの更新時の更新量に関する比例定数）をどのように決めるかどうかに各種手法があり、そこを工夫することで、効率的に学習を進めることができる。
# - 学習率が適正でない場合について
# 学習率が大きすぎると、いつまでも学習がうまくいかずに発散してしまう。
# 学習率が小さすぎると、収束までに時間がかかってしまう。また、局所解に陥ってしまう。
# - よく使われる手法
# よく使われる手法に以下のものがある。
#  1. モメンタム
#  2. AdaGrad
#  3. RMSProp
#  4. Adam
# - モメンタム
# 誤差をパラメータで微分したものと学習率の積を減算した後、現在の重みに前回の重みを減算した値と慣性の積を加算する。
# モメンタムではパラメータの更新が比較的なめらかな形で進んでいく。
# $$
# V_t = \mu V_{t-1} - \epsilon \nabla E\\
# w^{t+1} = w^{(t)} + V_t
# $$
# - AdaGrad
# 誤差をパラメータで微分したものと再定義した学習率の積を減算する。
# $$
# h_0 = \theta\\
# h_t = h_{t-1}+(\nabla E)^2\\
# w^{(t+1)} = w^{(t)} -\epsilon \frac{1}{\sqrt{h_t}+\theta}\nabla E
# $$
# 勾配の緩やかな斜面に対して最適解を見つけやすいが、学習率が徐々に小さくなるために、鞍点問題を引き起こすことがある。
# - RMSProp
# 誤差をパラメータで微分したものと再定義した学習率の積を減算する
# $$
# h_t = \alpha h_{t-1} + (1-\alpha )(\nabla E)^2\\
# w^{(t+1)} = w^{(t)}-\epsilon \frac{1}{\sqrt{h_t}+\theta}\nabla E
# $$
# 大域的最適解を見つけやすい。ハイパーパラメータの調整が必要な場合が少ない。
# - Adam
# 通常、もっとも良い方法。モメンタムとRMSPropを両方取り入れたような方法。

# %% [markdown]
# 以下pythonでの実装を確認する

# %%
class OptimizerTest:
    def __init__(self, activation, weight_init_std, x_train, d_train, x_test, d_test, OptimizerType, momentum = 0.9,
                 decay_rate = 0.99, beta1 = 0.9, beta2 = 0.99, hidden_size_list=[40,20], iters_num = 2000, batch_size = 100, learning_rate = 0.01):
        """
        OptimizerTypeは、SGD、Momentum、AdaGrad、RMSprop、ADAのいずれかを文字列で受け取る。
        """
        self.activation = activation
        self.weight_init_std = weight_init_std
        self.hidden_size_list = [40, 20]
        self.x_train = x_train
        self.d_train = d_train
        self.x_test = x_test
        self.d_test = d_test
        self.OptimizerType = OptimizerType
        self.learning_rate = learning_rate
        # 各Optimizer固有の値
        self.momentum = momentum
        self.decay_rate = 0.99
        self.beta1 = beta1
        self.beta2 = beta2
        
        self.input_size = x_train.shape[1]
        self.output_size = d_train.shape[1]
        self.network = MultiLayerNet(input_size = self.input_size, 
                                     hidden_size_list = self.hidden_size_list,
                                     output_size = self.output_size,
                                     activation = self.activation, 
                                     weight_init_std = self.weight_init_std)
        self.iters_num = iters_num
        self.batch_size = batch_size
        self.train_size = self.x_train.shape[0] 
        self.plot_interval = 10
        
    def train(self):
        self.train_loss_list = []
        self.accuracies_train = []
        self.accuracies_test = []
        
        for i in range(self.iters_num):
            batch_mask = np.random.choice(self.train_size, self.batch_size)
            x_batch = self.x_train[batch_mask]
            d_batch = self.d_train[batch_mask]
            
            grad = self.network.gradient(x_batch, d_batch)
            if self.OptimizerType == "Momentum":
                if i == 0:
                    v = {}
            elif self.OptimizerType == "AdaGrad" or self.OptimizerType == "RMSprop":
                if i == 0:
                    h = {}
            elif self.OptimizerType == "Adam":
                if i == 0:
                    m = {}
                    v = {}
                learning_rate_t = self.learning_rate * np.sqrt(1.0 - self.beta2 ** (i + 1)) / (1.0 - self.beta1 ** (i + 1))
            
            for key in ("W1", "W2", "W3", "b1", "b2", "b3"):
                if self.OptimizerType == "SGD":
                    self.network.params[key] -= self.learning_rate * grad[key]
                elif self.OptimizerType == "Momentum":
                    if i == 0:
                        v[key] = np.zeros_like(self.network.params[key])
                    v[key] = self.momentum * v[key] - self.learning_rate * grad[key]
                    self.network.params[key] += v[key]
                elif self.OptimizerType == "AdaGrad":
                    if i == 0:
                        h[key] = np.full_like(self.network.params[key], 1e-4)
                    else:
                        h[key] += np.square(grad[key])
                    self.network.params[key] -= self.learning_rate * grad[key] / (np.sqrt(h[key]))
                elif self.OptimizerType == "RMSprop":
                    if i == 0:
                        h[key] = np.zeros_like(self.network.params[key])
                    h[key] *= self.decay_rate
                    h[key] += (1 - self.decay_rate) * np.square(grad[key])
                    self.network.params[key] -= self.learning_rate * grad[key] / (np.sqrt(h[key]) + 1e-7)
                elif self.OptimizerType == "Adam":
                    if i == 0:
                        m[key] = np.zeros_like(self.network.params[key])
                        v[key] = np.zeros_like(self.network.params[key])
                    m[key] += (1 - self.beta1) * (grad[key] - m[key])
                    v[key] += (1 - self.beta2) * (grad[key] ** 2 -v[key])
                    self.network.params[key] -= learning_rate_t * m[key] / (np.sqrt(v[key]) + 1e-7)
                
            
            loss = self.network.loss(x_batch, d_batch)
            self.train_loss_list.append(loss)
            
            if (i + 1) % self.plot_interval == 0:
                accr_test = self.network.accuracy(self.x_test, self.d_test)
                self.accuracies_test.append(accr_test)
                accr_train = self.network.accuracy(self.x_train, self.d_train)
                self.accuracies_train.append(accr_train)
                
                print("Generation: " + str(i+1) + ". 正答率（トレーニング） = " + str(accr_train))
                print("                : " + str(i+1) + ". 正答率（テスト） = " + str(accr_test))
    
    def plot_results(self):
        lists = range(0, self.iters_num, self.plot_interval)
        plt.plot(lists, self.accuracies_train, label = "training set")
        plt.plot(lists, self.accuracies_test, label = "test set")
        plt.legend(loc = "lower right")
        plt.title("accuracy")
        plt.xlabel("count")
        plt.ylabel("accuracy")
        plt.ylim(0, 1.0)

# %% [markdown]
# まず、relu & He で各種オプティマイザーを試す。

# %%
Tester5 = OptimizerTest(activation = "relu", weight_init_std = "He" , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test, OptimizerType = "SGD")
Tester5.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.11823333333333333
#                 : 10. 正答率（テスト） = 0.1223
# Generation: 20. 正答率（トレーニング） = 0.15715
#                 : 20. 正答率（テスト） = 0.1576
# Generation: 30. 正答率（トレーニング） = 0.19685
#                 : 30. 正答率（テスト） = 0.1946
# Generation: 40. 正答率（トレーニング） = 0.2302
#                 : 40. 正答率（テスト） = 0.2307
# Generation: 50. 正答率（トレーニング） = 0.2639166666666667
#                 : 50. 正答率（テスト） = 0.2617
# Generation: 60. 正答率（トレーニング） = 0.2912666666666667
#                 : 60. 正答率（テスト） = 0.2903
# Generation: 70. 正答率（トレーニング） = 0.3326
#                 : 70. 正答率（テスト） = 0.3315
# Generation: 80. 正答率（トレーニング） = 0.37041666666666667
#                 : 80. 正答率（テスト） = 0.3714
# Generation: 90. 正答率（トレーニング） = 0.4161666666666667
#                 : 90. 正答率（テスト） = 0.4179
# Generation: 100. 正答率（トレーニング） = 0.44398333333333334
#                 : 100. 正答率（テスト） = 0.4486
# Generation: 110. 正答率（トレーニング） = 0.48145
#                 : 110. 正答率（テスト） = 0.4896
# Generation: 120. 正答率（トレーニング） = 0.5202333333333333
#                 : 120. 正答率（テスト） = 0.5287
# Generation: 130. 正答率（トレーニング） = 0.5527833333333333
#                 : 130. 正答率（テスト） = 0.5634
# Generation: 140. 正答率（トレーニング） = 0.5721
#                 : 140. 正答率（テスト） = 0.5817
# Generation: 150. 正答率（トレーニング） = 0.5835833333333333
#                 : 150. 正答率（テスト） = 0.592
# Generation: 160. 正答率（トレーニング） = 0.60655
#                 : 160. 正答率（テスト） = 0.6171
# Generation: 170. 正答率（トレーニング） = 0.6170666666666667
#                 : 170. 正答率（テスト） = 0.6276
# Generation: 180. 正答率（トレーニング） = 0.6283
#                 : 180. 正答率（テスト） = 0.6388
# Generation: 190. 正答率（トレーニング） = 0.6392833333333333
#                 : 190. 正答率（テスト） = 0.6489
# Generation: 200. 正答率（トレーニング） = 0.65465
#                 : 200. 正答率（テスト） = 0.6599
# Generation: 210. 正答率（トレーニング） = 0.6554166666666666
#                 : 210. 正答率（テスト） = 0.6623
# Generation: 220. 正答率（トレーニング） = 0.6642333333333333
#                 : 220. 正答率（テスト） = 0.6699
# Generation: 230. 正答率（トレーニング） = 0.6813166666666667
#                 : 230. 正答率（テスト） = 0.6861
# Generation: 240. 正答率（トレーニング） = 0.6956833333333333
#                 : 240. 正答率（テスト） = 0.6992
# Generation: 250. 正答率（トレーニング） = 0.7083666666666667
#                 : 250. 正答率（テスト） = 0.7121
# Generation: 260. 正答率（トレーニング） = 0.7182666666666667
#                 : 260. 正答率（テスト） = 0.7243
# Generation: 270. 正答率（トレーニング） = 0.7300666666666666
#                 : 270. 正答率（テスト） = 0.7361
# Generation: 280. 正答率（トレーニング） = 0.73915
#                 : 280. 正答率（テスト） = 0.7456
# Generation: 290. 正答率（トレーニング） = 0.7489333333333333
#                 : 290. 正答率（テスト） = 0.7557
# Generation: 300. 正答率（トレーニング） = 0.7612833333333333
#                 : 300. 正答率（テスト） = 0.7655
# Generation: 310. 正答率（トレーニング） = 0.76955
#                 : 310. 正答率（テスト） = 0.773
# Generation: 320. 正答率（トレーニング） = 0.7735
#                 : 320. 正答率（テスト） = 0.7768
# Generation: 330. 正答率（トレーニング） = 0.7767
#                 : 330. 正答率（テスト） = 0.7803
# Generation: 340. 正答率（トレーニング） = 0.7812333333333333
#                 : 340. 正答率（テスト） = 0.7832
# Generation: 350. 正答率（トレーニング） = 0.7876166666666666
#                 : 350. 正答率（テスト） = 0.79
# Generation: 360. 正答率（トレーニング） = 0.78965
#                 : 360. 正答率（テスト） = 0.7926
# Generation: 370. 正答率（トレーニング） = 0.7926
#                 : 370. 正答率（テスト） = 0.7938
# Generation: 380. 正答率（トレーニング） = 0.7966833333333333
#                 : 380. 正答率（テスト） = 0.7984
# Generation: 390. 正答率（トレーニング） = 0.7986
#                 : 390. 正答率（テスト） = 0.8016
# Generation: 400. 正答率（トレーニング） = 0.8016833333333333
#                 : 400. 正答率（テスト） = 0.8045
# Generation: 410. 正答率（トレーニング） = 0.8032
#                 : 410. 正答率（テスト） = 0.8087
# Generation: 420. 正答率（トレーニング） = 0.8046666666666666
#                 : 420. 正答率（テスト） = 0.8099
# Generation: 430. 正答率（トレーニング） = 0.8097333333333333
#                 : 430. 正答率（テスト） = 0.8136
# Generation: 440. 正答率（トレーニング） = 0.81075
#                 : 440. 正答率（テスト） = 0.8142
# Generation: 450. 正答率（トレーニング） = 0.8141333333333334
#                 : 450. 正答率（テスト） = 0.817
# Generation: 460. 正答率（トレーニング） = 0.8159166666666666
#                 : 460. 正答率（テスト） = 0.8191
# Generation: 470. 正答率（トレーニング） = 0.8175
#                 : 470. 正答率（テスト） = 0.8208
# Generation: 480. 正答率（トレーニング） = 0.8188333333333333
#                 : 480. 正答率（テスト） = 0.8202
# Generation: 490. 正答率（トレーニング） = 0.8227333333333333
#                 : 490. 正答率（テスト） = 0.8254
# Generation: 500. 正答率（トレーニング） = 0.8214666666666667
#                 : 500. 正答率（テスト） = 0.8244
# Generation: 510. 正答率（トレーニング） = 0.8243333333333334
#                 : 510. 正答率（テスト） = 0.8273
# Generation: 520. 正答率（トレーニング） = 0.82545
#                 : 520. 正答率（テスト） = 0.8291
# Generation: 530. 正答率（トレーニング） = 0.8276833333333333
#                 : 530. 正答率（テスト） = 0.8295
# Generation: 540. 正答率（トレーニング） = 0.82885
#                 : 540. 正答率（テスト） = 0.8299
# Generation: 550. 正答率（トレーニング） = 0.8279666666666666
#                 : 550. 正答率（テスト） = 0.8307
# Generation: 560. 正答率（トレーニング） = 0.8327833333333333
#                 : 560. 正答率（テスト） = 0.8345
# Generation: 570. 正答率（トレーニング） = 0.8344333333333334
#                 : 570. 正答率（テスト） = 0.837
# Generation: 580. 正答率（トレーニング） = 0.8354666666666667
#                 : 580. 正答率（テスト） = 0.8382
# Generation: 590. 正答率（トレーニング） = 0.8374
#                 : 590. 正答率（テスト） = 0.8416
# Generation: 600. 正答率（トレーニング） = 0.8385666666666667
#                 : 600. 正答率（テスト） = 0.8419
# Generation: 610. 正答率（トレーニング） = 0.8381333333333333
#                 : 610. 正答率（テスト） = 0.8408
# Generation: 620. 正答率（トレーニング） = 0.8398333333333333
#                 : 620. 正答率（テスト） = 0.843
# Generation: 630. 正答率（トレーニング） = 0.8428666666666667
#                 : 630. 正答率（テスト） = 0.8459
# Generation: 640. 正答率（トレーニング） = 0.84295
#                 : 640. 正答率（テスト） = 0.8467
# Generation: 650. 正答率（トレーニング） = 0.8454666666666667
#                 : 650. 正答率（テスト） = 0.8497
# Generation: 660. 正答率（トレーニング） = 0.8465666666666667
#                 : 660. 正答率（テスト） = 0.8493
# Generation: 670. 正答率（トレーニング） = 0.8450333333333333
#                 : 670. 正答率（テスト） = 0.8496
# Generation: 680. 正答率（トレーニング） = 0.8489166666666667
#                 : 680. 正答率（テスト） = 0.8529
# Generation: 690. 正答率（トレーニング） = 0.8486166666666667
#                 : 690. 正答率（テスト） = 0.8519
# Generation: 700. 正答率（トレーニング） = 0.8497833333333333
#                 : 700. 正答率（テスト） = 0.8544
# Generation: 710. 正答率（トレーニング） = 0.8506
#                 : 710. 正答率（テスト） = 0.8549
# Generation: 720. 正答率（トレーニング） = 0.8503833333333334
#                 : 720. 正答率（テスト） = 0.8535
# Generation: 730. 正答率（トレーニング） = 0.8516666666666667
#                 : 730. 正答率（テスト） = 0.8567
# Generation: 740. 正答率（トレーニング） = 0.8527833333333333
#                 : 740. 正答率（テスト） = 0.8583
# Generation: 750. 正答率（トレーニング） = 0.855
#                 : 750. 正答率（テスト） = 0.8606
# Generation: 760. 正答率（トレーニング） = 0.85585
#                 : 760. 正答率（テスト） = 0.86
# Generation: 770. 正答率（トレーニング） = 0.8567833333333333
#                 : 770. 正答率（テスト） = 0.8621
# Generation: 780. 正答率（トレーニング） = 0.8574333333333334
#                 : 780. 正答率（テスト） = 0.8621
# Generation: 790. 正答率（トレーニング） = 0.8584166666666667
#                 : 790. 正答率（テスト） = 0.8632
# Generation: 800. 正答率（トレーニング） = 0.8587
#                 : 800. 正答率（テスト） = 0.8654
# Generation: 810. 正答率（トレーニング） = 0.8600333333333333
#                 : 810. 正答率（テスト） = 0.8666
# Generation: 820. 正答率（トレーニング） = 0.86075
#                 : 820. 正答率（テスト） = 0.8673
# Generation: 830. 正答率（トレーニング） = 0.8621166666666666
#                 : 830. 正答率（テスト） = 0.8674
# Generation: 840. 正答率（トレーニング） = 0.8637333333333334
#                 : 840. 正答率（テスト） = 0.8706
# Generation: 850. 正答率（トレーニング） = 0.86325
#                 : 850. 正答率（テスト） = 0.8698
# Generation: 860. 正答率（トレーニング） = 0.86475
#                 : 860. 正答率（テスト） = 0.8704
# Generation: 870. 正答率（トレーニング） = 0.86565
#                 : 870. 正答率（テスト） = 0.8721
# Generation: 880. 正答率（トレーニング） = 0.86555
#                 : 880. 正答率（テスト） = 0.8711
# Generation: 890. 正答率（トレーニング） = 0.8670833333333333
#                 : 890. 正答率（テスト） = 0.874
# Generation: 900. 正答率（トレーニング） = 0.8678166666666667
#                 : 900. 正答率（テスト） = 0.8747
# Generation: 910. 正答率（トレーニング） = 0.8674666666666667
#                 : 910. 正答率（テスト） = 0.874
# Generation: 920. 正答率（トレーニング） = 0.8684
#                 : 920. 正答率（テスト） = 0.8748
# Generation: 930. 正答率（トレーニング） = 0.8691333333333333
#                 : 930. 正答率（テスト） = 0.8757
# Generation: 940. 正答率（トレーニング） = 0.86835
#                 : 940. 正答率（テスト） = 0.874
# Generation: 950. 正答率（トレーニング） = 0.8708
#                 : 950. 正答率（テスト） = 0.8758
# Generation: 960. 正答率（トレーニング） = 0.8724
#                 : 960. 正答率（テスト） = 0.8785
# Generation: 970. 正答率（トレーニング） = 0.8723833333333333
#                 : 970. 正答率（テスト） = 0.8783
# Generation: 980. 正答率（トレーニング） = 0.8732
#                 : 980. 正答率（テスト） = 0.8783
# Generation: 990. 正答率（トレーニング） = 0.87345
#                 : 990. 正答率（テスト） = 0.8792
# Generation: 1000. 正答率（トレーニング） = 0.8753666666666666
#                 : 1000. 正答率（テスト） = 0.8817
# Generation: 1010. 正答率（トレーニング） = 0.8748333333333334
#                 : 1010. 正答率（テスト） = 0.8826
# Generation: 1020. 正答率（トレーニング） = 0.87615
#                 : 1020. 正答率（テスト） = 0.8809
# Generation: 1030. 正答率（トレーニング） = 0.8745333333333334
#                 : 1030. 正答率（テスト） = 0.8795
# Generation: 1040. 正答率（トレーニング） = 0.8759833333333333
#                 : 1040. 正答率（テスト） = 0.8826
# Generation: 1050. 正答率（トレーニング） = 0.8765166666666667
#                 : 1050. 正答率（テスト） = 0.8826
# Generation: 1060. 正答率（トレーニング） = 0.8759333333333333
#                 : 1060. 正答率（テスト） = 0.8822
# Generation: 1070. 正答率（トレーニング） = 0.8775
#                 : 1070. 正答率（テスト） = 0.8834
# Generation: 1080. 正答率（トレーニング） = 0.8776
#                 : 1080. 正答率（テスト） = 0.8852
# Generation: 1090. 正答率（トレーニング） = 0.87885
#                 : 1090. 正答率（テスト） = 0.8853
# Generation: 1100. 正答率（トレーニング） = 0.87965
#                 : 1100. 正答率（テスト） = 0.8871
# Generation: 1110. 正答率（トレーニング） = 0.88065
#                 : 1110. 正答率（テスト） = 0.8871
# Generation: 1120. 正答率（トレーニング） = 0.8811166666666667
#                 : 1120. 正答率（テスト） = 0.8867
# Generation: 1130. 正答率（トレーニング） = 0.88205
#                 : 1130. 正答率（テスト） = 0.888
# Generation: 1140. 正答率（トレーニング） = 0.88225
#                 : 1140. 正答率（テスト） = 0.8877
# Generation: 1150. 正答率（トレーニング） = 0.8826833333333334
#                 : 1150. 正答率（テスト） = 0.8894
# Generation: 1160. 正答率（トレーニング） = 0.8827666666666667
#                 : 1160. 正答率（テスト） = 0.8905
# Generation: 1170. 正答率（トレーニング） = 0.8833333333333333
#                 : 1170. 正答率（テスト） = 0.8876
# Generation: 1180. 正答率（トレーニング） = 0.8829
#                 : 1180. 正答率（テスト） = 0.8882
# Generation: 1190. 正答率（トレーニング） = 0.8841166666666667
#                 : 1190. 正答率（テスト） = 0.8909
# Generation: 1200. 正答率（トレーニング） = 0.8837666666666667
#                 : 1200. 正答率（テスト） = 0.8904
# Generation: 1210. 正答率（トレーニング） = 0.8849333333333333
#                 : 1210. 正答率（テスト） = 0.892
# Generation: 1220. 正答率（トレーニング） = 0.88525
#                 : 1220. 正答率（テスト） = 0.8911
# Generation: 1230. 正答率（トレーニング） = 0.8859666666666667
#                 : 1230. 正答率（テスト） = 0.8932
# Generation: 1240. 正答率（トレーニング） = 0.8864166666666666
#                 : 1240. 正答率（テスト） = 0.8915
# Generation: 1250. 正答率（トレーニング） = 0.8858
#                 : 1250. 正答率（テスト） = 0.8926
# Generation: 1260. 正答率（トレーニング） = 0.8867166666666667
#                 : 1260. 正答率（テスト） = 0.8941
# Generation: 1270. 正答率（トレーニング） = 0.88795
#                 : 1270. 正答率（テスト） = 0.8947
# Generation: 1280. 正答率（トレーニング） = 0.8869333333333334
#                 : 1280. 正答率（テスト） = 0.8935
# Generation: 1290. 正答率（トレーニング） = 0.8871166666666667
#                 : 1290. 正答率（テスト） = 0.8938
# Generation: 1300. 正答率（トレーニング） = 0.8869166666666667
#                 : 1300. 正答率（テスト） = 0.8929
# Generation: 1310. 正答率（トレーニング） = 0.8886833333333334
#                 : 1310. 正答率（テスト） = 0.895
# Generation: 1320. 正答率（トレーニング） = 0.89015
#                 : 1320. 正答率（テスト） = 0.8953
# Generation: 1330. 正答率（トレーニング） = 0.8897833333333334
#                 : 1330. 正答率（テスト） = 0.8961
# Generation: 1340. 正答率（トレーニング） = 0.8906333333333334
#                 : 1340. 正答率（テスト） = 0.8973
# Generation: 1350. 正答率（トレーニング） = 0.89095
#                 : 1350. 正答率（テスト） = 0.8963
# Generation: 1360. 正答率（トレーニング） = 0.8905666666666666
#                 : 1360. 正答率（テスト） = 0.8969
# Generation: 1370. 正答率（トレーニング） = 0.8903333333333333
#                 : 1370. 正答率（テスト） = 0.8972
# Generation: 1380. 正答率（トレーニング） = 0.8917
#                 : 1380. 正答率（テスト） = 0.8977
# Generation: 1390. 正答率（トレーニング） = 0.8913833333333333
#                 : 1390. 正答率（テスト） = 0.8981
# Generation: 1400. 正答率（トレーニング） = 0.8913333333333333
#                 : 1400. 正答率（テスト） = 0.8969
# Generation: 1410. 正答率（トレーニング） = 0.8930333333333333
#                 : 1410. 正答率（テスト） = 0.9003
# Generation: 1420. 正答率（トレーニング） = 0.8924333333333333
#                 : 1420. 正答率（テスト） = 0.8983
# Generation: 1430. 正答率（トレーニング） = 0.8926833333333334
#                 : 1430. 正答率（テスト） = 0.8992
# Generation: 1440. 正答率（トレーニング） = 0.8918166666666667
#                 : 1440. 正答率（テスト） = 0.897
# Generation: 1450. 正答率（トレーニング） = 0.8930166666666667
#                 : 1450. 正答率（テスト） = 0.8989
# Generation: 1460. 正答率（トレーニング） = 0.8932
#                 : 1460. 正答率（テスト） = 0.8997
# Generation: 1470. 正答率（トレーニング） = 0.8944333333333333
#                 : 1470. 正答率（テスト） = 0.8991
# Generation: 1480. 正答率（トレーニング） = 0.89485
#                 : 1480. 正答率（テスト） = 0.9006
# Generation: 1490. 正答率（トレーニング） = 0.89505
#                 : 1490. 正答率（テスト） = 0.9007
# Generation: 1500. 正答率（トレーニング） = 0.8962166666666667
#                 : 1500. 正答率（テスト） = 0.9009
# Generation: 1510. 正答率（トレーニング） = 0.8958166666666667
#                 : 1510. 正答率（テスト） = 0.9015
# Generation: 1520. 正答率（トレーニング） = 0.8952166666666667
#                 : 1520. 正答率（テスト） = 0.9005
# Generation: 1530. 正答率（トレーニング） = 0.8965166666666666
#                 : 1530. 正答率（テスト） = 0.9005
# Generation: 1540. 正答率（トレーニング） = 0.8960333333333333
#                 : 1540. 正答率（テスト） = 0.9014
# Generation: 1550. 正答率（トレーニング） = 0.8968166666666667
#                 : 1550. 正答率（テスト） = 0.9019
# Generation: 1560. 正答率（トレーニング） = 0.8970666666666667
#                 : 1560. 正答率（テスト） = 0.9023
# Generation: 1570. 正答率（トレーニング） = 0.8975666666666666
#                 : 1570. 正答率（テスト） = 0.9041
# Generation: 1580. 正答率（トレーニング） = 0.8977833333333334
#                 : 1580. 正答率（テスト） = 0.9035
# Generation: 1590. 正答率（トレーニング） = 0.8981666666666667
#                 : 1590. 正答率（テスト） = 0.9035
# Generation: 1600. 正答率（トレーニング） = 0.8975
#                 : 1600. 正答率（テスト） = 0.9031
# Generation: 1610. 正答率（トレーニング） = 0.8978833333333334
#                 : 1610. 正答率（テスト） = 0.904
# Generation: 1620. 正答率（トレーニング） = 0.89845
#                 : 1620. 正答率（テスト） = 0.904
# Generation: 1630. 正答率（トレーニング） = 0.899
#                 : 1630. 正答率（テスト） = 0.9039
# Generation: 1640. 正答率（トレーニング） = 0.89915
#                 : 1640. 正答率（テスト） = 0.9041
# Generation: 1650. 正答率（トレーニング） = 0.8993333333333333
#                 : 1650. 正答率（テスト） = 0.9051
# Generation: 1660. 正答率（トレーニング） = 0.8991
#                 : 1660. 正答率（テスト） = 0.9041
# Generation: 1670. 正答率（トレーニング） = 0.9002333333333333
#                 : 1670. 正答率（テスト） = 0.905
# Generation: 1680. 正答率（トレーニング） = 0.89995
#                 : 1680. 正答率（テスト） = 0.9045
# Generation: 1690. 正答率（トレーニング） = 0.9002333333333333
#                 : 1690. 正答率（テスト） = 0.9059
# Generation: 1700. 正答率（トレーニング） = 0.90065
#                 : 1700. 正答率（テスト） = 0.9064
# Generation: 1710. 正答率（トレーニング） = 0.9009666666666667
#                 : 1710. 正答率（テスト） = 0.9058
# Generation: 1720. 正答率（トレーニング） = 0.9007833333333334
#                 : 1720. 正答率（テスト） = 0.9068
# Generation: 1730. 正答率（トレーニング） = 0.9017666666666667
#                 : 1730. 正答率（テスト） = 0.9061
# Generation: 1740. 正答率（トレーニング） = 0.9015
#                 : 1740. 正答率（テスト） = 0.9064
# Generation: 1750. 正答率（トレーニング） = 0.9018333333333334
#                 : 1750. 正答率（テスト） = 0.906
# Generation: 1760. 正答率（トレーニング） = 0.9027166666666666
#                 : 1760. 正答率（テスト） = 0.9072
# Generation: 1770. 正答率（トレーニング） = 0.9015
#                 : 1770. 正答率（テスト） = 0.9059
# Generation: 1780. 正答率（トレーニング） = 0.9016166666666666
#                 : 1780. 正答率（テスト） = 0.9064
# Generation: 1790. 正答率（トレーニング） = 0.90005
#                 : 1790. 正答率（テスト） = 0.9053
# Generation: 1800. 正答率（トレーニング） = 0.90325
#                 : 1800. 正答率（テスト） = 0.9074
# Generation: 1810. 正答率（トレーニング） = 0.9025
#                 : 1810. 正答率（テスト） = 0.9065
# Generation: 1820. 正答率（トレーニング） = 0.9032666666666667
#                 : 1820. 正答率（テスト） = 0.9084
# Generation: 1830. 正答率（トレーニング） = 0.9036666666666666
#                 : 1830. 正答率（テスト） = 0.908
# Generation: 1840. 正答率（トレーニング） = 0.9037666666666667
#                 : 1840. 正答率（テスト） = 0.9077
# Generation: 1850. 正答率（トレーニング） = 0.9041833333333333
#                 : 1850. 正答率（テスト） = 0.9084
# Generation: 1860. 正答率（トレーニング） = 0.9042
#                 : 1860. 正答率（テスト） = 0.9087
# Generation: 1870. 正答率（トレーニング） = 0.9029
#                 : 1870. 正答率（テスト） = 0.9088
# Generation: 1880. 正答率（トレーニング） = 0.9039666666666667
#                 : 1880. 正答率（テスト） = 0.9079
# Generation: 1890. 正答率（トレーニング） = 0.9033
#                 : 1890. 正答率（テスト） = 0.9083
# Generation: 1900. 正答率（トレーニング） = 0.9041833333333333
#                 : 1900. 正答率（テスト） = 0.9094
# Generation: 1910. 正答率（トレーニング） = 0.9049666666666667
#                 : 1910. 正答率（テスト） = 0.9094
# Generation: 1920. 正答率（トレーニング） = 0.9039833333333334
#                 : 1920. 正答率（テスト） = 0.9093
# Generation: 1930. 正答率（トレーニング） = 0.9046833333333333
#                 : 1930. 正答率（テスト） = 0.9096
# Generation: 1940. 正答率（トレーニング） = 0.90495
#                 : 1940. 正答率（テスト） = 0.9097
# Generation: 1950. 正答率（トレーニング） = 0.9058166666666667
#                 : 1950. 正答率（テスト） = 0.9099
# Generation: 1960. 正答率（トレーニング） = 0.9061
#                 : 1960. 正答率（テスト） = 0.91
# Generation: 1970. 正答率（トレーニング） = 0.9062333333333333
#                 : 1970. 正答率（テスト） = 0.9101
# Generation: 1980. 正答率（トレーニング） = 0.9056833333333333
#                 : 1980. 正答率（テスト） = 0.91
# Generation: 1990. 正答率（トレーニング） = 0.9052
#                 : 1990. 正答率（テスト） = 0.9105
# Generation: 2000. 正答率（トレーニング） = 0.9062
#                 : 2000. 正答率（テスト） = 0.9099

# %%
Tester5.plot_results()
plt.show()

# %%
Tester6 = OptimizerTest(activation = "relu", weight_init_std = "He" , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test, OptimizerType = "Momentum")
Tester6.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.1964
#                 : 10. 正答率（テスト） = 0.2016
# Generation: 20. 正答率（トレーニング） = 0.3612166666666667
#                 : 20. 正答率（テスト） = 0.3622
# Generation: 30. 正答率（トレーニング） = 0.48586666666666667
#                 : 30. 正答率（テスト） = 0.4927
# Generation: 40. 正答率（トレーニング） = 0.67675
#                 : 40. 正答率（テスト） = 0.6792
# Generation: 50. 正答率（トレーニング） = 0.7612
#                 : 50. 正答率（テスト） = 0.7682
# Generation: 60. 正答率（トレーニング） = 0.8021833333333334
#                 : 60. 正答率（テスト） = 0.8145
# Generation: 70. 正答率（トレーニング） = 0.8281
#                 : 70. 正答率（テスト） = 0.8344
# Generation: 80. 正答率（トレーニング） = 0.8459333333333333
#                 : 80. 正答率（テスト） = 0.8464
# Generation: 90. 正答率（トレーニング） = 0.8445
#                 : 90. 正答率（テスト） = 0.8506
# Generation: 100. 正答率（トレーニング） = 0.861
#                 : 100. 正答率（テスト） = 0.8637
# Generation: 110. 正答率（トレーニング） = 0.8717666666666667
#                 : 110. 正答率（テスト） = 0.8735
# Generation: 120. 正答率（トレーニング） = 0.8613166666666666
#                 : 120. 正答率（テスト） = 0.8688
# Generation: 130. 正答率（トレーニング） = 0.8749166666666667
#                 : 130. 正答率（テスト） = 0.8792
# Generation: 140. 正答率（トレーニング） = 0.8803
#                 : 140. 正答率（テスト） = 0.882
# Generation: 150. 正答率（トレーニング） = 0.8847166666666667
#                 : 150. 正答率（テスト） = 0.8847
# Generation: 160. 正答率（トレーニング） = 0.8883166666666666
#                 : 160. 正答率（テスト） = 0.8878
# Generation: 170. 正答率（トレーニング） = 0.8875
#                 : 170. 正答率（テスト） = 0.892
# Generation: 180. 正答率（トレーニング） = 0.8919833333333334
#                 : 180. 正答率（テスト） = 0.8907
# Generation: 190. 正答率（トレーニング） = 0.8958333333333334
#                 : 190. 正答率（テスト） = 0.8971
# Generation: 200. 正答率（トレーニング） = 0.88865
#                 : 200. 正答率（テスト） = 0.8925
# Generation: 210. 正答率（トレーニング） = 0.88835
#                 : 210. 正答率（テスト） = 0.8881
# Generation: 220. 正答率（トレーニング） = 0.8902333333333333
#                 : 220. 正答率（テスト） = 0.8928
# Generation: 230. 正答率（トレーニング） = 0.8945
#                 : 230. 正答率（テスト） = 0.8929
# Generation: 240. 正答率（トレーニング） = 0.8959166666666667
#                 : 240. 正答率（テスト） = 0.8986
# Generation: 250. 正答率（トレーニング） = 0.89335
#                 : 250. 正答率（テスト） = 0.8962
# Generation: 260. 正答率（トレーニング） = 0.9046333333333333
#                 : 260. 正答率（テスト） = 0.9067
# Generation: 270. 正答率（トレーニング） = 0.9033666666666667
#                 : 270. 正答率（テスト） = 0.9046
# Generation: 280. 正答率（トレーニング） = 0.9045
#                 : 280. 正答率（テスト） = 0.907
# Generation: 290. 正答率（トレーニング） = 0.9069833333333334
#                 : 290. 正答率（テスト） = 0.909
# Generation: 300. 正答率（トレーニング） = 0.9072
#                 : 300. 正答率（テスト） = 0.9098
# Generation: 310. 正答率（トレーニング） = 0.9121833333333333
#                 : 310. 正答率（テスト） = 0.9131
# Generation: 320. 正答率（トレーニング） = 0.91
#                 : 320. 正答率（テスト） = 0.9097
# Generation: 330. 正答率（トレーニング） = 0.9088666666666667
#                 : 330. 正答率（テスト） = 0.9086
# Generation: 340. 正答率（トレーニング） = 0.9146
#                 : 340. 正答率（テスト） = 0.9138
# Generation: 350. 正答率（トレーニング） = 0.9132833333333333
#                 : 350. 正答率（テスト） = 0.914
# Generation: 360. 正答率（トレーニング） = 0.9152333333333333
#                 : 360. 正答率（テスト） = 0.9169
# Generation: 370. 正答率（トレーニング） = 0.9122166666666667
#                 : 370. 正答率（テスト） = 0.913
# Generation: 380. 正答率（トレーニング） = 0.9123333333333333
#                 : 380. 正答率（テスト） = 0.9143
# Generation: 390. 正答率（トレーニング） = 0.91425
#                 : 390. 正答率（テスト） = 0.9149
# Generation: 400. 正答率（トレーニング） = 0.9174
#                 : 400. 正答率（テスト） = 0.9168
# Generation: 410. 正答率（トレーニング） = 0.9125666666666666
#                 : 410. 正答率（テスト） = 0.9167
# Generation: 420. 正答率（トレーニング） = 0.9153666666666667
#                 : 420. 正答率（テスト） = 0.9154
# Generation: 430. 正答率（トレーニング） = 0.9139833333333334
#                 : 430. 正答率（テスト） = 0.9145
# Generation: 440. 正答率（トレーニング） = 0.9214666666666667
#                 : 440. 正答率（テスト） = 0.9203
# Generation: 450. 正答率（トレーニング） = 0.9189833333333334
#                 : 450. 正答率（テスト） = 0.9187
# Generation: 460. 正答率（トレーニング） = 0.9199333333333334
#                 : 460. 正答率（テスト） = 0.9204
# Generation: 470. 正答率（トレーニング） = 0.9189
#                 : 470. 正答率（テスト） = 0.9181
# Generation: 480. 正答率（トレーニング） = 0.9211
#                 : 480. 正答率（テスト） = 0.9207
# Generation: 490. 正答率（トレーニング） = 0.92565
#                 : 490. 正答率（テスト） = 0.925
# Generation: 500. 正答率（トレーニング） = 0.9200833333333334
#                 : 500. 正答率（テスト） = 0.9227
# Generation: 510. 正答率（トレーニング） = 0.9230333333333334
#                 : 510. 正答率（テスト） = 0.9233
# Generation: 520. 正答率（トレーニング） = 0.9235166666666667
#                 : 520. 正答率（テスト） = 0.9225
# Generation: 530. 正答率（トレーニング） = 0.9240166666666667
#                 : 530. 正答率（テスト） = 0.9234
# Generation: 540. 正答率（トレーニング） = 0.92335
#                 : 540. 正答率（テスト） = 0.9235
# Generation: 550. 正答率（トレーニング） = 0.9218333333333333
#                 : 550. 正答率（テスト） = 0.9224
# Generation: 560. 正答率（トレーニング） = 0.92515
#                 : 560. 正答率（テスト） = 0.9227
# Generation: 570. 正答率（トレーニング） = 0.9270833333333334
#                 : 570. 正答率（テスト） = 0.9269
# Generation: 580. 正答率（トレーニング） = 0.9288333333333333
#                 : 580. 正答率（テスト） = 0.928
# Generation: 590. 正答率（トレーニング） = 0.9285666666666667
#                 : 590. 正答率（テスト） = 0.9268
# Generation: 600. 正答率（トレーニング） = 0.9233666666666667
#                 : 600. 正答率（テスト） = 0.9208
# Generation: 610. 正答率（トレーニング） = 0.9254666666666667
#                 : 610. 正答率（テスト） = 0.9239
# Generation: 620. 正答率（トレーニング） = 0.9300666666666667
#                 : 620. 正答率（テスト） = 0.929
# Generation: 630. 正答率（トレーニング） = 0.9259833333333334
#                 : 630. 正答率（テスト） = 0.9245
# Generation: 640. 正答率（トレーニング） = 0.9291
#                 : 640. 正答率（テスト） = 0.9274
# Generation: 650. 正答率（トレーニング） = 0.9304333333333333
#                 : 650. 正答率（テスト） = 0.9281
# Generation: 660. 正答率（トレーニング） = 0.9321666666666667
#                 : 660. 正答率（テスト） = 0.9313
# Generation: 670. 正答率（トレーニング） = 0.9324
#                 : 670. 正答率（テスト） = 0.9302
# Generation: 680. 正答率（トレーニング） = 0.9317666666666666
#                 : 680. 正答率（テスト） = 0.9329
# Generation: 690. 正答率（トレーニング） = 0.92755
#                 : 690. 正答率（テスト） = 0.9269
# Generation: 700. 正答率（トレーニング） = 0.9278166666666666
#                 : 700. 正答率（テスト） = 0.9257
# Generation: 710. 正答率（トレーニング） = 0.9280666666666667
#                 : 710. 正答率（テスト） = 0.9278
# Generation: 720. 正答率（トレーニング） = 0.927
#                 : 720. 正答率（テスト） = 0.9268
# Generation: 730. 正答率（トレーニング） = 0.9342166666666667
#                 : 730. 正答率（テスト） = 0.9295
# Generation: 740. 正答率（トレーニング） = 0.9324
#                 : 740. 正答率（テスト） = 0.9306
# Generation: 750. 正答率（トレーニング） = 0.9275833333333333
#                 : 750. 正答率（テスト） = 0.9237
# Generation: 760. 正答率（トレーニング） = 0.93675
#                 : 760. 正答率（テスト） = 0.9337
# Generation: 770. 正答率（トレーニング） = 0.93635
#                 : 770. 正答率（テスト） = 0.9358
# Generation: 780. 正答率（トレーニング） = 0.9364
#                 : 780. 正答率（テスト） = 0.9339
# Generation: 790. 正答率（トレーニング） = 0.9352166666666667
#                 : 790. 正答率（テスト） = 0.9332
# Generation: 800. 正答率（トレーニング） = 0.93615
#                 : 800. 正答率（テスト） = 0.933
# Generation: 810. 正答率（トレーニング） = 0.93585
#                 : 810. 正答率（テスト） = 0.935
# Generation: 820. 正答率（トレーニング） = 0.9345833333333333
#                 : 820. 正答率（テスト） = 0.9334
# Generation: 830. 正答率（トレーニング） = 0.9403166666666667
#                 : 830. 正答率（テスト） = 0.9378
# Generation: 840. 正答率（トレーニング） = 0.94
#                 : 840. 正答率（テスト） = 0.9396
# Generation: 850. 正答率（トレーニング） = 0.9373833333333333
#                 : 850. 正答率（テスト） = 0.9351
# Generation: 860. 正答率（トレーニング） = 0.9343333333333333
#                 : 860. 正答率（テスト） = 0.9325
# Generation: 870. 正答率（トレーニング） = 0.935
#                 : 870. 正答率（テスト） = 0.9355
# Generation: 880. 正答率（トレーニング） = 0.93675
#                 : 880. 正答率（テスト） = 0.9339
# Generation: 890. 正答率（トレーニング） = 0.9383833333333333
#                 : 890. 正答率（テスト） = 0.936
# Generation: 900. 正答率（トレーニング） = 0.9395833333333333
#                 : 900. 正答率（テスト） = 0.9395
# Generation: 910. 正答率（トレーニング） = 0.9394333333333333
#                 : 910. 正答率（テスト） = 0.9363
# Generation: 920. 正答率（トレーニング） = 0.9353
#                 : 920. 正答率（テスト） = 0.9344
# Generation: 930. 正答率（トレーニング） = 0.9380666666666667
#                 : 930. 正答率（テスト） = 0.9336
# Generation: 940. 正答率（トレーニング） = 0.9353833333333333
#                 : 940. 正答率（テスト） = 0.93
# Generation: 950. 正答率（トレーニング） = 0.9377333333333333
#                 : 950. 正答率（テスト） = 0.9339
# Generation: 960. 正答率（トレーニング） = 0.94115
#                 : 960. 正答率（テスト） = 0.9377
# Generation: 970. 正答率（トレーニング） = 0.9418166666666666
#                 : 970. 正答率（テスト） = 0.94
# Generation: 980. 正答率（トレーニング） = 0.9425333333333333
#                 : 980. 正答率（テスト） = 0.9398
# Generation: 990. 正答率（トレーニング） = 0.94035
#                 : 990. 正答率（テスト） = 0.9388
# Generation: 1000. 正答率（トレーニング） = 0.9419833333333333
#                 : 1000. 正答率（テスト） = 0.9421
# Generation: 1010. 正答率（トレーニング） = 0.9427833333333333
#                 : 1010. 正答率（テスト） = 0.94
# Generation: 1020. 正答率（トレーニング） = 0.9405833333333333
#                 : 1020. 正答率（テスト） = 0.9365
# Generation: 1030. 正答率（トレーニング） = 0.9433666666666667
#                 : 1030. 正答率（テスト） = 0.9409
# Generation: 1040. 正答率（トレーニング） = 0.9418333333333333
#                 : 1040. 正答率（テスト） = 0.9372
# Generation: 1050. 正答率（トレーニング） = 0.9414166666666667
#                 : 1050. 正答率（テスト） = 0.9366
# Generation: 1060. 正答率（トレーニング） = 0.9436666666666667
#                 : 1060. 正答率（テスト） = 0.9406
# Generation: 1070. 正答率（トレーニング） = 0.9448833333333333
#                 : 1070. 正答率（テスト） = 0.9399
# Generation: 1080. 正答率（トレーニング） = 0.9447
#                 : 1080. 正答率（テスト） = 0.9416
# Generation: 1090. 正答率（トレーニング） = 0.9453166666666667
#                 : 1090. 正答率（テスト） = 0.9426
# Generation: 1100. 正答率（トレーニング） = 0.9444
#                 : 1100. 正答率（テスト） = 0.9415
# Generation: 1110. 正答率（トレーニング） = 0.9453166666666667
#                 : 1110. 正答率（テスト） = 0.9425
# Generation: 1120. 正答率（トレーニング） = 0.9455333333333333
#                 : 1120. 正答率（テスト） = 0.9418
# Generation: 1130. 正答率（トレーニング） = 0.9434166666666667
#                 : 1130. 正答率（テスト） = 0.9387
# Generation: 1140. 正答率（トレーニング） = 0.9438166666666666
#                 : 1140. 正答率（テスト） = 0.942
# Generation: 1150. 正答率（トレーニング） = 0.9442166666666667
#                 : 1150. 正答率（テスト） = 0.9421
# Generation: 1160. 正答率（トレーニング） = 0.9433
#                 : 1160. 正答率（テスト） = 0.9419
# Generation: 1170. 正答率（トレーニング） = 0.9468166666666666
#                 : 1170. 正答率（テスト） = 0.9423
# Generation: 1180. 正答率（トレーニング） = 0.9456666666666667
#                 : 1180. 正答率（テスト） = 0.9405
# Generation: 1190. 正答率（トレーニング） = 0.9482833333333334
#                 : 1190. 正答率（テスト） = 0.9441
# Generation: 1200. 正答率（トレーニング） = 0.9474833333333333
#                 : 1200. 正答率（テスト） = 0.9452
# Generation: 1210. 正答率（トレーニング） = 0.94585
#                 : 1210. 正答率（テスト） = 0.942
# Generation: 1220. 正答率（トレーニング） = 0.94425
#                 : 1220. 正答率（テスト） = 0.939
# Generation: 1230. 正答率（トレーニング） = 0.9474166666666667
#                 : 1230. 正答率（テスト） = 0.9442
# Generation: 1240. 正答率（トレーニング） = 0.9477833333333333
#                 : 1240. 正答率（テスト） = 0.946
# Generation: 1250. 正答率（トレーニング） = 0.9469833333333333
#                 : 1250. 正答率（テスト） = 0.944
# Generation: 1260. 正答率（トレーニング） = 0.9452833333333334
#                 : 1260. 正答率（テスト） = 0.9427
# Generation: 1270. 正答率（トレーニング） = 0.9491
#                 : 1270. 正答率（テスト） = 0.9447
# Generation: 1280. 正答率（トレーニング） = 0.9496166666666667
#                 : 1280. 正答率（テスト） = 0.9468
# Generation: 1290. 正答率（トレーニング） = 0.9478166666666666
#                 : 1290. 正答率（テスト） = 0.9434
# Generation: 1300. 正答率（トレーニング） = 0.9491333333333334
#                 : 1300. 正答率（テスト） = 0.945
# Generation: 1310. 正答率（トレーニング） = 0.9468
#                 : 1310. 正答率（テスト） = 0.9437
# Generation: 1320. 正答率（トレーニング） = 0.9490166666666666
#                 : 1320. 正答率（テスト） = 0.946
# Generation: 1330. 正答率（トレーニング） = 0.94885
#                 : 1330. 正答率（テスト） = 0.9454
# Generation: 1340. 正答率（トレーニング） = 0.9463833333333334
#                 : 1340. 正答率（テスト） = 0.9405
# Generation: 1350. 正答率（トレーニング） = 0.9491166666666667
#                 : 1350. 正答率（テスト） = 0.9446
# Generation: 1360. 正答率（トレーニング） = 0.9504833333333333
#                 : 1360. 正答率（テスト） = 0.9456
# Generation: 1370. 正答率（トレーニング） = 0.9500166666666666
#                 : 1370. 正答率（テスト） = 0.944
# Generation: 1380. 正答率（トレーニング） = 0.94975
#                 : 1380. 正答率（テスト） = 0.9452
# Generation: 1390. 正答率（トレーニング） = 0.9505166666666667
#                 : 1390. 正答率（テスト） = 0.9481
# Generation: 1400. 正答率（トレーニング） = 0.95145
#                 : 1400. 正答率（テスト） = 0.9476
# Generation: 1410. 正答率（トレーニング） = 0.9475666666666667
#                 : 1410. 正答率（テスト） = 0.9452
# Generation: 1420. 正答率（トレーニング） = 0.9524666666666667
#                 : 1420. 正答率（テスト） = 0.9483
# Generation: 1430. 正答率（トレーニング） = 0.9499166666666666
#                 : 1430. 正答率（テスト） = 0.9461
# Generation: 1440. 正答率（トレーニング） = 0.9515166666666667
#                 : 1440. 正答率（テスト） = 0.9448
# Generation: 1450. 正答率（トレーニング） = 0.9513666666666667
#                 : 1450. 正答率（テスト） = 0.9483
# Generation: 1460. 正答率（トレーニング） = 0.9543
#                 : 1460. 正答率（テスト） = 0.9509
# Generation: 1470. 正答率（トレーニング） = 0.9514666666666667
#                 : 1470. 正答率（テスト） = 0.9478
# Generation: 1480. 正答率（トレーニング） = 0.951
#                 : 1480. 正答率（テスト） = 0.9484
# Generation: 1490. 正答率（トレーニング） = 0.9540833333333333
#                 : 1490. 正答率（テスト） = 0.9487
# Generation: 1500. 正答率（トレーニング） = 0.9529166666666666
#                 : 1500. 正答率（テスト） = 0.9489
# Generation: 1510. 正答率（トレーニング） = 0.9532166666666667
#                 : 1510. 正答率（テスト） = 0.9511
# Generation: 1520. 正答率（トレーニング） = 0.9540166666666666
#                 : 1520. 正答率（テスト） = 0.9518
# Generation: 1530. 正答率（トレーニング） = 0.9536833333333333
#                 : 1530. 正答率（テスト） = 0.9478
# Generation: 1540. 正答率（トレーニング） = 0.9511
#                 : 1540. 正答率（テスト） = 0.9469
# Generation: 1550. 正答率（トレーニング） = 0.9531833333333334
#                 : 1550. 正答率（テスト） = 0.9488
# Generation: 1560. 正答率（トレーニング） = 0.9514
#                 : 1560. 正答率（テスト） = 0.946
# Generation: 1570. 正答率（トレーニング） = 0.9522333333333334
#                 : 1570. 正答率（テスト） = 0.9489
# Generation: 1580. 正答率（トレーニング） = 0.9530833333333333
#                 : 1580. 正答率（テスト） = 0.9484
# Generation: 1590. 正答率（トレーニング） = 0.9551833333333334
#                 : 1590. 正答率（テスト） = 0.9503
# Generation: 1600. 正答率（トレーニング） = 0.953
#                 : 1600. 正答率（テスト） = 0.9466
# Generation: 1610. 正答率（トレーニング） = 0.9518333333333333
#                 : 1610. 正答率（テスト） = 0.9469
# Generation: 1620. 正答率（トレーニング） = 0.9501833333333334
#                 : 1620. 正答率（テスト） = 0.9455
# Generation: 1630. 正答率（トレーニング） = 0.9546
#                 : 1630. 正答率（テスト） = 0.9496
# Generation: 1640. 正答率（トレーニング） = 0.95325
#                 : 1640. 正答率（テスト） = 0.95
# Generation: 1650. 正答率（トレーニング） = 0.9527166666666667
#                 : 1650. 正答率（テスト） = 0.9504
# Generation: 1660. 正答率（トレーニング） = 0.9483833333333334
#                 : 1660. 正答率（テスト） = 0.9434
# Generation: 1670. 正答率（トレーニング） = 0.9534333333333334
#                 : 1670. 正答率（テスト） = 0.9502
# Generation: 1680. 正答率（トレーニング） = 0.9537666666666667
#                 : 1680. 正答率（テスト） = 0.95
# Generation: 1690. 正答率（トレーニング） = 0.9518
#                 : 1690. 正答率（テスト） = 0.9477
# Generation: 1700. 正答率（トレーニング） = 0.9551166666666666
#                 : 1700. 正答率（テスト） = 0.9491
# Generation: 1710. 正答率（トレーニング） = 0.9550333333333333
#                 : 1710. 正答率（テスト） = 0.9497
# Generation: 1720. 正答率（トレーニング） = 0.9538666666666666
#                 : 1720. 正答率（テスト） = 0.9493
# Generation: 1730. 正答率（トレーニング） = 0.95425
#                 : 1730. 正答率（テスト） = 0.9502
# Generation: 1740. 正答率（トレーニング） = 0.9569166666666666
#                 : 1740. 正答率（テスト） = 0.9519
# Generation: 1750. 正答率（トレーニング） = 0.9580333333333333
#                 : 1750. 正答率（テスト） = 0.9534
# Generation: 1760. 正答率（トレーニング） = 0.9567666666666667
#                 : 1760. 正答率（テスト） = 0.9526
# Generation: 1770. 正答率（トレーニング） = 0.95705
#                 : 1770. 正答率（テスト） = 0.9522
# Generation: 1780. 正答率（トレーニング） = 0.9575
#                 : 1780. 正答率（テスト） = 0.9518
# Generation: 1790. 正答率（トレーニング） = 0.9578166666666666
#                 : 1790. 正答率（テスト） = 0.9536
# Generation: 1800. 正答率（トレーニング） = 0.9583166666666667
#                 : 1800. 正答率（テスト） = 0.9531
# Generation: 1810. 正答率（トレーニング） = 0.95865
#                 : 1810. 正答率（テスト） = 0.9532
# Generation: 1820. 正答率（トレーニング） = 0.95785
#                 : 1820. 正答率（テスト） = 0.9519
# Generation: 1830. 正答率（トレーニング） = 0.9554833333333334
#                 : 1830. 正答率（テスト） = 0.9494
# Generation: 1840. 正答率（トレーニング） = 0.9524833333333333
#                 : 1840. 正答率（テスト） = 0.9481
# Generation: 1850. 正答率（トレーニング） = 0.9514666666666667
#                 : 1850. 正答率（テスト） = 0.9475
# Generation: 1860. 正答率（トレーニング） = 0.9565166666666667
#                 : 1860. 正答率（テスト） = 0.9516
# Generation: 1870. 正答率（トレーニング） = 0.9571
#                 : 1870. 正答率（テスト） = 0.9541
# Generation: 1880. 正答率（トレーニング） = 0.9585833333333333
#                 : 1880. 正答率（テスト） = 0.9542
# Generation: 1890. 正答率（トレーニング） = 0.9575
#                 : 1890. 正答率（テスト） = 0.9539
# Generation: 1900. 正答率（トレーニング） = 0.9592333333333334
#                 : 1900. 正答率（テスト） = 0.9533
# Generation: 1910. 正答率（トレーニング） = 0.9561833333333334
#                 : 1910. 正答率（テスト） = 0.9511
# Generation: 1920. 正答率（トレーニング） = 0.9562333333333334
#                 : 1920. 正答率（テスト） = 0.95
# Generation: 1930. 正答率（トレーニング） = 0.95855
#                 : 1930. 正答率（テスト） = 0.9523
# Generation: 1940. 正答率（トレーニング） = 0.9582666666666667
#                 : 1940. 正答率（テスト） = 0.9532
# Generation: 1950. 正答率（トレーニング） = 0.9560333333333333
#                 : 1950. 正答率（テスト） = 0.9499
# Generation: 1960. 正答率（トレーニング） = 0.956
#                 : 1960. 正答率（テスト） = 0.9514
# Generation: 1970. 正答率（トレーニング） = 0.9583666666666667
#                 : 1970. 正答率（テスト） = 0.9539
# Generation: 1980. 正答率（トレーニング） = 0.9575833333333333
#                 : 1980. 正答率（テスト） = 0.9544
# Generation: 1990. 正答率（トレーニング） = 0.9599
#                 : 1990. 正答率（テスト） = 0.9543
# Generation: 2000. 正答率（トレーニング） = 0.9591833333333334
#                 : 2000. 正答率（テスト） = 0.9534

# %%
Tester6.plot_results()
plt.show()

# %%
Tester7 = OptimizerTest(activation = "relu", weight_init_std = "He" , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test, OptimizerType = "AdaGrad")
Tester7.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.49355
#                 : 10. 正答率（テスト） = 0.5036
# Generation: 20. 正答率（トレーニング） = 0.6014
#                 : 20. 正答率（テスト） = 0.611
# Generation: 30. 正答率（トレーニング） = 0.71155
#                 : 30. 正答率（テスト） = 0.7199
# Generation: 40. 正答率（トレーニング） = 0.7874333333333333
#                 : 40. 正答率（テスト） = 0.7991
# Generation: 50. 正答率（トレーニング） = 0.8348166666666667
#                 : 50. 正答率（テスト） = 0.8434
# Generation: 60. 正答率（トレーニング） = 0.8480833333333333
#                 : 60. 正答率（テスト） = 0.8543
# Generation: 70. 正答率（トレーニング） = 0.86325
#                 : 70. 正答率（テスト） = 0.8669
# Generation: 80. 正答率（トレーニング） = 0.8696
#                 : 80. 正答率（テスト） = 0.8763
# Generation: 90. 正答率（トレーニング） = 0.8708666666666667
#                 : 90. 正答率（テスト） = 0.877
# Generation: 100. 正答率（トレーニング） = 0.8803666666666666
#                 : 100. 正答率（テスト） = 0.8819
# Generation: 110. 正答率（トレーニング） = 0.8797
#                 : 110. 正答率（テスト） = 0.8814
# Generation: 120. 正答率（トレーニング） = 0.8841833333333333
#                 : 120. 正答率（テスト） = 0.8868
# Generation: 130. 正答率（トレーニング） = 0.8874666666666666
#                 : 130. 正答率（テスト） = 0.8904
# Generation: 140. 正答率（トレーニング） = 0.8893166666666666
#                 : 140. 正答率（テスト） = 0.8894
# Generation: 150. 正答率（トレーニング） = 0.8855833333333333
#                 : 150. 正答率（テスト） = 0.8894
# Generation: 160. 正答率（トレーニング） = 0.8931
#                 : 160. 正答率（テスト） = 0.8966
# Generation: 170. 正答率（トレーニング） = 0.8953333333333333
#                 : 170. 正答率（テスト） = 0.8968
# Generation: 180. 正答率（トレーニング） = 0.8961
#                 : 180. 正答率（テスト） = 0.8966
# Generation: 190. 正答率（トレーニング） = 0.9015166666666666
#                 : 190. 正答率（テスト） = 0.901
# Generation: 200. 正答率（トレーニング） = 0.90175
#                 : 200. 正答率（テスト） = 0.9002
# Generation: 210. 正答率（トレーニング） = 0.90575
#                 : 210. 正答率（テスト） = 0.9039
# Generation: 220. 正答率（トレーニング） = 0.90565
#                 : 220. 正答率（テスト） = 0.9027
# Generation: 230. 正答率（トレーニング） = 0.9081
#                 : 230. 正答率（テスト） = 0.9038
# Generation: 240. 正答率（トレーニング） = 0.9086
#                 : 240. 正答率（テスト） = 0.9062
# Generation: 250. 正答率（トレーニング） = 0.90925
#                 : 250. 正答率（テスト） = 0.9057
# Generation: 260. 正答率（トレーニング） = 0.9104833333333333
#                 : 260. 正答率（テスト） = 0.9073
# Generation: 270. 正答率（トレーニング） = 0.91015
#                 : 270. 正答率（テスト） = 0.907
# Generation: 280. 正答率（トレーニング） = 0.91015
#                 : 280. 正答率（テスト） = 0.9102
# Generation: 290. 正答率（トレーニング） = 0.9128166666666667
#                 : 290. 正答率（テスト） = 0.9103
# Generation: 300. 正答率（トレーニング） = 0.9099166666666667
#                 : 300. 正答率（テスト） = 0.9094
# Generation: 310. 正答率（トレーニング） = 0.9121666666666667
#                 : 310. 正答率（テスト） = 0.9101
# Generation: 320. 正答率（トレーニング） = 0.9122666666666667
#                 : 320. 正答率（テスト） = 0.9121
# Generation: 330. 正答率（トレーニング） = 0.9147666666666666
#                 : 330. 正答率（テスト） = 0.9119
# Generation: 340. 正答率（トレーニング） = 0.9165166666666666
#                 : 340. 正答率（テスト） = 0.9129
# Generation: 350. 正答率（トレーニング） = 0.9154833333333333
#                 : 350. 正答率（テスト） = 0.9123
# Generation: 360. 正答率（トレーニング） = 0.9178333333333333
#                 : 360. 正答率（テスト） = 0.9128
# Generation: 370. 正答率（トレーニング） = 0.9183166666666667
#                 : 370. 正答率（テスト） = 0.9151
# Generation: 380. 正答率（トレーニング） = 0.9181
#                 : 380. 正答率（テスト） = 0.9152
# Generation: 390. 正答率（トレーニング） = 0.9161166666666667
#                 : 390. 正答率（テスト） = 0.9132
# Generation: 400. 正答率（トレーニング） = 0.9178833333333334
#                 : 400. 正答率（テスト） = 0.9159
# Generation: 410. 正答率（トレーニング） = 0.9212
#                 : 410. 正答率（テスト） = 0.9167
# Generation: 420. 正答率（トレーニング） = 0.9205833333333333
#                 : 420. 正答率（テスト） = 0.9155
# Generation: 430. 正答率（トレーニング） = 0.9204666666666667
#                 : 430. 正答率（テスト） = 0.9185
# Generation: 440. 正答率（トレーニング） = 0.91945
#                 : 440. 正答率（テスト） = 0.9175
# Generation: 450. 正答率（トレーニング） = 0.9217833333333333
#                 : 450. 正答率（テスト） = 0.9184
# Generation: 460. 正答率（トレーニング） = 0.9228333333333333
#                 : 460. 正答率（テスト） = 0.9197
# Generation: 470. 正答率（トレーニング） = 0.9231833333333334
#                 : 470. 正答率（テスト） = 0.9192
# Generation: 480. 正答率（トレーニング） = 0.9239333333333334
#                 : 480. 正答率（テスト） = 0.9211
# Generation: 490. 正答率（トレーニング） = 0.9216833333333333
#                 : 490. 正答率（テスト） = 0.9184
# Generation: 500. 正答率（トレーニング） = 0.9237666666666666
#                 : 500. 正答率（テスト） = 0.9202
# Generation: 510. 正答率（トレーニング） = 0.9248333333333333
#                 : 510. 正答率（テスト） = 0.9215
# Generation: 520. 正答率（トレーニング） = 0.92575
#                 : 520. 正答率（テスト） = 0.9207
# Generation: 530. 正答率（トレーニング） = 0.9257833333333333
#                 : 530. 正答率（テスト） = 0.9214
# Generation: 540. 正答率（トレーニング） = 0.9264166666666667
#                 : 540. 正答率（テスト） = 0.9226
# Generation: 550. 正答率（トレーニング） = 0.9261333333333334
#                 : 550. 正答率（テスト） = 0.923
# Generation: 560. 正答率（トレーニング） = 0.9251833333333334
#                 : 560. 正答率（テスト） = 0.9219
# Generation: 570. 正答率（トレーニング） = 0.9254833333333333
#                 : 570. 正答率（テスト） = 0.9243
# Generation: 580. 正答率（トレーニング） = 0.9259833333333334
#                 : 580. 正答率（テスト） = 0.9242
# Generation: 590. 正答率（トレーニング） = 0.92695
#                 : 590. 正答率（テスト） = 0.9232
# Generation: 600. 正答率（トレーニング） = 0.9288333333333333
#                 : 600. 正答率（テスト） = 0.9247
# Generation: 610. 正答率（トレーニング） = 0.9293333333333333
#                 : 610. 正答率（テスト） = 0.9248
# Generation: 620. 正答率（トレーニング） = 0.9277333333333333
#                 : 620. 正答率（テスト） = 0.9245
# Generation: 630. 正答率（トレーニング） = 0.9289
#                 : 630. 正答率（テスト） = 0.9249
# Generation: 640. 正答率（トレーニング） = 0.9302
#                 : 640. 正答率（テスト） = 0.927
# Generation: 650. 正答率（トレーニング） = 0.9300833333333334
#                 : 650. 正答率（テスト） = 0.9266
# Generation: 660. 正答率（トレーニング） = 0.92955
#                 : 660. 正答率（テスト） = 0.9255
# Generation: 670. 正答率（トレーニング） = 0.9298333333333333
#                 : 670. 正答率（テスト） = 0.9269
# Generation: 680. 正答率（トレーニング） = 0.9297833333333333
#                 : 680. 正答率（テスト） = 0.9278
# Generation: 690. 正答率（トレーニング） = 0.93075
#                 : 690. 正答率（テスト） = 0.9264
# Generation: 700. 正答率（トレーニング） = 0.9292333333333334
#                 : 700. 正答率（テスト） = 0.9255
# Generation: 710. 正答率（トレーニング） = 0.9306666666666666
#                 : 710. 正答率（テスト） = 0.9276
# Generation: 720. 正答率（トレーニング） = 0.9317833333333333
#                 : 720. 正答率（テスト） = 0.9294
# Generation: 730. 正答率（トレーニング） = 0.92975
#                 : 730. 正答率（テスト） = 0.9267
# Generation: 740. 正答率（トレーニング） = 0.9299666666666667
#                 : 740. 正答率（テスト） = 0.9271
# Generation: 750. 正答率（トレーニング） = 0.9314666666666667
#                 : 750. 正答率（テスト） = 0.9281
# Generation: 760. 正答率（トレーニング） = 0.9335666666666667
#                 : 760. 正答率（テスト） = 0.9301
# Generation: 770. 正答率（トレーニング） = 0.9339
#                 : 770. 正答率（テスト） = 0.9305
# Generation: 780. 正答率（トレーニング） = 0.9337
#                 : 780. 正答率（テスト） = 0.9309
# Generation: 790. 正答率（トレーニング） = 0.9337666666666666
#                 : 790. 正答率（テスト） = 0.9299
# Generation: 800. 正答率（トレーニング） = 0.93395
#                 : 800. 正答率（テスト） = 0.9293
# Generation: 810. 正答率（トレーニング） = 0.9338666666666666
#                 : 810. 正答率（テスト） = 0.931
# Generation: 820. 正答率（トレーニング） = 0.9338
#                 : 820. 正答率（テスト） = 0.9303
# Generation: 830. 正答率（トレーニング） = 0.93435
#                 : 830. 正答率（テスト） = 0.9293
# Generation: 840. 正答率（トレーニング） = 0.9355666666666667
#                 : 840. 正答率（テスト） = 0.9315
# Generation: 850. 正答率（トレーニング） = 0.9305166666666667
#                 : 850. 正答率（テスト） = 0.9255
# Generation: 860. 正答率（トレーニング） = 0.9341833333333334
#                 : 860. 正答率（テスト） = 0.9304
# Generation: 870. 正答率（トレーニング） = 0.9345
#                 : 870. 正答率（テスト） = 0.9315
# Generation: 880. 正答率（トレーニング） = 0.9364833333333333
#                 : 880. 正答率（テスト） = 0.9327
# Generation: 890. 正答率（トレーニング） = 0.9363666666666667
#                 : 890. 正答率（テスト） = 0.9323
# Generation: 900. 正答率（トレーニング） = 0.93575
#                 : 900. 正答率（テスト） = 0.9327
# Generation: 910. 正答率（トレーニング） = 0.9345
#                 : 910. 正答率（テスト） = 0.93
# Generation: 920. 正答率（トレーニング） = 0.9363333333333334
#                 : 920. 正答率（テスト） = 0.9327
# Generation: 930. 正答率（トレーニング） = 0.936
#                 : 930. 正答率（テスト） = 0.9337
# Generation: 940. 正答率（トレーニング） = 0.9366833333333333
#                 : 940. 正答率（テスト） = 0.9333
# Generation: 950. 正答率（トレーニング） = 0.9377166666666666
#                 : 950. 正答率（テスト） = 0.9336
# Generation: 960. 正答率（トレーニング） = 0.9365833333333333
#                 : 960. 正答率（テスト） = 0.9344
# Generation: 970. 正答率（トレーニング） = 0.9374666666666667
#                 : 970. 正答率（テスト） = 0.935
# Generation: 980. 正答率（トレーニング） = 0.9370833333333334
#                 : 980. 正答率（テスト） = 0.9333
# Generation: 990. 正答率（トレーニング） = 0.9383
#                 : 990. 正答率（テスト） = 0.9338
# Generation: 1000. 正答率（トレーニング） = 0.9386333333333333
#                 : 1000. 正答率（テスト） = 0.9344
# Generation: 1010. 正答率（トレーニング） = 0.9381666666666667
#                 : 1010. 正答率（テスト） = 0.9352
# Generation: 1020. 正答率（トレーニング） = 0.9387
#                 : 1020. 正答率（テスト） = 0.9342
# Generation: 1030. 正答率（トレーニング） = 0.9393166666666667
#                 : 1030. 正答率（テスト） = 0.9346
# Generation: 1040. 正答率（トレーニング） = 0.9390833333333334
#                 : 1040. 正答率（テスト） = 0.9343
# Generation: 1050. 正答率（トレーニング） = 0.9375666666666667
#                 : 1050. 正答率（テスト） = 0.9323
# Generation: 1060. 正答率（トレーニング） = 0.9398833333333333
#                 : 1060. 正答率（テスト） = 0.9355
# Generation: 1070. 正答率（トレーニング） = 0.9389
#                 : 1070. 正答率（テスト） = 0.9353
# Generation: 1080. 正答率（トレーニング） = 0.9396
#                 : 1080. 正答率（テスト） = 0.9365
# Generation: 1090. 正答率（トレーニング） = 0.9399833333333333
#                 : 1090. 正答率（テスト） = 0.9369
# Generation: 1100. 正答率（トレーニング） = 0.9387666666666666
#                 : 1100. 正答率（テスト） = 0.9352
# Generation: 1110. 正答率（トレーニング） = 0.9404
#                 : 1110. 正答率（テスト） = 0.9363
# Generation: 1120. 正答率（トレーニング） = 0.9393
#                 : 1120. 正答率（テスト） = 0.9347
# Generation: 1130. 正答率（トレーニング） = 0.9400333333333334
#                 : 1130. 正答率（テスト） = 0.9368
# Generation: 1140. 正答率（トレーニング） = 0.9403166666666667
#                 : 1140. 正答率（テスト） = 0.9368
# Generation: 1150. 正答率（トレーニング） = 0.9406666666666667
#                 : 1150. 正答率（テスト） = 0.9378
# Generation: 1160. 正答率（トレーニング） = 0.9395833333333333
#                 : 1160. 正答率（テスト） = 0.9347
# Generation: 1170. 正答率（トレーニング） = 0.9399166666666666
#                 : 1170. 正答率（テスト） = 0.9348
# Generation: 1180. 正答率（トレーニング） = 0.9402833333333334
#                 : 1180. 正答率（テスト） = 0.9371
# Generation: 1190. 正答率（トレーニング） = 0.9407
#                 : 1190. 正答率（テスト） = 0.9366
# Generation: 1200. 正答率（トレーニング） = 0.9403833333333333
#                 : 1200. 正答率（テスト） = 0.9353
# Generation: 1210. 正答率（トレーニング） = 0.9407166666666666
#                 : 1210. 正答率（テスト） = 0.9377
# Generation: 1220. 正答率（トレーニング） = 0.9400833333333334
#                 : 1220. 正答率（テスト） = 0.9371
# Generation: 1230. 正答率（トレーニング） = 0.94125
#                 : 1230. 正答率（テスト） = 0.9388
# Generation: 1240. 正答率（トレーニング） = 0.9413
#                 : 1240. 正答率（テスト） = 0.9381
# Generation: 1250. 正答率（トレーニング） = 0.9411666666666667
#                 : 1250. 正答率（テスト） = 0.9377
# Generation: 1260. 正答率（トレーニング） = 0.94215
#                 : 1260. 正答率（テスト） = 0.9382
# Generation: 1270. 正答率（トレーニング） = 0.9401833333333334
#                 : 1270. 正答率（テスト） = 0.9375
# Generation: 1280. 正答率（トレーニング） = 0.9417666666666666
#                 : 1280. 正答率（テスト） = 0.9386
# Generation: 1290. 正答率（トレーニング） = 0.9416333333333333
#                 : 1290. 正答率（テスト） = 0.9367
# Generation: 1300. 正答率（トレーニング） = 0.9417333333333333
#                 : 1300. 正答率（テスト） = 0.9398
# Generation: 1310. 正答率（トレーニング） = 0.94295
#                 : 1310. 正答率（テスト） = 0.9399
# Generation: 1320. 正答率（トレーニング） = 0.9426
#                 : 1320. 正答率（テスト） = 0.9382
# Generation: 1330. 正答率（トレーニング） = 0.9431333333333334
#                 : 1330. 正答率（テスト） = 0.9392
# Generation: 1340. 正答率（トレーニング） = 0.9433166666666667
#                 : 1340. 正答率（テスト） = 0.9386
# Generation: 1350. 正答率（トレーニング） = 0.9432833333333334
#                 : 1350. 正答率（テスト） = 0.9387
# Generation: 1360. 正答率（トレーニング） = 0.94225
#                 : 1360. 正答率（テスト） = 0.938
# Generation: 1370. 正答率（トレーニング） = 0.94275
#                 : 1370. 正答率（テスト） = 0.939
# Generation: 1380. 正答率（トレーニング） = 0.94325
#                 : 1380. 正答率（テスト） = 0.9393
# Generation: 1390. 正答率（トレーニング） = 0.9434166666666667
#                 : 1390. 正答率（テスト） = 0.9397
# Generation: 1400. 正答率（トレーニング） = 0.9430333333333333
#                 : 1400. 正答率（テスト） = 0.9386
# Generation: 1410. 正答率（トレーニング） = 0.9437
#                 : 1410. 正答率（テスト） = 0.9395
# Generation: 1420. 正答率（トレーニング） = 0.9436833333333333
#                 : 1420. 正答率（テスト） = 0.9387
# Generation: 1430. 正答率（トレーニング） = 0.9436
#                 : 1430. 正答率（テスト） = 0.9396
# Generation: 1440. 正答率（トレーニング） = 0.9447333333333333
#                 : 1440. 正答率（テスト） = 0.9402
# Generation: 1450. 正答率（トレーニング） = 0.94325
#                 : 1450. 正答率（テスト） = 0.9391
# Generation: 1460. 正答率（トレーニング） = 0.9435166666666667
#                 : 1460. 正答率（テスト） = 0.9408
# Generation: 1470. 正答率（トレーニング） = 0.94445
#                 : 1470. 正答率（テスト） = 0.9398
# Generation: 1480. 正答率（トレーニング） = 0.9444
#                 : 1480. 正答率（テスト） = 0.9398
# Generation: 1490. 正答率（トレーニング） = 0.9447833333333333
#                 : 1490. 正答率（テスト） = 0.9398
# Generation: 1500. 正答率（トレーニング） = 0.9437666666666666
#                 : 1500. 正答率（テスト） = 0.9401
# Generation: 1510. 正答率（トレーニング） = 0.94485
#                 : 1510. 正答率（テスト） = 0.9398
# Generation: 1520. 正答率（トレーニング） = 0.9449
#                 : 1520. 正答率（テスト） = 0.9394
# Generation: 1530. 正答率（トレーニング） = 0.9456833333333333
#                 : 1530. 正答率（テスト） = 0.9412
# Generation: 1540. 正答率（トレーニング） = 0.9453
#                 : 1540. 正答率（テスト） = 0.9404
# Generation: 1550. 正答率（トレーニング） = 0.94505
#                 : 1550. 正答率（テスト） = 0.9403
# Generation: 1560. 正答率（トレーニング） = 0.94585
#                 : 1560. 正答率（テスト） = 0.9408
# Generation: 1570. 正答率（トレーニング） = 0.9459333333333333
#                 : 1570. 正答率（テスト） = 0.941
# Generation: 1580. 正答率（トレーニング） = 0.9458833333333333
#                 : 1580. 正答率（テスト） = 0.9413
# Generation: 1590. 正答率（トレーニング） = 0.9456833333333333
#                 : 1590. 正答率（テスト） = 0.9397
# Generation: 1600. 正答率（トレーニング） = 0.9452666666666667
#                 : 1600. 正答率（テスト） = 0.9415
# Generation: 1610. 正答率（トレーニング） = 0.9437333333333333
#                 : 1610. 正答率（テスト） = 0.9399
# Generation: 1620. 正答率（トレーニング） = 0.9464833333333333
#                 : 1620. 正答率（テスト） = 0.941
# Generation: 1630. 正答率（トレーニング） = 0.9449166666666666
#                 : 1630. 正答率（テスト） = 0.9403
# Generation: 1640. 正答率（トレーニング） = 0.9465666666666667
#                 : 1640. 正答率（テスト） = 0.9417
# Generation: 1650. 正答率（トレーニング） = 0.9470333333333333
#                 : 1650. 正答率（テスト） = 0.9426
# Generation: 1660. 正答率（トレーニング） = 0.9467833333333333
#                 : 1660. 正答率（テスト） = 0.9411
# Generation: 1670. 正答率（トレーニング） = 0.9458333333333333
#                 : 1670. 正答率（テスト） = 0.942
# Generation: 1680. 正答率（トレーニング） = 0.9465166666666667
#                 : 1680. 正答率（テスト） = 0.943
# Generation: 1690. 正答率（トレーニング） = 0.9467833333333333
#                 : 1690. 正答率（テスト） = 0.9415
# Generation: 1700. 正答率（トレーニング） = 0.9467833333333333
#                 : 1700. 正答率（テスト） = 0.942
# Generation: 1710. 正答率（トレーニング） = 0.9458833333333333
#                 : 1710. 正答率（テスト） = 0.9409
# Generation: 1720. 正答率（トレーニング） = 0.94705
#                 : 1720. 正答率（テスト） = 0.9427
# Generation: 1730. 正答率（トレーニング） = 0.9463833333333334
#                 : 1730. 正答率（テスト） = 0.944
# Generation: 1740. 正答率（トレーニング） = 0.9458166666666666
#                 : 1740. 正答率（テスト） = 0.9423
# Generation: 1750. 正答率（トレーニング） = 0.9459166666666666
#                 : 1750. 正答率（テスト） = 0.9424
# Generation: 1760. 正答率（トレーニング） = 0.9467
#                 : 1760. 正答率（テスト） = 0.9414
# Generation: 1770. 正答率（トレーニング） = 0.94735
#                 : 1770. 正答率（テスト） = 0.9422
# Generation: 1780. 正答率（トレーニング） = 0.9470833333333334
#                 : 1780. 正答率（テスト） = 0.9429
# Generation: 1790. 正答率（トレーニング） = 0.9472166666666667
#                 : 1790. 正答率（テスト） = 0.9416
# Generation: 1800. 正答率（トレーニング） = 0.9476833333333333
#                 : 1800. 正答率（テスト） = 0.9432
# Generation: 1810. 正答率（トレーニング） = 0.9479166666666666
#                 : 1810. 正答率（テスト） = 0.9442
# Generation: 1820. 正答率（トレーニング） = 0.9480666666666666
#                 : 1820. 正答率（テスト） = 0.9433
# Generation: 1830. 正答率（トレーニング） = 0.9480166666666666
#                 : 1830. 正答率（テスト） = 0.943
# Generation: 1840. 正答率（トレーニング） = 0.9479
#                 : 1840. 正答率（テスト） = 0.943
# Generation: 1850. 正答率（トレーニング） = 0.9476333333333333
#                 : 1850. 正答率（テスト） = 0.9415
# Generation: 1860. 正答率（トレーニング） = 0.9478
#                 : 1860. 正答率（テスト） = 0.9423
# Generation: 1870. 正答率（トレーニング） = 0.9479833333333333
#                 : 1870. 正答率（テスト） = 0.9436
# Generation: 1880. 正答率（トレーニング） = 0.9480833333333333
#                 : 1880. 正答率（テスト） = 0.9434
# Generation: 1890. 正答率（トレーニング） = 0.94815
#                 : 1890. 正答率（テスト） = 0.9431
# Generation: 1900. 正答率（トレーニング） = 0.9473833333333334
#                 : 1900. 正答率（テスト） = 0.941
# Generation: 1910. 正答率（トレーニング） = 0.94815
#                 : 1910. 正答率（テスト） = 0.9423
# Generation: 1920. 正答率（トレーニング） = 0.9480833333333333
#                 : 1920. 正答率（テスト） = 0.9411
# Generation: 1930. 正答率（トレーニング） = 0.9480166666666666
#                 : 1930. 正答率（テスト） = 0.9439
# Generation: 1940. 正答率（トレーニング） = 0.9478166666666666
#                 : 1940. 正答率（テスト） = 0.9427
# Generation: 1950. 正答率（トレーニング） = 0.9482333333333334
#                 : 1950. 正答率（テスト） = 0.9431
# Generation: 1960. 正答率（トレーニング） = 0.9477
#                 : 1960. 正答率（テスト） = 0.942
# Generation: 1970. 正答率（トレーニング） = 0.9487166666666667
#                 : 1970. 正答率（テスト） = 0.944
# Generation: 1980. 正答率（トレーニング） = 0.9480166666666666
#                 : 1980. 正答率（テスト） = 0.9422
# Generation: 1990. 正答率（トレーニング） = 0.9488666666666666
#                 : 1990. 正答率（テスト） = 0.9432
# Generation: 2000. 正答率（トレーニング） = 0.9490666666666666
#                 : 2000. 正答率（テスト） = 0.9424

# %%
Tester7.plot_results()
plt.show()

# %%
Tester8 = OptimizerTest(activation = "relu", weight_init_std = "He" , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test, OptimizerType = "RMSprop")
Tester8.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.45695
#                 : 10. 正答率（テスト） = 0.4512
# Generation: 20. 正答率（トレーニング） = 0.7617
#                 : 20. 正答率（テスト） = 0.7636
# Generation: 30. 正答率（トレーニング） = 0.8112333333333334
#                 : 30. 正答率（テスト） = 0.8085
# Generation: 40. 正答率（トレーニング） = 0.8065166666666667
#                 : 40. 正答率（テスト） = 0.8016
# Generation: 50. 正答率（トレーニング） = 0.8171166666666667
#                 : 50. 正答率（テスト） = 0.8191
# Generation: 60. 正答率（トレーニング） = 0.8455166666666667
#                 : 60. 正答率（テスト） = 0.8444
# Generation: 70. 正答率（トレーニング） = 0.85555
#                 : 70. 正答率（テスト） = 0.8533
# Generation: 80. 正答率（トレーニング） = 0.8903833333333333
#                 : 80. 正答率（テスト） = 0.8921
# Generation: 90. 正答率（トレーニング） = 0.8951166666666667
#                 : 90. 正答率（テスト） = 0.8971
# Generation: 100. 正答率（トレーニング） = 0.8932166666666667
#                 : 100. 正答率（テスト） = 0.8986
# Generation: 110. 正答率（トレーニング） = 0.8896
#                 : 110. 正答率（テスト） = 0.8919
# Generation: 120. 正答率（トレーニング） = 0.8735333333333334
#                 : 120. 正答率（テスト） = 0.8758
# Generation: 130. 正答率（トレーニング） = 0.9047333333333333
#                 : 130. 正答率（テスト） = 0.9021
# Generation: 140. 正答率（トレーニング） = 0.9011833333333333
#                 : 140. 正答率（テスト） = 0.9012
# Generation: 150. 正答率（トレーニング） = 0.9006166666666666
#                 : 150. 正答率（テスト） = 0.9001
# Generation: 160. 正答率（トレーニング） = 0.90585
#                 : 160. 正答率（テスト） = 0.9071
# Generation: 170. 正答率（トレーニング） = 0.9006666666666666
#                 : 170. 正答率（テスト） = 0.9024
# Generation: 180. 正答率（トレーニング） = 0.9125
#                 : 180. 正答率（テスト） = 0.9102
# Generation: 190. 正答率（トレーニング） = 0.9111333333333334
#                 : 190. 正答率（テスト） = 0.9084
# Generation: 200. 正答率（トレーニング） = 0.9126333333333333
#                 : 200. 正答率（テスト） = 0.914
# Generation: 210. 正答率（トレーニング） = 0.9173666666666667
#                 : 210. 正答率（テスト） = 0.918
# Generation: 220. 正答率（トレーニング） = 0.9094333333333333
#                 : 220. 正答率（テスト） = 0.9067
# Generation: 230. 正答率（トレーニング） = 0.9161333333333334
#                 : 230. 正答率（テスト） = 0.9197
# Generation: 240. 正答率（トレーニング） = 0.91745
#                 : 240. 正答率（テスト） = 0.918
# Generation: 250. 正答率（トレーニング） = 0.9104
#                 : 250. 正答率（テスト） = 0.9115
# Generation: 260. 正答率（トレーニング） = 0.9174166666666667
#                 : 260. 正答率（テスト） = 0.914
# Generation: 270. 正答率（トレーニング） = 0.9275666666666667
#                 : 270. 正答率（テスト） = 0.927
# Generation: 280. 正答率（トレーニング） = 0.91865
#                 : 280. 正答率（テスト） = 0.9185
# Generation: 290. 正答率（トレーニング） = 0.8802333333333333
#                 : 290. 正答率（テスト） = 0.8792
# Generation: 300. 正答率（トレーニング） = 0.9267666666666666
#                 : 300. 正答率（テスト） = 0.9236
# Generation: 310. 正答率（トレーニング） = 0.9266166666666666
#                 : 310. 正答率（テスト） = 0.9225
# Generation: 320. 正答率（トレーニング） = 0.9303
#                 : 320. 正答率（テスト） = 0.9295
# Generation: 330. 正答率（トレーニング） = 0.9292166666666667
#                 : 330. 正答率（テスト） = 0.9267
# Generation: 340. 正答率（トレーニング） = 0.9269833333333334
#                 : 340. 正答率（テスト） = 0.9259
# Generation: 350. 正答率（トレーニング） = 0.9197166666666666
#                 : 350. 正答率（テスト） = 0.9116
# Generation: 360. 正答率（トレーニング） = 0.9208833333333334
#                 : 360. 正答率（テスト） = 0.9187
# Generation: 370. 正答率（トレーニング） = 0.9209666666666667
#                 : 370. 正答率（テスト） = 0.915
# Generation: 380. 正答率（トレーニング） = 0.9214
#                 : 380. 正答率（テスト） = 0.9202
# Generation: 390. 正答率（トレーニング） = 0.9124166666666667
#                 : 390. 正答率（テスト） = 0.9062
# Generation: 400. 正答率（トレーニング） = 0.9198
#                 : 400. 正答率（テスト） = 0.9172
# Generation: 410. 正答率（トレーニング） = 0.9371166666666667
#                 : 410. 正答率（テスト） = 0.9312
# Generation: 420. 正答率（トレーニング） = 0.9229666666666667
#                 : 420. 正答率（テスト） = 0.9164
# Generation: 430. 正答率（トレーニング） = 0.9224166666666667
#                 : 430. 正答率（テスト） = 0.9197
# Generation: 440. 正答率（トレーニング） = 0.9277666666666666
#                 : 440. 正答率（テスト） = 0.9226
# Generation: 450. 正答率（トレーニング） = 0.9427833333333333
#                 : 450. 正答率（テスト） = 0.9387
# Generation: 460. 正答率（トレーニング） = 0.9335
#                 : 460. 正答率（テスト） = 0.9277
# Generation: 470. 正答率（トレーニング） = 0.9392833333333334
#                 : 470. 正答率（テスト） = 0.936
# Generation: 480. 正答率（トレーニング） = 0.9440333333333333
#                 : 480. 正答率（テスト） = 0.9404
# Generation: 490. 正答率（トレーニング） = 0.9398833333333333
#                 : 490. 正答率（テスト） = 0.9329
# Generation: 500. 正答率（トレーニング） = 0.9434166666666667
#                 : 500. 正答率（テスト） = 0.9369
# Generation: 510. 正答率（トレーニング） = 0.9389166666666666
#                 : 510. 正答率（テスト） = 0.9341
# Generation: 520. 正答率（トレーニング） = 0.9403833333333333
#                 : 520. 正答率（テスト） = 0.9375
# Generation: 530. 正答率（トレーニング） = 0.9419166666666666
#                 : 530. 正答率（テスト） = 0.9353
# Generation: 540. 正答率（トレーニング） = 0.9385833333333333
#                 : 540. 正答率（テスト） = 0.9342
# Generation: 550. 正答率（トレーニング） = 0.9354666666666667
#                 : 550. 正答率（テスト） = 0.9301
# Generation: 560. 正答率（トレーニング） = 0.9388166666666666
#                 : 560. 正答率（テスト） = 0.9353
# Generation: 570. 正答率（トレーニング） = 0.9367833333333333
#                 : 570. 正答率（テスト） = 0.9312
# Generation: 580. 正答率（トレーニング） = 0.9217333333333333
#                 : 580. 正答率（テスト） = 0.9135
# Generation: 590. 正答率（トレーニング） = 0.9401333333333334
#                 : 590. 正答率（テスト） = 0.9357
# Generation: 600. 正答率（トレーニング） = 0.9437833333333333
#                 : 600. 正答率（テスト） = 0.9372
# Generation: 610. 正答率（トレーニング） = 0.9396333333333333
#                 : 610. 正答率（テスト） = 0.937
# Generation: 620. 正答率（トレーニング） = 0.94325
#                 : 620. 正答率（テスト） = 0.9408
# Generation: 630. 正答率（トレーニング） = 0.9412
#                 : 630. 正答率（テスト） = 0.9372
# Generation: 640. 正答率（トレーニング） = 0.9459666666666666
#                 : 640. 正答率（テスト） = 0.9421
# Generation: 650. 正答率（トレーニング） = 0.9041
#                 : 650. 正答率（テスト） = 0.9029
# Generation: 660. 正答率（トレーニング） = 0.9265166666666667
#                 : 660. 正答率（テスト） = 0.9237
# Generation: 670. 正答率（トレーニング） = 0.9358
#                 : 670. 正答率（テスト） = 0.928
# Generation: 680. 正答率（トレーニング） = 0.9453
#                 : 680. 正答率（テスト） = 0.9391
# Generation: 690. 正答率（トレーニング） = 0.9353
#                 : 690. 正答率（テスト） = 0.9258
# Generation: 700. 正答率（トレーニング） = 0.9487166666666667
#                 : 700. 正答率（テスト） = 0.9451
# Generation: 710. 正答率（トレーニング） = 0.9432166666666667
#                 : 710. 正答率（テスト） = 0.9377
# Generation: 720. 正答率（トレーニング） = 0.9421666666666667
#                 : 720. 正答率（テスト） = 0.9373
# Generation: 730. 正答率（トレーニング） = 0.9376
#                 : 730. 正答率（テスト） = 0.933
# Generation: 740. 正答率（トレーニング） = 0.9306666666666666
#                 : 740. 正答率（テスト） = 0.9254
# Generation: 750. 正答率（トレーニング） = 0.9516166666666667
#                 : 750. 正答率（テスト） = 0.9457
# Generation: 760. 正答率（トレーニング） = 0.9346
#                 : 760. 正答率（テスト） = 0.9301
# Generation: 770. 正答率（トレーニング） = 0.9484166666666667
#                 : 770. 正答率（テスト） = 0.9427
# Generation: 780. 正答率（トレーニング） = 0.9476166666666667
#                 : 780. 正答率（テスト） = 0.9449
# Generation: 790. 正答率（トレーニング） = 0.94645
#                 : 790. 正答率（テスト） = 0.9411
# Generation: 800. 正答率（トレーニング） = 0.94695
#                 : 800. 正答率（テスト） = 0.9368
# Generation: 810. 正答率（トレーニング） = 0.9471166666666667
#                 : 810. 正答率（テスト） = 0.9402
# Generation: 820. 正答率（トレーニング） = 0.9491666666666667
#                 : 820. 正答率（テスト） = 0.9441
# Generation: 830. 正答率（トレーニング） = 0.94925
#                 : 830. 正答率（テスト） = 0.9418
# Generation: 840. 正答率（トレーニング） = 0.93825
#                 : 840. 正答率（テスト） = 0.9344
# Generation: 850. 正答率（トレーニング） = 0.9526833333333333
#                 : 850. 正答率（テスト） = 0.9463
# Generation: 860. 正答率（トレーニング） = 0.9485833333333333
#                 : 860. 正答率（テスト） = 0.9407
# Generation: 870. 正答率（トレーニング） = 0.949
#                 : 870. 正答率（テスト） = 0.9423
# Generation: 880. 正答率（トレーニング） = 0.9233833333333333
#                 : 880. 正答率（テスト） = 0.9197
# Generation: 890. 正答率（トレーニング） = 0.9483333333333334
#                 : 890. 正答率（テスト） = 0.9451
# Generation: 900. 正答率（トレーニング） = 0.9497666666666666
#                 : 900. 正答率（テスト） = 0.9435
# Generation: 910. 正答率（トレーニング） = 0.9429166666666666
#                 : 910. 正答率（テスト） = 0.9386
# Generation: 920. 正答率（トレーニング） = 0.9467333333333333
#                 : 920. 正答率（テスト） = 0.9449
# Generation: 930. 正答率（トレーニング） = 0.9515333333333333
#                 : 930. 正答率（テスト） = 0.9504
# Generation: 940. 正答率（トレーニング） = 0.9405833333333333
#                 : 940. 正答率（テスト） = 0.9344
# Generation: 950. 正答率（トレーニング） = 0.9495333333333333
#                 : 950. 正答率（テスト） = 0.9463
# Generation: 960. 正答率（トレーニング） = 0.9375333333333333
#                 : 960. 正答率（テスト） = 0.934
# Generation: 970. 正答率（トレーニング） = 0.9510666666666666
#                 : 970. 正答率（テスト） = 0.9456
# Generation: 980. 正答率（トレーニング） = 0.9379166666666666
#                 : 980. 正答率（テスト） = 0.9341
# Generation: 990. 正答率（トレーニング） = 0.93695
#                 : 990. 正答率（テスト） = 0.9319
# Generation: 1000. 正答率（トレーニング） = 0.9522333333333334
#                 : 1000. 正答率（テスト） = 0.9478
# Generation: 1010. 正答率（トレーニング） = 0.9419666666666666
#                 : 1010. 正答率（テスト） = 0.9327
# Generation: 1020. 正答率（トレーニング） = 0.9522
#                 : 1020. 正答率（テスト） = 0.9437
# Generation: 1030. 正答率（トレーニング） = 0.95375
#                 : 1030. 正答率（テスト） = 0.9462
# Generation: 1040. 正答率（トレーニング） = 0.94225
#                 : 1040. 正答率（テスト） = 0.9346
# Generation: 1050. 正答率（トレーニング） = 0.9546833333333333
#                 : 1050. 正答率（テスト） = 0.9496
# Generation: 1060. 正答率（トレーニング） = 0.9493166666666667
#                 : 1060. 正答率（テスト） = 0.9473
# Generation: 1070. 正答率（トレーニング） = 0.9496666666666667
#                 : 1070. 正答率（テスト） = 0.9426
# Generation: 1080. 正答率（トレーニング） = 0.9585833333333333
#                 : 1080. 正答率（テスト） = 0.9533
# Generation: 1090. 正答率（トレーニング） = 0.9522166666666667
#                 : 1090. 正答率（テスト） = 0.9484
# Generation: 1100. 正答率（トレーニング） = 0.95025
#                 : 1100. 正答率（テスト） = 0.9454
# Generation: 1110. 正答率（トレーニング） = 0.95335
#                 : 1110. 正答率（テスト） = 0.9478
# Generation: 1120. 正答率（トレーニング） = 0.9554833333333334
#                 : 1120. 正答率（テスト） = 0.9492
# Generation: 1130. 正答率（トレーニング） = 0.9526
#                 : 1130. 正答率（テスト） = 0.9467
# Generation: 1140. 正答率（トレーニング） = 0.9549833333333333
#                 : 1140. 正答率（テスト） = 0.9475
# Generation: 1150. 正答率（トレーニング） = 0.9406166666666667
#                 : 1150. 正答率（テスト） = 0.9377
# Generation: 1160. 正答率（トレーニング） = 0.95355
#                 : 1160. 正答率（テスト） = 0.9481
# Generation: 1170. 正答率（トレーニング） = 0.9537333333333333
#                 : 1170. 正答率（テスト） = 0.9496
# Generation: 1180. 正答率（トレーニング） = 0.9535666666666667
#                 : 1180. 正答率（テスト） = 0.9485
# Generation: 1190. 正答率（トレーニング） = 0.94675
#                 : 1190. 正答率（テスト） = 0.9361
# Generation: 1200. 正答率（トレーニング） = 0.9571666666666667
#                 : 1200. 正答率（テスト） = 0.954
# Generation: 1210. 正答率（トレーニング） = 0.9547833333333333
#                 : 1210. 正答率（テスト） = 0.953
# Generation: 1220. 正答率（トレーニング） = 0.95475
#                 : 1220. 正答率（テスト） = 0.9484
# Generation: 1230. 正答率（トレーニング） = 0.9486
#                 : 1230. 正答率（テスト） = 0.9476
# Generation: 1240. 正答率（トレーニング） = 0.9497666666666666
#                 : 1240. 正答率（テスト） = 0.9457
# Generation: 1250. 正答率（トレーニング） = 0.9479166666666666
#                 : 1250. 正答率（テスト） = 0.944
# Generation: 1260. 正答率（トレーニング） = 0.9524666666666667
#                 : 1260. 正答率（テスト） = 0.9486
# Generation: 1270. 正答率（トレーニング） = 0.9477
#                 : 1270. 正答率（テスト） = 0.944
# Generation: 1280. 正答率（トレーニング） = 0.9543666666666667
#                 : 1280. 正答率（テスト） = 0.9502
# Generation: 1290. 正答率（トレーニング） = 0.9497166666666667
#                 : 1290. 正答率（テスト） = 0.9432
# Generation: 1300. 正答率（トレーニング） = 0.9580166666666666
#                 : 1300. 正答率（テスト） = 0.9522
# Generation: 1310. 正答率（トレーニング） = 0.9564333333333334
#                 : 1310. 正答率（テスト） = 0.9482
# Generation: 1320. 正答率（トレーニング） = 0.9571166666666666
#                 : 1320. 正答率（テスト） = 0.9506
# Generation: 1330. 正答率（トレーニング） = 0.9434666666666667
#                 : 1330. 正答率（テスト） = 0.9357
# Generation: 1340. 正答率（トレーニング） = 0.9517
#                 : 1340. 正答率（テスト） = 0.9441
# Generation: 1350. 正答率（トレーニング） = 0.9549666666666666
#                 : 1350. 正答率（テスト） = 0.9474
# Generation: 1360. 正答率（トレーニング） = 0.9561
#                 : 1360. 正答率（テスト） = 0.9504
# Generation: 1370. 正答率（トレーニング） = 0.95925
#                 : 1370. 正答率（テスト） = 0.9531
# Generation: 1380. 正答率（トレーニング） = 0.9549833333333333
#                 : 1380. 正答率（テスト） = 0.9456
# Generation: 1390. 正答率（トレーニング） = 0.9595333333333333
#                 : 1390. 正答率（テスト） = 0.9508
# Generation: 1400. 正答率（トレーニング） = 0.95875
#                 : 1400. 正答率（テスト） = 0.9499
# Generation: 1410. 正答率（トレーニング） = 0.9583666666666667
#                 : 1410. 正答率（テスト） = 0.9522
# Generation: 1420. 正答率（トレーニング） = 0.9612333333333334
#                 : 1420. 正答率（テスト） = 0.9537
# Generation: 1430. 正答率（トレーニング） = 0.9589
#                 : 1430. 正答率（テスト） = 0.9529
# Generation: 1440. 正答率（トレーニング） = 0.957
#                 : 1440. 正答率（テスト） = 0.9513
# Generation: 1450. 正答率（トレーニング） = 0.9568666666666666
#                 : 1450. 正答率（テスト） = 0.9506
# Generation: 1460. 正答率（トレーニング） = 0.9498666666666666
#                 : 1460. 正答率（テスト） = 0.9451
# Generation: 1470. 正答率（トレーニング） = 0.9611166666666666
#                 : 1470. 正答率（テスト） = 0.9548
# Generation: 1480. 正答率（トレーニング） = 0.9437
#                 : 1480. 正答率（テスト） = 0.9348
# Generation: 1490. 正答率（トレーニング） = 0.9578666666666666
#                 : 1490. 正答率（テスト） = 0.95
# Generation: 1500. 正答率（トレーニング） = 0.9502833333333334
#                 : 1500. 正答率（テスト） = 0.9442
# Generation: 1510. 正答率（トレーニング） = 0.9559166666666666
#                 : 1510. 正答率（テスト） = 0.9519
# Generation: 1520. 正答率（トレーニング） = 0.9606666666666667
#                 : 1520. 正答率（テスト） = 0.9549
# Generation: 1530. 正答率（トレーニング） = 0.9588333333333333
#                 : 1530. 正答率（テスト） = 0.9514
# Generation: 1540. 正答率（トレーニング） = 0.9578333333333333
#                 : 1540. 正答率（テスト） = 0.9505
# Generation: 1550. 正答率（トレーニング） = 0.9609166666666666
#                 : 1550. 正答率（テスト） = 0.9513
# Generation: 1560. 正答率（トレーニング） = 0.9526
#                 : 1560. 正答率（テスト） = 0.9471
# Generation: 1570. 正答率（トレーニング） = 0.9583833333333334
#                 : 1570. 正答率（テスト） = 0.9539
# Generation: 1580. 正答率（トレーニング） = 0.95935
#                 : 1580. 正答率（テスト） = 0.952
# Generation: 1590. 正答率（トレーニング） = 0.9560166666666666
#                 : 1590. 正答率（テスト） = 0.9479
# Generation: 1600. 正答率（トレーニング） = 0.9535166666666667
#                 : 1600. 正答率（テスト） = 0.9475
# Generation: 1610. 正答率（トレーニング） = 0.9564
#                 : 1610. 正答率（テスト） = 0.9463
# Generation: 1620. 正答率（トレーニング） = 0.9569166666666666
#                 : 1620. 正答率（テスト） = 0.947
# Generation: 1630. 正答率（トレーニング） = 0.9485166666666667
#                 : 1630. 正答率（テスト） = 0.9425
# Generation: 1640. 正答率（トレーニング） = 0.9631333333333333
#                 : 1640. 正答率（テスト） = 0.9569
# Generation: 1650. 正答率（トレーニング） = 0.9590333333333333
#                 : 1650. 正答率（テスト） = 0.9519
# Generation: 1660. 正答率（トレーニング） = 0.9577833333333333
#                 : 1660. 正答率（テスト） = 0.9486
# Generation: 1670. 正答率（トレーニング） = 0.9608
#                 : 1670. 正答率（テスト） = 0.9517
# Generation: 1680. 正答率（トレーニング） = 0.9625
#                 : 1680. 正答率（テスト） = 0.9561
# Generation: 1690. 正答率（トレーニング） = 0.9607
#                 : 1690. 正答率（テスト） = 0.9532
# Generation: 1700. 正答率（トレーニング） = 0.9642833333333334
#                 : 1700. 正答率（テスト） = 0.9573
# Generation: 1710. 正答率（トレーニング） = 0.9651666666666666
#                 : 1710. 正答率（テスト） = 0.9584
# Generation: 1720. 正答率（トレーニング） = 0.96055
#                 : 1720. 正答率（テスト） = 0.9555
# Generation: 1730. 正答率（トレーニング） = 0.9563666666666667
#                 : 1730. 正答率（テスト） = 0.9504
# Generation: 1740. 正答率（トレーニング） = 0.9628333333333333
#                 : 1740. 正答率（テスト） = 0.9574
# Generation: 1750. 正答率（トレーニング） = 0.9628
#                 : 1750. 正答率（テスト） = 0.9584
# Generation: 1760. 正答率（トレーニング） = 0.9625
#                 : 1760. 正答率（テスト） = 0.9552
# Generation: 1770. 正答率（トレーニング） = 0.9624666666666667
#                 : 1770. 正答率（テスト） = 0.954
# Generation: 1780. 正答率（トレーニング） = 0.9625166666666667
#                 : 1780. 正答率（テスト） = 0.9552
# Generation: 1790. 正答率（トレーニング） = 0.9634666666666667
#                 : 1790. 正答率（テスト） = 0.9589
# Generation: 1800. 正答率（トレーニング） = 0.9652666666666667
#                 : 1800. 正答率（テスト） = 0.9571
# Generation: 1810. 正答率（トレーニング） = 0.9616
#                 : 1810. 正答率（テスト） = 0.952
# Generation: 1820. 正答率（トレーニング） = 0.96475
#                 : 1820. 正答率（テスト） = 0.9545
# Generation: 1830. 正答率（トレーニング） = 0.9605833333333333
#                 : 1830. 正答率（テスト） = 0.9474
# Generation: 1840. 正答率（トレーニング） = 0.96175
#                 : 1840. 正答率（テスト） = 0.9544
# Generation: 1850. 正答率（トレーニング） = 0.9604666666666667
#                 : 1850. 正答率（テスト） = 0.9515
# Generation: 1860. 正答率（トレーニング） = 0.9540333333333333
#                 : 1860. 正答率（テスト） = 0.946
# Generation: 1870. 正答率（トレーニング） = 0.96065
#                 : 1870. 正答率（テスト） = 0.9559
# Generation: 1880. 正答率（トレーニング） = 0.9619666666666666
#                 : 1880. 正答率（テスト） = 0.9548
# Generation: 1890. 正答率（トレーニング） = 0.9574666666666667
#                 : 1890. 正答率（テスト） = 0.9497
# Generation: 1900. 正答率（トレーニング） = 0.9580666666666666
#                 : 1900. 正答率（テスト） = 0.9503
# Generation: 1910. 正答率（トレーニング） = 0.9582666666666667
#                 : 1910. 正答率（テスト） = 0.9521
# Generation: 1920. 正答率（トレーニング） = 0.96185
#                 : 1920. 正答率（テスト） = 0.9558
# Generation: 1930. 正答率（トレーニング） = 0.9622833333333334
#                 : 1930. 正答率（テスト） = 0.9563
# Generation: 1940. 正答率（トレーニング） = 0.9449833333333333
#                 : 1940. 正答率（テスト） = 0.9364
# Generation: 1950. 正答率（トレーニング） = 0.9610333333333333
#                 : 1950. 正答率（テスト） = 0.949
# Generation: 1960. 正答率（トレーニング） = 0.96505
#                 : 1960. 正答率（テスト） = 0.9576
# Generation: 1970. 正答率（トレーニング） = 0.9585666666666667
#                 : 1970. 正答率（テスト） = 0.9489
# Generation: 1980. 正答率（トレーニング） = 0.9577166666666667
#                 : 1980. 正答率（テスト） = 0.9501
# Generation: 1990. 正答率（トレーニング） = 0.95975
#                 : 1990. 正答率（テスト） = 0.9536
# Generation: 2000. 正答率（トレーニング） = 0.9608166666666667
#                 : 2000. 正答率（テスト） = 0.952

# %%
Tester8.plot_results()
plt.show()

# %%
Tester9 = OptimizerTest(activation = "relu", weight_init_std = "He" , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test, OptimizerType = "Adam")
Tester9.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.7483
#                 : 10. 正答率（テスト） = 0.7553
# Generation: 20. 正答率（トレーニング） = 0.80525
#                 : 20. 正答率（テスト） = 0.8123
# Generation: 30. 正答率（トレーニング） = 0.8496166666666667
#                 : 30. 正答率（テスト） = 0.8512
# Generation: 40. 正答率（トレーニング） = 0.8708333333333333
#                 : 40. 正答率（テスト） = 0.8768
# Generation: 50. 正答率（トレーニング） = 0.8749166666666667
#                 : 50. 正答率（テスト） = 0.8828
# Generation: 60. 正答率（トレーニング） = 0.8847333333333334
#                 : 60. 正答率（テスト） = 0.8882
# Generation: 70. 正答率（トレーニング） = 0.8935
#                 : 70. 正答率（テスト） = 0.8946
# Generation: 80. 正答率（トレーニング） = 0.9027
#                 : 80. 正答率（テスト） = 0.9031
# Generation: 90. 正答率（トレーニング） = 0.9027833333333334
#                 : 90. 正答率（テスト） = 0.9028
# Generation: 100. 正答率（トレーニング） = 0.9199666666666667
#                 : 100. 正答率（テスト） = 0.9192
# Generation: 110. 正答率（トレーニング） = 0.9193
#                 : 110. 正答率（テスト） = 0.9198
# Generation: 120. 正答率（トレーニング） = 0.9234333333333333
#                 : 120. 正答率（テスト） = 0.9215
# Generation: 130. 正答率（トレーニング） = 0.9158833333333334
#                 : 130. 正答率（テスト） = 0.9168
# Generation: 140. 正答率（トレーニング） = 0.92255
#                 : 140. 正答率（テスト） = 0.9222
# Generation: 150. 正答率（トレーニング） = 0.8913833333333333
#                 : 150. 正答率（テスト） = 0.8917
# Generation: 160. 正答率（トレーニング） = 0.9186333333333333
#                 : 160. 正答率（テスト） = 0.9189
# Generation: 170. 正答率（トレーニング） = 0.92505
#                 : 170. 正答率（テスト） = 0.9207
# Generation: 180. 正答率（トレーニング） = 0.9299
#                 : 180. 正答率（テスト） = 0.9287
# Generation: 190. 正答率（トレーニング） = 0.93125
#                 : 190. 正答率（テスト） = 0.9297
# Generation: 200. 正答率（トレーニング） = 0.9329833333333334
#                 : 200. 正答率（テスト） = 0.9268
# Generation: 210. 正答率（トレーニング） = 0.92765
#                 : 210. 正答率（テスト） = 0.9225
# Generation: 220. 正答率（トレーニング） = 0.9345333333333333
#                 : 220. 正答率（テスト） = 0.9315
# Generation: 230. 正答率（トレーニング） = 0.9328
#                 : 230. 正答率（テスト） = 0.9325
# Generation: 240. 正答率（トレーニング） = 0.9367666666666666
#                 : 240. 正答率（テスト） = 0.9337
# Generation: 250. 正答率（トレーニング） = 0.9388833333333333
#                 : 250. 正答率（テスト） = 0.9349
# Generation: 260. 正答率（トレーニング） = 0.9389333333333333
#                 : 260. 正答率（テスト） = 0.9387
# Generation: 270. 正答率（トレーニング） = 0.9380333333333334
#                 : 270. 正答率（テスト） = 0.9331
# Generation: 280. 正答率（トレーニング） = 0.9358333333333333
#                 : 280. 正答率（テスト） = 0.9339
# Generation: 290. 正答率（トレーニング） = 0.9358833333333333
#                 : 290. 正答率（テスト） = 0.9325
# Generation: 300. 正答率（トレーニング） = 0.9375
#                 : 300. 正答率（テスト） = 0.9336
# Generation: 310. 正答率（トレーニング） = 0.94195
#                 : 310. 正答率（テスト） = 0.9413
# Generation: 320. 正答率（トレーニング） = 0.9384333333333333
#                 : 320. 正答率（テスト） = 0.9368
# Generation: 330. 正答率（トレーニング） = 0.93475
#                 : 330. 正答率（テスト） = 0.9316
# Generation: 340. 正答率（トレーニング） = 0.9429833333333333
#                 : 340. 正答率（テスト） = 0.9387
# Generation: 350. 正答率（トレーニング） = 0.9462666666666667
#                 : 350. 正答率（テスト） = 0.9412
# Generation: 360. 正答率（トレーニング） = 0.952
#                 : 360. 正答率（テスト） = 0.9475
# Generation: 370. 正答率（トレーニング） = 0.9418166666666666
#                 : 370. 正答率（テスト） = 0.939
# Generation: 380. 正答率（トレーニング） = 0.9446833333333333
#                 : 380. 正答率（テスト） = 0.9396
# Generation: 390. 正答率（トレーニング） = 0.94155
#                 : 390. 正答率（テスト） = 0.9369
# Generation: 400. 正答率（トレーニング） = 0.9406333333333333
#                 : 400. 正答率（テスト） = 0.9392
# Generation: 410. 正答率（トレーニング） = 0.94905
#                 : 410. 正答率（テスト） = 0.9438
# Generation: 420. 正答率（トレーニング） = 0.9511
#                 : 420. 正答率（テスト） = 0.9447
# Generation: 430. 正答率（トレーニング） = 0.9427333333333333
#                 : 430. 正答率（テスト） = 0.9414
# Generation: 440. 正答率（トレーニング） = 0.9496166666666667
#                 : 440. 正答率（テスト） = 0.9456
# Generation: 450. 正答率（トレーニング） = 0.9486333333333333
#                 : 450. 正答率（テスト） = 0.9405
# Generation: 460. 正答率（トレーニング） = 0.95295
#                 : 460. 正答率（テスト） = 0.947
# Generation: 470. 正答率（トレーニング） = 0.9457833333333333
#                 : 470. 正答率（テスト） = 0.9399
# Generation: 480. 正答率（トレーニング） = 0.9524166666666667
#                 : 480. 正答率（テスト） = 0.9487
# Generation: 490. 正答率（トレーニング） = 0.9458333333333333
#                 : 490. 正答率（テスト） = 0.9398
# Generation: 500. 正答率（トレーニング） = 0.95085
#                 : 500. 正答率（テスト） = 0.9457
# Generation: 510. 正答率（トレーニング） = 0.9496666666666667
#                 : 510. 正答率（テスト） = 0.94
# Generation: 520. 正答率（トレーニング） = 0.9430166666666666
#                 : 520. 正答率（テスト） = 0.9339
# Generation: 530. 正答率（トレーニング） = 0.9492333333333334
#                 : 530. 正答率（テスト） = 0.9417
# Generation: 540. 正答率（トレーニング） = 0.9555666666666667
#                 : 540. 正答率（テスト） = 0.9474
# Generation: 550. 正答率（トレーニング） = 0.9489833333333333
#                 : 550. 正答率（テスト） = 0.9447
# Generation: 560. 正答率（トレーニング） = 0.9526
#                 : 560. 正答率（テスト） = 0.945
# Generation: 570. 正答率（トレーニング） = 0.948
#                 : 570. 正答率（テスト） = 0.9443
# Generation: 580. 正答率（トレーニング） = 0.9516166666666667
#                 : 580. 正答率（テスト） = 0.9442
# Generation: 590. 正答率（トレーニング） = 0.9492166666666667
#                 : 590. 正答率（テスト） = 0.9454
# Generation: 600. 正答率（トレーニング） = 0.9475833333333333
#                 : 600. 正答率（テスト） = 0.9418
# Generation: 610. 正答率（トレーニング） = 0.946
#                 : 610. 正答率（テスト） = 0.942
# Generation: 620. 正答率（トレーニング） = 0.9441833333333334
#                 : 620. 正答率（テスト） = 0.9402
# Generation: 630. 正答率（トレーニング） = 0.94915
#                 : 630. 正答率（テスト） = 0.9492
# Generation: 640. 正答率（トレーニング） = 0.9492166666666667
#                 : 640. 正答率（テスト） = 0.9442
# Generation: 650. 正答率（トレーニング） = 0.9545666666666667
#                 : 650. 正答率（テスト） = 0.9492
# Generation: 660. 正答率（トレーニング） = 0.9543166666666667
#                 : 660. 正答率（テスト） = 0.9495
# Generation: 670. 正答率（トレーニング） = 0.9506833333333333
#                 : 670. 正答率（テスト） = 0.9448
# Generation: 680. 正答率（トレーニング） = 0.9515
#                 : 680. 正答率（テスト） = 0.9458
# Generation: 690. 正答率（トレーニング） = 0.9526666666666667
#                 : 690. 正答率（テスト） = 0.9481
# Generation: 700. 正答率（トレーニング） = 0.9462166666666667
#                 : 700. 正答率（テスト） = 0.9438
# Generation: 710. 正答率（トレーニング） = 0.94655
#                 : 710. 正答率（テスト） = 0.9449
# Generation: 720. 正答率（トレーニング） = 0.9532333333333334
#                 : 720. 正答率（テスト） = 0.9476
# Generation: 730. 正答率（トレーニング） = 0.9552333333333334
#                 : 730. 正答率（テスト） = 0.95
# Generation: 740. 正答率（トレーニング） = 0.96025
#                 : 740. 正答率（テスト） = 0.9536
# Generation: 750. 正答率（トレーニング） = 0.9539333333333333
#                 : 750. 正答率（テスト） = 0.9494
# Generation: 760. 正答率（トレーニング） = 0.9543833333333334
#                 : 760. 正答率（テスト） = 0.9473
# Generation: 770. 正答率（トレーニング） = 0.94735
#                 : 770. 正答率（テスト） = 0.9423
# Generation: 780. 正答率（トレーニング） = 0.9527333333333333
#                 : 780. 正答率（テスト） = 0.9461
# Generation: 790. 正答率（トレーニング） = 0.9536833333333333
#                 : 790. 正答率（テスト） = 0.9499
# Generation: 800. 正答率（トレーニング） = 0.9515
#                 : 800. 正答率（テスト） = 0.9429
# Generation: 810. 正答率（トレーニング） = 0.95385
#                 : 810. 正答率（テスト） = 0.9457
# Generation: 820. 正答率（トレーニング） = 0.9507333333333333
#                 : 820. 正答率（テスト） = 0.9445
# Generation: 830. 正答率（トレーニング） = 0.9565833333333333
#                 : 830. 正答率（テスト） = 0.9504
# Generation: 840. 正答率（トレーニング） = 0.9608
#                 : 840. 正答率（テスト） = 0.9522
# Generation: 850. 正答率（トレーニング） = 0.9614333333333334
#                 : 850. 正答率（テスト） = 0.9519
# Generation: 860. 正答率（トレーニング） = 0.9629333333333333
#                 : 860. 正答率（テスト） = 0.9541
# Generation: 870. 正答率（トレーニング） = 0.9601833333333334
#                 : 870. 正答率（テスト） = 0.9538
# Generation: 880. 正答率（トレーニング） = 0.9613666666666667
#                 : 880. 正答率（テスト） = 0.9545
# Generation: 890. 正答率（トレーニング） = 0.9586166666666667
#                 : 890. 正答率（テスト） = 0.9509
# Generation: 900. 正答率（トレーニング） = 0.9604166666666667
#                 : 900. 正答率（テスト） = 0.953
# Generation: 910. 正答率（トレーニング） = 0.9636333333333333
#                 : 910. 正答率（テスト） = 0.9575
# Generation: 920. 正答率（トレーニング） = 0.9583
#                 : 920. 正答率（テスト） = 0.9531
# Generation: 930. 正答率（トレーニング） = 0.9636833333333333
#                 : 930. 正答率（テスト） = 0.9565
# Generation: 940. 正答率（トレーニング） = 0.9605166666666667
#                 : 940. 正答率（テスト） = 0.9541
# Generation: 950. 正答率（トレーニング） = 0.9535666666666667
#                 : 950. 正答率（テスト） = 0.9486
# Generation: 960. 正答率（トレーニング） = 0.96145
#                 : 960. 正答率（テスト） = 0.9553
# Generation: 970. 正答率（トレーニング） = 0.9567666666666667
#                 : 970. 正答率（テスト） = 0.9495
# Generation: 980. 正答率（トレーニング） = 0.9597
#                 : 980. 正答率（テスト） = 0.951
# Generation: 990. 正答率（トレーニング） = 0.9624333333333334
#                 : 990. 正答率（テスト） = 0.9554
# Generation: 1000. 正答率（トレーニング） = 0.9613666666666667
#                 : 1000. 正答率（テスト） = 0.954
# Generation: 1010. 正答率（トレーニング） = 0.9602166666666667
#                 : 1010. 正答率（テスト） = 0.9523
# Generation: 1020. 正答率（トレーニング） = 0.9588833333333333
#                 : 1020. 正答率（テスト） = 0.9495
# Generation: 1030. 正答率（トレーニング） = 0.9604333333333334
#                 : 1030. 正答率（テスト） = 0.9529
# Generation: 1040. 正答率（トレーニング） = 0.95805
#                 : 1040. 正答率（テスト） = 0.9523
# Generation: 1050. 正答率（トレーニング） = 0.9604833333333334
#                 : 1050. 正答率（テスト） = 0.9542
# Generation: 1060. 正答率（トレーニング） = 0.96385
#                 : 1060. 正答率（テスト） = 0.9575
# Generation: 1070. 正答率（トレーニング） = 0.9544333333333334
#                 : 1070. 正答率（テスト） = 0.9489
# Generation: 1080. 正答率（トレーニング） = 0.9532166666666667
#                 : 1080. 正答率（テスト） = 0.9474
# Generation: 1090. 正答率（トレーニング） = 0.9503
#                 : 1090. 正答率（テスト） = 0.9421
# Generation: 1100. 正答率（トレーニング） = 0.9551
#                 : 1100. 正答率（テスト） = 0.9477
# Generation: 1110. 正答率（トレーニング） = 0.9595833333333333
#                 : 1110. 正答率（テスト） = 0.951
# Generation: 1120. 正答率（トレーニング） = 0.95755
#                 : 1120. 正答率（テスト） = 0.9544
# Generation: 1130. 正答率（トレーニング） = 0.9587333333333333
#                 : 1130. 正答率（テスト） = 0.9544
# Generation: 1140. 正答率（トレーニング） = 0.9621166666666666
#                 : 1140. 正答率（テスト） = 0.9556
# Generation: 1150. 正答率（トレーニング） = 0.9622333333333334
#                 : 1150. 正答率（テスト） = 0.9541
# Generation: 1160. 正答率（トレーニング） = 0.9631166666666666
#                 : 1160. 正答率（テスト） = 0.9542
# Generation: 1170. 正答率（トレーニング） = 0.9624833333333334
#                 : 1170. 正答率（テスト） = 0.9578
# Generation: 1180. 正答率（トレーニング） = 0.95755
#                 : 1180. 正答率（テスト） = 0.949
# Generation: 1190. 正答率（トレーニング） = 0.9616666666666667
#                 : 1190. 正答率（テスト） = 0.9541
# Generation: 1200. 正答率（トレーニング） = 0.9640166666666666
#                 : 1200. 正答率（テスト） = 0.9564
# Generation: 1210. 正答率（トレーニング） = 0.9607833333333333
#                 : 1210. 正答率（テスト） = 0.9534
# Generation: 1220. 正答率（トレーニング） = 0.9614666666666667
#                 : 1220. 正答率（テスト） = 0.9554
# Generation: 1230. 正答率（トレーニング） = 0.9563
#                 : 1230. 正答率（テスト） = 0.9493
# Generation: 1240. 正答率（トレーニング） = 0.9635
#                 : 1240. 正答率（テスト） = 0.9581
# Generation: 1250. 正答率（トレーニング） = 0.9640666666666666
#                 : 1250. 正答率（テスト） = 0.9581
# Generation: 1260. 正答率（トレーニング） = 0.96465
#                 : 1260. 正答率（テスト） = 0.9585
# Generation: 1270. 正答率（トレーニング） = 0.9585833333333333
#                 : 1270. 正答率（テスト） = 0.9535
# Generation: 1280. 正答率（トレーニング） = 0.9638333333333333
#                 : 1280. 正答率（テスト） = 0.9565
# Generation: 1290. 正答率（トレーニング） = 0.9598333333333333
#                 : 1290. 正答率（テスト） = 0.953
# Generation: 1300. 正答率（トレーニング） = 0.95435
#                 : 1300. 正答率（テスト） = 0.9496
# Generation: 1310. 正答率（トレーニング） = 0.9636666666666667
#                 : 1310. 正答率（テスト） = 0.9559
# Generation: 1320. 正答率（トレーニング） = 0.95965
#                 : 1320. 正答率（テスト） = 0.9547
# Generation: 1330. 正答率（トレーニング） = 0.9578166666666666
#                 : 1330. 正答率（テスト） = 0.9529
# Generation: 1340. 正答率（トレーニング） = 0.96525
#                 : 1340. 正答率（テスト） = 0.9588
# Generation: 1350. 正答率（トレーニング） = 0.9530833333333333
#                 : 1350. 正答率（テスト） = 0.9446
# Generation: 1360. 正答率（トレーニング） = 0.9635833333333333
#                 : 1360. 正答率（テスト） = 0.9559
# Generation: 1370. 正答率（トレーニング） = 0.9623833333333334
#                 : 1370. 正答率（テスト） = 0.9548
# Generation: 1380. 正答率（トレーニング） = 0.9592833333333334
#                 : 1380. 正答率（テスト） = 0.9508
# Generation: 1390. 正答率（トレーニング） = 0.9583
#                 : 1390. 正答率（テスト） = 0.9504
# Generation: 1400. 正答率（トレーニング） = 0.9611833333333333
#                 : 1400. 正答率（テスト） = 0.9544
# Generation: 1410. 正答率（トレーニング） = 0.9618
#                 : 1410. 正答率（テスト） = 0.9555
# Generation: 1420. 正答率（トレーニング） = 0.9644666666666667
#                 : 1420. 正答率（テスト） = 0.9556
# Generation: 1430. 正答率（トレーニング） = 0.9648166666666667
#                 : 1430. 正答率（テスト） = 0.957
# Generation: 1440. 正答率（トレーニング） = 0.9612166666666667
#                 : 1440. 正答率（テスト） = 0.9556
# Generation: 1450. 正答率（トレーニング） = 0.9632666666666667
#                 : 1450. 正答率（テスト） = 0.9567
# Generation: 1460. 正答率（トレーニング） = 0.9636833333333333
#                 : 1460. 正答率（テスト） = 0.9557
# Generation: 1470. 正答率（トレーニング） = 0.9652166666666666
#                 : 1470. 正答率（テスト） = 0.9578
# Generation: 1480. 正答率（トレーニング） = 0.9639666666666666
#                 : 1480. 正答率（テスト） = 0.9575
# Generation: 1490. 正答率（トレーニング） = 0.9608666666666666
#                 : 1490. 正答率（テスト） = 0.9524
# Generation: 1500. 正答率（トレーニング） = 0.9680833333333333
#                 : 1500. 正答率（テスト） = 0.9598
# Generation: 1510. 正答率（トレーニング） = 0.9623833333333334
#                 : 1510. 正答率（テスト） = 0.9553
# Generation: 1520. 正答率（トレーニング） = 0.9647333333333333
#                 : 1520. 正答率（テスト） = 0.9569
# Generation: 1530. 正答率（トレーニング） = 0.9668
#                 : 1530. 正答率（テスト） = 0.957
# Generation: 1540. 正答率（トレーニング） = 0.96855
#                 : 1540. 正答率（テスト） = 0.9604
# Generation: 1550. 正答率（トレーニング） = 0.9633166666666667
#                 : 1550. 正答率（テスト） = 0.9525
# Generation: 1560. 正答率（トレーニング） = 0.96815
#                 : 1560. 正答率（テスト） = 0.9595
# Generation: 1570. 正答率（トレーニング） = 0.9687
#                 : 1570. 正答率（テスト） = 0.9585
# Generation: 1580. 正答率（トレーニング） = 0.9592166666666667
#                 : 1580. 正答率（テスト） = 0.9503
# Generation: 1590. 正答率（トレーニング） = 0.9649
#                 : 1590. 正答率（テスト） = 0.9559
# Generation: 1600. 正答率（トレーニング） = 0.9651666666666666
#                 : 1600. 正答率（テスト） = 0.9562
# Generation: 1610. 正答率（トレーニング） = 0.9646666666666667
#                 : 1610. 正答率（テスト） = 0.956
# Generation: 1620. 正答率（トレーニング） = 0.9690833333333333
#                 : 1620. 正答率（テスト） = 0.9613
# Generation: 1630. 正答率（トレーニング） = 0.9674166666666667
#                 : 1630. 正答率（テスト） = 0.9586
# Generation: 1640. 正答率（トレーニング） = 0.9542
#                 : 1640. 正答率（テスト） = 0.9444
# Generation: 1650. 正答率（トレーニング） = 0.9653333333333334
#                 : 1650. 正答率（テスト） = 0.9542
# Generation: 1660. 正答率（トレーニング） = 0.9667166666666667
#                 : 1660. 正答率（テスト） = 0.958
# Generation: 1670. 正答率（トレーニング） = 0.9667833333333333
#                 : 1670. 正答率（テスト） = 0.9582
# Generation: 1680. 正答率（トレーニング） = 0.9664333333333334
#                 : 1680. 正答率（テスト） = 0.9589
# Generation: 1690. 正答率（トレーニング） = 0.9658166666666667
#                 : 1690. 正答率（テスト） = 0.9596
# Generation: 1700. 正答率（トレーニング） = 0.9645333333333334
#                 : 1700. 正答率（テスト） = 0.9574
# Generation: 1710. 正答率（トレーニング） = 0.9678
#                 : 1710. 正答率（テスト） = 0.9571
# Generation: 1720. 正答率（トレーニング） = 0.9661833333333333
#                 : 1720. 正答率（テスト） = 0.9564
# Generation: 1730. 正答率（トレーニング） = 0.9699
#                 : 1730. 正答率（テスト） = 0.96
# Generation: 1740. 正答率（トレーニング） = 0.9670833333333333
#                 : 1740. 正答率（テスト） = 0.9562
# Generation: 1750. 正答率（トレーニング） = 0.9626333333333333
#                 : 1750. 正答率（テスト） = 0.9528
# Generation: 1760. 正答率（トレーニング） = 0.95825
#                 : 1760. 正答率（テスト） = 0.952
# Generation: 1770. 正答率（トレーニング） = 0.9649833333333333
#                 : 1770. 正答率（テスト） = 0.9562
# Generation: 1780. 正答率（トレーニング） = 0.9675166666666667
#                 : 1780. 正答率（テスト） = 0.9597
# Generation: 1790. 正答率（トレーニング） = 0.9662333333333334
#                 : 1790. 正答率（テスト） = 0.9589
# Generation: 1800. 正答率（トレーニング） = 0.9685333333333334
#                 : 1800. 正答率（テスト） = 0.963
# Generation: 1810. 正答率（トレーニング） = 0.9603666666666667
#                 : 1810. 正答率（テスト） = 0.9524
# Generation: 1820. 正答率（トレーニング） = 0.9642666666666667
#                 : 1820. 正答率（テスト） = 0.9565
# Generation: 1830. 正答率（トレーニング） = 0.9683333333333334
#                 : 1830. 正答率（テスト） = 0.9616
# Generation: 1840. 正答率（トレーニング） = 0.9679166666666666
#                 : 1840. 正答率（テスト） = 0.9576
# Generation: 1850. 正答率（トレーニング） = 0.9677666666666667
#                 : 1850. 正答率（テスト） = 0.9581
# Generation: 1860. 正答率（トレーニング） = 0.9708166666666667
#                 : 1860. 正答率（テスト） = 0.9624
# Generation: 1870. 正答率（トレーニング） = 0.96825
#                 : 1870. 正答率（テスト） = 0.9575
# Generation: 1880. 正答率（トレーニング） = 0.96675
#                 : 1880. 正答率（テスト） = 0.9598
# Generation: 1890. 正答率（トレーニング） = 0.9703833333333334
#                 : 1890. 正答率（テスト） = 0.9628
# Generation: 1900. 正答率（トレーニング） = 0.9661166666666666
#                 : 1900. 正答率（テスト） = 0.9573
# Generation: 1910. 正答率（トレーニング） = 0.96615
#                 : 1910. 正答率（テスト） = 0.9545
# Generation: 1920. 正答率（トレーニング） = 0.9669166666666666
#                 : 1920. 正答率（テスト） = 0.9554
# Generation: 1930. 正答率（トレーニング） = 0.9644666666666667
#                 : 1930. 正答率（テスト） = 0.9564
# Generation: 1940. 正答率（トレーニング） = 0.9717333333333333
#                 : 1940. 正答率（テスト） = 0.9626
# Generation: 1950. 正答率（トレーニング） = 0.9669666666666666
#                 : 1950. 正答率（テスト） = 0.9588
# Generation: 1960. 正答率（トレーニング） = 0.9713333333333334
#                 : 1960. 正答率（テスト） = 0.9626
# Generation: 1970. 正答率（トレーニング） = 0.9670666666666666
#                 : 1970. 正答率（テスト） = 0.9581
# Generation: 1980. 正答率（トレーニング） = 0.96735
#                 : 1980. 正答率（テスト） = 0.961
# Generation: 1990. 正答率（トレーニング） = 0.96755
#                 : 1990. 正答率（テスト） = 0.9596
# Generation: 2000. 正答率（トレーニング） = 0.9692166666666666
#                 : 2000. 正答率（テスト） = 0.9593

# %%
Tester9.plot_results()
plt.show()

# %%
Tester10 = OptimizerTest(activation = "sigmoid", weight_init_std = "Xavier" , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test, OptimizerType = "Adam")
Tester10.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.3289
#                 : 10. 正答率（テスト） = 0.3349
# Generation: 20. 正答率（トレーニング） = 0.59635
#                 : 20. 正答率（テスト） = 0.6088
# Generation: 30. 正答率（トレーニング） = 0.7135
#                 : 30. 正答率（テスト） = 0.7237
# Generation: 40. 正答率（トレーニング） = 0.7434666666666667
#                 : 40. 正答率（テスト） = 0.7491
# Generation: 50. 正答率（トレーニング） = 0.8210833333333334
#                 : 50. 正答率（テスト） = 0.8242
# Generation: 60. 正答率（トレーニング） = 0.8399166666666666
#                 : 60. 正答率（テスト） = 0.8455
# Generation: 70. 正答率（トレーニング） = 0.8587833333333333
#                 : 70. 正答率（テスト） = 0.8628
# Generation: 80. 正答率（トレーニング） = 0.8669333333333333
#                 : 80. 正答率（テスト） = 0.8684
# Generation: 90. 正答率（トレーニング） = 0.8799333333333333
#                 : 90. 正答率（テスト） = 0.8841
# Generation: 100. 正答率（トレーニング） = 0.8892
#                 : 100. 正答率（テスト） = 0.8877
# Generation: 110. 正答率（トレーニング） = 0.8919
#                 : 110. 正答率（テスト） = 0.8934
# Generation: 120. 正答率（トレーニング） = 0.8871833333333333
#                 : 120. 正答率（テスト） = 0.8869
# Generation: 130. 正答率（トレーニング） = 0.8946166666666666
#                 : 130. 正答率（テスト） = 0.8968
# Generation: 140. 正答率（トレーニング） = 0.9037833333333334
#                 : 140. 正答率（テスト） = 0.9061
# Generation: 150. 正答率（トレーニング） = 0.9060666666666667
#                 : 150. 正答率（テスト） = 0.9082
# Generation: 160. 正答率（トレーニング） = 0.9051666666666667
#                 : 160. 正答率（テスト） = 0.907
# Generation: 170. 正答率（トレーニング） = 0.91045
#                 : 170. 正答率（テスト） = 0.9133
# Generation: 180. 正答率（トレーニング） = 0.9116833333333333
#                 : 180. 正答率（テスト） = 0.912
# Generation: 190. 正答率（トレーニング） = 0.9133333333333333
#                 : 190. 正答率（テスト） = 0.9138
# Generation: 200. 正答率（トレーニング） = 0.9198333333333333
#                 : 200. 正答率（テスト） = 0.9185
# Generation: 210. 正答率（トレーニング） = 0.9179333333333334
#                 : 210. 正答率（テスト） = 0.9197
# Generation: 220. 正答率（トレーニング） = 0.919
#                 : 220. 正答率（テスト） = 0.9172
# Generation: 230. 正答率（トレーニング） = 0.9192833333333333
#                 : 230. 正答率（テスト） = 0.9173
# Generation: 240. 正答率（トレーニング） = 0.9232166666666667
#                 : 240. 正答率（テスト） = 0.9217
# Generation: 250. 正答率（トレーニング） = 0.9247666666666666
#                 : 250. 正答率（テスト） = 0.9222
# Generation: 260. 正答率（トレーニング） = 0.92735
#                 : 260. 正答率（テスト） = 0.9266
# Generation: 270. 正答率（トレーニング） = 0.9276166666666666
#                 : 270. 正答率（テスト） = 0.9238
# Generation: 280. 正答率（トレーニング） = 0.9241
#                 : 280. 正答率（テスト） = 0.9214
# Generation: 290. 正答率（トレーニング） = 0.92865
#                 : 290. 正答率（テスト） = 0.9243
# Generation: 300. 正答率（トレーニング） = 0.9312833333333334
#                 : 300. 正答率（テスト） = 0.9282
# Generation: 310. 正答率（トレーニング） = 0.9314666666666667
#                 : 310. 正答率（テスト） = 0.9286
# Generation: 320. 正答率（トレーニング） = 0.9331
#                 : 320. 正答率（テスト） = 0.9321
# Generation: 330. 正答率（トレーニング） = 0.93015
#                 : 330. 正答率（テスト） = 0.9294
# Generation: 340. 正答率（トレーニング） = 0.9346166666666667
#                 : 340. 正答率（テスト） = 0.9331
# Generation: 350. 正答率（トレーニング） = 0.9331333333333334
#                 : 350. 正答率（テスト） = 0.9306
# Generation: 360. 正答率（トレーニング） = 0.9393333333333334
#                 : 360. 正答率（テスト） = 0.9372
# Generation: 370. 正答率（トレーニング） = 0.9334666666666667
#                 : 370. 正答率（テスト） = 0.9304
# Generation: 380. 正答率（トレーニング） = 0.9349
#                 : 380. 正答率（テスト） = 0.9308
# Generation: 390. 正答率（トレーニング） = 0.9376666666666666
#                 : 390. 正答率（テスト） = 0.9343
# Generation: 400. 正答率（トレーニング） = 0.9380833333333334
#                 : 400. 正答率（テスト） = 0.9331
# Generation: 410. 正答率（トレーニング） = 0.9391
#                 : 410. 正答率（テスト） = 0.9414
# Generation: 420. 正答率（トレーニング） = 0.9380166666666667
#                 : 420. 正答率（テスト） = 0.936
# Generation: 430. 正答率（トレーニング） = 0.9384833333333333
#                 : 430. 正答率（テスト） = 0.9366
# Generation: 440. 正答率（トレーニング） = 0.9396333333333333
#                 : 440. 正答率（テスト） = 0.9372
# Generation: 450. 正答率（トレーニング） = 0.9432166666666667
#                 : 450. 正答率（テスト） = 0.9395
# Generation: 460. 正答率（トレーニング） = 0.9439833333333333
#                 : 460. 正答率（テスト） = 0.9409
# Generation: 470. 正答率（トレーニング） = 0.9463833333333334
#                 : 470. 正答率（テスト） = 0.9435
# Generation: 480. 正答率（トレーニング） = 0.9443333333333334
#                 : 480. 正答率（テスト） = 0.9412
# Generation: 490. 正答率（トレーニング） = 0.9444333333333333
#                 : 490. 正答率（テスト） = 0.9424
# Generation: 500. 正答率（トレーニング） = 0.9406333333333333
#                 : 500. 正答率（テスト） = 0.9368
# Generation: 510. 正答率（トレーニング） = 0.9419
#                 : 510. 正答率（テスト） = 0.9369
# Generation: 520. 正答率（トレーニング） = 0.9457333333333333
#                 : 520. 正答率（テスト） = 0.9425
# Generation: 530. 正答率（トレーニング） = 0.9430166666666666
#                 : 530. 正答率（テスト） = 0.9373
# Generation: 540. 正答率（トレーニング） = 0.9395
#                 : 540. 正答率（テスト） = 0.9357
# Generation: 550. 正答率（トレーニング） = 0.9477833333333333
#                 : 550. 正答率（テスト） = 0.9421
# Generation: 560. 正答率（トレーニング） = 0.9445
#                 : 560. 正答率（テスト） = 0.9389
# Generation: 570. 正答率（トレーニング） = 0.9494833333333333
#                 : 570. 正答率（テスト） = 0.9452
# Generation: 580. 正答率（トレーニング） = 0.9499166666666666
#                 : 580. 正答率（テスト） = 0.9453
# Generation: 590. 正答率（トレーニング） = 0.95145
#                 : 590. 正答率（テスト） = 0.9471
# Generation: 600. 正答率（トレーニング） = 0.9505333333333333
#                 : 600. 正答率（テスト） = 0.9461
# Generation: 610. 正答率（トレーニング） = 0.9466
#                 : 610. 正答率（テスト） = 0.9414
# Generation: 620. 正答率（トレーニング） = 0.9476166666666667
#                 : 620. 正答率（テスト） = 0.9427
# Generation: 630. 正答率（トレーニング） = 0.9464166666666667
#                 : 630. 正答率（テスト） = 0.9429
# Generation: 640. 正答率（トレーニング） = 0.95165
#                 : 640. 正答率（テスト） = 0.9456
# Generation: 650. 正答率（トレーニング） = 0.95175
#                 : 650. 正答率（テスト） = 0.9464
# Generation: 660. 正答率（トレーニング） = 0.9532166666666667
#                 : 660. 正答率（テスト） = 0.9495
# Generation: 670. 正答率（トレーニング） = 0.9544333333333334
#                 : 670. 正答率（テスト） = 0.9497
# Generation: 680. 正答率（トレーニング） = 0.9535666666666667
#                 : 680. 正答率（テスト） = 0.9492
# Generation: 690. 正答率（トレーニング） = 0.9531833333333334
#                 : 690. 正答率（テスト） = 0.9494
# Generation: 700. 正答率（トレーニング） = 0.9514833333333333
#                 : 700. 正答率（テスト） = 0.9455
# Generation: 710. 正答率（トレーニング） = 0.9544333333333334
#                 : 710. 正答率（テスト） = 0.9469
# Generation: 720. 正答率（トレーニング） = 0.9516166666666667
#                 : 720. 正答率（テスト） = 0.9464
# Generation: 730. 正答率（トレーニング） = 0.9544833333333334
#                 : 730. 正答率（テスト） = 0.9484
# Generation: 740. 正答率（トレーニング） = 0.9540666666666666
#                 : 740. 正答率（テスト） = 0.9474
# Generation: 750. 正答率（トレーニング） = 0.9567333333333333
#                 : 750. 正答率（テスト） = 0.9526
# Generation: 760. 正答率（トレーニング） = 0.9558166666666666
#                 : 760. 正答率（テスト） = 0.9509
# Generation: 770. 正答率（トレーニング） = 0.9580833333333333
#                 : 770. 正答率（テスト） = 0.9517
# Generation: 780. 正答率（トレーニング） = 0.9527
#                 : 780. 正答率（テスト） = 0.9481
# Generation: 790. 正答率（トレーニング） = 0.95245
#                 : 790. 正答率（テスト） = 0.9479
# Generation: 800. 正答率（トレーニング） = 0.9552166666666667
#                 : 800. 正答率（テスト） = 0.948
# Generation: 810. 正答率（トレーニング） = 0.95485
#                 : 810. 正答率（テスト） = 0.9508
# Generation: 820. 正答率（トレーニング） = 0.95485
#                 : 820. 正答率（テスト） = 0.9513
# Generation: 830. 正答率（トレーニング） = 0.9546166666666667
#                 : 830. 正答率（テスト） = 0.9521
# Generation: 840. 正答率（トレーニング） = 0.9553666666666667
#                 : 840. 正答率（テスト） = 0.952
# Generation: 850. 正答率（トレーニング） = 0.9551666666666667
#                 : 850. 正答率（テスト） = 0.9518
# Generation: 860. 正答率（トレーニング） = 0.95535
#                 : 860. 正答率（テスト） = 0.95
# Generation: 870. 正答率（トレーニング） = 0.9581166666666666
#                 : 870. 正答率（テスト） = 0.952
# Generation: 880. 正答率（トレーニング） = 0.95825
#                 : 880. 正答率（テスト） = 0.9521
# Generation: 890. 正答率（トレーニング） = 0.95995
#                 : 890. 正答率（テスト） = 0.9537
# Generation: 900. 正答率（トレーニング） = 0.9563333333333334
#                 : 900. 正答率（テスト） = 0.9496
# Generation: 910. 正答率（トレーニング） = 0.9588333333333333
#                 : 910. 正答率（テスト） = 0.9527
# Generation: 920. 正答率（トレーニング） = 0.95835
#                 : 920. 正答率（テスト） = 0.9499
# Generation: 930. 正答率（トレーニング） = 0.9581
#                 : 930. 正答率（テスト） = 0.9522
# Generation: 940. 正答率（トレーニング） = 0.9583833333333334
#                 : 940. 正答率（テスト） = 0.9547
# Generation: 950. 正答率（トレーニング） = 0.9553166666666667
#                 : 950. 正答率（テスト） = 0.95
# Generation: 960. 正答率（トレーニング） = 0.9542333333333334
#                 : 960. 正答率（テスト） = 0.9496
# Generation: 970. 正答率（トレーニング） = 0.9519833333333333
#                 : 970. 正答率（テスト） = 0.9448
# Generation: 980. 正答率（トレーニング） = 0.9563666666666667
#                 : 980. 正答率（テスト） = 0.9484
# Generation: 990. 正答率（トレーニング） = 0.9587166666666667
#                 : 990. 正答率（テスト） = 0.9518
# Generation: 1000. 正答率（トレーニング） = 0.9600833333333333
#                 : 1000. 正答率（テスト） = 0.9545
# Generation: 1010. 正答率（トレーニング） = 0.9602666666666667
#                 : 1010. 正答率（テスト） = 0.9553
# Generation: 1020. 正答率（トレーニング） = 0.9592666666666667
#                 : 1020. 正答率（テスト） = 0.9513
# Generation: 1030. 正答率（トレーニング） = 0.9597166666666667
#                 : 1030. 正答率（テスト） = 0.9545
# Generation: 1040. 正答率（トレーニング） = 0.9600833333333333
#                 : 1040. 正答率（テスト） = 0.9558
# Generation: 1050. 正答率（トレーニング） = 0.9602333333333334
#                 : 1050. 正答率（テスト） = 0.9525
# Generation: 1060. 正答率（トレーニング） = 0.96125
#                 : 1060. 正答率（テスト） = 0.9547
# Generation: 1070. 正答率（トレーニング） = 0.9620833333333333
#                 : 1070. 正答率（テスト） = 0.9552
# Generation: 1080. 正答率（トレーニング） = 0.96005
#                 : 1080. 正答率（テスト） = 0.955
# Generation: 1090. 正答率（トレーニング） = 0.9611
#                 : 1090. 正答率（テスト） = 0.9542
# Generation: 1100. 正答率（トレーニング） = 0.96175
#                 : 1100. 正答率（テスト） = 0.9555
# Generation: 1110. 正答率（トレーニング） = 0.9635
#                 : 1110. 正答率（テスト） = 0.958
# Generation: 1120. 正答率（トレーニング） = 0.96255
#                 : 1120. 正答率（テスト） = 0.9544
# Generation: 1130. 正答率（トレーニング） = 0.9645833333333333
#                 : 1130. 正答率（テスト） = 0.9557
# Generation: 1140. 正答率（トレーニング） = 0.9598833333333333
#                 : 1140. 正答率（テスト） = 0.9519
# Generation: 1150. 正答率（トレーニング） = 0.9601
#                 : 1150. 正答率（テスト） = 0.9533
# Generation: 1160. 正答率（トレーニング） = 0.96155
#                 : 1160. 正答率（テスト） = 0.9557
# Generation: 1170. 正答率（トレーニング） = 0.9657333333333333
#                 : 1170. 正答率（テスト） = 0.9579
# Generation: 1180. 正答率（トレーニング） = 0.962
#                 : 1180. 正答率（テスト） = 0.9523
# Generation: 1190. 正答率（トレーニング） = 0.9607833333333333
#                 : 1190. 正答率（テスト） = 0.9521
# Generation: 1200. 正答率（トレーニング） = 0.9551333333333333
#                 : 1200. 正答率（テスト） = 0.9478
# Generation: 1210. 正答率（トレーニング） = 0.9634
#                 : 1210. 正答率（テスト） = 0.956
# Generation: 1220. 正答率（トレーニング） = 0.96455
#                 : 1220. 正答率（テスト） = 0.9586
# Generation: 1230. 正答率（トレーニング） = 0.9640833333333333
#                 : 1230. 正答率（テスト） = 0.9569
# Generation: 1240. 正答率（トレーニング） = 0.9631
#                 : 1240. 正答率（テスト） = 0.9583
# Generation: 1250. 正答率（トレーニング） = 0.9644833333333334
#                 : 1250. 正答率（テスト） = 0.958
# Generation: 1260. 正答率（トレーニング） = 0.96365
#                 : 1260. 正答率（テスト） = 0.9551
# Generation: 1270. 正答率（トレーニング） = 0.96365
#                 : 1270. 正答率（テスト） = 0.9537
# Generation: 1280. 正答率（トレーニング） = 0.9643166666666667
#                 : 1280. 正答率（テスト） = 0.9561
# Generation: 1290. 正答率（トレーニング） = 0.9659666666666666
#                 : 1290. 正答率（テスト） = 0.9585
# Generation: 1300. 正答率（トレーニング） = 0.96535
#                 : 1300. 正答率（テスト） = 0.9566
# Generation: 1310. 正答率（トレーニング） = 0.9626833333333333
#                 : 1310. 正答率（テスト） = 0.9544
# Generation: 1320. 正答率（トレーニング） = 0.9632833333333334
#                 : 1320. 正答率（テスト） = 0.9561
# Generation: 1330. 正答率（トレーニング） = 0.9651333333333333
#                 : 1330. 正答率（テスト） = 0.9559
# Generation: 1340. 正答率（トレーニング） = 0.9663666666666667
#                 : 1340. 正答率（テスト） = 0.9566
# Generation: 1350. 正答率（トレーニング） = 0.9675166666666667
#                 : 1350. 正答率（テスト） = 0.9581
# Generation: 1360. 正答率（トレーニング） = 0.9651
#                 : 1360. 正答率（テスト） = 0.9567
# Generation: 1370. 正答率（トレーニング） = 0.9641666666666666
#                 : 1370. 正答率（テスト） = 0.9537
# Generation: 1380. 正答率（トレーニング） = 0.9651333333333333
#                 : 1380. 正答率（テスト） = 0.9546
# Generation: 1390. 正答率（トレーニング） = 0.9646666666666667
#                 : 1390. 正答率（テスト） = 0.9553
# Generation: 1400. 正答率（トレーニング） = 0.9603833333333334
#                 : 1400. 正答率（テスト） = 0.9515
# Generation: 1410. 正答率（トレーニング） = 0.9630333333333333
#                 : 1410. 正答率（テスト） = 0.9558
# Generation: 1420. 正答率（トレーニング） = 0.966
#                 : 1420. 正答率（テスト） = 0.9583
# Generation: 1430. 正答率（トレーニング） = 0.9610166666666666
#                 : 1430. 正答率（テスト） = 0.9555
# Generation: 1440. 正答率（トレーニング） = 0.9616333333333333
#                 : 1440. 正答率（テスト） = 0.9577
# Generation: 1450. 正答率（トレーニング） = 0.9649
#                 : 1450. 正答率（テスト） = 0.9571
# Generation: 1460. 正答率（トレーニング） = 0.9649
#                 : 1460. 正答率（テスト） = 0.9587
# Generation: 1470. 正答率（トレーニング） = 0.9657
#                 : 1470. 正答率（テスト） = 0.957
# Generation: 1480. 正答率（トレーニング） = 0.9614333333333334
#                 : 1480. 正答率（テスト） = 0.9526
# Generation: 1490. 正答率（トレーニング） = 0.9628166666666667
#                 : 1490. 正答率（テスト） = 0.9553
# Generation: 1500. 正答率（トレーニング） = 0.9674166666666667
#                 : 1500. 正答率（テスト） = 0.9592
# Generation: 1510. 正答率（トレーニング） = 0.9665333333333334
#                 : 1510. 正答率（テスト） = 0.9586
# Generation: 1520. 正答率（トレーニング） = 0.96585
#                 : 1520. 正答率（テスト） = 0.9577
# Generation: 1530. 正答率（トレーニング） = 0.9687
#                 : 1530. 正答率（テスト） = 0.9602
# Generation: 1540. 正答率（トレーニング） = 0.9664666666666667
#                 : 1540. 正答率（テスト） = 0.9574
# Generation: 1550. 正答率（トレーニング） = 0.9668333333333333
#                 : 1550. 正答率（テスト） = 0.9608
# Generation: 1560. 正答率（トレーニング） = 0.9646
#                 : 1560. 正答率（テスト） = 0.9575
# Generation: 1570. 正答率（トレーニング） = 0.96725
#                 : 1570. 正答率（テスト） = 0.9587
# Generation: 1580. 正答率（トレーニング） = 0.9676333333333333
#                 : 1580. 正答率（テスト） = 0.9574
# Generation: 1590. 正答率（トレーニング） = 0.9656333333333333
#                 : 1590. 正答率（テスト） = 0.9567
# Generation: 1600. 正答率（トレーニング） = 0.9675166666666667
#                 : 1600. 正答率（テスト） = 0.9585
# Generation: 1610. 正答率（トレーニング） = 0.9651833333333333
#                 : 1610. 正答率（テスト） = 0.9579
# Generation: 1620. 正答率（トレーニング） = 0.9688333333333333
#                 : 1620. 正答率（テスト） = 0.9603
# Generation: 1630. 正答率（トレーニング） = 0.9657166666666667
#                 : 1630. 正答率（テスト） = 0.9566
# Generation: 1640. 正答率（トレーニング） = 0.9679333333333333
#                 : 1640. 正答率（テスト） = 0.9592
# Generation: 1650. 正答率（トレーニング） = 0.9627333333333333
#                 : 1650. 正答率（テスト） = 0.9543
# Generation: 1660. 正答率（トレーニング） = 0.9651833333333333
#                 : 1660. 正答率（テスト） = 0.9563
# Generation: 1670. 正答率（トレーニング） = 0.9662333333333334
#                 : 1670. 正答率（テスト） = 0.9578
# Generation: 1680. 正答率（トレーニング） = 0.9646333333333333
#                 : 1680. 正答率（テスト） = 0.9565
# Generation: 1690. 正答率（トレーニング） = 0.9678833333333333
#                 : 1690. 正答率（テスト） = 0.9588
# Generation: 1700. 正答率（トレーニング） = 0.9675
#                 : 1700. 正答率（テスト） = 0.9576
# Generation: 1710. 正答率（トレーニング） = 0.9671166666666666
#                 : 1710. 正答率（テスト） = 0.9588
# Generation: 1720. 正答率（トレーニング） = 0.9654
#                 : 1720. 正答率（テスト） = 0.9588
# Generation: 1730. 正答率（トレーニング） = 0.9655166666666667
#                 : 1730. 正答率（テスト） = 0.9587
# Generation: 1740. 正答率（トレーニング） = 0.96685
#                 : 1740. 正答率（テスト） = 0.9614
# Generation: 1750. 正答率（トレーニング） = 0.9626333333333333
#                 : 1750. 正答率（テスト） = 0.9568
# Generation: 1760. 正答率（トレーニング） = 0.9647333333333333
#                 : 1760. 正答率（テスト） = 0.9528
# Generation: 1770. 正答率（トレーニング） = 0.9645333333333334
#                 : 1770. 正答率（テスト） = 0.955
# Generation: 1780. 正答率（トレーニング） = 0.9672166666666666
#                 : 1780. 正答率（テスト） = 0.9571
# Generation: 1790. 正答率（トレーニング） = 0.9686166666666667
#                 : 1790. 正答率（テスト） = 0.9593
# Generation: 1800. 正答率（トレーニング） = 0.969
#                 : 1800. 正答率（テスト） = 0.9599
# Generation: 1810. 正答率（トレーニング） = 0.9692333333333333
#                 : 1810. 正答率（テスト） = 0.9585
# Generation: 1820. 正答率（トレーニング） = 0.9719333333333333
#                 : 1820. 正答率（テスト） = 0.9615
# Generation: 1830. 正答率（トレーニング） = 0.96865
#                 : 1830. 正答率（テスト） = 0.9593
# Generation: 1840. 正答率（トレーニング） = 0.9666666666666667
#                 : 1840. 正答率（テスト） = 0.9569
# Generation: 1850. 正答率（トレーニング） = 0.9666
#                 : 1850. 正答率（テスト） = 0.9591
# Generation: 1860. 正答率（トレーニング） = 0.9679333333333333
#                 : 1860. 正答率（テスト） = 0.9589
# Generation: 1870. 正答率（トレーニング） = 0.9653333333333334
#                 : 1870. 正答率（テスト） = 0.9561
# Generation: 1880. 正答率（トレーニング） = 0.9568166666666666
#                 : 1880. 正答率（テスト） = 0.9475
# Generation: 1890. 正答率（トレーニング） = 0.96325
#                 : 1890. 正答率（テスト） = 0.9524
# Generation: 1900. 正答率（トレーニング） = 0.9692666666666667
#                 : 1900. 正答率（テスト） = 0.9594
# Generation: 1910. 正答率（トレーニング） = 0.9697
#                 : 1910. 正答率（テスト） = 0.9611
# Generation: 1920. 正答率（トレーニング） = 0.9634166666666667
#                 : 1920. 正答率（テスト） = 0.9521
# Generation: 1930. 正答率（トレーニング） = 0.9683166666666667
#                 : 1930. 正答率（テスト） = 0.9571
# Generation: 1940. 正答率（トレーニング） = 0.9706833333333333
#                 : 1940. 正答率（テスト） = 0.9603
# Generation: 1950. 正答率（トレーニング） = 0.97065
#                 : 1950. 正答率（テスト） = 0.9601
# Generation: 1960. 正答率（トレーニング） = 0.9665
#                 : 1960. 正答率（テスト） = 0.9567
# Generation: 1970. 正答率（トレーニング） = 0.9688666666666667
#                 : 1970. 正答率（テスト） = 0.9574
# Generation: 1980. 正答率（トレーニング） = 0.9717
#                 : 1980. 正答率（テスト） = 0.9593
# Generation: 1990. 正答率（トレーニング） = 0.9703833333333334
#                 : 1990. 正答率（テスト） = 0.9593
# Generation: 2000. 正答率（トレーニング） = 0.9662166666666666
#                 : 2000. 正答率（テスト） = 0.9558

# %%
Tester10.plot_results()
plt.show()

# %%
Tester9 = OptimizerTest(activation = "relu", weight_init_std = "He" , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test, OptimizerType = "Adam")
Tester9.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.7483
#                 : 10. 正答率（テスト） = 0.7553
# Generation: 20. 正答率（トレーニング） = 0.80525
#                 : 20. 正答率（テスト） = 0.8123
# Generation: 30. 正答率（トレーニング） = 0.8496166666666667
#                 : 30. 正答率（テスト） = 0.8512
# Generation: 40. 正答率（トレーニング） = 0.8708333333333333
#                 : 40. 正答率（テスト） = 0.8768
# Generation: 50. 正答率（トレーニング） = 0.8749166666666667
#                 : 50. 正答率（テスト） = 0.8828
# Generation: 60. 正答率（トレーニング） = 0.8847333333333334
#                 : 60. 正答率（テスト） = 0.8882
# Generation: 70. 正答率（トレーニング） = 0.8935
#                 : 70. 正答率（テスト） = 0.8946
# Generation: 80. 正答率（トレーニング） = 0.9027
#                 : 80. 正答率（テスト） = 0.9031
# Generation: 90. 正答率（トレーニング） = 0.9027833333333334
#                 : 90. 正答率（テスト） = 0.9028
# Generation: 100. 正答率（トレーニング） = 0.9199666666666667
#                 : 100. 正答率（テスト） = 0.9192
# Generation: 110. 正答率（トレーニング） = 0.9193
#                 : 110. 正答率（テスト） = 0.9198
# Generation: 120. 正答率（トレーニング） = 0.9234333333333333
#                 : 120. 正答率（テスト） = 0.9215
# Generation: 130. 正答率（トレーニング） = 0.9158833333333334
#                 : 130. 正答率（テスト） = 0.9168
# Generation: 140. 正答率（トレーニング） = 0.92255
#                 : 140. 正答率（テスト） = 0.9222
# Generation: 150. 正答率（トレーニング） = 0.8913833333333333
#                 : 150. 正答率（テスト） = 0.8917
# Generation: 160. 正答率（トレーニング） = 0.9186333333333333
#                 : 160. 正答率（テスト） = 0.9189
# Generation: 170. 正答率（トレーニング） = 0.92505
#                 : 170. 正答率（テスト） = 0.9207
# Generation: 180. 正答率（トレーニング） = 0.9299
#                 : 180. 正答率（テスト） = 0.9287
# Generation: 190. 正答率（トレーニング） = 0.93125
#                 : 190. 正答率（テスト） = 0.9297
# Generation: 200. 正答率（トレーニング） = 0.9329833333333334
#                 : 200. 正答率（テスト） = 0.9268
# Generation: 210. 正答率（トレーニング） = 0.92765
#                 : 210. 正答率（テスト） = 0.9225
# Generation: 220. 正答率（トレーニング） = 0.9345333333333333
#                 : 220. 正答率（テスト） = 0.9315
# Generation: 230. 正答率（トレーニング） = 0.9328
#                 : 230. 正答率（テスト） = 0.9325
# Generation: 240. 正答率（トレーニング） = 0.9367666666666666
#                 : 240. 正答率（テスト） = 0.9337
# Generation: 250. 正答率（トレーニング） = 0.9388833333333333
#                 : 250. 正答率（テスト） = 0.9349
# Generation: 260. 正答率（トレーニング） = 0.9389333333333333
#                 : 260. 正答率（テスト） = 0.9387
# Generation: 270. 正答率（トレーニング） = 0.9380333333333334
#                 : 270. 正答率（テスト） = 0.9331
# Generation: 280. 正答率（トレーニング） = 0.9358333333333333
#                 : 280. 正答率（テスト） = 0.9339
# Generation: 290. 正答率（トレーニング） = 0.9358833333333333
#                 : 290. 正答率（テスト） = 0.9325
# Generation: 300. 正答率（トレーニング） = 0.9375
#                 : 300. 正答率（テスト） = 0.9336
# Generation: 310. 正答率（トレーニング） = 0.94195
#                 : 310. 正答率（テスト） = 0.9413
# Generation: 320. 正答率（トレーニング） = 0.9384333333333333
#                 : 320. 正答率（テスト） = 0.9368
# Generation: 330. 正答率（トレーニング） = 0.93475
#                 : 330. 正答率（テスト） = 0.9316
# Generation: 340. 正答率（トレーニング） = 0.9429833333333333
#                 : 340. 正答率（テスト） = 0.9387
# Generation: 350. 正答率（トレーニング） = 0.9462666666666667
#                 : 350. 正答率（テスト） = 0.9412
# Generation: 360. 正答率（トレーニング） = 0.952
#                 : 360. 正答率（テスト） = 0.9475
# Generation: 370. 正答率（トレーニング） = 0.9418166666666666
#                 : 370. 正答率（テスト） = 0.939
# Generation: 380. 正答率（トレーニング） = 0.9446833333333333
#                 : 380. 正答率（テスト） = 0.9396
# Generation: 390. 正答率（トレーニング） = 0.94155
#                 : 390. 正答率（テスト） = 0.9369
# Generation: 400. 正答率（トレーニング） = 0.9406333333333333
#                 : 400. 正答率（テスト） = 0.9392
# Generation: 410. 正答率（トレーニング） = 0.94905
#                 : 410. 正答率（テスト） = 0.9438
# Generation: 420. 正答率（トレーニング） = 0.9511
#                 : 420. 正答率（テスト） = 0.9447
# Generation: 430. 正答率（トレーニング） = 0.9427333333333333
#                 : 430. 正答率（テスト） = 0.9414
# Generation: 440. 正答率（トレーニング） = 0.9496166666666667
#                 : 440. 正答率（テスト） = 0.9456
# Generation: 450. 正答率（トレーニング） = 0.9486333333333333
#                 : 450. 正答率（テスト） = 0.9405
# Generation: 460. 正答率（トレーニング） = 0.95295
#                 : 460. 正答率（テスト） = 0.947
# Generation: 470. 正答率（トレーニング） = 0.9457833333333333
#                 : 470. 正答率（テスト） = 0.9399
# Generation: 480. 正答率（トレーニング） = 0.9524166666666667
#                 : 480. 正答率（テスト） = 0.9487
# Generation: 490. 正答率（トレーニング） = 0.9458333333333333
#                 : 490. 正答率（テスト） = 0.9398
# Generation: 500. 正答率（トレーニング） = 0.95085
#                 : 500. 正答率（テスト） = 0.9457
# Generation: 510. 正答率（トレーニング） = 0.9496666666666667
#                 : 510. 正答率（テスト） = 0.94
# Generation: 520. 正答率（トレーニング） = 0.9430166666666666
#                 : 520. 正答率（テスト） = 0.9339
# Generation: 530. 正答率（トレーニング） = 0.9492333333333334
#                 : 530. 正答率（テスト） = 0.9417
# Generation: 540. 正答率（トレーニング） = 0.9555666666666667
#                 : 540. 正答率（テスト） = 0.9474
# Generation: 550. 正答率（トレーニング） = 0.9489833333333333
#                 : 550. 正答率（テスト） = 0.9447
# Generation: 560. 正答率（トレーニング） = 0.9526
#                 : 560. 正答率（テスト） = 0.945
# Generation: 570. 正答率（トレーニング） = 0.948
#                 : 570. 正答率（テスト） = 0.9443
# Generation: 580. 正答率（トレーニング） = 0.9516166666666667
#                 : 580. 正答率（テスト） = 0.9442
# Generation: 590. 正答率（トレーニング） = 0.9492166666666667
#                 : 590. 正答率（テスト） = 0.9454
# Generation: 600. 正答率（トレーニング） = 0.9475833333333333
#                 : 600. 正答率（テスト） = 0.9418
# Generation: 610. 正答率（トレーニング） = 0.946
#                 : 610. 正答率（テスト） = 0.942
# Generation: 620. 正答率（トレーニング） = 0.9441833333333334
#                 : 620. 正答率（テスト） = 0.9402
# Generation: 630. 正答率（トレーニング） = 0.94915
#                 : 630. 正答率（テスト） = 0.9492
# Generation: 640. 正答率（トレーニング） = 0.9492166666666667
#                 : 640. 正答率（テスト） = 0.9442
# Generation: 650. 正答率（トレーニング） = 0.9545666666666667
#                 : 650. 正答率（テスト） = 0.9492
# Generation: 660. 正答率（トレーニング） = 0.9543166666666667
#                 : 660. 正答率（テスト） = 0.9495
# Generation: 670. 正答率（トレーニング） = 0.9506833333333333
#                 : 670. 正答率（テスト） = 0.9448
# Generation: 680. 正答率（トレーニング） = 0.9515
#                 : 680. 正答率（テスト） = 0.9458
# Generation: 690. 正答率（トレーニング） = 0.9526666666666667
#                 : 690. 正答率（テスト） = 0.9481
# Generation: 700. 正答率（トレーニング） = 0.9462166666666667
#                 : 700. 正答率（テスト） = 0.9438
# Generation: 710. 正答率（トレーニング） = 0.94655
#                 : 710. 正答率（テスト） = 0.9449
# Generation: 720. 正答率（トレーニング） = 0.9532333333333334
#                 : 720. 正答率（テスト） = 0.9476
# Generation: 730. 正答率（トレーニング） = 0.9552333333333334
#                 : 730. 正答率（テスト） = 0.95
# Generation: 740. 正答率（トレーニング） = 0.96025
#                 : 740. 正答率（テスト） = 0.9536
# Generation: 750. 正答率（トレーニング） = 0.9539333333333333
#                 : 750. 正答率（テスト） = 0.9494
# Generation: 760. 正答率（トレーニング） = 0.9543833333333334
#                 : 760. 正答率（テスト） = 0.9473
# Generation: 770. 正答率（トレーニング） = 0.94735
#                 : 770. 正答率（テスト） = 0.9423
# Generation: 780. 正答率（トレーニング） = 0.9527333333333333
#                 : 780. 正答率（テスト） = 0.9461
# Generation: 790. 正答率（トレーニング） = 0.9536833333333333
#                 : 790. 正答率（テスト） = 0.9499
# Generation: 800. 正答率（トレーニング） = 0.9515
#                 : 800. 正答率（テスト） = 0.9429
# Generation: 810. 正答率（トレーニング） = 0.95385
#                 : 810. 正答率（テスト） = 0.9457
# Generation: 820. 正答率（トレーニング） = 0.9507333333333333
#                 : 820. 正答率（テスト） = 0.9445
# Generation: 830. 正答率（トレーニング） = 0.9565833333333333
#                 : 830. 正答率（テスト） = 0.9504
# Generation: 840. 正答率（トレーニング） = 0.9608
#                 : 840. 正答率（テスト） = 0.9522
# Generation: 850. 正答率（トレーニング） = 0.9614333333333334
#                 : 850. 正答率（テスト） = 0.9519
# Generation: 860. 正答率（トレーニング） = 0.9629333333333333
#                 : 860. 正答率（テスト） = 0.9541
# Generation: 870. 正答率（トレーニング） = 0.9601833333333334
#                 : 870. 正答率（テスト） = 0.9538
# Generation: 880. 正答率（トレーニング） = 0.9613666666666667
#                 : 880. 正答率（テスト） = 0.9545
# Generation: 890. 正答率（トレーニング） = 0.9586166666666667
#                 : 890. 正答率（テスト） = 0.9509
# Generation: 900. 正答率（トレーニング） = 0.9604166666666667
#                 : 900. 正答率（テスト） = 0.953
# Generation: 910. 正答率（トレーニング） = 0.9636333333333333
#                 : 910. 正答率（テスト） = 0.9575
# Generation: 920. 正答率（トレーニング） = 0.9583
#                 : 920. 正答率（テスト） = 0.9531
# Generation: 930. 正答率（トレーニング） = 0.9636833333333333
#                 : 930. 正答率（テスト） = 0.9565
# Generation: 940. 正答率（トレーニング） = 0.9605166666666667
#                 : 940. 正答率（テスト） = 0.9541
# Generation: 950. 正答率（トレーニング） = 0.9535666666666667
#                 : 950. 正答率（テスト） = 0.9486
# Generation: 960. 正答率（トレーニング） = 0.96145
#                 : 960. 正答率（テスト） = 0.9553
# Generation: 970. 正答率（トレーニング） = 0.9567666666666667
#                 : 970. 正答率（テスト） = 0.9495
# Generation: 980. 正答率（トレーニング） = 0.9597
#                 : 980. 正答率（テスト） = 0.951
# Generation: 990. 正答率（トレーニング） = 0.9624333333333334
#                 : 990. 正答率（テスト） = 0.9554
# Generation: 1000. 正答率（トレーニング） = 0.9613666666666667
#                 : 1000. 正答率（テスト） = 0.954
# Generation: 1010. 正答率（トレーニング） = 0.9602166666666667
#                 : 1010. 正答率（テスト） = 0.9523
# Generation: 1020. 正答率（トレーニング） = 0.9588833333333333
#                 : 1020. 正答率（テスト） = 0.9495
# Generation: 1030. 正答率（トレーニング） = 0.9604333333333334
#                 : 1030. 正答率（テスト） = 0.9529
# Generation: 1040. 正答率（トレーニング） = 0.95805
#                 : 1040. 正答率（テスト） = 0.9523
# Generation: 1050. 正答率（トレーニング） = 0.9604833333333334
#                 : 1050. 正答率（テスト） = 0.9542
# Generation: 1060. 正答率（トレーニング） = 0.96385
#                 : 1060. 正答率（テスト） = 0.9575
# Generation: 1070. 正答率（トレーニング） = 0.9544333333333334
#                 : 1070. 正答率（テスト） = 0.9489
# Generation: 1080. 正答率（トレーニング） = 0.9532166666666667
#                 : 1080. 正答率（テスト） = 0.9474
# Generation: 1090. 正答率（トレーニング） = 0.9503
#                 : 1090. 正答率（テスト） = 0.9421
# Generation: 1100. 正答率（トレーニング） = 0.9551
#                 : 1100. 正答率（テスト） = 0.9477
# Generation: 1110. 正答率（トレーニング） = 0.9595833333333333
#                 : 1110. 正答率（テスト） = 0.951
# Generation: 1120. 正答率（トレーニング） = 0.95755
#                 : 1120. 正答率（テスト） = 0.9544
# Generation: 1130. 正答率（トレーニング） = 0.9587333333333333
#                 : 1130. 正答率（テスト） = 0.9544
# Generation: 1140. 正答率（トレーニング） = 0.9621166666666666
#                 : 1140. 正答率（テスト） = 0.9556
# Generation: 1150. 正答率（トレーニング） = 0.9622333333333334
#                 : 1150. 正答率（テスト） = 0.9541
# Generation: 1160. 正答率（トレーニング） = 0.9631166666666666
#                 : 1160. 正答率（テスト） = 0.9542
# Generation: 1170. 正答率（トレーニング） = 0.9624833333333334
#                 : 1170. 正答率（テスト） = 0.9578
# Generation: 1180. 正答率（トレーニング） = 0.95755
#                 : 1180. 正答率（テスト） = 0.949
# Generation: 1190. 正答率（トレーニング） = 0.9616666666666667
#                 : 1190. 正答率（テスト） = 0.9541
# Generation: 1200. 正答率（トレーニング） = 0.9640166666666666
#                 : 1200. 正答率（テスト） = 0.9564
# Generation: 1210. 正答率（トレーニング） = 0.9607833333333333
#                 : 1210. 正答率（テスト） = 0.9534
# Generation: 1220. 正答率（トレーニング） = 0.9614666666666667
#                 : 1220. 正答率（テスト） = 0.9554
# Generation: 1230. 正答率（トレーニング） = 0.9563
#                 : 1230. 正答率（テスト） = 0.9493
# Generation: 1240. 正答率（トレーニング） = 0.9635
#                 : 1240. 正答率（テスト） = 0.9581
# Generation: 1250. 正答率（トレーニング） = 0.9640666666666666
#                 : 1250. 正答率（テスト） = 0.9581
# Generation: 1260. 正答率（トレーニング） = 0.96465
#                 : 1260. 正答率（テスト） = 0.9585
# Generation: 1270. 正答率（トレーニング） = 0.9585833333333333
#                 : 1270. 正答率（テスト） = 0.9535
# Generation: 1280. 正答率（トレーニング） = 0.9638333333333333
#                 : 1280. 正答率（テスト） = 0.9565
# Generation: 1290. 正答率（トレーニング） = 0.9598333333333333
#                 : 1290. 正答率（テスト） = 0.953
# Generation: 1300. 正答率（トレーニング） = 0.95435
#                 : 1300. 正答率（テスト） = 0.9496
# Generation: 1310. 正答率（トレーニング） = 0.9636666666666667
#                 : 1310. 正答率（テスト） = 0.9559
# Generation: 1320. 正答率（トレーニング） = 0.95965
#                 : 1320. 正答率（テスト） = 0.9547
# Generation: 1330. 正答率（トレーニング） = 0.9578166666666666
#                 : 1330. 正答率（テスト） = 0.9529
# Generation: 1340. 正答率（トレーニング） = 0.96525
#                 : 1340. 正答率（テスト） = 0.9588
# Generation: 1350. 正答率（トレーニング） = 0.9530833333333333
#                 : 1350. 正答率（テスト） = 0.9446
# Generation: 1360. 正答率（トレーニング） = 0.9635833333333333
#                 : 1360. 正答率（テスト） = 0.9559
# Generation: 1370. 正答率（トレーニング） = 0.9623833333333334
#                 : 1370. 正答率（テスト） = 0.9548
# Generation: 1380. 正答率（トレーニング） = 0.9592833333333334
#                 : 1380. 正答率（テスト） = 0.9508
# Generation: 1390. 正答率（トレーニング） = 0.9583
#                 : 1390. 正答率（テスト） = 0.9504
# Generation: 1400. 正答率（トレーニング） = 0.9611833333333333
#                 : 1400. 正答率（テスト） = 0.9544
# Generation: 1410. 正答率（トレーニング） = 0.9618
#                 : 1410. 正答率（テスト） = 0.9555
# Generation: 1420. 正答率（トレーニング） = 0.9644666666666667
#                 : 1420. 正答率（テスト） = 0.9556
# Generation: 1430. 正答率（トレーニング） = 0.9648166666666667
#                 : 1430. 正答率（テスト） = 0.957
# Generation: 1440. 正答率（トレーニング） = 0.9612166666666667
#                 : 1440. 正答率（テスト） = 0.9556
# Generation: 1450. 正答率（トレーニング） = 0.9632666666666667
#                 : 1450. 正答率（テスト） = 0.9567
# Generation: 1460. 正答率（トレーニング） = 0.9636833333333333
#                 : 1460. 正答率（テスト） = 0.9557
# Generation: 1470. 正答率（トレーニング） = 0.9652166666666666
#                 : 1470. 正答率（テスト） = 0.9578
# Generation: 1480. 正答率（トレーニング） = 0.9639666666666666
#                 : 1480. 正答率（テスト） = 0.9575
# Generation: 1490. 正答率（トレーニング） = 0.9608666666666666
#                 : 1490. 正答率（テスト） = 0.9524
# Generation: 1500. 正答率（トレーニング） = 0.9680833333333333
#                 : 1500. 正答率（テスト） = 0.9598
# Generation: 1510. 正答率（トレーニング） = 0.9623833333333334
#                 : 1510. 正答率（テスト） = 0.9553
# Generation: 1520. 正答率（トレーニング） = 0.9647333333333333
#                 : 1520. 正答率（テスト） = 0.9569
# Generation: 1530. 正答率（トレーニング） = 0.9668
#                 : 1530. 正答率（テスト） = 0.957
# Generation: 1540. 正答率（トレーニング） = 0.96855
#                 : 1540. 正答率（テスト） = 0.9604
# Generation: 1550. 正答率（トレーニング） = 0.9633166666666667
#                 : 1550. 正答率（テスト） = 0.9525
# Generation: 1560. 正答率（トレーニング） = 0.96815
#                 : 1560. 正答率（テスト） = 0.9595
# Generation: 1570. 正答率（トレーニング） = 0.9687
#                 : 1570. 正答率（テスト） = 0.9585
# Generation: 1580. 正答率（トレーニング） = 0.9592166666666667
#                 : 1580. 正答率（テスト） = 0.9503
# Generation: 1590. 正答率（トレーニング） = 0.9649
#                 : 1590. 正答率（テスト） = 0.9559
# Generation: 1600. 正答率（トレーニング） = 0.9651666666666666
#                 : 1600. 正答率（テスト） = 0.9562
# Generation: 1610. 正答率（トレーニング） = 0.9646666666666667
#                 : 1610. 正答率（テスト） = 0.956
# Generation: 1620. 正答率（トレーニング） = 0.9690833333333333
#                 : 1620. 正答率（テスト） = 0.9613
# Generation: 1630. 正答率（トレーニング） = 0.9674166666666667
#                 : 1630. 正答率（テスト） = 0.9586
# Generation: 1640. 正答率（トレーニング） = 0.9542
#                 : 1640. 正答率（テスト） = 0.9444
# Generation: 1650. 正答率（トレーニング） = 0.9653333333333334
#                 : 1650. 正答率（テスト） = 0.9542
# Generation: 1660. 正答率（トレーニング） = 0.9667166666666667
#                 : 1660. 正答率（テスト） = 0.958
# Generation: 1670. 正答率（トレーニング） = 0.9667833333333333
#                 : 1670. 正答率（テスト） = 0.9582
# Generation: 1680. 正答率（トレーニング） = 0.9664333333333334
#                 : 1680. 正答率（テスト） = 0.9589
# Generation: 1690. 正答率（トレーニング） = 0.9658166666666667
#                 : 1690. 正答率（テスト） = 0.9596
# Generation: 1700. 正答率（トレーニング） = 0.9645333333333334
#                 : 1700. 正答率（テスト） = 0.9574
# Generation: 1710. 正答率（トレーニング） = 0.9678
#                 : 1710. 正答率（テスト） = 0.9571
# Generation: 1720. 正答率（トレーニング） = 0.9661833333333333
#                 : 1720. 正答率（テスト） = 0.9564
# Generation: 1730. 正答率（トレーニング） = 0.9699
#                 : 1730. 正答率（テスト） = 0.96
# Generation: 1740. 正答率（トレーニング） = 0.9670833333333333
#                 : 1740. 正答率（テスト） = 0.9562
# Generation: 1750. 正答率（トレーニング） = 0.9626333333333333
#                 : 1750. 正答率（テスト） = 0.9528
# Generation: 1760. 正答率（トレーニング） = 0.95825
#                 : 1760. 正答率（テスト） = 0.952
# Generation: 1770. 正答率（トレーニング） = 0.9649833333333333
#                 : 1770. 正答率（テスト） = 0.9562
# Generation: 1780. 正答率（トレーニング） = 0.9675166666666667
#                 : 1780. 正答率（テスト） = 0.9597
# Generation: 1790. 正答率（トレーニング） = 0.9662333333333334
#                 : 1790. 正答率（テスト） = 0.9589
# Generation: 1800. 正答率（トレーニング） = 0.9685333333333334
#                 : 1800. 正答率（テスト） = 0.963
# Generation: 1810. 正答率（トレーニング） = 0.9603666666666667
#                 : 1810. 正答率（テスト） = 0.9524
# Generation: 1820. 正答率（トレーニング） = 0.9642666666666667
#                 : 1820. 正答率（テスト） = 0.9565
# Generation: 1830. 正答率（トレーニング） = 0.9683333333333334
#                 : 1830. 正答率（テスト） = 0.9616
# Generation: 1840. 正答率（トレーニング） = 0.9679166666666666
#                 : 1840. 正答率（テスト） = 0.9576
# Generation: 1850. 正答率（トレーニング） = 0.9677666666666667
#                 : 1850. 正答率（テスト） = 0.9581
# Generation: 1860. 正答率（トレーニング） = 0.9708166666666667
#                 : 1860. 正答率（テスト） = 0.9624
# Generation: 1870. 正答率（トレーニング） = 0.96825
#                 : 1870. 正答率（テスト） = 0.9575
# Generation: 1880. 正答率（トレーニング） = 0.96675
#                 : 1880. 正答率（テスト） = 0.9598
# Generation: 1890. 正答率（トレーニング） = 0.9703833333333334
#                 : 1890. 正答率（テスト） = 0.9628
# Generation: 1900. 正答率（トレーニング） = 0.9661166666666666
#                 : 1900. 正答率（テスト） = 0.9573
# Generation: 1910. 正答率（トレーニング） = 0.96615
#                 : 1910. 正答率（テスト） = 0.9545
# Generation: 1920. 正答率（トレーニング） = 0.9669166666666666
#                 : 1920. 正答率（テスト） = 0.9554
# Generation: 1930. 正答率（トレーニング） = 0.9644666666666667
#                 : 1930. 正答率（テスト） = 0.9564
# Generation: 1940. 正答率（トレーニング） = 0.9717333333333333
#                 : 1940. 正答率（テスト） = 0.9626
# Generation: 1950. 正答率（トレーニング） = 0.9669666666666666
#                 : 1950. 正答率（テスト） = 0.9588
# Generation: 1960. 正答率（トレーニング） = 0.9713333333333334
#                 : 1960. 正答率（テスト） = 0.9626
# Generation: 1970. 正答率（トレーニング） = 0.9670666666666666
#                 : 1970. 正答率（テスト） = 0.9581
# Generation: 1980. 正答率（トレーニング） = 0.96735
#                 : 1980. 正答率（テスト） = 0.961
# Generation: 1990. 正答率（トレーニング） = 0.96755
#                 : 1990. 正答率（テスト） = 0.9596
# Generation: 2000. 正答率（トレーニング） = 0.9692166666666666
#                 : 2000. 正答率（テスト） = 0.9593

# %%
Tester9.plot_results()
plt.show()

# %% [markdown]
# 以下、 sigmoid & Xavierを試す。こちらも有効に機能している様子が観察できる。

# %%
Tester13 = OptimizerTest(activation = "sigmoid", weight_init_std = "Xavier" , x_train = x_train, d_train = d_train, x_test = x_test, d_test = d_test, OptimizerType = "Adam")
Tester13.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.4999
#                 : 10. 正答率（テスト） = 0.4895
# Generation: 20. 正答率（トレーニング） = 0.5571166666666667
#                 : 20. 正答率（テスト） = 0.5615
# Generation: 30. 正答率（トレーニング） = 0.6936166666666667
#                 : 30. 正答率（テスト） = 0.6956
# Generation: 40. 正答率（トレーニング） = 0.7816833333333333
#                 : 40. 正答率（テスト） = 0.7896
# Generation: 50. 正答率（トレーニング） = 0.82955
#                 : 50. 正答率（テスト） = 0.8361
# Generation: 60. 正答率（トレーニング） = 0.8027
#                 : 60. 正答率（テスト） = 0.8074
# Generation: 70. 正答率（トレーニング） = 0.8561333333333333
#                 : 70. 正答率（テスト） = 0.864
# Generation: 80. 正答率（トレーニング） = 0.8791166666666667
#                 : 80. 正答率（テスト） = 0.8803
# Generation: 90. 正答率（トレーニング） = 0.88095
#                 : 90. 正答率（テスト） = 0.8827
# Generation: 100. 正答率（トレーニング） = 0.8865333333333333
#                 : 100. 正答率（テスト） = 0.8894
# Generation: 110. 正答率（トレーニング） = 0.8906
#                 : 110. 正答率（テスト） = 0.8962
# Generation: 120. 正答率（トレーニング） = 0.8949166666666667
#                 : 120. 正答率（テスト） = 0.8961
# Generation: 130. 正答率（トレーニング） = 0.8935166666666666
#                 : 130. 正答率（テスト） = 0.8989
# Generation: 140. 正答率（トレーニング） = 0.8970166666666667
#                 : 140. 正答率（テスト） = 0.8982
# Generation: 150. 正答率（トレーニング） = 0.8997666666666667
#                 : 150. 正答率（テスト） = 0.9055
# Generation: 160. 正答率（トレーニング） = 0.9051833333333333
#                 : 160. 正答率（テスト） = 0.9056
# Generation: 170. 正答率（トレーニング） = 0.9096333333333333
#                 : 170. 正答率（テスト） = 0.9106
# Generation: 180. 正答率（トレーニング） = 0.9120833333333334
#                 : 180. 正答率（テスト） = 0.9124
# Generation: 190. 正答率（トレーニング） = 0.9102333333333333
#                 : 190. 正答率（テスト） = 0.9098
# Generation: 200. 正答率（トレーニング） = 0.9132333333333333
#                 : 200. 正答率（テスト） = 0.911
# Generation: 210. 正答率（トレーニング） = 0.9129
#                 : 210. 正答率（テスト） = 0.9111
# Generation: 220. 正答率（トレーニング） = 0.9156
#                 : 220. 正答率（テスト） = 0.9129
# Generation: 230. 正答率（トレーニング） = 0.9193166666666667
#                 : 230. 正答率（テスト） = 0.9195
# Generation: 240. 正答率（トレーニング） = 0.9181
#                 : 240. 正答率（テスト） = 0.9181
# Generation: 250. 正答率（トレーニング） = 0.9243
#                 : 250. 正答率（テスト） = 0.9222
# Generation: 260. 正答率（トレーニング） = 0.9243333333333333
#                 : 260. 正答率（テスト） = 0.9249
# Generation: 270. 正答率（トレーニング） = 0.9260833333333334
#                 : 270. 正答率（テスト） = 0.9244
# Generation: 280. 正答率（トレーニング） = 0.92705
#                 : 280. 正答率（テスト） = 0.9252
# Generation: 290. 正答率（トレーニング） = 0.92775
#                 : 290. 正答率（テスト） = 0.9243
# Generation: 300. 正答率（トレーニング） = 0.9210833333333334
#                 : 300. 正答率（テスト） = 0.9175
# Generation: 310. 正答率（トレーニング） = 0.9285
#                 : 310. 正答率（テスト） = 0.9269
# Generation: 320. 正答率（トレーニング） = 0.9276666666666666
#                 : 320. 正答率（テスト） = 0.9253
# Generation: 330. 正答率（トレーニング） = 0.9272666666666667
#                 : 330. 正答率（テスト） = 0.9278
# Generation: 340. 正答率（トレーニング） = 0.9284666666666667
#                 : 340. 正答率（テスト） = 0.9259
# Generation: 350. 正答率（トレーニング） = 0.92805
#                 : 350. 正答率（テスト） = 0.9253
# Generation: 360. 正答率（トレーニング） = 0.9286666666666666
#                 : 360. 正答率（テスト） = 0.9252
# Generation: 370. 正答率（トレーニング） = 0.9305666666666667
#                 : 370. 正答率（テスト） = 0.9265
# Generation: 380. 正答率（トレーニング） = 0.9306666666666666
#                 : 380. 正答率（テスト） = 0.9306
# Generation: 390. 正答率（トレーニング） = 0.9246333333333333
#                 : 390. 正答率（テスト） = 0.925
# Generation: 400. 正答率（トレーニング） = 0.9362166666666667
#                 : 400. 正答率（テスト） = 0.9341
# Generation: 410. 正答率（トレーニング） = 0.9350666666666667
#                 : 410. 正答率（テスト） = 0.9335
# Generation: 420. 正答率（トレーニング） = 0.9360166666666667
#                 : 420. 正答率（テスト） = 0.9314
# Generation: 430. 正答率（トレーニング） = 0.93635
#                 : 430. 正答率（テスト） = 0.9344
# Generation: 440. 正答率（トレーニング） = 0.9401
#                 : 440. 正答率（テスト） = 0.937
# Generation: 450. 正答率（トレーニング） = 0.9390833333333334
#                 : 450. 正答率（テスト） = 0.9348
# Generation: 460. 正答率（トレーニング） = 0.9375
#                 : 460. 正答率（テスト） = 0.9363
# Generation: 470. 正答率（トレーニング） = 0.9381166666666667
#                 : 470. 正答率（テスト） = 0.9368
# Generation: 480. 正答率（トレーニング） = 0.9397833333333333
#                 : 480. 正答率（テスト） = 0.9383
# Generation: 490. 正答率（トレーニング） = 0.9408833333333333
#                 : 490. 正答率（テスト） = 0.9374
# Generation: 500. 正答率（トレーニング） = 0.9411333333333334
#                 : 500. 正答率（テスト） = 0.9378
# Generation: 510. 正答率（トレーニング） = 0.9367833333333333
#                 : 510. 正答率（テスト） = 0.9335
# Generation: 520. 正答率（トレーニング） = 0.9418666666666666
#                 : 520. 正答率（テスト） = 0.9368
# Generation: 530. 正答率（トレーニング） = 0.9442166666666667
#                 : 530. 正答率（テスト） = 0.9408
# Generation: 540. 正答率（トレーニング） = 0.93735
#                 : 540. 正答率（テスト） = 0.9372
# Generation: 550. 正答率（トレーニング） = 0.9467333333333333
#                 : 550. 正答率（テスト） = 0.9439
# Generation: 560. 正答率（トレーニング） = 0.9438833333333333
#                 : 560. 正答率（テスト） = 0.9402
# Generation: 570. 正答率（トレーニング） = 0.9428
#                 : 570. 正答率（テスト） = 0.9399
# Generation: 580. 正答率（トレーニング） = 0.9448333333333333
#                 : 580. 正答率（テスト） = 0.9432
# Generation: 590. 正答率（トレーニング） = 0.9409333333333333
#                 : 590. 正答率（テスト） = 0.9358
# Generation: 600. 正答率（トレーニング） = 0.9459666666666666
#                 : 600. 正答率（テスト） = 0.9411
# Generation: 610. 正答率（トレーニング） = 0.9430333333333333
#                 : 610. 正答率（テスト） = 0.939
# Generation: 620. 正答率（トレーニング） = 0.9444333333333333
#                 : 620. 正答率（テスト） = 0.9412
# Generation: 630. 正答率（トレーニング） = 0.9468
#                 : 630. 正答率（テスト） = 0.9416
# Generation: 640. 正答率（トレーニング） = 0.9482666666666667
#                 : 640. 正答率（テスト） = 0.944
# Generation: 650. 正答率（トレーニング） = 0.9456333333333333
#                 : 650. 正答率（テスト） = 0.9425
# Generation: 660. 正答率（トレーニング） = 0.94555
#                 : 660. 正答率（テスト） = 0.9412
# Generation: 670. 正答率（トレーニング） = 0.9429666666666666
#                 : 670. 正答率（テスト） = 0.9407
# Generation: 680. 正答率（トレーニング） = 0.94845
#                 : 680. 正答率（テスト） = 0.9438
# Generation: 690. 正答率（トレーニング） = 0.9507
#                 : 690. 正答率（テスト） = 0.9462
# Generation: 700. 正答率（トレーニング） = 0.9515
#                 : 700. 正答率（テスト） = 0.9471
# Generation: 710. 正答率（トレーニング） = 0.9491666666666667
#                 : 710. 正答率（テスト） = 0.944
# Generation: 720. 正答率（トレーニング） = 0.9532333333333334
#                 : 720. 正答率（テスト） = 0.9482
# Generation: 730. 正答率（トレーニング） = 0.9491166666666667
#                 : 730. 正答率（テスト） = 0.9439
# Generation: 740. 正答率（トレーニング） = 0.9509166666666666
#                 : 740. 正答率（テスト） = 0.9434
# Generation: 750. 正答率（トレーニング） = 0.9505166666666667
#                 : 750. 正答率（テスト） = 0.9455
# Generation: 760. 正答率（トレーニング） = 0.9525
#                 : 760. 正答率（テスト） = 0.9453
# Generation: 770. 正答率（トレーニング） = 0.9519166666666666
#                 : 770. 正答率（テスト） = 0.9463
# Generation: 780. 正答率（トレーニング） = 0.9465
#                 : 780. 正答率（テスト） = 0.9414
# Generation: 790. 正答率（トレーニング） = 0.9502833333333334
#                 : 790. 正答率（テスト） = 0.9449
# Generation: 800. 正答率（トレーニング） = 0.9526833333333333
#                 : 800. 正答率（テスト） = 0.9481
# Generation: 810. 正答率（トレーニング） = 0.9433666666666667
#                 : 810. 正答率（テスト） = 0.9377
# Generation: 820. 正答率（トレーニング） = 0.9541166666666666
#                 : 820. 正答率（テスト） = 0.9476
# Generation: 830. 正答率（トレーニング） = 0.9556666666666667
#                 : 830. 正答率（テスト） = 0.9486
# Generation: 840. 正答率（トレーニング） = 0.9546333333333333
#                 : 840. 正答率（テスト） = 0.9477
# Generation: 850. 正答率（トレーニング） = 0.9573666666666667
#                 : 850. 正答率（テスト） = 0.9515
# Generation: 860. 正答率（トレーニング） = 0.9552
#                 : 860. 正答率（テスト） = 0.9503
# Generation: 870. 正答率（トレーニング） = 0.9545
#                 : 870. 正答率（テスト） = 0.948
# Generation: 880. 正答率（トレーニング） = 0.95465
#                 : 880. 正答率（テスト） = 0.9494
# Generation: 890. 正答率（トレーニング） = 0.9524666666666667
#                 : 890. 正答率（テスト） = 0.9506
# Generation: 900. 正答率（トレーニング） = 0.9549333333333333
#                 : 900. 正答率（テスト） = 0.9497
# Generation: 910. 正答率（トレーニング） = 0.95505
#                 : 910. 正答率（テスト） = 0.9491
# Generation: 920. 正答率（トレーニング） = 0.9574333333333334
#                 : 920. 正答率（テスト） = 0.9526
# Generation: 930. 正答率（トレーニング） = 0.9587666666666667
#                 : 930. 正答率（テスト） = 0.9542
# Generation: 940. 正答率（トレーニング） = 0.9565666666666667
#                 : 940. 正答率（テスト） = 0.948
# Generation: 950. 正答率（トレーニング） = 0.9558666666666666
#                 : 950. 正答率（テスト） = 0.9473
# Generation: 960. 正答率（トレーニング） = 0.9521833333333334
#                 : 960. 正答率（テスト） = 0.9477
# Generation: 970. 正答率（トレーニング） = 0.95695
#                 : 970. 正答率（テスト） = 0.9507
# Generation: 980. 正答率（トレーニング） = 0.9551333333333333
#                 : 980. 正答率（テスト） = 0.9499
# Generation: 990. 正答率（トレーニング） = 0.9585
#                 : 990. 正答率（テスト） = 0.952
# Generation: 1000. 正答率（トレーニング） = 0.956
#                 : 1000. 正答率（テスト） = 0.9511
# Generation: 1010. 正答率（トレーニング） = 0.9563333333333334
#                 : 1010. 正答率（テスト） = 0.9501
# Generation: 1020. 正答率（トレーニング） = 0.9574333333333334
#                 : 1020. 正答率（テスト） = 0.9527
# Generation: 1030. 正答率（トレーニング） = 0.9592333333333334
#                 : 1030. 正答率（テスト） = 0.9512
# Generation: 1040. 正答率（トレーニング） = 0.9611166666666666
#                 : 1040. 正答率（テスト） = 0.9539
# Generation: 1050. 正答率（トレーニング） = 0.9589333333333333
#                 : 1050. 正答率（テスト） = 0.9533
# Generation: 1060. 正答率（トレーニング） = 0.9588333333333333
#                 : 1060. 正答率（テスト） = 0.9517
# Generation: 1070. 正答率（トレーニング） = 0.9590166666666666
#                 : 1070. 正答率（テスト） = 0.9524
# Generation: 1080. 正答率（トレーニング） = 0.9611166666666666
#                 : 1080. 正答率（テスト） = 0.9524
# Generation: 1090. 正答率（トレーニング） = 0.9543333333333334
#                 : 1090. 正答率（テスト） = 0.9477
# Generation: 1100. 正答率（トレーニング） = 0.9602666666666667
#                 : 1100. 正答率（テスト） = 0.9535
# Generation: 1110. 正答率（トレーニング） = 0.9586666666666667
#                 : 1110. 正答率（テスト） = 0.9523
# Generation: 1120. 正答率（トレーニング） = 0.95605
#                 : 1120. 正答率（テスト） = 0.9494
# Generation: 1130. 正答率（トレーニング） = 0.9570333333333333
#                 : 1130. 正答率（テスト） = 0.9512
# Generation: 1140. 正答率（トレーニング） = 0.9593
#                 : 1140. 正答率（テスト） = 0.9535
# Generation: 1150. 正答率（トレーニング） = 0.96175
#                 : 1150. 正答率（テスト） = 0.954
# Generation: 1160. 正答率（トレーニング） = 0.9597166666666667
#                 : 1160. 正答率（テスト） = 0.9534
# Generation: 1170. 正答率（トレーニング） = 0.96105
#                 : 1170. 正答率（テスト） = 0.9545
# Generation: 1180. 正答率（トレーニング） = 0.9620166666666666
#                 : 1180. 正答率（テスト） = 0.956
# Generation: 1190. 正答率（トレーニング） = 0.9602833333333334
#                 : 1190. 正答率（テスト） = 0.9523
# Generation: 1200. 正答率（トレーニング） = 0.9611666666666666
#                 : 1200. 正答率（テスト） = 0.9548
# Generation: 1210. 正答率（トレーニング） = 0.96235
#                 : 1210. 正答率（テスト） = 0.9572
# Generation: 1220. 正答率（トレーニング） = 0.9605833333333333
#                 : 1220. 正答率（テスト） = 0.9549
# Generation: 1230. 正答率（トレーニング） = 0.9552166666666667
#                 : 1230. 正答率（テスト） = 0.9487
# Generation: 1240. 正答率（トレーニング） = 0.9586833333333333
#                 : 1240. 正答率（テスト） = 0.9513
# Generation: 1250. 正答率（トレーニング） = 0.9573833333333334
#                 : 1250. 正答率（テスト） = 0.9506
# Generation: 1260. 正答率（トレーニング） = 0.9584333333333334
#                 : 1260. 正答率（テスト） = 0.9519
# Generation: 1270. 正答率（トレーニング） = 0.9594833333333334
#                 : 1270. 正答率（テスト） = 0.9508
# Generation: 1280. 正答率（トレーニング） = 0.96255
#                 : 1280. 正答率（テスト） = 0.9563
# Generation: 1290. 正答率（トレーニング） = 0.9627166666666667
#                 : 1290. 正答率（テスト） = 0.9533
# Generation: 1300. 正答率（トレーニング） = 0.9621833333333333
#                 : 1300. 正答率（テスト） = 0.9544
# Generation: 1310. 正答率（トレーニング） = 0.96455
#                 : 1310. 正答率（テスト） = 0.9569
# Generation: 1320. 正答率（トレーニング） = 0.9637
#                 : 1320. 正答率（テスト） = 0.9558
# Generation: 1330. 正答率（トレーニング） = 0.96105
#                 : 1330. 正答率（テスト） = 0.9539
# Generation: 1340. 正答率（トレーニング） = 0.9623166666666667
#                 : 1340. 正答率（テスト） = 0.9562
# Generation: 1350. 正答率（トレーニング） = 0.9597833333333333
#                 : 1350. 正答率（テスト） = 0.9531
# Generation: 1360. 正答率（トレーニング） = 0.9606
#                 : 1360. 正答率（テスト） = 0.9505
# Generation: 1370. 正答率（トレーニング） = 0.964
#                 : 1370. 正答率（テスト） = 0.9542
# Generation: 1380. 正答率（トレーニング） = 0.9623
#                 : 1380. 正答率（テスト） = 0.9533
# Generation: 1390. 正答率（トレーニング） = 0.96325
#                 : 1390. 正答率（テスト） = 0.9551
# Generation: 1400. 正答率（トレーニング） = 0.9613333333333334
#                 : 1400. 正答率（テスト） = 0.9497
# Generation: 1410. 正答率（トレーニング） = 0.9635833333333333
#                 : 1410. 正答率（テスト） = 0.9549
# Generation: 1420. 正答率（トレーニング） = 0.9641333333333333
#                 : 1420. 正答率（テスト） = 0.9563
# Generation: 1430. 正答率（トレーニング） = 0.9630833333333333
#                 : 1430. 正答率（テスト） = 0.9543
# Generation: 1440. 正答率（トレーニング） = 0.9611666666666666
#                 : 1440. 正答率（テスト） = 0.955
# Generation: 1450. 正答率（トレーニング） = 0.9611333333333333
#                 : 1450. 正答率（テスト） = 0.9548
# Generation: 1460. 正答率（トレーニング） = 0.9645666666666667
#                 : 1460. 正答率（テスト） = 0.9565
# Generation: 1470. 正答率（トレーニング） = 0.9636833333333333
#                 : 1470. 正答率（テスト） = 0.956
# Generation: 1480. 正答率（トレーニング） = 0.9611833333333333
#                 : 1480. 正答率（テスト） = 0.9531
# Generation: 1490. 正答率（トレーニング） = 0.9657
#                 : 1490. 正答率（テスト） = 0.9565
# Generation: 1500. 正答率（トレーニング） = 0.9645333333333334
#                 : 1500. 正答率（テスト） = 0.9553
# Generation: 1510. 正答率（トレーニング） = 0.9637166666666667
#                 : 1510. 正答率（テスト） = 0.9529
# Generation: 1520. 正答率（トレーニング） = 0.9647333333333333
#                 : 1520. 正答率（テスト） = 0.9544
# Generation: 1530. 正答率（トレーニング） = 0.962
#                 : 1530. 正答率（テスト） = 0.9538
# Generation: 1540. 正答率（トレーニング） = 0.96365
#                 : 1540. 正答率（テスト） = 0.9549
# Generation: 1550. 正答率（トレーニング） = 0.9631666666666666
#                 : 1550. 正答率（テスト） = 0.954
# Generation: 1560. 正答率（トレーニング） = 0.9650333333333333
#                 : 1560. 正答率（テスト） = 0.9543
# Generation: 1570. 正答率（トレーニング） = 0.9670166666666666
#                 : 1570. 正答率（テスト） = 0.9565
# Generation: 1580. 正答率（トレーニング） = 0.9670166666666666
#                 : 1580. 正答率（テスト） = 0.9569
# Generation: 1590. 正答率（トレーニング） = 0.9630333333333333
#                 : 1590. 正答率（テスト） = 0.9542
# Generation: 1600. 正答率（トレーニング） = 0.96675
#                 : 1600. 正答率（テスト） = 0.9565
# Generation: 1610. 正答率（トレーニング） = 0.9648166666666667
#                 : 1610. 正答率（テスト） = 0.954
# Generation: 1620. 正答率（トレーニング） = 0.96575
#                 : 1620. 正答率（テスト） = 0.9562
# Generation: 1630. 正答率（トレーニング） = 0.9620833333333333
#                 : 1630. 正答率（テスト） = 0.9526
# Generation: 1640. 正答率（トレーニング） = 0.9654833333333334
#                 : 1640. 正答率（テスト） = 0.9568
# Generation: 1650. 正答率（トレーニング） = 0.9626166666666667
#                 : 1650. 正答率（テスト） = 0.9547
# Generation: 1660. 正答率（トレーニング） = 0.9625666666666667
#                 : 1660. 正答率（テスト） = 0.9541
# Generation: 1670. 正答率（トレーニング） = 0.96465
#                 : 1670. 正答率（テスト） = 0.9546
# Generation: 1680. 正答率（トレーニング） = 0.9639333333333333
#                 : 1680. 正答率（テスト） = 0.9543
# Generation: 1690. 正答率（トレーニング） = 0.9647333333333333
#                 : 1690. 正答率（テスト） = 0.955
# Generation: 1700. 正答率（トレーニング） = 0.9652666666666667
#                 : 1700. 正答率（テスト） = 0.9542
# Generation: 1710. 正答率（トレーニング） = 0.9638833333333333
#                 : 1710. 正答率（テスト） = 0.9531
# Generation: 1720. 正答率（トレーニング） = 0.96755
#                 : 1720. 正答率（テスト） = 0.9575
# Generation: 1730. 正答率（トレーニング） = 0.9675
#                 : 1730. 正答率（テスト） = 0.9561
# Generation: 1740. 正答率（トレーニング） = 0.96685
#                 : 1740. 正答率（テスト） = 0.9572
# Generation: 1750. 正答率（トレーニング） = 0.9671833333333333
#                 : 1750. 正答率（テスト） = 0.9561
# Generation: 1760. 正答率（トレーニング） = 0.9672
#                 : 1760. 正答率（テスト） = 0.9559
# Generation: 1770. 正答率（トレーニング） = 0.96755
#                 : 1770. 正答率（テスト） = 0.9595
# Generation: 1780. 正答率（トレーニング） = 0.967
#                 : 1780. 正答率（テスト） = 0.9573
# Generation: 1790. 正答率（トレーニング） = 0.96675
#                 : 1790. 正答率（テスト） = 0.9591
# Generation: 1800. 正答率（トレーニング） = 0.9662333333333334
#                 : 1800. 正答率（テスト） = 0.9584
# Generation: 1810. 正答率（トレーニング） = 0.96875
#                 : 1810. 正答率（テスト） = 0.9588
# Generation: 1820. 正答率（トレーニング） = 0.9664333333333334
#                 : 1820. 正答率（テスト） = 0.9546
# Generation: 1830. 正答率（トレーニング） = 0.9654333333333334
#                 : 1830. 正答率（テスト） = 0.9565
# Generation: 1840. 正答率（トレーニング） = 0.9635833333333333
#                 : 1840. 正答率（テスト） = 0.9574
# Generation: 1850. 正答率（トレーニング） = 0.9656666666666667
#                 : 1850. 正答率（テスト） = 0.9577
# Generation: 1860. 正答率（トレーニング） = 0.96285
#                 : 1860. 正答率（テスト） = 0.9528
# Generation: 1870. 正答率（トレーニング） = 0.9666833333333333
#                 : 1870. 正答率（テスト） = 0.9593
# Generation: 1880. 正答率（トレーニング） = 0.96775
#                 : 1880. 正答率（テスト） = 0.9597
# Generation: 1890. 正答率（トレーニング） = 0.9683833333333334
#                 : 1890. 正答率（テスト） = 0.958
# Generation: 1900. 正答率（トレーニング） = 0.9694666666666667
#                 : 1900. 正答率（テスト） = 0.9601
# Generation: 1910. 正答率（トレーニング） = 0.9676666666666667
#                 : 1910. 正答率（テスト） = 0.9583
# Generation: 1920. 正答率（トレーニング） = 0.9684166666666667
#                 : 1920. 正答率（テスト） = 0.9588
# Generation: 1930. 正答率（トレーニング） = 0.9695
#                 : 1930. 正答率（テスト） = 0.9604
# Generation: 1940. 正答率（トレーニング） = 0.9679666666666666
#                 : 1940. 正答率（テスト） = 0.9608
# Generation: 1950. 正答率（トレーニング） = 0.9697666666666667
#                 : 1950. 正答率（テスト） = 0.9614
# Generation: 1960. 正答率（トレーニング） = 0.9669166666666666
#                 : 1960. 正答率（テスト） = 0.9563
# Generation: 1970. 正答率（トレーニング） = 0.9675333333333334
#                 : 1970. 正答率（テスト） = 0.9583
# Generation: 1980. 正答率（トレーニング） = 0.9656
#                 : 1980. 正答率（テスト） = 0.9567
# Generation: 1990. 正答率（トレーニング） = 0.9649333333333333
#                 : 1990. 正答率（テスト） = 0.9553
# Generation: 2000. 正答率（トレーニング） = 0.96685
#                 : 2000. 正答率（テスト） = 0.9563

# %%
Tester13.plot_results()
plt.show()

# %% [markdown]
# ## Section3 過学習

# %% [markdown]
# - 過学習とは
# 学習用（訓練用）データでは良い出力が出るが、検証用データでは良い出力が出ない状態になってしまう。
# 特定の訓練サンプルに特化した学習になってしまっている。
# 学習結果をエポック数対誤差でプロットすることで、テスト誤差と訓練誤差の乖離から過学習が進んでいるか判断できる。
# - 過学習の原因
# パラメータ数が多い。パラメータの値が適切でない。ノードが多い。など。ネットワークの自由度が高い（高すぎる）と過学習が起きやすい。
# - 過学習の対策：正則化
# 正則化とは、ネットワークの自由度を制限する。
# 過学習が起きていると、特定のパラメータが極端に大きくなってしまっている。
# つまり、パラメータが極端な値を取れないようにする。
# ⇒誤差に対して、正則化項を加算することで、重みを抑制する。
# 正則化項は
# $$
#     \frac{1}{p}\lambda ||x||_p\\
#     ||x||_p = (|x_1|^p+\cdot\cdot\cdot +|x_n|^p)^{\frac{1}{p}}
# $$
# と書ける。p=1がL1正則化（マンハッタン距離：各パラメータの和）p=2がL2正則化（ユークリッド距離：二乗和の平方根）である。
# L1正則化では、パラメータが0になりやすく、スパース化が進みやすい。
#
# - 過学習の対策：ドロップアウト
# ランダムにノードを削除して学習させること。
# データのバリエーションが生まれてデータ拡張の効果が表れる。

# %% [markdown]
# 以下、過学習になるようにデータ等を調整して、過学習発生をpython上で確認する。

# %%
class Dropout:
    def __init__(self, dropout_ratio = 0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None
    
    def forward(self, x, train_flg = True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)
        
    def backward(self, dout):
        return dout * self.mask

# %%
class MultiLayerNet2:
    '''
    input_size        : 入力層のノード数(例えば、mnistなら、8x8=64)
    hidden_size_list  :隠れ層のノード数のリスト
    output_size       :出力層のノード数
    activation        :活性化関数 ("relu"または"sigmoid")
    weight_init_std   :重みの初期化方法（数値を、あるいは"Xavier","He"）
    use_dropout       :ドロップアウトの有無
    dropout_ratio     :ドロップアウト率
    '''
    def __init__(self, input_size, hidden_size_list, output_size, activation="relu", weight_init_std="relu",
                 use_dropout = False, dropout_ratio = 0.5):
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size_list = hidden_size_list
        self.hidden_layer_num = len(hidden_size_list)
        self.activation = activation
        self.weight_init_std = weight_init_std
        self.params = {}
        self.use_dropout = use_dropout
        self.dropout_ratio = dropout_ratio
        
        # 重みの初期化
        # ここで、self.params["W" + str(idx)]が定義されている。 
        self.__init_weight()
        
        # レイヤの生成,sigmoidまたはreluの選択
        activation_layer = {"sigmoid": Sigmoid,"relu": Relu}
        self.layers = OrderedDict()
        for idx in range(1, self.hidden_layer_num + 1):
            self.layers["Affine" + str(idx)] = Affine(self.params["W" + str(idx)], self.params["b" + str(idx)])
            self.layers["Activation_function" + str(idx)] = activation_layer[self.activation]()
            
            if self.use_dropout:
                self.layers["Dropout" + str(idx)] = Dropout(self.dropout_ratio)
        
        idx = self.hidden_layer_num + 1
        self.layers["Affine" + str(idx)] = Affine(self.params["W" + str(idx)], self.params["b" + str(idx)])
        
        self.last_layer = SoftMaxWithLoss()
        
    def __init_weight(self):
        all_size_list = [self.input_size] + self.hidden_size_list + [self.output_size]
        for idx in range(1, len(all_size_list)):
            scale = self.weight_init_std
            if str(self.weight_init_std).lower() in ("relu", "he"):
                scale = np.sqrt(2.0 / all_size_list[idx - 1])
            elif str(self.weight_init_std).lower() in ("sigmoid", "xavier"):
                scale = np.sqrt(1.0 / all_size_list[idx - 1])
                
            self.params["W" + str(idx)] = scale * np.random.randn(all_size_list[idx - 1], all_size_list[idx])
            self.params["b" + str(idx)] = np.zeros(all_size_list[idx])
    
    def predict(self, x, train_flg = False):
        # 順伝播の計算
        for key, layer in self.layers.items():
            if "Dropout" in key:
                x = layer.forward(x, train_flg)
            else:
                x = layer.forward(x)
        
        return x
    
    def loss(self, x, d, train_flg = False):
        y = self.predict(x, train_flg)
        
        for idx in range(1, self.hidden_layer_num + 2):
            W = self.params["W" + str(idx)]
        
        return self.last_layer.forward(y,d)
    
    def accuracy(self, x, d):
        y = self.predict(x)
        y = np.argmax(y, axis = 1)
        if d.ndim != 1 : d = np.argmax(d, axis = 1)
        
        accuracy = np.sum(y == d) / float(x.shape[0])
        return accuracy
    
    def gradient(self, x, d):
        # forward
        self.loss(x,d, train_flg=True)
        
        # backward
        dout = 1
        dout = self.last_layer.backward(dout)
        
        layerBuf = list(self.layers.values())
        layerBuf.reverse()
        
        for layer in layerBuf:
            dout = layer.backward(dout)
            
        grad = {}
        for idx in range(1, self.hidden_layer_num + 2):
            grad["W" + str(idx)] = self.layers["Affine" + str(idx)].dW
            grad["b" + str(idx)] = self.layers["Affine" + str(idx)].db

        return grad

# %%
class OverfittingTest:
    def __init__(self, activation, weight_init_std, x_train, d_train, x_test, d_test, 
                 OptimizerType = "SDG", momentum = 0.9, decay_rate = 0.99, beta1 = 0.9, beta2 = 0.99, 
                 weight_decay_type = None, weight_decay_lambda = 0.01, dropout = False, dropout_ratio = 0.5, 
                 hidden_size_list=[40,20], iters_num = 2000, batch_size = 100, learning_rate = 0.01):
        """
        OptimizerTypeは、SGD、Momentum、AdaGrad、RMSprop、ADAのいずれかを文字列で受け取る。
        weight_dcay_typeは、L1,L2のいずれかを文字列で受け取る。
        """
        self.activation = activation
        self.weight_init_std = weight_init_std
        self.hidden_size_list = hidden_size_list
        self.hidden_layer_num = len(hidden_size_list)
        self.x_train = x_train
        self.d_train = d_train
        self.x_test = x_test
        self.d_test = d_test
        self.OptimizerType = OptimizerType
        self.learning_rate = learning_rate
        # 各Optimizer固有の値
        self.momentum = momentum
        self.decay_rate = 0.99
        self.beta1 = beta1
        self.beta2 = beta2
        # 過学習防止処理
        self.weight_decay_type = weight_decay_type
        self.weight_decay_lambda = weight_decay_lambda
        self.dropout = dropout
        self.dropout_ratio = dropout_ratio
        
        self.input_size = x_train.shape[1]
        self.output_size = d_train.shape[1]
        self.network = MultiLayerNet2(input_size = self.input_size, 
                                     hidden_size_list = self.hidden_size_list,
                                     output_size = self.output_size,
                                     activation = self.activation, 
                                     weight_init_std = self.weight_init_std,
                                     use_dropout = self.dropout,
                                     dropout_ratio = self.dropout_ratio)

        
        self.iters_num = iters_num
        self.batch_size = batch_size
        self.train_size = self.x_train.shape[0] 
        self.plot_interval = 10
        
    def train(self):
        self.train_loss_list = []
        self.accuracies_train = []
        self.accuracies_test = []
        
        for i in range(self.iters_num):
            batch_mask = np.random.choice(self.train_size, self.batch_size)
            x_batch = self.x_train[batch_mask]
            d_batch = self.d_train[batch_mask]
            
            grad = self.network.gradient(x_batch, d_batch)
            if self.OptimizerType == "Momentum":
                if i == 0:
                    v = {}
            elif self.OptimizerType == "AdaGrad" or self.OptimizerType == "RMSprop":
                if i == 0:
                    h = {}
            elif self.OptimizerType == "Adam":
                if i == 0:
                    m = {}
                    v = {}
                learning_rate_t = self.learning_rate * np.sqrt(1.0 - self.beta2 ** (i + 1)) / (1.0 - self.beta1 ** (i + 1))
            
            weight_decay = 0
            for idx in range(1, self.hidden_layer_num + 1):
                if self.OptimizerType == "SGD":
                    if self.weight_decay_type == "L1":
                        grad["W" + str(idx)] = self.network.layers["Affine" + str(idx)].dW + self.weight_decay_lambda * np.sign(self.network.params["W" + str(idx)])
                        grad["b" + str(idx)] = self.network.layers["Affine" + str(idx)].db
                        self.network.params["W" + str(idx)] -= self.learning_rate * grad["W" + str(idx)]
                        self.network.params["b" + str(idx)] -= self.learning_rate * grad["b" + str(idx)]
                        weight_decay += self.weight_decay_lambda * np.sum(np.abs(self.network.params["W" + str(idx)]))                        
                    elif self.weight_decay_type == "L2":
                        grad["W" + str(idx)] = self.network.layers["Affine" + str(idx)].dW + self.weight_decay_lambda * self.network.params["W" + str(idx)]
                        grad["b" + str(idx)] = self.network.layers["Affine" + str(idx)].db
                        self.network.params["W" + str(idx)] -= self.learning_rate * grad["W" + str(idx)]
                        self.network.params["b" + str(idx)] -= self.learning_rate * grad["b" + str(idx)]
                        weight_decay += 0.5 * self.weight_decay_lambda * np.sqrt(np.sum(self.network.params["W" + str(idx)]**2))
                    else:
                        grad["W" + str(idx)] = self.network.layers["Affine" + str(idx)].dW
                        grad["b" + str(idx)] = self.network.layers["Affine" + str(idx)].db
                        self.network.params["W" + str(idx)] -= self.learning_rate * grad["W" + str(idx)]
                        self.network.params["b" + str(idx)] -= self.learning_rate * grad["b" + str(idx)]
                elif self.OptimizerType == "Momentum":
                    if i == 0:
                        v["W" + str(idx)] = np.zeros_like(self.network.params["W" + str(idx)])
                        v["b" + str(idx)] = np.zeros_like(self.network.params["b" + str(idx)])
                    v["W" + str(idx)] = self.momentum * v["W" + str(idx)] - self.learning_rate * grad["W" + str(idx)]
                    v["b" + str(idx)] = self.momentum * v["b" + str(idx)] - self.learning_rate * grad["b" + str(idx)]
                    self.network.params["W" + str(idx)] += v["W" + str(idx)]
                    self.network.params["b" + str(idx)] += v["b" + str(idx)]
                elif self.OptimizerType == "AdaGrad":
                    if i == 0:
                        h["W" + str(idx)] = np.full_like(self.network.params["W" + str(idx)], 1e-4)
                        h["b" + str(idx)] = np.full_like(self.network.params["b" + str(idx)], 1e-4)
                    else:
                        h["W" + str(idx)] += np.square(grad["W" + str(idx)])
                        h["b" + str(idx)] += np.square(grad["b" + str(idx)])
                    self.network.params["W" + str(idx)] -= self.learning_rate * grad["W" + str(idx)] / (np.sqrt(h["W" + str(idx)]))
                    self.network.params["b" + str(idx)] -= self.learning_rate * grad["b" + str(idx)] / (np.sqrt(h["b" + str(idx)]))
                elif self.OptimizerType == "RMSprop":
                    if i == 0:
                        h["W" + str(idx)] = np.zeros_like(self.network.params["W" + str(idx)])
                        h["b" + str(idx)] = np.zeros_like(self.network.params["b" + str(idx)])
                    h["W" + str(idx)] *= self.decay_rate
                    h["b" + str(idx)] *= self.decay_rate
                    h["W" + str(idx)] += (1 - self.decay_rate) * np.square(grad["W" + str(idx)])
                    h["b" + str(idx)] += (1 - self.decay_rate) * np.square(grad["b" + str(idx)])
                    self.network.params["W" + str(idx)] -= self.learning_rate * grad["W" + str(idx)] / (np.sqrt(h["W" + str(idx)]) + 1e-7)
                    self.network.params["b" + str(idx)] -= self.learning_rate * grad["b" + str(idx)] / (np.sqrt(h["b" + str(idx)]) + 1e-7)
                elif self.OptimizerType == "Adam":
                    if i == 0:
                        m["W" + str(idx)] = np.zeros_like(self.network.params["W" + str(idx)])
                        m["b" + str(idx)] = np.zeros_like(self.network.params["b" + str(idx)])
                        v["W" + str(idx)] = np.zeros_like(self.network.params["W" + str(idx)])
                        v["b" + str(idx)] = np.zeros_like(self.network.params["b" + str(idx)])
                    m["W" + str(idx)] += (1 - self.beta1) * (grad["W" + str(idx)] - m["W" + str(idx)])
                    m["b" + str(idx)] += (1 - self.beta1) * (grad["b" + str(idx)] - m["b" + str(idx)])
                    v["W" + str(idx)] += (1 - self.beta2) * (grad["W" + str(idx)] ** 2 -v["W" + str(idx)])
                    v["b" + str(idx)] += (1 - self.beta2) * (grad["b" + str(idx)] ** 2 -v["b" + str(idx)])
                    self.network.params["W" + str(idx)] -= learning_rate_t * m["W" + str(idx)] / (np.sqrt(v["W" + str(idx)]) + 1e-7)
                    self.network.params["b" + str(idx)] -= learning_rate_t * m["b" + str(idx)] / (np.sqrt(v["b" + str(idx)]) + 1e-7)
                
            
            loss = self.network.loss(x_batch, d_batch) + weight_decay
            self.train_loss_list.append(loss)
            
            if (i + 1) % self.plot_interval == 0:
                accr_test = self.network.accuracy(self.x_test, self.d_test)
                self.accuracies_test.append(accr_test)
                accr_train = self.network.accuracy(self.x_train, self.d_train)
                self.accuracies_train.append(accr_train)
                
                print("Generation: " + str(i+1) + ". 正答率（トレーニング） = " + str(accr_train))
                print("                : " + str(i+1) + ". 正答率（テスト） = " + str(accr_test))
    
    def plot_results(self):
        lists = range(0, self.iters_num, self.plot_interval)
        plt.plot(lists, self.accuracies_train, label = "training set")
        plt.plot(lists, self.accuracies_test, label = "test set")
        plt.legend(loc = "lower right")
        plt.title("accuracy")
        plt.xlabel("count")
        plt.ylabel("accuracy")
        plt.ylim(0, 1.0)

# %%
x_train_overfitting = x_train[:300]
d_train_overfitting = d_train[:300]

# %%
# hidden_size_listを大きくして、表現力を極端に大きくしている。
Tester15 = OverfittingTest(activation = "relu", weight_init_std = "relu" , x_train = x_train_overfitting, d_train = d_train_overfitting, x_test = x_test, d_test = d_test, 
                           OptimizerType = "SGD",
                           hidden_size_list = [100,100,100,100,100,100], iters_num = 1000)
Tester15.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.19
#                 : 10. 正答率（テスト） = 0.1863
# Generation: 20. 正答率（トレーニング） = 0.29333333333333333
#                 : 20. 正答率（テスト） = 0.2317
# Generation: 30. 正答率（トレーニング） = 0.3933333333333333
#                 : 30. 正答率（テスト） = 0.2823
# Generation: 40. 正答率（トレーニング） = 0.42333333333333334
#                 : 40. 正答率（テスト） = 0.3125
# Generation: 50. 正答率（トレーニング） = 0.5
#                 : 50. 正答率（テスト） = 0.3472
# Generation: 60. 正答率（トレーニング） = 0.5133333333333333
#                 : 60. 正答率（テスト） = 0.3714
# Generation: 70. 正答率（トレーニング） = 0.54
#                 : 70. 正答率（テスト） = 0.3962
# Generation: 80. 正答率（トレーニング） = 0.5733333333333334
#                 : 80. 正答率（テスト） = 0.4302
# Generation: 90. 正答率（トレーニング） = 0.61
#                 : 90. 正答率（テスト） = 0.4542
# Generation: 100. 正答率（トレーニング） = 0.6433333333333333
#                 : 100. 正答率（テスト） = 0.4868
# Generation: 110. 正答率（トレーニング） = 0.7033333333333334
#                 : 110. 正答率（テスト） = 0.5223
# Generation: 120. 正答率（トレーニング） = 0.7133333333333334
#                 : 120. 正答率（テスト） = 0.5484
# Generation: 130. 正答率（トレーニング） = 0.7766666666666666
#                 : 130. 正答率（テスト） = 0.592
# Generation: 140. 正答率（トレーニング） = 0.8033333333333333
#                 : 140. 正答率（テスト） = 0.6113
# Generation: 150. 正答率（トレーニング） = 0.8166666666666667
#                 : 150. 正答率（テスト） = 0.6272
# Generation: 160. 正答率（トレーニング） = 0.8433333333333334
#                 : 160. 正答率（テスト） = 0.6473
# Generation: 170. 正答率（トレーニング） = 0.88
#                 : 170. 正答率（テスト） = 0.6665
# Generation: 180. 正答率（トレーニング） = 0.8866666666666667
#                 : 180. 正答率（テスト） = 0.6856
# Generation: 190. 正答率（トレーニング） = 0.8866666666666667
#                 : 190. 正答率（テスト） = 0.6918
# Generation: 200. 正答率（トレーニング） = 0.9166666666666666
#                 : 200. 正答率（テスト） = 0.6993
# Generation: 210. 正答率（トレーニング） = 0.9266666666666666
#                 : 210. 正答率（テスト） = 0.704
# Generation: 220. 正答率（トレーニング） = 0.9433333333333334
#                 : 220. 正答率（テスト） = 0.7169
# Generation: 230. 正答率（トレーニング） = 0.9566666666666667
#                 : 230. 正答率（テスト） = 0.7208
# Generation: 240. 正答率（トレーニング） = 0.96
#                 : 240. 正答率（テスト） = 0.7231
# Generation: 250. 正答率（トレーニング） = 0.9666666666666667
#                 : 250. 正答率（テスト） = 0.7218
# Generation: 260. 正答率（トレーニング） = 0.97
#                 : 260. 正答率（テスト） = 0.7248
# Generation: 270. 正答率（トレーニング） = 0.9833333333333333
#                 : 270. 正答率（テスト） = 0.7312
# Generation: 280. 正答率（トレーニング） = 0.9833333333333333
#                 : 280. 正答率（テスト） = 0.7278
# Generation: 290. 正答率（トレーニング） = 0.9833333333333333
#                 : 290. 正答率（テスト） = 0.7323
# Generation: 300. 正答率（トレーニング） = 0.9866666666666667
#                 : 300. 正答率（テスト） = 0.7345
# Generation: 310. 正答率（トレーニング） = 0.9833333333333333
#                 : 310. 正答率（テスト） = 0.7349
# Generation: 320. 正答率（トレーニング） = 0.99
#                 : 320. 正答率（テスト） = 0.7375
# Generation: 330. 正答率（トレーニング） = 0.99
#                 : 330. 正答率（テスト） = 0.7389
# Generation: 340. 正答率（トレーニング） = 0.99
#                 : 340. 正答率（テスト） = 0.7411
# Generation: 350. 正答率（トレーニング） = 0.99
#                 : 350. 正答率（テスト） = 0.744
# Generation: 360. 正答率（トレーニング） = 0.9933333333333333
#                 : 360. 正答率（テスト） = 0.7448
# Generation: 370. 正答率（トレーニング） = 0.99
#                 : 370. 正答率（テスト） = 0.7407
# Generation: 380. 正答率（トレーニング） = 0.9933333333333333
#                 : 380. 正答率（テスト） = 0.7462
# Generation: 390. 正答率（トレーニング） = 0.9933333333333333
#                 : 390. 正答率（テスト） = 0.7479
# Generation: 400. 正答率（トレーニング） = 0.9933333333333333
#                 : 400. 正答率（テスト） = 0.7491
# Generation: 410. 正答率（トレーニング） = 0.9933333333333333
#                 : 410. 正答率（テスト） = 0.747
# Generation: 420. 正答率（トレーニング） = 0.9933333333333333
#                 : 420. 正答率（テスト） = 0.7466
# Generation: 430. 正答率（トレーニング） = 0.9933333333333333
#                 : 430. 正答率（テスト） = 0.7456
# Generation: 440. 正答率（トレーニング） = 0.9966666666666667
#                 : 440. 正答率（テスト） = 0.7465
# Generation: 450. 正答率（トレーニング） = 0.9966666666666667
#                 : 450. 正答率（テスト） = 0.7455
# Generation: 460. 正答率（トレーニング） = 0.9966666666666667
#                 : 460. 正答率（テスト） = 0.7486
# Generation: 470. 正答率（トレーニング） = 0.9966666666666667
#                 : 470. 正答率（テスト） = 0.7513
# Generation: 480. 正答率（トレーニング） = 0.9966666666666667
#                 : 480. 正答率（テスト） = 0.7508
# Generation: 490. 正答率（トレーニング） = 0.9966666666666667
#                 : 490. 正答率（テスト） = 0.7533
# Generation: 500. 正答率（トレーニング） = 0.9966666666666667
#                 : 500. 正答率（テスト） = 0.7525
# Generation: 510. 正答率（トレーニング） = 0.9966666666666667
#                 : 510. 正答率（テスト） = 0.7515
# Generation: 520. 正答率（トレーニング） = 0.9966666666666667
#                 : 520. 正答率（テスト） = 0.752
# Generation: 530. 正答率（トレーニング） = 0.9966666666666667
#                 : 530. 正答率（テスト） = 0.7534
# Generation: 540. 正答率（トレーニング） = 0.9966666666666667
#                 : 540. 正答率（テスト） = 0.757
# Generation: 550. 正答率（トレーニング） = 1.0
#                 : 550. 正答率（テスト） = 0.7549
# Generation: 560. 正答率（トレーニング） = 1.0
#                 : 560. 正答率（テスト） = 0.7561
# Generation: 570. 正答率（トレーニング） = 1.0
#                 : 570. 正答率（テスト） = 0.7556
# Generation: 580. 正答率（トレーニング） = 1.0
#                 : 580. 正答率（テスト） = 0.7547
# Generation: 590. 正答率（トレーニング） = 1.0
#                 : 590. 正答率（テスト） = 0.7551
# Generation: 600. 正答率（トレーニング） = 1.0
#                 : 600. 正答率（テスト） = 0.7556
# Generation: 610. 正答率（トレーニング） = 1.0
#                 : 610. 正答率（テスト） = 0.7535
# Generation: 620. 正答率（トレーニング） = 1.0
#                 : 620. 正答率（テスト） = 0.7573
# Generation: 630. 正答率（トレーニング） = 1.0
#                 : 630. 正答率（テスト） = 0.7579
# Generation: 640. 正答率（トレーニング） = 1.0
#                 : 640. 正答率（テスト） = 0.7583
# Generation: 650. 正答率（トレーニング） = 1.0
#                 : 650. 正答率（テスト） = 0.7576
# Generation: 660. 正答率（トレーニング） = 1.0
#                 : 660. 正答率（テスト） = 0.7581
# Generation: 670. 正答率（トレーニング） = 1.0
#                 : 670. 正答率（テスト） = 0.7579
# Generation: 680. 正答率（トレーニング） = 1.0
#                 : 680. 正答率（テスト） = 0.7577
# Generation: 690. 正答率（トレーニング） = 1.0
#                 : 690. 正答率（テスト） = 0.758
# Generation: 700. 正答率（トレーニング） = 1.0
#                 : 700. 正答率（テスト） = 0.7589
# Generation: 710. 正答率（トレーニング） = 1.0
#                 : 710. 正答率（テスト） = 0.761
# Generation: 720. 正答率（トレーニング） = 1.0
#                 : 720. 正答率（テスト） = 0.7588
# Generation: 730. 正答率（トレーニング） = 1.0
#                 : 730. 正答率（テスト） = 0.759
# Generation: 740. 正答率（トレーニング） = 1.0
#                 : 740. 正答率（テスト） = 0.7577
# Generation: 750. 正答率（トレーニング） = 1.0
#                 : 750. 正答率（テスト） = 0.7586
# Generation: 760. 正答率（トレーニング） = 1.0
#                 : 760. 正答率（テスト） = 0.7601
# Generation: 770. 正答率（トレーニング） = 1.0
#                 : 770. 正答率（テスト） = 0.7596
# Generation: 780. 正答率（トレーニング） = 1.0
#                 : 780. 正答率（テスト） = 0.7605
# Generation: 790. 正答率（トレーニング） = 1.0
#                 : 790. 正答率（テスト） = 0.7608
# Generation: 800. 正答率（トレーニング） = 1.0
#                 : 800. 正答率（テスト） = 0.7609
# Generation: 810. 正答率（トレーニング） = 1.0
#                 : 810. 正答率（テスト） = 0.7609
# Generation: 820. 正答率（トレーニング） = 1.0
#                 : 820. 正答率（テスト） = 0.7616
# Generation: 830. 正答率（トレーニング） = 1.0
#                 : 830. 正答率（テスト） = 0.762
# Generation: 840. 正答率（トレーニング） = 1.0
#                 : 840. 正答率（テスト） = 0.7612
# Generation: 850. 正答率（トレーニング） = 1.0
#                 : 850. 正答率（テスト） = 0.7608
# Generation: 860. 正答率（トレーニング） = 1.0
#                 : 860. 正答率（テスト） = 0.7609
# Generation: 870. 正答率（トレーニング） = 1.0
#                 : 870. 正答率（テスト） = 0.7628
# Generation: 880. 正答率（トレーニング） = 1.0
#                 : 880. 正答率（テスト） = 0.7612
# Generation: 890. 正答率（トレーニング） = 1.0
#                 : 890. 正答率（テスト） = 0.7633
# Generation: 900. 正答率（トレーニング） = 1.0
#                 : 900. 正答率（テスト） = 0.7617
# Generation: 910. 正答率（トレーニング） = 1.0
#                 : 910. 正答率（テスト） = 0.7604
# Generation: 920. 正答率（トレーニング） = 1.0
#                 : 920. 正答率（テスト） = 0.7616
# Generation: 930. 正答率（トレーニング） = 1.0
#                 : 930. 正答率（テスト） = 0.762
# Generation: 940. 正答率（トレーニング） = 1.0
#                 : 940. 正答率（テスト） = 0.7607
# Generation: 950. 正答率（トレーニング） = 1.0
#                 : 950. 正答率（テスト） = 0.7615
# Generation: 960. 正答率（トレーニング） = 1.0
#                 : 960. 正答率（テスト） = 0.7622
# Generation: 970. 正答率（トレーニング） = 1.0
#                 : 970. 正答率（テスト） = 0.762
# Generation: 980. 正答率（トレーニング） = 1.0
#                 : 980. 正答率（テスト） = 0.7617
# Generation: 990. 正答率（トレーニング） = 1.0
#                 : 990. 正答率（テスト） = 0.762
# Generation: 1000. 正答率（トレーニング） = 1.0
#                 : 1000. 正答率（テスト） = 0.7618

# %%
Tester15.plot_results()
plt.show()

# %% [markdown]
# training_set とtest_setでaccuracyの乖離が確認できる。
#
# なお、訓練データ数が十分であれば、同様のhidden_size_listを使っても、過学習はさけられている。

# %%
# hidden_size_listを大きくして、表現力を極端に大きくしている。
Tester14 = OverfittingTest(activation = "relu", weight_init_std = "relu" , x_train = x_train_overfitting, d_train = d_train_overfitting, x_test = x_test, d_test = d_test, 
                           OptimizerType = "SGD",
                           weight_decay_type = "L2", weight_decay_lambda = 0.1,
                           hidden_size_list = [100,100,100,100,100,100], iters_num = 1000)
Tester14.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.13666666666666666
#                 : 10. 正答率（テスト） = 0.1112
# Generation: 20. 正答率（トレーニング） = 0.25666666666666665
#                 : 20. 正答率（テスト） = 0.1777
# Generation: 30. 正答率（トレーニング） = 0.36
#                 : 30. 正答率（テスト） = 0.2465
# Generation: 40. 正答率（トレーニング） = 0.4
#                 : 40. 正答率（テスト） = 0.2922
# Generation: 50. 正答率（トレーニング） = 0.44
#                 : 50. 正答率（テスト） = 0.3188
# Generation: 60. 正答率（トレーニング） = 0.5033333333333333
#                 : 60. 正答率（テスト） = 0.3516
# Generation: 70. 正答率（トレーニング） = 0.53
#                 : 70. 正答率（テスト） = 0.3856
# Generation: 80. 正答率（トレーニング） = 0.54
#                 : 80. 正答率（テスト） = 0.4112
# Generation: 90. 正答率（トレーニング） = 0.5366666666666666
#                 : 90. 正答率（テスト） = 0.4214
# Generation: 100. 正答率（トレーニング） = 0.5566666666666666
#                 : 100. 正答率（テスト） = 0.4464
# Generation: 110. 正答率（トレーニング） = 0.5866666666666667
#                 : 110. 正答率（テスト） = 0.4742
# Generation: 120. 正答率（トレーニング） = 0.6066666666666667
#                 : 120. 正答率（テスト） = 0.4956
# Generation: 130. 正答率（トレーニング） = 0.62
#                 : 130. 正答率（テスト） = 0.5171
# Generation: 140. 正答率（トレーニング） = 0.6366666666666667
#                 : 140. 正答率（テスト） = 0.5245
# Generation: 150. 正答率（トレーニング） = 0.6533333333333333
#                 : 150. 正答率（テスト） = 0.5452
# Generation: 160. 正答率（トレーニング） = 0.66
#                 : 160. 正答率（テスト） = 0.5576
# Generation: 170. 正答率（トレーニング） = 0.6533333333333333
#                 : 170. 正答率（テスト） = 0.549
# Generation: 180. 正答率（トレーニング） = 0.71
#                 : 180. 正答率（テスト） = 0.5862
# Generation: 190. 正答率（トレーニング） = 0.7233333333333334
#                 : 190. 正答率（テスト） = 0.5929
# Generation: 200. 正答率（トレーニング） = 0.7566666666666667
#                 : 200. 正答率（テスト） = 0.6125
# Generation: 210. 正答率（トレーニング） = 0.76
#                 : 210. 正答率（テスト） = 0.623
# Generation: 220. 正答率（トレーニング） = 0.7833333333333333
#                 : 220. 正答率（テスト） = 0.6307
# Generation: 230. 正答率（トレーニング） = 0.7866666666666666
#                 : 230. 正答率（テスト） = 0.6289
# Generation: 240. 正答率（トレーニング） = 0.8
#                 : 240. 正答率（テスト） = 0.6454
# Generation: 250. 正答率（トレーニング） = 0.7933333333333333
#                 : 250. 正答率（テスト） = 0.6512
# Generation: 260. 正答率（トレーニング） = 0.8066666666666666
#                 : 260. 正答率（テスト） = 0.6417
# Generation: 270. 正答率（トレーニング） = 0.8133333333333334
#                 : 270. 正答率（テスト） = 0.6594
# Generation: 280. 正答率（トレーニング） = 0.7966666666666666
#                 : 280. 正答率（テスト） = 0.6439
# Generation: 290. 正答率（トレーニング） = 0.8233333333333334
#                 : 290. 正答率（テスト） = 0.6535
# Generation: 300. 正答率（トレーニング） = 0.82
#                 : 300. 正答率（テスト） = 0.6634
# Generation: 310. 正答率（トレーニング） = 0.8366666666666667
#                 : 310. 正答率（テスト） = 0.672
# Generation: 320. 正答率（トレーニング） = 0.83
#                 : 320. 正答率（テスト） = 0.6717
# Generation: 330. 正答率（トレーニング） = 0.8366666666666667
#                 : 330. 正答率（テスト） = 0.6745
# Generation: 340. 正答率（トレーニング） = 0.8466666666666667
#                 : 340. 正答率（テスト） = 0.6818
# Generation: 350. 正答率（トレーニング） = 0.8366666666666667
#                 : 350. 正答率（テスト） = 0.6849
# Generation: 360. 正答率（トレーニング） = 0.8566666666666667
#                 : 360. 正答率（テスト） = 0.695
# Generation: 370. 正答率（トレーニング） = 0.86
#                 : 370. 正答率（テスト） = 0.6905
# Generation: 380. 正答率（トレーニング） = 0.86
#                 : 380. 正答率（テスト） = 0.6909
# Generation: 390. 正答率（トレーニング） = 0.8566666666666667
#                 : 390. 正答率（テスト） = 0.6847
# Generation: 400. 正答率（トレーニング） = 0.8666666666666667
#                 : 400. 正答率（テスト） = 0.6919
# Generation: 410. 正答率（トレーニング） = 0.8666666666666667
#                 : 410. 正答率（テスト） = 0.6935
# Generation: 420. 正答率（トレーニング） = 0.8733333333333333
#                 : 420. 正答率（テスト） = 0.6928
# Generation: 430. 正答率（トレーニング） = 0.8633333333333333
#                 : 430. 正答率（テスト） = 0.6875
# Generation: 440. 正答率（トレーニング） = 0.8733333333333333
#                 : 440. 正答率（テスト） = 0.6958
# Generation: 450. 正答率（トレーニング） = 0.87
#                 : 450. 正答率（テスト） = 0.6994
# Generation: 460. 正答率（トレーニング） = 0.8866666666666667
#                 : 460. 正答率（テスト） = 0.7
# Generation: 470. 正答率（トレーニング） = 0.87
#                 : 470. 正答率（テスト） = 0.6951
# Generation: 480. 正答率（トレーニング） = 0.8833333333333333
#                 : 480. 正答率（テスト） = 0.7012
# Generation: 490. 正答率（トレーニング） = 0.8933333333333333
#                 : 490. 正答率（テスト） = 0.7042
# Generation: 500. 正答率（トレーニング） = 0.8866666666666667
#                 : 500. 正答率（テスト） = 0.7041
# Generation: 510. 正答率（トレーニング） = 0.89
#                 : 510. 正答率（テスト） = 0.7037
# Generation: 520. 正答率（トレーニング） = 0.8833333333333333
#                 : 520. 正答率（テスト） = 0.7071
# Generation: 530. 正答率（トレーニング） = 0.8833333333333333
#                 : 530. 正答率（テスト） = 0.6997
# Generation: 540. 正答率（トレーニング） = 0.8966666666666666
#                 : 540. 正答率（テスト） = 0.7063
# Generation: 550. 正答率（トレーニング） = 0.9
#                 : 550. 正答率（テスト） = 0.7066
# Generation: 560. 正答率（トレーニング） = 0.89
#                 : 560. 正答率（テスト） = 0.7095
# Generation: 570. 正答率（トレーニング） = 0.8766666666666667
#                 : 570. 正答率（テスト） = 0.7045
# Generation: 580. 正答率（トレーニング） = 0.87
#                 : 580. 正答率（テスト） = 0.7024
# Generation: 590. 正答率（トレーニング） = 0.8766666666666667
#                 : 590. 正答率（テスト） = 0.6977
# Generation: 600. 正答率（トレーニング） = 0.8966666666666666
#                 : 600. 正答率（テスト） = 0.7056
# Generation: 610. 正答率（トレーニング） = 0.89
#                 : 610. 正答率（テスト） = 0.7109
# Generation: 620. 正答率（トレーニング） = 0.8866666666666667
#                 : 620. 正答率（テスト） = 0.7027
# Generation: 630. 正答率（トレーニング） = 0.8966666666666666
#                 : 630. 正答率（テスト） = 0.7087
# Generation: 640. 正答率（トレーニング） = 0.9033333333333333
#                 : 640. 正答率（テスト） = 0.7084
# Generation: 650. 正答率（トレーニング） = 0.8966666666666666
#                 : 650. 正答率（テスト） = 0.7067
# Generation: 660. 正答率（トレーニング） = 0.9
#                 : 660. 正答率（テスト） = 0.709
# Generation: 670. 正答率（トレーニング） = 0.9066666666666666
#                 : 670. 正答率（テスト） = 0.7122
# Generation: 680. 正答率（トレーニング） = 0.91
#                 : 680. 正答率（テスト） = 0.7117
# Generation: 690. 正答率（トレーニング） = 0.9033333333333333
#                 : 690. 正答率（テスト） = 0.7164
# Generation: 700. 正答率（トレーニング） = 0.9033333333333333
#                 : 700. 正答率（テスト） = 0.7141
# Generation: 710. 正答率（トレーニング） = 0.9166666666666666
#                 : 710. 正答率（テスト） = 0.7158
# Generation: 720. 正答率（トレーニング） = 0.9166666666666666
#                 : 720. 正答率（テスト） = 0.7186
# Generation: 730. 正答率（トレーニング） = 0.8933333333333333
#                 : 730. 正答率（テスト） = 0.7144
# Generation: 740. 正答率（トレーニング） = 0.92
#                 : 740. 正答率（テスト） = 0.7196
# Generation: 750. 正答率（トレーニング） = 0.9033333333333333
#                 : 750. 正答率（テスト） = 0.7105
# Generation: 760. 正答率（トレーニング） = 0.9
#                 : 760. 正答率（テスト） = 0.7093
# Generation: 770. 正答率（トレーニング） = 0.9133333333333333
#                 : 770. 正答率（テスト） = 0.7149
# Generation: 780. 正答率（トレーニング） = 0.89
#                 : 780. 正答率（テスト） = 0.7101
# Generation: 790. 正答率（トレーニング） = 0.9
#                 : 790. 正答率（テスト） = 0.7126
# Generation: 800. 正答率（トレーニング） = 0.9033333333333333
#                 : 800. 正答率（テスト） = 0.7143
# Generation: 810. 正答率（トレーニング） = 0.9033333333333333
#                 : 810. 正答率（テスト） = 0.7115
# Generation: 820. 正答率（トレーニング） = 0.9
#                 : 820. 正答率（テスト） = 0.7076
# Generation: 830. 正答率（トレーニング） = 0.9066666666666666
#                 : 830. 正答率（テスト） = 0.7143
# Generation: 840. 正答率（トレーニング） = 0.9066666666666666
#                 : 840. 正答率（テスト） = 0.7099
# Generation: 850. 正答率（トレーニング） = 0.92
#                 : 850. 正答率（テスト） = 0.7192
# Generation: 860. 正答率（トレーニング） = 0.9066666666666666
#                 : 860. 正答率（テスト） = 0.7175
# Generation: 870. 正答率（トレーニング） = 0.9233333333333333
#                 : 870. 正答率（テスト） = 0.72
# Generation: 880. 正答率（トレーニング） = 0.92
#                 : 880. 正答率（テスト） = 0.7183
# Generation: 890. 正答率（トレーニング） = 0.92
#                 : 890. 正答率（テスト） = 0.7189
# Generation: 900. 正答率（トレーニング） = 0.9266666666666666
#                 : 900. 正答率（テスト） = 0.7205
# Generation: 910. 正答率（トレーニング） = 0.9066666666666666
#                 : 910. 正答率（テスト） = 0.7134
# Generation: 920. 正答率（トレーニング） = 0.9133333333333333
#                 : 920. 正答率（テスト） = 0.7166
# Generation: 930. 正答率（トレーニング） = 0.91
#                 : 930. 正答率（テスト） = 0.7161
# Generation: 940. 正答率（トレーニング） = 0.9166666666666666
#                 : 940. 正答率（テスト） = 0.7211
# Generation: 950. 正答率（トレーニング） = 0.92
#                 : 950. 正答率（テスト） = 0.7246
# Generation: 960. 正答率（トレーニング） = 0.92
#                 : 960. 正答率（テスト） = 0.7178
# Generation: 970. 正答率（トレーニング） = 0.91
#                 : 970. 正答率（テスト） = 0.718
# Generation: 980. 正答率（トレーニング） = 0.93
#                 : 980. 正答率（テスト） = 0.7199
# Generation: 990. 正答率（トレーニング） = 0.9166666666666666
#                 : 990. 正答率（テスト） = 0.7253
# Generation: 1000. 正答率（トレーニング） = 0.9333333333333333
#                 : 1000. 正答率（テスト） = 0.7245

# %%
Tester14.plot_results()
plt.show()

# %%
# hidden_size_listを大きくして、表現力を極端に大きくしている。
Tester16 = OverfittingTest(activation = "relu", weight_init_std = "relu" , x_train = x_train_overfitting, d_train = d_train_overfitting, x_test = x_test, d_test = d_test, 
                           OptimizerType = "SGD",
                           weight_decay_type = "L1", weight_decay_lambda = 0.005,
                           hidden_size_list = [100,100,100,100,100,100], iters_num = 1000)
Tester16.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.20666666666666667
#                 : 10. 正答率（テスト） = 0.1583
# Generation: 20. 正答率（トレーニング） = 0.23333333333333334
#                 : 20. 正答率（テスト） = 0.1875
# Generation: 30. 正答率（トレーニング） = 0.3333333333333333
#                 : 30. 正答率（テスト） = 0.2398
# Generation: 40. 正答率（トレーニング） = 0.38333333333333336
#                 : 40. 正答率（テスト） = 0.2848
# Generation: 50. 正答率（トレーニング） = 0.43
#                 : 50. 正答率（テスト） = 0.3202
# Generation: 60. 正答率（トレーニング） = 0.44666666666666666
#                 : 60. 正答率（テスト） = 0.3407
# Generation: 70. 正答率（トレーニング） = 0.4866666666666667
#                 : 70. 正答率（テスト） = 0.3679
# Generation: 80. 正答率（トレーニング） = 0.53
#                 : 80. 正答率（テスト） = 0.397
# Generation: 90. 正答率（トレーニング） = 0.6066666666666667
#                 : 90. 正答率（テスト） = 0.4377
# Generation: 100. 正答率（トレーニング） = 0.67
#                 : 100. 正答率（テスト） = 0.4844
# Generation: 110. 正答率（トレーニング） = 0.7033333333333334
#                 : 110. 正答率（テスト） = 0.5166
# Generation: 120. 正答率（トレーニング） = 0.7366666666666667
#                 : 120. 正答率（テスト） = 0.5582
# Generation: 130. 正答率（トレーニング） = 0.7966666666666666
#                 : 130. 正答率（テスト） = 0.5839
# Generation: 140. 正答率（トレーニング） = 0.8166666666666667
#                 : 140. 正答率（テスト） = 0.6002
# Generation: 150. 正答率（トレーニング） = 0.83
#                 : 150. 正答率（テスト） = 0.6186
# Generation: 160. 正答率（トレーニング） = 0.84
#                 : 160. 正答率（テスト） = 0.6354
# Generation: 170. 正答率（トレーニング） = 0.8566666666666667
#                 : 170. 正答率（テスト） = 0.6338
# Generation: 180. 正答率（トレーニング） = 0.8866666666666667
#                 : 180. 正答率（テスト） = 0.6489
# Generation: 190. 正答率（トレーニング） = 0.9
#                 : 190. 正答率（テスト） = 0.6611
# Generation: 200. 正答率（トレーニング） = 0.8933333333333333
#                 : 200. 正答率（テスト） = 0.6587
# Generation: 210. 正答率（トレーニング） = 0.9
#                 : 210. 正答率（テスト） = 0.6703
# Generation: 220. 正答率（トレーニング） = 0.9233333333333333
#                 : 220. 正答率（テスト） = 0.6778
# Generation: 230. 正答率（トレーニング） = 0.9266666666666666
#                 : 230. 正答率（テスト） = 0.6865
# Generation: 240. 正答率（トレーニング） = 0.93
#                 : 240. 正答率（テスト） = 0.6964
# Generation: 250. 正答率（トレーニング） = 0.95
#                 : 250. 正答率（テスト） = 0.6889
# Generation: 260. 正答率（トレーニング） = 0.94
#                 : 260. 正答率（テスト） = 0.7014
# Generation: 270. 正答率（トレーニング） = 0.9433333333333334
#                 : 270. 正答率（テスト） = 0.7033
# Generation: 280. 正答率（トレーニング） = 0.9566666666666667
#                 : 280. 正答率（テスト） = 0.706
# Generation: 290. 正答率（トレーニング） = 0.9466666666666667
#                 : 290. 正答率（テスト） = 0.7125
# Generation: 300. 正答率（トレーニング） = 0.95
#                 : 300. 正答率（テスト） = 0.7057
# Generation: 310. 正答率（トレーニング） = 0.9566666666666667
#                 : 310. 正答率（テスト） = 0.7171
# Generation: 320. 正答率（トレーニング） = 0.96
#                 : 320. 正答率（テスト） = 0.7196
# Generation: 330. 正答率（トレーニング） = 0.9566666666666667
#                 : 330. 正答率（テスト） = 0.7237
# Generation: 340. 正答率（トレーニング） = 0.9633333333333334
#                 : 340. 正答率（テスト） = 0.7221
# Generation: 350. 正答率（トレーニング） = 0.9633333333333334
#                 : 350. 正答率（テスト） = 0.7232
# Generation: 360. 正答率（トレーニング） = 0.9633333333333334
#                 : 360. 正答率（テスト） = 0.7253
# Generation: 370. 正答率（トレーニング） = 0.97
#                 : 370. 正答率（テスト） = 0.7291
# Generation: 380. 正答率（トレーニング） = 0.9766666666666667
#                 : 380. 正答率（テスト） = 0.7327
# Generation: 390. 正答率（トレーニング） = 0.9766666666666667
#                 : 390. 正答率（テスト） = 0.7363
# Generation: 400. 正答率（トレーニング） = 0.98
#                 : 400. 正答率（テスト） = 0.7342
# Generation: 410. 正答率（トレーニング） = 0.9766666666666667
#                 : 410. 正答率（テスト） = 0.7386
# Generation: 420. 正答率（トレーニング） = 0.9766666666666667
#                 : 420. 正答率（テスト） = 0.7362
# Generation: 430. 正答率（トレーニング） = 0.98
#                 : 430. 正答率（テスト） = 0.7385
# Generation: 440. 正答率（トレーニング） = 0.9766666666666667
#                 : 440. 正答率（テスト） = 0.731
# Generation: 450. 正答率（トレーニング） = 0.9766666666666667
#                 : 450. 正答率（テスト） = 0.7409
# Generation: 460. 正答率（トレーニング） = 0.9766666666666667
#                 : 460. 正答率（テスト） = 0.7431
# Generation: 470. 正答率（トレーニング） = 0.98
#                 : 470. 正答率（テスト） = 0.7419
# Generation: 480. 正答率（トレーニング） = 0.9866666666666667
#                 : 480. 正答率（テスト） = 0.7405
# Generation: 490. 正答率（トレーニング） = 0.9833333333333333
#                 : 490. 正答率（テスト） = 0.7447
# Generation: 500. 正答率（トレーニング） = 0.9833333333333333
#                 : 500. 正答率（テスト） = 0.741
# Generation: 510. 正答率（トレーニング） = 0.9866666666666667
#                 : 510. 正答率（テスト） = 0.7443
# Generation: 520. 正答率（トレーニング） = 0.98
#                 : 520. 正答率（テスト） = 0.7432
# Generation: 530. 正答率（トレーニング） = 0.9833333333333333
#                 : 530. 正答率（テスト） = 0.7425
# Generation: 540. 正答率（トレーニング） = 0.9866666666666667
#                 : 540. 正答率（テスト） = 0.7469
# Generation: 550. 正答率（トレーニング） = 0.9866666666666667
#                 : 550. 正答率（テスト） = 0.7484
# Generation: 560. 正答率（トレーニング） = 0.9833333333333333
#                 : 560. 正答率（テスト） = 0.7476
# Generation: 570. 正答率（トレーニング） = 0.9866666666666667
#                 : 570. 正答率（テスト） = 0.7489
# Generation: 580. 正答率（トレーニング） = 0.9866666666666667
#                 : 580. 正答率（テスト） = 0.7466
# Generation: 590. 正答率（トレーニング） = 0.9866666666666667
#                 : 590. 正答率（テスト） = 0.7504
# Generation: 600. 正答率（トレーニング） = 0.9866666666666667
#                 : 600. 正答率（テスト） = 0.7482
# Generation: 610. 正答率（トレーニング） = 0.9866666666666667
#                 : 610. 正答率（テスト） = 0.7492
# Generation: 620. 正答率（トレーニング） = 0.9866666666666667
#                 : 620. 正答率（テスト） = 0.7465
# Generation: 630. 正答率（トレーニング） = 0.99
#                 : 630. 正答率（テスト） = 0.7468
# Generation: 640. 正答率（トレーニング） = 0.9866666666666667
#                 : 640. 正答率（テスト） = 0.7514
# Generation: 650. 正答率（トレーニング） = 0.99
#                 : 650. 正答率（テスト） = 0.7494
# Generation: 660. 正答率（トレーニング） = 0.9833333333333333
#                 : 660. 正答率（テスト） = 0.7489
# Generation: 670. 正答率（トレーニング） = 0.9866666666666667
#                 : 670. 正答率（テスト） = 0.7502
# Generation: 680. 正答率（トレーニング） = 0.9866666666666667
#                 : 680. 正答率（テスト） = 0.7511
# Generation: 690. 正答率（トレーニング） = 0.99
#                 : 690. 正答率（テスト） = 0.7499
# Generation: 700. 正答率（トレーニング） = 0.99
#                 : 700. 正答率（テスト） = 0.7493
# Generation: 710. 正答率（トレーニング） = 0.9933333333333333
#                 : 710. 正答率（テスト） = 0.7483
# Generation: 720. 正答率（トレーニング） = 0.9933333333333333
#                 : 720. 正答率（テスト） = 0.75
# Generation: 730. 正答率（トレーニング） = 0.99
#                 : 730. 正答率（テスト） = 0.7486
# Generation: 740. 正答率（トレーニング） = 0.99
#                 : 740. 正答率（テスト） = 0.7489
# Generation: 750. 正答率（トレーニング） = 0.9933333333333333
#                 : 750. 正答率（テスト） = 0.7492
# Generation: 760. 正答率（トレーニング） = 0.99
#                 : 760. 正答率（テスト） = 0.7482
# Generation: 770. 正答率（トレーニング） = 0.9966666666666667
#                 : 770. 正答率（テスト） = 0.7521
# Generation: 780. 正答率（トレーニング） = 0.99
#                 : 780. 正答率（テスト） = 0.7517
# Generation: 790. 正答率（トレーニング） = 0.9933333333333333
#                 : 790. 正答率（テスト） = 0.7536
# Generation: 800. 正答率（トレーニング） = 0.9933333333333333
#                 : 800. 正答率（テスト） = 0.7507
# Generation: 810. 正答率（トレーニング） = 0.9933333333333333
#                 : 810. 正答率（テスト） = 0.754
# Generation: 820. 正答率（トレーニング） = 0.9966666666666667
#                 : 820. 正答率（テスト） = 0.7554
# Generation: 830. 正答率（トレーニング） = 0.9933333333333333
#                 : 830. 正答率（テスト） = 0.7493
# Generation: 840. 正答率（トレーニング） = 0.9966666666666667
#                 : 840. 正答率（テスト） = 0.7558
# Generation: 850. 正答率（トレーニング） = 0.9933333333333333
#                 : 850. 正答率（テスト） = 0.7515
# Generation: 860. 正答率（トレーニング） = 0.9933333333333333
#                 : 860. 正答率（テスト） = 0.7494
# Generation: 870. 正答率（トレーニング） = 0.9966666666666667
#                 : 870. 正答率（テスト） = 0.7528
# Generation: 880. 正答率（トレーニング） = 0.9933333333333333
#                 : 880. 正答率（テスト） = 0.7463
# Generation: 890. 正答率（トレーニング） = 0.9933333333333333
#                 : 890. 正答率（テスト） = 0.7486
# Generation: 900. 正答率（トレーニング） = 0.9933333333333333
#                 : 900. 正答率（テスト） = 0.7499
# Generation: 910. 正答率（トレーニング） = 0.99
#                 : 910. 正答率（テスト） = 0.7516
# Generation: 920. 正答率（トレーニング） = 0.9933333333333333
#                 : 920. 正答率（テスト） = 0.7503
# Generation: 930. 正答率（トレーニング） = 0.9966666666666667
#                 : 930. 正答率（テスト） = 0.7499
# Generation: 940. 正答率（トレーニング） = 0.9966666666666667
#                 : 940. 正答率（テスト） = 0.7552
# Generation: 950. 正答率（トレーニング） = 0.9966666666666667
#                 : 950. 正答率（テスト） = 0.754
# Generation: 960. 正答率（トレーニング） = 0.9933333333333333
#                 : 960. 正答率（テスト） = 0.7551
# Generation: 970. 正答率（トレーニング） = 0.9966666666666667
#                 : 970. 正答率（テスト） = 0.7528
# Generation: 980. 正答率（トレーニング） = 0.9966666666666667
#                 : 980. 正答率（テスト） = 0.7518
# Generation: 990. 正答率（トレーニング） = 0.9966666666666667
#                 : 990. 正答率（テスト） = 0.7552
# Generation: 1000. 正答率（トレーニング） = 0.99
#                 : 1000. 正答率（テスト） = 0.751

# %%
Tester16.plot_results()
plt.show()

# %%
# hidden_size_listを大きくして、表現力を極端に大きくしている。
Tester17 = OverfittingTest(activation = "relu", weight_init_std = "relu" , x_train = x_train_overfitting, d_train = d_train_overfitting, x_test = x_test, d_test = d_test, 
                           OptimizerType = "SGD",
                           dropout = True, dropout_ratio = 0.15,
                           hidden_size_list = [100,100,100,100,100,100], iters_num = 1000)
Tester17.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.13666666666666666
#                 : 10. 正答率（テスト） = 0.1157
# Generation: 20. 正答率（トレーニング） = 0.14
#                 : 20. 正答率（テスト） = 0.1217
# Generation: 30. 正答率（トレーニング） = 0.15666666666666668
#                 : 30. 正答率（テスト） = 0.1299
# Generation: 40. 正答率（トレーニング） = 0.15333333333333332
#                 : 40. 正答率（テスト） = 0.138
# Generation: 50. 正答率（トレーニング） = 0.17
#                 : 50. 正答率（テスト） = 0.1478
# Generation: 60. 正答率（トレーニング） = 0.18666666666666668
#                 : 60. 正答率（テスト） = 0.158
# Generation: 70. 正答率（トレーニング） = 0.19666666666666666
#                 : 70. 正答率（テスト） = 0.166
# Generation: 80. 正答率（トレーニング） = 0.2
#                 : 80. 正答率（テスト） = 0.1744
# Generation: 90. 正答率（トレーニング） = 0.19666666666666666
#                 : 90. 正答率（テスト） = 0.181
# Generation: 100. 正答率（トレーニング） = 0.20666666666666667
#                 : 100. 正答率（テスト） = 0.1876
# Generation: 110. 正答率（トレーニング） = 0.21333333333333335
#                 : 110. 正答率（テスト） = 0.1939
# Generation: 120. 正答率（トレーニング） = 0.22
#                 : 120. 正答率（テスト） = 0.1997
# Generation: 130. 正答率（トレーニング） = 0.22
#                 : 130. 正答率（テスト） = 0.2024
# Generation: 140. 正答率（トレーニング） = 0.22
#                 : 140. 正答率（テスト） = 0.2027
# Generation: 150. 正答率（トレーニング） = 0.23666666666666666
#                 : 150. 正答率（テスト） = 0.2002
# Generation: 160. 正答率（トレーニング） = 0.23333333333333334
#                 : 160. 正答率（テスト） = 0.1975
# Generation: 170. 正答率（トレーニング） = 0.24333333333333335
#                 : 170. 正答率（テスト） = 0.2016
# Generation: 180. 正答率（トレーニング） = 0.23666666666666666
#                 : 180. 正答率（テスト） = 0.1996
# Generation: 190. 正答率（トレーニング） = 0.24
#                 : 190. 正答率（テスト） = 0.2019
# Generation: 200. 正答率（トレーニング） = 0.24333333333333335
#                 : 200. 正答率（テスト） = 0.2097
# Generation: 210. 正答率（トレーニング） = 0.25
#                 : 210. 正答率（テスト） = 0.2195
# Generation: 220. 正答率（トレーニング） = 0.24
#                 : 220. 正答率（テスト） = 0.2193
# Generation: 230. 正答率（トレーニング） = 0.25333333333333335
#                 : 230. 正答率（テスト） = 0.2217
# Generation: 240. 正答率（トレーニング） = 0.25
#                 : 240. 正答率（テスト） = 0.2237
# Generation: 250. 正答率（トレーニング） = 0.26
#                 : 250. 正答率（テスト） = 0.2222
# Generation: 260. 正答率（トレーニング） = 0.2633333333333333
#                 : 260. 正答率（テスト） = 0.227
# Generation: 270. 正答率（トレーニング） = 0.2966666666666667
#                 : 270. 正答率（テスト） = 0.2489
# Generation: 280. 正答率（トレーニング） = 0.30666666666666664
#                 : 280. 正答率（テスト） = 0.2548
# Generation: 290. 正答率（トレーニング） = 0.32
#                 : 290. 正答率（テスト） = 0.2589
# Generation: 300. 正答率（トレーニング） = 0.32
#                 : 300. 正答率（テスト） = 0.2625
# Generation: 310. 正答率（トレーニング） = 0.3333333333333333
#                 : 310. 正答率（テスト） = 0.271
# Generation: 320. 正答率（トレーニング） = 0.34
#                 : 320. 正答率（テスト） = 0.2826
# Generation: 330. 正答率（トレーニング） = 0.3566666666666667
#                 : 330. 正答率（テスト） = 0.2951
# Generation: 340. 正答率（トレーニング） = 0.37333333333333335
#                 : 340. 正答率（テスト） = 0.3025
# Generation: 350. 正答率（トレーニング） = 0.3933333333333333
#                 : 350. 正答率（テスト） = 0.3125
# Generation: 360. 正答率（トレーニング） = 0.4033333333333333
#                 : 360. 正答率（テスト） = 0.3254
# Generation: 370. 正答率（トレーニング） = 0.43333333333333335
#                 : 370. 正答率（テスト） = 0.3392
# Generation: 380. 正答率（トレーニング） = 0.4633333333333333
#                 : 380. 正答率（テスト） = 0.3548
# Generation: 390. 正答率（トレーニング） = 0.4766666666666667
#                 : 390. 正答率（テスト） = 0.3623
# Generation: 400. 正答率（トレーニング） = 0.49666666666666665
#                 : 400. 正答率（テスト） = 0.3791
# Generation: 410. 正答率（トレーニング） = 0.49666666666666665
#                 : 410. 正答率（テスト） = 0.382
# Generation: 420. 正答率（トレーニング） = 0.5366666666666666
#                 : 420. 正答率（テスト） = 0.399
# Generation: 430. 正答率（トレーニング） = 0.5666666666666667
#                 : 430. 正答率（テスト） = 0.4156
# Generation: 440. 正答率（トレーニング） = 0.5633333333333334
#                 : 440. 正答率（テスト） = 0.4216
# Generation: 450. 正答率（トレーニング） = 0.58
#                 : 450. 正答率（テスト） = 0.436
# Generation: 460. 正答率（トレーニング） = 0.6133333333333333
#                 : 460. 正答率（テスト） = 0.4518
# Generation: 470. 正答率（トレーニング） = 0.61
#                 : 470. 正答率（テスト） = 0.4535
# Generation: 480. 正答率（トレーニング） = 0.6266666666666667
#                 : 480. 正答率（テスト） = 0.4685
# Generation: 490. 正答率（トレーニング） = 0.6266666666666667
#                 : 490. 正答率（テスト） = 0.4718
# Generation: 500. 正答率（トレーニング） = 0.6366666666666667
#                 : 500. 正答率（テスト） = 0.4804
# Generation: 510. 正答率（トレーニング） = 0.63
#                 : 510. 正答率（テスト） = 0.4818
# Generation: 520. 正答率（トレーニング） = 0.64
#                 : 520. 正答率（テスト） = 0.4844
# Generation: 530. 正答率（トレーニング） = 0.6433333333333333
#                 : 530. 正答率（テスト） = 0.4922
# Generation: 540. 正答率（トレーニング） = 0.6366666666666667
#                 : 540. 正答率（テスト） = 0.5011
# Generation: 550. 正答率（トレーニング） = 0.64
#                 : 550. 正答率（テスト） = 0.5024
# Generation: 560. 正答率（トレーニング） = 0.65
#                 : 560. 正答率（テスト） = 0.508
# Generation: 570. 正答率（トレーニング） = 0.65
#                 : 570. 正答率（テスト） = 0.5124
# Generation: 580. 正答率（トレーニング） = 0.6566666666666666
#                 : 580. 正答率（テスト） = 0.5153
# Generation: 590. 正答率（トレーニング） = 0.66
#                 : 590. 正答率（テスト） = 0.5184
# Generation: 600. 正答率（トレーニング） = 0.6566666666666666
#                 : 600. 正答率（テスト） = 0.5187
# Generation: 610. 正答率（トレーニング） = 0.6566666666666666
#                 : 610. 正答率（テスト） = 0.5221
# Generation: 620. 正答率（トレーニング） = 0.66
#                 : 620. 正答率（テスト） = 0.5268
# Generation: 630. 正答率（トレーニング） = 0.6566666666666666
#                 : 630. 正答率（テスト） = 0.5296
# Generation: 640. 正答率（トレーニング） = 0.66
#                 : 640. 正答率（テスト） = 0.5321
# Generation: 650. 正答率（トレーニング） = 0.6633333333333333
#                 : 650. 正答率（テスト） = 0.5342
# Generation: 660. 正答率（トレーニング） = 0.6533333333333333
#                 : 660. 正答率（テスト） = 0.5329
# Generation: 670. 正答率（トレーニング） = 0.6533333333333333
#                 : 670. 正答率（テスト） = 0.5378
# Generation: 680. 正答率（トレーニング） = 0.66
#                 : 680. 正答率（テスト） = 0.538
# Generation: 690. 正答率（トレーニング） = 0.6633333333333333
#                 : 690. 正答率（テスト） = 0.5419
# Generation: 700. 正答率（トレーニング） = 0.68
#                 : 700. 正答率（テスト） = 0.5483
# Generation: 710. 正答率（トレーニング） = 0.69
#                 : 710. 正答率（テスト） = 0.55
# Generation: 720. 正答率（トレーニング） = 0.6833333333333333
#                 : 720. 正答率（テスト） = 0.5571
# Generation: 730. 正答率（トレーニング） = 0.7
#                 : 730. 正答率（テスト） = 0.5639
# Generation: 740. 正答率（トレーニング） = 0.7
#                 : 740. 正答率（テスト） = 0.5688
# Generation: 750. 正答率（トレーニング） = 0.7133333333333334
#                 : 750. 正答率（テスト） = 0.5643
# Generation: 760. 正答率（トレーニング） = 0.74
#                 : 760. 正答率（テスト） = 0.5761
# Generation: 770. 正答率（トレーニング） = 0.7333333333333333
#                 : 770. 正答率（テスト） = 0.5797
# Generation: 780. 正答率（トレーニング） = 0.7466666666666667
#                 : 780. 正答率（テスト） = 0.5929
# Generation: 790. 正答率（トレーニング） = 0.76
#                 : 790. 正答率（テスト） = 0.5994
# Generation: 800. 正答率（トレーニング） = 0.76
#                 : 800. 正答率（テスト） = 0.5941
# Generation: 810. 正答率（トレーニング） = 0.7733333333333333
#                 : 810. 正答率（テスト） = 0.6025
# Generation: 820. 正答率（トレーニング） = 0.7866666666666666
#                 : 820. 正答率（テスト） = 0.6128
# Generation: 830. 正答率（トレーニング） = 0.79
#                 : 830. 正答率（テスト） = 0.6192
# Generation: 840. 正答率（トレーニング） = 0.8033333333333333
#                 : 840. 正答率（テスト） = 0.6246
# Generation: 850. 正答率（トレーニング） = 0.81
#                 : 850. 正答率（テスト） = 0.6264
# Generation: 860. 正答率（トレーニング） = 0.8133333333333334
#                 : 860. 正答率（テスト） = 0.6296
# Generation: 870. 正答率（トレーニング） = 0.82
#                 : 870. 正答率（テスト） = 0.6322
# Generation: 880. 正答率（トレーニング） = 0.82
#                 : 880. 正答率（テスト） = 0.6346
# Generation: 890. 正答率（トレーニング） = 0.82
#                 : 890. 正答率（テスト） = 0.6417
# Generation: 900. 正答率（トレーニング） = 0.83
#                 : 900. 正答率（テスト） = 0.6379
# Generation: 910. 正答率（トレーニング） = 0.8466666666666667
#                 : 910. 正答率（テスト） = 0.6471
# Generation: 920. 正答率（トレーニング） = 0.8466666666666667
#                 : 920. 正答率（テスト） = 0.6526
# Generation: 930. 正答率（トレーニング） = 0.8433333333333334
#                 : 930. 正答率（テスト） = 0.6556
# Generation: 940. 正答率（トレーニング） = 0.8366666666666667
#                 : 940. 正答率（テスト） = 0.6561
# Generation: 950. 正答率（トレーニング） = 0.8466666666666667
#                 : 950. 正答率（テスト） = 0.6609
# Generation: 960. 正答率（トレーニング） = 0.8533333333333334
#                 : 960. 正答率（テスト） = 0.6684
# Generation: 970. 正答率（トレーニング） = 0.8566666666666667
#                 : 970. 正答率（テスト） = 0.6666
# Generation: 980. 正答率（トレーニング） = 0.86
#                 : 980. 正答率（テスト） = 0.6752
# Generation: 990. 正答率（トレーニング） = 0.8566666666666667
#                 : 990. 正答率（テスト） = 0.6713
# Generation: 1000. 正答率（トレーニング） = 0.8666666666666667
#                 : 1000. 正答率（テスト） = 0.6754

# %%
Tester17.plot_results()
plt.show()

# %%
# hidden_size_listを大きくして、表現力を極端に大きくしている。
Tester18 = OverfittingTest(activation = "relu", weight_init_std = "relu" , x_train = x_train_overfitting, d_train = d_train_overfitting, x_test = x_test, d_test = d_test, 
                           OptimizerType = "SGD",
                           weight_decay_type = "L1", weight_decay_lambda = 0.004,                           
                           dropout = True, dropout_ratio = 0.08,
                           hidden_size_list = [100,100,100,100,100,100], iters_num = 1000)
Tester18.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.15666666666666668
#                 : 10. 正答率（テスト） = 0.1051
# Generation: 20. 正答率（トレーニング） = 0.18333333333333332
#                 : 20. 正答率（テスト） = 0.1255
# Generation: 30. 正答率（トレーニング） = 0.24333333333333335
#                 : 30. 正答率（テスト） = 0.1525
# Generation: 40. 正答率（トレーニング） = 0.2866666666666667
#                 : 40. 正答率（テスト） = 0.1764
# Generation: 50. 正答率（トレーニング） = 0.32666666666666666
#                 : 50. 正答率（テスト） = 0.2067
# Generation: 60. 正答率（トレーニング） = 0.38
#                 : 60. 正答率（テスト） = 0.2354
# Generation: 70. 正答率（トレーニング） = 0.4166666666666667
#                 : 70. 正答率（テスト） = 0.2672
# Generation: 80. 正答率（トレーニング） = 0.41333333333333333
#                 : 80. 正答率（テスト） = 0.2693
# Generation: 90. 正答率（トレーニング） = 0.4066666666666667
#                 : 90. 正答率（テスト） = 0.2763
# Generation: 100. 正答率（トレーニング） = 0.41333333333333333
#                 : 100. 正答率（テスト） = 0.2862
# Generation: 110. 正答率（トレーニング） = 0.39666666666666667
#                 : 110. 正答率（テスト） = 0.2851
# Generation: 120. 正答率（トレーニング） = 0.37666666666666665
#                 : 120. 正答率（テスト） = 0.2938
# Generation: 130. 正答率（トレーニング） = 0.42333333333333334
#                 : 130. 正答率（テスト） = 0.3163
# Generation: 140. 正答率（トレーニング） = 0.45
#                 : 140. 正答率（テスト） = 0.3382
# Generation: 150. 正答率（トレーニング） = 0.49666666666666665
#                 : 150. 正答率（テスト） = 0.3587
# Generation: 160. 正答率（トレーニング） = 0.49
#                 : 160. 正答率（テスト） = 0.3564
# Generation: 170. 正答率（トレーニング） = 0.5133333333333333
#                 : 170. 正答率（テスト） = 0.3722
# Generation: 180. 正答率（トレーニング） = 0.5566666666666666
#                 : 180. 正答率（テスト） = 0.4031
# Generation: 190. 正答率（トレーニング） = 0.5866666666666667
#                 : 190. 正答率（テスト） = 0.418
# Generation: 200. 正答率（トレーニング） = 0.5933333333333334
#                 : 200. 正答率（テスト） = 0.4304
# Generation: 210. 正答率（トレーニング） = 0.5966666666666667
#                 : 210. 正答率（テスト） = 0.4497
# Generation: 220. 正答率（トレーニング） = 0.62
#                 : 220. 正答率（テスト） = 0.4679
# Generation: 230. 正答率（トレーニング） = 0.6266666666666667
#                 : 230. 正答率（テスト） = 0.4897
# Generation: 240. 正答率（トレーニング） = 0.6233333333333333
#                 : 240. 正答率（テスト） = 0.5016
# Generation: 250. 正答率（トレーニング） = 0.6133333333333333
#                 : 250. 正答率（テスト） = 0.509
# Generation: 260. 正答率（トレーニング） = 0.66
#                 : 260. 正答率（テスト） = 0.5346
# Generation: 270. 正答率（トレーニング） = 0.65
#                 : 270. 正答率（テスト） = 0.529
# Generation: 280. 正答率（トレーニング） = 0.6833333333333333
#                 : 280. 正答率（テスト） = 0.5458
# Generation: 290. 正答率（トレーニング） = 0.6766666666666666
#                 : 290. 正答率（テスト） = 0.5507
# Generation: 300. 正答率（トレーニング） = 0.7233333333333334
#                 : 300. 正答率（テスト） = 0.588
# Generation: 310. 正答率（トレーニング） = 0.71
#                 : 310. 正答率（テスト） = 0.5946
# Generation: 320. 正答率（トレーニング） = 0.7266666666666667
#                 : 320. 正答率（テスト） = 0.6035
# Generation: 330. 正答率（トレーニング） = 0.73
#                 : 330. 正答率（テスト） = 0.6039
# Generation: 340. 正答率（トレーニング） = 0.74
#                 : 340. 正答率（テスト） = 0.601
# Generation: 350. 正答率（トレーニング） = 0.7233333333333334
#                 : 350. 正答率（テスト） = 0.606
# Generation: 360. 正答率（トレーニング） = 0.7266666666666667
#                 : 360. 正答率（テスト） = 0.6143
# Generation: 370. 正答率（トレーニング） = 0.74
#                 : 370. 正答率（テスト） = 0.6291
# Generation: 380. 正答率（トレーニング） = 0.7266666666666667
#                 : 380. 正答率（テスト） = 0.6224
# Generation: 390. 正答率（トレーニング） = 0.76
#                 : 390. 正答率（テスト） = 0.6375
# Generation: 400. 正答率（トレーニング） = 0.78
#                 : 400. 正答率（テスト） = 0.6515
# Generation: 410. 正答率（トレーニング） = 0.78
#                 : 410. 正答率（テスト） = 0.6522
# Generation: 420. 正答率（トレーニング） = 0.7766666666666666
#                 : 420. 正答率（テスト） = 0.6592
# Generation: 430. 正答率（トレーニング） = 0.7966666666666666
#                 : 430. 正答率（テスト） = 0.6631
# Generation: 440. 正答率（トレーニング） = 0.7966666666666666
#                 : 440. 正答率（テスト） = 0.6741
# Generation: 450. 正答率（トレーニング） = 0.7666666666666667
#                 : 450. 正答率（テスト） = 0.6692
# Generation: 460. 正答率（トレーニング） = 0.7866666666666666
#                 : 460. 正答率（テスト） = 0.6795
# Generation: 470. 正答率（トレーニング） = 0.8166666666666667
#                 : 470. 正答率（テスト） = 0.6858
# Generation: 480. 正答率（トレーニング） = 0.82
#                 : 480. 正答率（テスト） = 0.6899
# Generation: 490. 正答率（トレーニング） = 0.8166666666666667
#                 : 490. 正答率（テスト） = 0.6902
# Generation: 500. 正答率（トレーニング） = 0.8233333333333334
#                 : 500. 正答率（テスト） = 0.6914
# Generation: 510. 正答率（トレーニング） = 0.83
#                 : 510. 正答率（テスト） = 0.6938
# Generation: 520. 正答率（トレーニング） = 0.8366666666666667
#                 : 520. 正答率（テスト） = 0.7057
# Generation: 530. 正答率（トレーニング） = 0.8333333333333334
#                 : 530. 正答率（テスト） = 0.7036
# Generation: 540. 正答率（トレーニング） = 0.8533333333333334
#                 : 540. 正答率（テスト） = 0.7119
# Generation: 550. 正答率（トレーニング） = 0.8633333333333333
#                 : 550. 正答率（テスト） = 0.7157
# Generation: 560. 正答率（トレーニング） = 0.86
#                 : 560. 正答率（テスト） = 0.7202
# Generation: 570. 正答率（トレーニング） = 0.8666666666666667
#                 : 570. 正答率（テスト） = 0.7241
# Generation: 580. 正答率（トレーニング） = 0.8766666666666667
#                 : 580. 正答率（テスト） = 0.725
# Generation: 590. 正答率（トレーニング） = 0.89
#                 : 590. 正答率（テスト） = 0.723
# Generation: 600. 正答率（トレーニング） = 0.8933333333333333
#                 : 600. 正答率（テスト） = 0.734
# Generation: 610. 正答率（トレーニング） = 0.9
#                 : 610. 正答率（テスト） = 0.7404
# Generation: 620. 正答率（トレーニング） = 0.9
#                 : 620. 正答率（テスト） = 0.7406
# Generation: 630. 正答率（トレーニング） = 0.9033333333333333
#                 : 630. 正答率（テスト） = 0.7374
# Generation: 640. 正答率（トレーニング） = 0.9133333333333333
#                 : 640. 正答率（テスト） = 0.7377
# Generation: 650. 正答率（トレーニング） = 0.9133333333333333
#                 : 650. 正答率（テスト） = 0.7457
# Generation: 660. 正答率（トレーニング） = 0.91
#                 : 660. 正答率（テスト） = 0.7455
# Generation: 670. 正答率（トレーニング） = 0.9066666666666666
#                 : 670. 正答率（テスト） = 0.7426
# Generation: 680. 正答率（トレーニング） = 0.9133333333333333
#                 : 680. 正答率（テスト） = 0.7402
# Generation: 690. 正答率（トレーニング） = 0.9133333333333333
#                 : 690. 正答率（テスト） = 0.7529
# Generation: 700. 正答率（トレーニング） = 0.91
#                 : 700. 正答率（テスト） = 0.7485
# Generation: 710. 正答率（トレーニング） = 0.9133333333333333
#                 : 710. 正答率（テスト） = 0.7538
# Generation: 720. 正答率（トレーニング） = 0.9133333333333333
#                 : 720. 正答率（テスト） = 0.7572
# Generation: 730. 正答率（トレーニング） = 0.9166666666666666
#                 : 730. 正答率（テスト） = 0.7604
# Generation: 740. 正答率（トレーニング） = 0.9233333333333333
#                 : 740. 正答率（テスト） = 0.7604
# Generation: 750. 正答率（トレーニング） = 0.92
#                 : 750. 正答率（テスト） = 0.7573
# Generation: 760. 正答率（トレーニング） = 0.9266666666666666
#                 : 760. 正答率（テスト） = 0.7617
# Generation: 770. 正答率（トレーニング） = 0.92
#                 : 770. 正答率（テスト） = 0.7624
# Generation: 780. 正答率（トレーニング） = 0.93
#                 : 780. 正答率（テスト） = 0.767
# Generation: 790. 正答率（トレーニング） = 0.93
#                 : 790. 正答率（テスト） = 0.7663
# Generation: 800. 正答率（トレーニング） = 0.9266666666666666
#                 : 800. 正答率（テスト） = 0.7647
# Generation: 810. 正答率（トレーニング） = 0.9266666666666666
#                 : 810. 正答率（テスト） = 0.7591
# Generation: 820. 正答率（トレーニング） = 0.93
#                 : 820. 正答率（テスト） = 0.767
# Generation: 830. 正答率（トレーニング） = 0.9333333333333333
#                 : 830. 正答率（テスト） = 0.7663
# Generation: 840. 正答率（トレーニング） = 0.93
#                 : 840. 正答率（テスト） = 0.7602
# Generation: 850. 正答率（トレーニング） = 0.9333333333333333
#                 : 850. 正答率（テスト） = 0.7639
# Generation: 860. 正答率（トレーニング） = 0.94
#                 : 860. 正答率（テスト） = 0.7686
# Generation: 870. 正答率（トレーニング） = 0.94
#                 : 870. 正答率（テスト） = 0.7768
# Generation: 880. 正答率（トレーニング） = 0.9433333333333334
#                 : 880. 正答率（テスト） = 0.7763
# Generation: 890. 正答率（トレーニング） = 0.9366666666666666
#                 : 890. 正答率（テスト） = 0.7723
# Generation: 900. 正答率（トレーニング） = 0.9366666666666666
#                 : 900. 正答率（テスト） = 0.7696
# Generation: 910. 正答率（トレーニング） = 0.9333333333333333
#                 : 910. 正答率（テスト） = 0.7745
# Generation: 920. 正答率（トレーニング） = 0.9333333333333333
#                 : 920. 正答率（テスト） = 0.7723
# Generation: 930. 正答率（トレーニング） = 0.94
#                 : 930. 正答率（テスト） = 0.7707
# Generation: 940. 正答率（トレーニング） = 0.94
#                 : 940. 正答率（テスト） = 0.774
# Generation: 950. 正答率（トレーニング） = 0.94
#                 : 950. 正答率（テスト） = 0.774
# Generation: 960. 正答率（トレーニング） = 0.9366666666666666
#                 : 960. 正答率（テスト） = 0.7757
# Generation: 970. 正答率（トレーニング） = 0.9433333333333334
#                 : 970. 正答率（テスト） = 0.7764
# Generation: 980. 正答率（トレーニング） = 0.9433333333333334
#                 : 980. 正答率（テスト） = 0.7757
# Generation: 990. 正答率（トレーニング） = 0.9433333333333334
#                 : 990. 正答率（テスト） = 0.7783
# Generation: 1000. 正答率（トレーニング） = 0.9433333333333334
#                 : 1000. 正答率（テスト） = 0.7749

# %%
Tester18.plot_results()
plt.show()

# %%
# 正則化はせず、dropoutのみ、Optimizerを変更
Tester18 = OverfittingTest(activation = "relu", weight_init_std = "relu" , x_train = x_train_overfitting, d_train = d_train_overfitting, x_test = x_test, d_test = d_test, 
                           OptimizerType = "SGD",
                           weight_decay_type = "L1", weight_decay_lambda = 0.004,                           
                           dropout = True, dropout_ratio = 0.08,
                           hidden_size_list = [100,100,100,100,100,100], iters_num = 1000)
Tester18.train()
# Out:
# Generation: 10. 正答率（トレーニング） = 0.15666666666666668
#                 : 10. 正答率（テスト） = 0.1051
# Generation: 20. 正答率（トレーニング） = 0.18333333333333332
#                 : 20. 正答率（テスト） = 0.1255
# Generation: 30. 正答率（トレーニング） = 0.24333333333333335
#                 : 30. 正答率（テスト） = 0.1525
# Generation: 40. 正答率（トレーニング） = 0.2866666666666667
#                 : 40. 正答率（テスト） = 0.1764
# Generation: 50. 正答率（トレーニング） = 0.32666666666666666
#                 : 50. 正答率（テスト） = 0.2067
# Generation: 60. 正答率（トレーニング） = 0.38
#                 : 60. 正答率（テスト） = 0.2354
# Generation: 70. 正答率（トレーニング） = 0.4166666666666667
#                 : 70. 正答率（テスト） = 0.2672
# Generation: 80. 正答率（トレーニング） = 0.41333333333333333
#                 : 80. 正答率（テスト） = 0.2693
# Generation: 90. 正答率（トレーニング） = 0.4066666666666667
#                 : 90. 正答率（テスト） = 0.2763
# Generation: 100. 正答率（トレーニング） = 0.41333333333333333
#                 : 100. 正答率（テスト） = 0.2862
# Generation: 110. 正答率（トレーニング） = 0.39666666666666667
#                 : 110. 正答率（テスト） = 0.2851
# Generation: 120. 正答率（トレーニング） = 0.37666666666666665
#                 : 120. 正答率（テスト） = 0.2938
# Generation: 130. 正答率（トレーニング） = 0.42333333333333334
#                 : 130. 正答率（テスト） = 0.3163
# Generation: 140. 正答率（トレーニング） = 0.45
#                 : 140. 正答率（テスト） = 0.3382
# Generation: 150. 正答率（トレーニング） = 0.49666666666666665
#                 : 150. 正答率（テスト） = 0.3587
# Generation: 160. 正答率（トレーニング） = 0.49
#                 : 160. 正答率（テスト） = 0.3564
# Generation: 170. 正答率（トレーニング） = 0.5133333333333333
#                 : 170. 正答率（テスト） = 0.3722
# Generation: 180. 正答率（トレーニング） = 0.5566666666666666
#                 : 180. 正答率（テスト） = 0.4031
# Generation: 190. 正答率（トレーニング） = 0.5866666666666667
#                 : 190. 正答率（テスト） = 0.418
# Generation: 200. 正答率（トレーニング） = 0.5933333333333334
#                 : 200. 正答率（テスト） = 0.4304
# Generation: 210. 正答率（トレーニング） = 0.5966666666666667
#                 : 210. 正答率（テスト） = 0.4497
# Generation: 220. 正答率（トレーニング） = 0.62
#                 : 220. 正答率（テスト） = 0.4679
# Generation: 230. 正答率（トレーニング） = 0.6266666666666667
#                 : 230. 正答率（テスト） = 0.4897
# Generation: 240. 正答率（トレーニング） = 0.6233333333333333
#                 : 240. 正答率（テスト） = 0.5016
# Generation: 250. 正答率（トレーニング） = 0.6133333333333333
#                 : 250. 正答率（テスト） = 0.509
# Generation: 260. 正答率（トレーニング） = 0.66
#                 : 260. 正答率（テスト） = 0.5346
# Generation: 270. 正答率（トレーニング） = 0.65
#                 : 270. 正答率（テスト） = 0.529
# Generation: 280. 正答率（トレーニング） = 0.6833333333333333
#                 : 280. 正答率（テスト） = 0.5458
# Generation: 290. 正答率（トレーニング） = 0.6766666666666666
#                 : 290. 正答率（テスト） = 0.5507
# Generation: 300. 正答率（トレーニング） = 0.7233333333333334
#                 : 300. 正答率（テスト） = 0.588
# Generation: 310. 正答率（トレーニング） = 0.71
#                 : 310. 正答率（テスト） = 0.5946
# Generation: 320. 正答率（トレーニング） = 0.7266666666666667
#                 : 320. 正答率（テスト） = 0.6035
# Generation: 330. 正答率（トレーニング） = 0.73
#                 : 330. 正答率（テスト） = 0.6039
# Generation: 340. 正答率（トレーニング） = 0.74
#                 : 340. 正答率（テスト） = 0.601
# Generation: 350. 正答率（トレーニング） = 0.7233333333333334
#                 : 350. 正答率（テスト） = 0.606
# Generation: 360. 正答率（トレーニング） = 0.7266666666666667
#                 : 360. 正答率（テスト） = 0.6143
# Generation: 370. 正答率（トレーニング） = 0.74
#                 : 370. 正答率（テスト） = 0.6291
# Generation: 380. 正答率（トレーニング） = 0.7266666666666667
#                 : 380. 正答率（テスト） = 0.6224
# Generation: 390. 正答率（トレーニング） = 0.76
#                 : 390. 正答率（テスト） = 0.6375
# Generation: 400. 正答率（トレーニング） = 0.78
#                 : 400. 正答率（テスト） = 0.6515
# Generation: 410. 正答率（トレーニング） = 0.78
#                 : 410. 正答率（テスト） = 0.6522
# Generation: 420. 正答率（トレーニング） = 0.7766666666666666
#                 : 420. 正答率（テスト） = 0.6592
# Generation: 430. 正答率（トレーニング） = 0.7966666666666666
#                 : 430. 正答率（テスト） = 0.6631
# Generation: 440. 正答率（トレーニング） = 0.7966666666666666
#                 : 440. 正答率（テスト） = 0.6741
# Generation: 450. 正答率（トレーニング） = 0.7666666666666667
#                 : 450. 正答率（テスト） = 0.6692
# Generation: 460. 正答率（トレーニング） = 0.7866666666666666
#                 : 460. 正答率（テスト） = 0.6795
# Generation: 470. 正答率（トレーニング） = 0.8166666666666667
#                 : 470. 正答率（テスト） = 0.6858
# Generation: 480. 正答率（トレーニング） = 0.82
#                 : 480. 正答率（テスト） = 0.6899
# Generation: 490. 正答率（トレーニング） = 0.8166666666666667
#                 : 490. 正答率（テスト） = 0.6902
# Generation: 500. 正答率（トレーニング） = 0.8233333333333334
#                 : 500. 正答率（テスト） = 0.6914
# Generation: 510. 正答率（トレーニング） = 0.83
#                 : 510. 正答率（テスト） = 0.6938
# Generation: 520. 正答率（トレーニング） = 0.8366666666666667
#                 : 520. 正答率（テスト） = 0.7057
# Generation: 530. 正答率（トレーニング） = 0.8333333333333334
#                 : 530. 正答率（テスト） = 0.7036
# Generation: 540. 正答率（トレーニング） = 0.8533333333333334
#                 : 540. 正答率（テスト） = 0.7119
# Generation: 550. 正答率（トレーニング） = 0.8633333333333333
#                 : 550. 正答率（テスト） = 0.7157
# Generation: 560. 正答率（トレーニング） = 0.86
#                 : 560. 正答率（テスト） = 0.7202
# Generation: 570. 正答率（トレーニング） = 0.8666666666666667
#                 : 570. 正答率（テスト） = 0.7241
# Generation: 580. 正答率（トレーニング） = 0.8766666666666667
#                 : 580. 正答率（テスト） = 0.725
# Generation: 590. 正答率（トレーニング） = 0.89
#                 : 590. 正答率（テスト） = 0.723
# Generation: 600. 正答率（トレーニング） = 0.8933333333333333
#                 : 600. 正答率（テスト） = 0.734
# Generation: 610. 正答率（トレーニング） = 0.9
#                 : 610. 正答率（テスト） = 0.7404
# Generation: 620. 正答率（トレーニング） = 0.9
#                 : 620. 正答率（テスト） = 0.7406
# Generation: 630. 正答率（トレーニング） = 0.9033333333333333
#                 : 630. 正答率（テスト） = 0.7374
# Generation: 640. 正答率（トレーニング） = 0.9133333333333333
#                 : 640. 正答率（テスト） = 0.7377
# Generation: 650. 正答率（トレーニング） = 0.9133333333333333
#                 : 650. 正答率（テスト） = 0.7457
# Generation: 660. 正答率（トレーニング） = 0.91
#                 : 660. 正答率（テスト） = 0.7455
# Generation: 670. 正答率（トレーニング） = 0.9066666666666666
#                 : 670. 正答率（テスト） = 0.7426
# Generation: 680. 正答率（トレーニング） = 0.9133333333333333
#                 : 680. 正答率（テスト） = 0.7402
# Generation: 690. 正答率（トレーニング） = 0.9133333333333333
#                 : 690. 正答率（テスト） = 0.7529
# Generation: 700. 正答率（トレーニング） = 0.91
#                 : 700. 正答率（テスト） = 0.7485
# Generation: 710. 正答率（トレーニング） = 0.9133333333333333
#                 : 710. 正答率（テスト） = 0.7538
# Generation: 720. 正答率（トレーニング） = 0.9133333333333333
#                 : 720. 正答率（テスト） = 0.7572
# Generation: 730. 正答率（トレーニング） = 0.9166666666666666
#                 : 730. 正答率（テスト） = 0.7604
# Generation: 740. 正答率（トレーニング） = 0.9233333333333333
#                 : 740. 正答率（テスト） = 0.7604
# Generation: 750. 正答率（トレーニング） = 0.92
#                 : 750. 正答率（テスト） = 0.7573
# Generation: 760. 正答率（トレーニング） = 0.9266666666666666
#                 : 760. 正答率（テスト） = 0.7617
# Generation: 770. 正答率（トレーニング） = 0.92
#                 : 770. 正答率（テスト） = 0.7624
# Generation: 780. 正答率（トレーニング） = 0.93
#                 : 780. 正答率（テスト） = 0.767
# Generation: 790. 正答率（トレーニング） = 0.93
#                 : 790. 正答率（テスト） = 0.7663
# Generation: 800. 正答率（トレーニング） = 0.9266666666666666
#                 : 800. 正答率（テスト） = 0.7647
# Generation: 810. 正答率（トレーニング） = 0.9266666666666666
#                 : 810. 正答率（テスト） = 0.7591
# Generation: 820. 正答率（トレーニング） = 0.93
#                 : 820. 正答率（テスト） = 0.767
# Generation: 830. 正答率（トレーニング） = 0.9333333333333333
#                 : 830. 正答率（テスト） = 0.7663
# Generation: 840. 正答率（トレーニング） = 0.93
#                 : 840. 正答率（テスト） = 0.7602
# Generation: 850. 正答率（トレーニング） = 0.9333333333333333
#                 : 850. 正答率（テスト） = 0.7639
# Generation: 860. 正答率（トレーニング） = 0.94
#                 : 860. 正答率（テスト） = 0.7686
# Generation: 870. 正答率（トレーニング） = 0.94
#                 : 870. 正答率（テスト） = 0.7768
# Generation: 880. 正答率（トレーニング） = 0.9433333333333334
#                 : 880. 正答率（テスト） = 0.7763
# Generation: 890. 正答率（トレーニング） = 0.9366666666666666
#                 : 890. 正答率（テスト） = 0.7723
# Generation: 900. 正答率（トレーニング） = 0.9366666666666666
#                 : 900. 正答率（テスト） = 0.7696
# Generation: 910. 正答率（トレーニング） = 0.9333333333333333
#                 : 910. 正答率（テスト） = 0.7745
# Generation: 920. 正答率（トレーニング） = 0.9333333333333333
#                 : 920. 正答率（テスト） = 0.7723
# Generation: 930. 正答率（トレーニング） = 0.94
#                 : 930. 正答率（テスト） = 0.7707
# Generation: 940. 正答率（トレーニング） = 0.94
#                 : 940. 正答率（テスト） = 0.774
# Generation: 950. 正答率（トレーニング） = 0.94
#                 : 950. 正答率（テスト） = 0.774
# Generation: 960. 正答率（トレーニング） = 0.9366666666666666
#                 : 960. 正答率（テスト） = 0.7757
# Generation: 970. 正答率（トレーニング） = 0.9433333333333334
#                 : 970. 正答率（テスト） = 0.7764
# Generation: 980. 正答率（トレーニング） = 0.9433333333333334
#                 : 980. 正答率（テスト） = 0.7757
# Generation: 990. 正答率（トレーニング） = 0.9433333333333334
#                 : 990. 正答率（テスト） = 0.7783
# Generation: 1000. 正答率（トレーニング） = 0.9433333333333334
#                 : 1000. 正答率（テスト） = 0.7749

# %%
Tester18.plot_results()
plt.show()

# %% [markdown]
# データ数や層数を制限しすぎたためか、過学習を完全には防止できていないが、多少マシにはなっている。

# %% [markdown]
# ## Section4 畳み込みニューラルネットワークの概念

# %% [markdown]
# - 畳み込みニューラルネットワーク（CNN）とは？
# 画像の分析で使うことが多い。
# 次元のつながりのデータを効率的に扱える。（つまり、各入力パラメータ同士に順番や並び方に意味がある場合）
# - 画像のCNNのケース
# 入力層の後で、畳み込み層/プーリング層をかさね、出力層の直前で全結合層を挟んで出力層が得られる。
# - LuNetのケース
# 入力層(32,32)を一層目（畳み込み層）で(28,28,6）の出力に変換される。（畳み込み数では、「評価を6人で行う」のように数を増やす）
# 次にプーリング層では要約がなされ、(14,14,6）の出力に変換される。
# 応用に畳み込み層で（10,10,16）に変換され、次にプーリング層で(5,5,16）に変換される。
# ここから全結合層でひとまとめにされて、(120,)→(84,)→(10,)と変換され、欲しい出力を得る。
# - 畳み込み層
# 入力に対してフィルターを複数用意する（評価を複数人で行うことに対応）。
# 畳み込み層では次元的なつながりがあるものは何でも学習できる。
# フィルターの持つ値がニューロンの重みパラメータに対応する。
# フィルターが$n \times n$の時、画像の縦横の画素数を$n-1$だけ減らすことになってしまうため、画像の外側に特定の値があるとみなして、畳み込み処理をすることがある。（パディング）
# また、フィルターを1マスずつ動かす代わりに、1マス飛ばしのようにすることもできる（ストライド）。これを行うと画像サイズが一気に小さくなる。1/ストライド、になる。
# 畳み込み演算をする際は、行列の積で演算ができるように、変換する処理が行われる。
# - プーリング層
# プーリング層では、畳み込み同様に少しずつずらして値を取得するが、「要約」するような処理が行われる。
# Max Poolingでは、最大値を、Avg. Poolingでは平均値を出力する。
# - 全結合層
# いわゆる普通のNNと変わらない。
# CNNでは、畳み込み層/プーリング層では次元のつながりが保たれているが、
# 全結合層ではその繋がりをばらして、学習が行われる。

# %% [markdown]
# 以下Python上での実装を確認する。

# %%
import numpy as np
from collections import OrderedDict
from data.mnist import load_mnist
import matplotlib.pyplot as plt

# %%
# im2col関数  
def im2col(input_data, filter_h, filter_w, stride=1, pad=0):
    N, C, H, W = input_data.shape
    out_h = (H + 2 * pad - filter_h) // stride + 1
    out_w = (W + 2 * pad - filter_w) // stride + 1
    
    img = np.pad(input_data, [(0,0), (0,0), (pad,pad), (pad,pad)], "constant")
    col = np.zeros((N, C, filter_h, filter_w, out_h, out_w))
    
    for y in range(filter_h):
        y_max = y + stride * out_h
        for x in range(filter_w):
            x_max = x + stride * out_w
            col[:, :, y, x, :, :] = img[:, :, y: y_max:stride, x:x_max:stride]
    col = col.transpose(0,4,5,1,2,3)
    col = col.reshape(N * out_h * out_w, -1)
    return col

# %%
input_data = np.random.rand(2,1,4,4) * 100 // 1
print("==== input_data ====")
print(input_data)
print("====================")
filter_h = 3
filter_w = 3
stride = 1
pad = 0
col = im2col(input_data, filter_h = filter_h, filter_w = filter_w, stride = stride, pad = pad)

print("======= col ========")
print(col)
print("====================")
# Out:
# ==== input_data ====
# [[[[70. 36. 43. 18.]
#    [27. 35. 55. 64.]
#    [ 8. 27. 11. 52.]
#    [46. 31. 38. 66.]]]
#
#
#  [[[75. 48. 16. 73.]
#    [40. 63. 22.  0.]
#    [79. 93. 79. 83.]
#    [32. 56. 28. 75.]]]]
# ====================
# ======= col ========
# [[70. 36. 43. 27. 35. 55.  8. 27. 11.]
#  [36. 43. 18. 35. 55. 64. 27. 11. 52.]
#  [27. 35. 55.  8. 27. 11. 46. 31. 38.]
#  [35. 55. 64. 27. 11. 52. 31. 38. 66.]
#  [75. 48. 16. 40. 63. 22. 79. 93. 79.]
#  [48. 16. 73. 63. 22.  0. 93. 79. 83.]
#  [40. 63. 22. 79. 93. 79. 32. 56. 28.]
#  [63. 22.  0. 93. 79. 83. 56. 28. 75.]]
# ====================

# %%
def col2im(col, input_shape, filter_h, filter_w, stride = 1, pad = 0):
    N, C, H, W = input_shape
    out_h = (H + 2 * pad - filter_h) // stride + 1
    out_w = (W + 2 * pad - filter_w) // stride + 1
    col = col.reshape(N, out_h, out_w, C, filter_h, filter_w).transpose(0, 3, 4, 5, 1, 2)
    
    img = np.zeros((N, C, H + 2 * pad + stride - 1, W + 2 * pad + stride - 1))
    for y in range(filter_h):
        y_max = y + stride * out_h
        for x in range(filter_w):
            x_max = x + stride * out_w
            img[:, :, y:y_max:stride, x:x_max:stride] += col[:, :, y, x, :, :]
            
    return img[:, :, pad:H + pad, pad:W + pad]

# %%
img = col2im(col, input_shape = input_data.shape, filter_h = filter_h, filter_w = filter_w, stride=stride, pad = pad)
print(img)
# Out:
# [[[[ 70.  72.  86.  18.]
#    [ 54. 140. 220. 128.]
#    [ 16. 108.  44. 104.]
#    [ 46.  62.  76.  66.]]]
#
#
#  [[[ 75.  96.  32.  73.]
#    [ 80. 252.  88.   0.]
#    [158. 372. 316. 166.]
#    [ 32. 112.  56.  75.]]]]

# %% [markdown]
# 上記処理によって、imgを行列積を取るのに適した形に変形し、また、元の形式に戻すことができていることが確認された。

# %%
class Convolution:
    def __init__(self, W, b, stride=1, pad=0):
        self.W = W
        self.b = b
        self.stride = stride
        self.pad = pad
        
        self.x = None
        self.col = None
        self.col_W = None
        
        self.dW = None
        self.db = None
    
    def forward(self, x):
        FN, C, FH, FW = self.W.shape
        N, C, H, W = x.shape
        out_h = 1 + int((H + 2 * self.pad -FH) / self.stride)
        out_w = 1 + int((W + 2 * self.pad -FH) / self.stride)
        
        col = im2col(x, FH, FW, self.stride, self.pad)
        col_W = self.W.reshape(FN, -1).T
        out = np.dot(col, col_W) + self.b
        out = out.reshape(N, out_h, out_w, -1).transpose(0,3,1,2)
        
        self.x = x
        self.col = col
        self.col_W = col_W
        
        return out
    
    def backward(self, dout):
        FN, C, FH, FW = self.W.shape
        dout = dout.transpose(0,2,3,1).reshape(-1, FN)
        
        self.db = np.sum(dout, axis = 0)
        self.dW = np.dot(self.col.T, dout)
        self.dW = self.dW.transpose(1,0).reshape(FN, C, FH, FW)
        dcol = np.dot(dout, self.col_W.T)
        dx = col2im(dcol, self.x.shape, FH, FW, self.stride, self.pad)
        
        return dx

# %%
class Pooling:
    def __init__(self, pool_h, pool_w, stride = 1, pad = 0):
        self.pool_h = pool_h
        self.pool_w = pool_w
        self.stride = stride
        self.pad = pad
        
        self.x = None
        self.arg_max = None
        
    def forward(self, x):
        N, C, H, W = x.shape
        out_h = int(1 + (H - self.pool_h) / self.stride)
        out_w = int(1 + (W - self.pool_w) / self.stride)
        
        col = im2col(x, self.pool_h, self.pool_w, self.stride, self.pad)
        col = col.reshape(-1, self.pool_h * self.pool_w)
        
        arg_max = np.argmax(col, axis=1)
        out = np.max(col, axis=1)
        out = out.reshape(N, out_h, out_w, C).transpose(0,3,1,2)
        
        self.x = x
        self.arg_max = arg_max
        
        return out
    
    def backward(self, dout):
        dout = dout.transpose(0,2,3,1)
        
        pool_size = self.pool_h * self.pool_w
        dmax = np.zeros((dout.size, pool_size))
        dmax[np.arange(self.arg_max.size), self.arg_max.flatten()] = dout.flatten()
        dmax = dmax.reshape(dout.shape + (pool_size,))
        
        dcol = dmax.reshape(dmax.shape[0] * dmax.shape[1] * dmax.shape[2], -1)
        dx = col2im(dcol, self.x.shape, self.pool_h, self.pool_w, self.stride, self.pad)
        
        return dx

# %%
class Relu:
    def __init__(self):
        self.mask = None
        
    def forward(self, x):
        self.mask = ( x <= 0)
        out = x.copy()
        out[self.mask] = 0
        
        return out
    
    def backward(self, dout):
        dout[self.mask] = 0
        dx = dout
        
        return dx

# %%
class SimpleConvNet:
    def __init__(self, input_dim=(1,28,28), conv_param={'filter_num':30, 'filter_size':5, "pad":0, "stride":1},
                 hidden_size = 100, output_size = 10, weight_init_std=0.01):
        filter_num = conv_param["filter_num"]
        filter_size = conv_param["filter_size"]
        filter_pad = conv_param["pad"]
        filter_stride = conv_param["stride"]
        input_size = input_dim[1]
        conv_output_size = (input_size - filter_size + 2 * filter_pad) / filter_stride + 1
        pool_output_size = int(filter_num * (conv_output_size / 2) * (conv_output_size / 2))
        
        # 重みの初期化
        self.params = {}
        self.params["W1"] = weight_init_std * np.random.randn(filter_num, input_dim[0], filter_size, filter_size)
        self.params["b1"] = np.zeros(filter_num)
        self.params["W2"] = weight_init_std * np.random.randn(pool_output_size, hidden_size)
        self.params["b2"] = np.zeros(hidden_size)
        self.params["W3"] = weight_init_std * np.random.randn(hidden_size, output_size)
        self.params["b3"] = np.zeros(output_size)
        
        # レイヤの生成
        self.layers = OrderedDict()
        self.layers["Conv1"] = Convolution(self.params["W1"], self.params["b1"], conv_param["stride"], conv_param["pad"])
        self.layers["Relu1"] = Relu()
        self.layers["Pool1"] = Pooling(pool_h=2, pool_w=2, stride=2)
        self.layers["Affine1"] = Affine(self.params["W2"], self.params["b2"])
        self.layers["Relu2"] = Relu()
        self.layers["Affine2"] = Affine(self.params["W3"], self.params["b3"])
        
        self.last_layer = SoftMaxWithLoss()
        
    def predict(self, x):
        for key in self.layers.keys():
            x = self.layers[key].forward(x)
        return x

    def loss(self, x, d):
        y = self.predict(x)
        return self.last_layer.forward(y,d)
    
    def accuracy(self, x, d, batch_size = 100):
        if d.ndim != 1 : d = np.argmax(d, axis=1)
            
        acc = 0.0
        
        for i in range(int(x.shape[0] / batch_size)):
            tx = x[i*batch_size:(i+1)*batch_size]
            td = d[i*batch_size:(i+1)*batch_size]
            y = self.predict(tx)
            y = np.argmax(y, axis=1)
            acc += np.sum(y == td)
        
        return acc / x.shape[0]
    
    def gradient(self, x, d):
        self.loss(x,d)
        
        dout = 1
        dout = self.last_layer.backward(dout)
        layers = list(self.layers.values())
        
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)
            
        grad = {}
        grad["W1"], grad["b1"] = self.layers["Conv1"].dW, self.layers["Conv1"].db
        grad["W2"], grad["b2"] = self.layers["Affine1"].dW, self.layers["Affine1"].db
        grad["W3"], grad["b3"] = self.layers["Affine2"].dW, self.layers["Affine2"].db
        
        return grad

# %%
class Adam:
    def __init__(self, learning_rate = 0.001, beta1 = 0.9, beta2 = 0.999):
        self.learning_rate = learning_rate
        self.beta1 = beta1
        self.beta2 = beta2
        self.iter = 0
        self.m = None
        self.v = None
    
    def update(self, params, grad):
        if self.m is None:
            self.m, self.v = {},{}
            for key, val in params.items():
                self.m[key] = np.zeros_like(val)
                self.v[key] = np.zeros_like(val)
        
        self.iter += 1
        lr_t = self.learning_rate * np.sqrt(1.0 - self.beta2 ** self.iter) / (1.0 - self.beta1 ** self.iter)
        
        for key in params.keys():
            self.m[key] += (1 - self.beta1) * (grad[key] - self.m[key])
            self.v[key] += (1 - self.beta2) * (grad[key] ** 2 - self.v[key])
            
            params[key] -= lr_t * self.m[key] / (np.sqrt(self.v[key]) + 1e-7)

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(flatten=False)

print("データの読み込み官僚")

x_train, d_train = x_train[:5000], d_train[:5000]
x_test, d_test = x_test[:1000], d_test[:1000]

network = SimpleConvNet(input_dim=(1,28,28), conv_param = {"filter_num":30, "filter_size":5, "pad": 0, "stride": 1},
                        hidden_size = 100, output_size = 10, weight_init_std = 0.01)
optimizer = Adam()

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval = 10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]
    
    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print("Generation: " + str(i+1) + ". 正答率(train) = " + str(accr_train))
        print("                :" + str(i+1) + ". 正答率(test) = " + str(accr_test))
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label = "training set")
plt.plot(lists, accuracies_test, label = "test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.show()
# Out:
# データの読み込み官僚
# Generation: 10. 正答率(train) = 0.4444
#                 :10. 正答率(test) = 0.435
# Generation: 20. 正答率(train) = 0.6744
#                 :20. 正答率(test) = 0.656
# Generation: 30. 正答率(train) = 0.7582
#                 :30. 正答率(test) = 0.728
# Generation: 40. 正答率(train) = 0.8114
#                 :40. 正答率(test) = 0.794
# Generation: 50. 正答率(train) = 0.809
#                 :50. 正答率(test) = 0.762
# Generation: 60. 正答率(train) = 0.8544
#                 :60. 正答率(test) = 0.819
# Generation: 70. 正答率(train) = 0.8724
#                 :70. 正答率(test) = 0.847
# Generation: 80. 正答率(train) = 0.8848
#                 :80. 正答率(test) = 0.856
# Generation: 90. 正答率(train) = 0.898
#                 :90. 正答率(test) = 0.859
# Generation: 100. 正答率(train) = 0.8934
#                 :100. 正答率(test) = 0.866
# Generation: 110. 正答率(train) = 0.9026
#                 :110. 正答率(test) = 0.875
# Generation: 120. 正答率(train) = 0.9104
#                 :120. 正答率(test) = 0.882
# Generation: 130. 正答率(train) = 0.9062
#                 :130. 正答率(test) = 0.88
# Generation: 140. 正答率(train) = 0.9076
#                 :140. 正答率(test) = 0.893
# Generation: 150. 正答率(train) = 0.918
#                 :150. 正答率(test) = 0.889
# Generation: 160. 正答率(train) = 0.9072
#                 :160. 正答率(test) = 0.889
# Generation: 170. 正答率(train) = 0.9098
#                 :170. 正答率(test) = 0.875
# Generation: 180. 正答率(train) = 0.9208
#                 :180. 正答率(test) = 0.893
# Generation: 190. 正答率(train) = 0.9284
#                 :190. 正答率(test) = 0.898
# Generation: 200. 正答率(train) = 0.9214
#                 :200. 正答率(test) = 0.897
# Generation: 210. 正答率(train) = 0.928
#                 :210. 正答率(test) = 0.905
# Generation: 220. 正答率(train) = 0.9348
#                 :220. 正答率(test) = 0.91
# Generation: 230. 正答率(train) = 0.9278
#                 :230. 正答率(test) = 0.902
# Generation: 240. 正答率(train) = 0.9326
#                 :240. 正答率(test) = 0.91
# Generation: 250. 正答率(train) = 0.9276
#                 :250. 正答率(test) = 0.899
# Generation: 260. 正答率(train) = 0.9306
#                 :260. 正答率(test) = 0.907
# Generation: 270. 正答率(train) = 0.9374
#                 :270. 正答率(test) = 0.902
# Generation: 280. 正答率(train) = 0.9414
#                 :280. 正答率(test) = 0.917
# Generation: 290. 正答率(train) = 0.9452
#                 :290. 正答率(test) = 0.911
# Generation: 300. 正答率(train) = 0.9344
#                 :300. 正答率(test) = 0.909
# Generation: 310. 正答率(train) = 0.938
#                 :310. 正答率(test) = 0.895
# Generation: 320. 正答率(train) = 0.9536
#                 :320. 正答率(test) = 0.926
# Generation: 330. 正答率(train) = 0.9546
#                 :330. 正答率(test) = 0.929
# Generation: 340. 正答率(train) = 0.949
#                 :340. 正答率(test) = 0.921
# Generation: 350. 正答率(train) = 0.9352
#                 :350. 正答率(test) = 0.911
# Generation: 360. 正答率(train) = 0.9446
#                 :360. 正答率(test) = 0.916
# Generation: 370. 正答率(train) = 0.9554
#                 :370. 正答率(test) = 0.926
# Generation: 380. 正答率(train) = 0.9602
#                 :380. 正答率(test) = 0.926
# Generation: 390. 正答率(train) = 0.961
#                 :390. 正答率(test) = 0.931
# Generation: 400. 正答率(train) = 0.962
#                 :400. 正答率(test) = 0.939
# Generation: 410. 正答率(train) = 0.9602
#                 :410. 正答率(test) = 0.928
# Generation: 420. 正答率(train) = 0.9638
#                 :420. 正答率(test) = 0.932
# Generation: 430. 正答率(train) = 0.9644
#                 :430. 正答率(test) = 0.937
# Generation: 440. 正答率(train) = 0.9694
#                 :440. 正答率(test) = 0.936
# Generation: 450. 正答率(train) = 0.9666
#                 :450. 正答率(test) = 0.938
# Generation: 460. 正答率(train) = 0.9724
#                 :460. 正答率(test) = 0.931
# Generation: 470. 正答率(train) = 0.9698
#                 :470. 正答率(test) = 0.937
# Generation: 480. 正答率(train) = 0.9744
#                 :480. 正答率(test) = 0.936
# Generation: 490. 正答率(train) = 0.9692
#                 :490. 正答率(test) = 0.933
# Generation: 500. 正答率(train) = 0.97
#                 :500. 正答率(test) = 0.943
# Generation: 510. 正答率(train) = 0.974
#                 :510. 正答率(test) = 0.939
# Generation: 520. 正答率(train) = 0.9718
#                 :520. 正答率(test) = 0.938
# Generation: 530. 正答率(train) = 0.9746
#                 :530. 正答率(test) = 0.939
# Generation: 540. 正答率(train) = 0.9764
#                 :540. 正答率(test) = 0.944
# Generation: 550. 正答率(train) = 0.9744
#                 :550. 正答率(test) = 0.939
# Generation: 560. 正答率(train) = 0.9782
#                 :560. 正答率(test) = 0.949
# Generation: 570. 正答率(train) = 0.9708
#                 :570. 正答率(test) = 0.928
# Generation: 580. 正答率(train) = 0.9708
#                 :580. 正答率(test) = 0.944
# Generation: 590. 正答率(train) = 0.9776
#                 :590. 正答率(test) = 0.949
# Generation: 600. 正答率(train) = 0.973
#                 :600. 正答率(test) = 0.943
# Generation: 610. 正答率(train) = 0.9772
#                 :610. 正答率(test) = 0.941
# Generation: 620. 正答率(train) = 0.9816
#                 :620. 正答率(test) = 0.952
# Generation: 630. 正答率(train) = 0.9822
#                 :630. 正答率(test) = 0.949
# Generation: 640. 正答率(train) = 0.9808
#                 :640. 正答率(test) = 0.946
# Generation: 650. 正答率(train) = 0.983
#                 :650. 正答率(test) = 0.953
# Generation: 660. 正答率(train) = 0.982
#                 :660. 正答率(test) = 0.948
# Generation: 670. 正答率(train) = 0.9802
#                 :670. 正答率(test) = 0.948
# Generation: 680. 正答率(train) = 0.9806
#                 :680. 正答率(test) = 0.945
# Generation: 690. 正答率(train) = 0.9836
#                 :690. 正答率(test) = 0.949
# Generation: 700. 正答率(train) = 0.9828
#                 :700. 正答率(test) = 0.946
# Generation: 710. 正答率(train) = 0.9832
#                 :710. 正答率(test) = 0.945
# Generation: 720. 正答率(train) = 0.9866
#                 :720. 正答率(test) = 0.954
# Generation: 730. 正答率(train) = 0.9878
#                 :730. 正答率(test) = 0.952
# Generation: 740. 正答率(train) = 0.9832
#                 :740. 正答率(test) = 0.953
# Generation: 750. 正答率(train) = 0.9864
#                 :750. 正答率(test) = 0.955
# Generation: 760. 正答率(train) = 0.9854
#                 :760. 正答率(test) = 0.95
# Generation: 770. 正答率(train) = 0.9848
#                 :770. 正答率(test) = 0.961
# Generation: 780. 正答率(train) = 0.9886
#                 :780. 正答率(test) = 0.956
# Generation: 790. 正答率(train) = 0.9884
#                 :790. 正答率(test) = 0.951
# Generation: 800. 正答率(train) = 0.9908
#                 :800. 正答率(test) = 0.955
# Generation: 810. 正答率(train) = 0.9906
#                 :810. 正答率(test) = 0.959
# Generation: 820. 正答率(train) = 0.99
#                 :820. 正答率(test) = 0.957
# Generation: 830. 正答率(train) = 0.9902
#                 :830. 正答率(test) = 0.957
# Generation: 840. 正答率(train) = 0.9904
#                 :840. 正答率(test) = 0.956
# Generation: 850. 正答率(train) = 0.992
#                 :850. 正答率(test) = 0.955
# Generation: 860. 正答率(train) = 0.9928
#                 :860. 正答率(test) = 0.944
# Generation: 870. 正答率(train) = 0.9902
#                 :870. 正答率(test) = 0.95
# Generation: 880. 正答率(train) = 0.9896
#                 :880. 正答率(test) = 0.951
# Generation: 890. 正答率(train) = 0.992
#                 :890. 正答率(test) = 0.955
# Generation: 900. 正答率(train) = 0.9932
#                 :900. 正答率(test) = 0.952
# Generation: 910. 正答率(train) = 0.9878
#                 :910. 正答率(test) = 0.946
# Generation: 920. 正答率(train) = 0.993
#                 :920. 正答率(test) = 0.954
# Generation: 930. 正答率(train) = 0.9906
#                 :930. 正答率(test) = 0.945
# Generation: 940. 正答率(train) = 0.9928
#                 :940. 正答率(test) = 0.951
# Generation: 950. 正答率(train) = 0.9936
#                 :950. 正答率(test) = 0.952
# Generation: 960. 正答率(train) = 0.9928
#                 :960. 正答率(test) = 0.948
# Generation: 970. 正答率(train) = 0.993
#                 :970. 正答率(test) = 0.953
# Generation: 980. 正答率(train) = 0.9916
#                 :980. 正答率(test) = 0.952
# Generation: 990. 正答率(train) = 0.9942
#                 :990. 正答率(test) = 0.956
# Generation: 1000. 正答率(train) = 0.9936
#                 :1000. 正答率(test) = 0.955

# %% [markdown]
# ## Section5 最新のCNN

# %% [markdown]
# - AlexNetのモデル説明
# 以下のような層構成をしている。
#  元入力：(224, 224,3)
#  最初の畳み込みフィルター:(11, 11)を32枚。 →(55, 55, 96)
#  プーリング層:(5, 5)でmax pooling。→ (27, 27, 256)
#  プーリング層:(3, 3)でmax pooling。→(13,13,384)
#  畳み込み層:(3,3)→(13,13,384)
#  畳み込み層:(3,3)→(13,13,256)
#  全結合層：(4096,)
#  全結合層：(4096,)
#  全結合層：(1000,)(最終出力)
# - 全結合層への移行時の次元の落とし方
#  1. Fratten ：単純に一列に並べる。
#  2. Global Max Pooling :最初の2次元分の値で、最大値をとる。
#  3. Global Avg Pooling :最初の2次元分の値で、平均値をとる。

# %%
import tensorflow.compat.v1 as tf
import tf_slim as slim
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-6ac713a0fee3> in <module>
#       1 import tensorflow.compat.v1 as tf
# ----> 2 import tf_slim as slim
#
# ModuleNotFoundError: No module named 'tf_slim'
